# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.4.1.tar.gz (28 kB)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from googlemaps) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.25.8)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.4.1-py3-none-any.whl size=37823 sha256=1a4d881f4ad4894046ea0779a4841c893167c06e2d41cac47f01a5d6f939de74
#   Stored in directory: c:\users\canon\appdata\local\pip\cache\wheels\59\eb\61\bba46c3c7dcb0866d48fd67a0c406cc54b80559613449e25e5
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.4.1

# %%
import googlemaps

# %%
gmaps = googlemaps.Client(key='AIzaSyBYrbp34OohAHsX1cub8ZeHlMEFajv15fY')

# %%
# !pip install shapely
# Out:
# Collecting shapely
#   Downloading Shapely-1.7.0-cp37-cp37m-win_amd64.whl (1.0 MB)
# Installing collected packages: shapely
# Successfully installed shapely-1.7.0

# %%
import pandas as pd
import datetime
d = datetime.datetime.today().weekday()+1
m = datetime.datetime.today().month
y = datetime.datetime.today().year
address = "서울특별시 구로구 186 제이플라 츠 901 호"
add = address.split()[1]
add

data = pd.read_csv("./data/main.csv",encoding='CP949')  
yuil = data[(data["CTGG_NM"]==add)&(data["DAY_CD"]==d)&(data["MONTH"]==m)&(data["RANK"]==1)]
yuil 
# data[data["CTGG_NM"]=="송파구"]
yuil 
# = yuil.iloc[0,2]
# category
# Out:
#      STD_YM  DAY_CD INDTY_CGR_NM CTPV_NM CTGG_NM  RANK  YEAR  MONTH
# 196  201907       4           한식   서울특별시     구로구     1  2019      7

# %%
#***********************************************************


d = datetime.datetime.today().weekday()+1
m = datetime.datetime.today().month
address = "서울특별시 금천구 186 제이플라 츠 901 호"
add = address.split()[1]
add

data = pd.read_csv("./data/main.csv",encoding='CP949')  
yuil = data[(data["CTGG_NM"]==add)&(data["DAY_CD"]==d)&(data["MONTH"]==m)&(data["RANK"]==1)]
category = yuil.iloc[0,2]
category


nalsi = ['카테고리','clear sky','few clouds','scattered clouds','broken clouds','shower rain','rain','thunderstorm','snow','mist']
# index_col : 지정한 컬럼을 Row Index로 사용한다.
ondo = pd.read_csv('./data/mainpage.csv',encoding="euc-kr")
ondo
ondo.set_index(ondo['온도'],inplace=True)
ondo
del ondo['온도']

categoryindex = nalsi.index('clear sky')
menu = ondo[ondo['카테고리']==category].loc[[30]].iloc[0,1]#2자리에 categoryindex
menu
# Out:
# '치킨'

# %%
import datetime
r = datetime.datetime.today().weekday()
r
# Out:
# 0

# %%
#&&&&&&&&&&&&777777777777777777777777777
# %matplotlib inline

import matplotlib.pyplot as plt

# 한글등록
from matplotlib import font_manager, rc  # rc : resource

# 추가설정 - 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
plt.rcParams['axes.unicode_minus']=False 

fong_loc = "c:/Windows/Fonts/malgun.ttf" # 글꼴 경로
font_name = font_manager.FontProperties(fname=fong_loc).get_name()
# print(font_name) # 폰트매니저를 통해 인식하고 있는 글꼴 이름을 가져온다
rc('font', family=font_name) # 리소스에 글꼴을 등록

# %%
#88888888888888888888888888888888888888888888888888888888
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-eb7d8a3a9e03> in <module>
#      10
#      11 categoryindex = nalsi.index('clear sky')
# ---> 12 menu = ondo[ondo['카테고리']==category].loc[[30]].iloc[0,1]#2자리에 categoryindex
#      13 menu
#
# NameError: name 'category' is not defined

# %%
menu = pd.read_csv('./data/menu.csv',encoding="euc-kr")
menu

ondoresult = ondo.loc[[30],["clear sky"]]
ondoresult = ondoresult.iloc[0,0]
ondoresult
menu
# Out:
#           메뉴 카테고리
# 0         냉면   한식
# 1        칼국수   한식
# 2      한우불고기   한식
# 3        삼겹살   한식
# 4         파전   한식
# 5        빈대떡   한식
# 6         갈비   한식
# 7        미역국   한식
# 8       김치찌개   한식
# 9       부대찌개   한식
# 10         죽   한식
# 11       닭갈비   한식
# 12       마라탕   중식
# 13        덮밥   중식
# 14        초밥   일식
# 15         회   일식
# 16       돈까스   일식
# 17       오뎅탕   일식
# 18        라멘   일식
# 19        메밀   일식
# 20      샌드위치   양식
# 21       햄버거   양식
# 22        치킨   양식
# 23       파스타   양식
# 24        타코   양식
# 25       핫도그   양식
# 26  아이스아메리카노   양식
# 27     따뜻한커피   양식
# 28        피자   양식
# 29       리조또   양식
# 30        쫄면   분식
# 31        김밥   분식
# 32        라면   분식
# 33       떡볶이   분식
# 34       쌀국수  동남아
# 35      샤브샤브  동남아

# %%
remenu = menu[menu["카테고리"]==yuil] 
remenu

menu
# Out:
#           메뉴 카테고리
# 0         냉면   한식
# 1        칼국수   한식
# 2      한우불고기   한식
# 3        삼겹살   한식
# 4         파전   한식
# 5        빈대떡   한식
# 6         갈비   한식
# 7        미역국   한식
# 8       김치찌개   한식
# 9       부대찌개   한식
# 10         죽   한식
# 11       닭갈비   한식
# 12       마라탕   중식
# 13        덮밥   중식
# 14        초밥   일식
# 15         회   일식
# 16       돈까스   일식
# 17       오뎅탕   일식
# 18        라멘   일식
# 19        메밀   일식
# 20      샌드위치   양식
# 21       햄버거   양식
# 22        치킨   양식
# 23       파스타   양식
# 24        타코   양식
# 25       핫도그   양식
# 26  아이스아메리카노   양식
# 27     따뜻한커피   양식
# 28        피자   양식
# 29       리조또   양식
# 30        쫄면   분식
# 31        김밥   분식
# 32        라면   분식
# 33       떡볶이   분식
# 34       쌀국수  동남아
# 35      샤브샤브  동남아
