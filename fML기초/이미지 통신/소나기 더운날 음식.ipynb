# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('소나기 더운 날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('소나기 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('소나기 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('소나기 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('소나기 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('소나기 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '2013.02',
#  '.',
#  '15',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '제발',
#  '부탁드림니다',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  '정답',
#  '질문',
#  '전통',
#  '한식',
#  '상차림',
#  '2019.09',
#  '.',
#  '16',
#  '.',
#  '1',
#  '.',
#  '전통',
#  '한식',
#  '의',
#  '첩',
#  '반상',
#  '(',
#  '3',
#  ',',
#  '5',
#  ',',
#  '7',
#  ',',
#  '9',
#  ',',
#  '12',
#  ')',
#  '과',
#  '반찬',
#  '2',
#  '.',
#  '전통',
#  '밥상',
#  '차림',
#  '어떤',
#  '배열',
#  '을',
#  '하는가',
#  '3',
#  '.',
#  '전통',
#  '상',
#  '에',
#  '죽',
#  '상',
#  ',',
#  '장국상',
#  '주안상',
#  '교자상',
#  '다과상',
#  '등',
#  '이',
#  '것',
#  '들',
#  '좀',
#  '알려주세요',
#  '답변',
#  '숟가락',
#  '은',
#  '뜨거운',
#  '국물',
#  '음식',
#  '이',
#  '발달',
#  '한',
#  '한식',
#  '의',
#  '특성',
#  '에',
#  '잘',
#  '맞는',
#  '도구',
#  '이다',
#  '.',
#  '젓가락',
#  '은',
#  '...',
#  '오른쪽',
#  '에는',
#  '더운',
#  '반찬',
#  '을',
#  '놓아',
#  '오른손',
#  '으로',
#  '집어',
#  '먹기',
#  '편하게',
#  '배려',
#  '한',
#  '것',
#  '이',
#  '재미있다',
#  '....',
#  '닉네임',
#  '골드',
#  '질문',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는',
#  '음식',
#  '추천',
#  '!!(',
#  '한식',
#  ')',
#  '2007.08',
#  '.',
#  '04',
#  '.',
#  '질리',
#  '고',
#  '뭔가',
#  '색다른',
#  '것',
#  '먹고싶은데',
#  '뭐',
#  '가',
#  '있을까요',
#  '??',
#  '맛있는',
#  '메뉴',
#  '좀',
#  '추천',
#  '해주세요',
#  '.',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는것',
#  '뜨거운거',
#  '매운건',
#  '싫어요',
#  '~~',
#  '한식',
#  '으로',
#  '추천',
#  '부탁드립니다',
#  '.^^',
#  '답변',
#  '한식',
#  '은',
#  '아니지만',
#  '씨',
#  '푸드',
#  '뷔페',
#  '레스토랑',
#  '어때요',
#  '?',
#  '^',
#  'ㅡ',
#  '^',
#  '해산물',
#  '중',
#  '에서',
#  '장어',
#  ',',
#  '병어',
#  ',',
#  '농어',
#  '...',
#  '▦',
#  '찬',
#  '음식',
#  '에서',
#  '더운',
#  '음식',
#  '으로',
#  '=',
#  '뷔페',
#  '도',
#  '일종',
#  '의',
#  '코스',
#  '요리',
#  '로',
#  '생각',
#  '하고',
#  '음식',
#  '을',
#  '선택',
#  '해야',
#  '...',
#  '질문',
#  '2013년',
#  '한식',
#  '날',
#  '2013.01',
#  '.',
#  '02',
#  '.',
#  '저기',
#  '한식',
#  '날',
#  '날짜',
#  '가',
#  '어떻게',
#  '되나요',
#  '??',
#  '인터넷',
#  '찾아봐도',
#  '없어서요',
#  '.......',
#  '자세하게',
#  '답좀',
#  '해주세요',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어야',
#  '한다는',
#  '속',
#  '신',
#  '(',
#  '俗信',
#  ')...',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제',
#  '사',
#  '음식',
#  '을',
#  '마련',
#  '하여',
#  '제사',
#  '를',
#  '지내는데',
#  ',',
#  '이를',
#  '절사',
#  '(',
#  '節祀',
#  ')...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '한식',
#  '조사',
#  '여',
#  '.....',
#  '2016.06',
#  '.',
#  '01',
#  '.',
#  '뭐',
#  '가',
#  '우리나라',
#  '음식',
#  '인지',
#  '모르겠어서요',
#  '일단',
#  '1',
#  '.',
#  '한식',
#  '종류',
#  '!',
#  '를',
#  '알려주세요',
#  '2',
#  '.',
#  '그',
#  '음식',
#  '들',
#  '을',
#  '만드는',
#  '방법',
#  '도',
#  '알려주세요',
#  '오늘',
#  '안',
#  '에',
#  '알려주세요',
#  '.....',
#  '지금',
#  '엄청',
#  '급해서요',
#  '.....',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '2005.04',
#  '.',
#  '05',
#  '.',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '작은',
#  '사진',
#  '을',
#  '올려주셔도',
#  '괜찮습니다',
#  '.',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '이',
#  '뭐',
#  '에요',
#  '?',
#  '2011.08',
#  '.',
#  '26',
#  '.',
#  '그',
#  '..',
#  '우리나라',
#  '음식',
#  '한식',
#  '말구요',
#  '..;;',
#  '차가울',
#  '한',
#  '?',
#  '그거',
#  '쓴',
#  '...',
#  '한',
#  '문',
#  '숙제',
#  '가',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '에',
#  '대해',
#  '서',
#  '조사',
#  '해오는건데',
#  '....',
#  '조사',
#  '를',
#  '해서',
#  '어떻게',
#  '해야',
#  '될지도',
#  '모르겠고',
#  '..',
#  '사전',
#  '같은',
#  '덴',
#  '너무',
#  '...',
#  '답변',
#  '더운',
#  '밥',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '밥',
#  '을',
#  '먹는다고는',
#  '하나',
#  '잘',
#  '지켜지지',
#  '않았다',
#  '.',
#  '한식',
#  '은',
#  '조선시대',
#  '에',
#  '설날',
#  '·',
#  '단오',
#  '·',
#  '추석',
#  '과',
#  '함께',
#  '사대',
#  '명절',
#  '(',
#  '四大名節',
#  ')',
#  '에',
#  '속',
#  '했다',
#  '.',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제사',
#  '음식',
#  '...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대하',
#  '여',
#  '2007.04',
#  '.',
#  '05',
#  '.',
#  '학교숙제',
#  '인대',
#  '요',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대한',
#  '조사',
#  '를',
#  '해',
#  '라',
#  '해서',
#  '하게',
#  '된것인데',
#  '제',
#  '말',
#  '도와주세요',
#  'ㅠㅠ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '닉네임',
#  'han',
#  '0',
#  '****',
#  '질문',
#  '한식',
#  '에',
#  '관',
#  '한',
#  '여러가지',
#  '알려주세요',
#  '2005.04',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '이란',
#  '?',
#  '시기',
#  '유래',
#  '풍습',
#  '속담',
#  '한식',
#  '날',
#  '먹는',
#  '음식',
#  '이',
#  '것좀',
#  '간단하게',
#  '알려주세요',
#  '할것이',
#  '너무',
#  '많아서',
#  '여기저기',
#  '찾아볼',
#  '시간',
#  '이',
#  '없네요',
#  'ㅋ',
#  '꼭좀',
#  '알려주세요',
#  'ㅋ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '한식',
#  '의',
#  '종류',
#  '가르쳐주세요',
#  '2017.10',
#  '.',
#  '28',
#  '.',
#  '한식',
#  '의',
#  '종류',
#  '와',
#  '특징',
#  '을',
#  '가르쳐주세요',
#  '답변',
#  '한식',
#  '에',
#  '대한',
#  '모든',
#  '것',
#  ',',
#  '한식',
#  '의',
#  '종류',
#  ',',
#  '한식',
#  '의',
#  '특징',
#  '...',
#  '것',
#  '이다',
#  '.',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '...',
#  '굴',
#  '이나',
#  '조갯살',
#  '로',
#  '국물',
#  '을',
#  '내어',
#  '날',
#  '떡국',
#  '이나',
#  '칼국수',
#  '를',
#  '끓이며',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '(',
#  '월욜',
#  '까지',
#  ')',
#  '2007.02',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '좀',
#  '부탁',
#  '해요',
#  '!!!!',
#  '답변',
#  '바랍니다',
#  '한식',
#  '(',
#  '寒食',
#  ':',
#  '동지',
#  '후',
#  '105일',
#  '째',
#  '되는',
#  '날',
#  ')',
#  '한식',
#  '의',
#  '어원',
#  '에',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='소나기 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='소나기 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='소나기 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='소나기 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='소나기 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='소나기 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 91509
# 7119

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 3894),
#  ('...', 3015),
#  ('을', 1852),
#  (':', 1631),
#  (',', 1470),
#  ('이', 1446),
#  ('의', 1351),
#  ('에', 1305),
#  ('가', 1149),
#  ('답변', 1098),
#  ('질문', 1066),
#  ('음식', 1063),
#  ('를', 1000),
#  ('더운', 840),
#  ('닉네임', 838),
#  ('소나기', 741),
#  ('날', 721),
#  ('단어', 665),
#  ('는', 663),
#  ('****', 647),
#  ('하는', 584),
#  ('은', 504),
#  ('좀', 497),
#  ('안', 496),
#  ('로', 459),
#  ('우리말', 454),
#  ('●', 437),
#  ('(', 436),
#  ('한', 430),
#  ('때', 409),
#  ('검색', 404),
#  ('일', 370),
#  ('등', 347),
#  ('과', 347),
#  (')', 341),
#  ('비', 326),
#  ('들', 324),
#  ('개', 318),
#  ('..', 316),
#  ('입력', 300),
#  ('요', 291),
#  ('도', 281),
#  ('내공', 278),
#  ('알려주세요', 273),
#  ('몸', 271),
#  ('으로', 265),
#  ('게', 262),
#  ('밥', 261),
#  ('....', 258),
#  ('동남아', 248),
#  ('오는', 245),
#  ('여러', 243),
#  ('방', 243),
#  ('도르리', 237),
#  ('나라', 236),
#  ('돌아가며', 236),
#  ('제각기', 236),
#  ('내는', 236),
#  ('것', 234),
#  ('나무', 234),
#  ('날씨', 233),
#  ('에서', 230),
#  ('소', 230),
#  ('된', 226),
#  ('질', 226),
#  ('돌', 225),
#  ('마소', 224),
#  ('전', 223),
#  ('고', 222),
#  ('비비는', 220),
#  ('속담', 217),
#  ('숙제', 214),
#  ('뜻', 212),
#  ('포함', 206),
#  ('에는', 205),
#  ('위', 203),
#  ('합니다', 201),
#  ('순우리말', 201),
#  ('아이', 196),
#  ('모', 192),
#  ('꾼', 189),
#  ('나', 188),
#  ('할', 186),
#  ('짓', 186),
#  ('채', 186),
#  ('바로', 184),
#  ('아름다운', 180),
#  ('보꾹', 178),
#  ('제', 177),
#  ('이상', 174),
#  ('지붕', 174),
#  ('산', 174),
#  ('1', 173),
#  ('여름', 168),
#  ('?', 167),
#  ('저', 162),
#  ('먹는', 161),
#  ('명절', 161),
#  ('다른', 160),
#  ('중', 159),
#  ('찬', 159),
#  ('학년', 159),
#  ('계절', 158),
#  ('~', 152),
#  ('이다', 149),
#  ('까지', 148),
#  ('여행', 147),
#  ('20', 146),
#  ('이나', 143),
#  ('사람', 142),
#  ('해서', 139),
#  ('4', 139),
#  ('많이', 139),
#  ('세계', 138),
#  ('말', 136),
#  ('부탁', 136),
#  ('와', 135),
#  ('만', 133),
#  ('거리', 133),
#  ('3', 132),
#  ('고유어', 131),
#  ('또', 130),
#  ('시간', 130),
#  ('입니다', 129),
#  ('다시', 129),
#  ('10', 127),
#  ('놀이', 127),
#  ('/', 125),
#  ('해', 125),
#  ('씩', 125),
#  ('-', 125),
#  ('①', 123),
#  ('사용', 122),
#  ('적', 122),
#  ('되지기', 120),
#  ('얹어', 120),
#  ('찌거나', 120),
#  ('인데', 119),
#  ('영어', 119),
#  ('하나', 118),
#  ('정도', 118),
#  ('쏟아지는', 118),
#  ('여름철', 118),
#  ('새참', 116),
#  ('핵심', 116),
#  ('관련', 115),
#  ('고갱', 115),
#  ('사물', 115),
#  ('인', 114),
#  ('기', 109),
#  ('그', 109),
#  ('이름', 109),
#  ('100', 109),
#  ('문장', 108),
#  ('기본', 106),
#  ('제외', 105),
#  ('!!', 105),
#  ('돌림', 105),
#  ('사방', 105),
#  ('돌아다니며', 105),
#  ('줄기', 105),
#  ('기념일', 105),
#  (')...', 105),
#  ('정확히', 104),
#  ('구분', 104),
#  ('하세요', 104),
#  ('전통', 104),
#  ('만든', 103),
#  ('본', 102),
#  ('상세', 101),
#  ('반드시', 101),
#  ('범위', 101),
#  ('2', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('결과', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('주세요', 100),
#  ('가지', 100),
#  ('우리나라', 99),
#  ('"', 97),
#  ('우리', 97),
#  ('소리', 97),
#  ('5', 96),
#  ('면', 95),
#  ('빨리', 95),
#  ('!', 93),
#  ('설날', 93),
#  ('하며', 93),
#  ('곳', 92),
#  ('있는', 92),
#  ('성인', 92),
#  ('수', 91),
#  ('대해', 91),
#  ('즐거운', 91),
#  ('시원한', 90),
#  ('연날리기', 90),
#  ('보낸다', 90),
#  ('못', 89),
#  ('2010.12', 89),
#  ('成人の日', 89),
#  ('잘', 89),
#  ('생활', 89),
#  ('83', 89),
#  ('안녕하세요', 88),
#  ("'", 86),
#  ('조사', 86),
#  ('지나가고', 86),
#  ('도래', 86),
#  ('순', 86),
#  ('맛', 85),
#  ('방학', 85),
#  ('필리핀', 84),
#  ('추천', 83),
#  ('ㅠㅠ', 83),
#  ('하고', 81),
#  ('30', 80),
#  ('다', 78),
#  ('선생님', 77),
#  ('내', 76),
#  ('제발', 75),
#  ('부탁드립니다', 74),
#  ('해주세요', 73),
#  ('꼭', 72),
#  ('^^', 72),
#  ('학교', 72),
#  ('여', 72),
#  ('바람', 72),
#  ('그리고', 71),
#  ('태국', 71),
#  ('예쁜', 71),
#  ('예', 71),
#  ('난', 70),
#  ('*', 70),
#  ('분', 69),
#  ('가장', 69),
#  ('하기', 68),
#  ('쪽', 67),
#  ('서', 67),
#  ('한국', 66),
#  ('알', 66),
#  ('하는데', 65),
#  ('사회', 65),
#  ('오늘', 64),
#  ('111', 64),
#  ('좋은', 63),
#  ('물', 63),
#  ('6', 62),
#  ('이면', 62),
#  ('순수한', 62),
#  ('15', 61),
#  ('호텔', 60),
#  ('오후', 60),
#  ('구름', 60),
#  ('2008.04', 59),
#  ('샤워', 59),
#  ('잠깐', 58),
#  ('많은', 58),
#  ('그래서', 57),
#  ('2008.03', 57),
#  ('지', 56),
#  ('이라', 56),
#  ('??', 56),
#  ('18', 56),
#  ('아', 56),
#  ('어떤', 55),
#  ('중국', 55),
#  ('ㅠ', 55),
#  ('2008.09', 55),
#  ('더', 54),
#  ('무엇', 53),
#  ('ag', 53),
#  ('16', 52),
#  ('물건', 52),
#  ('hot', 52),
#  ('아래', 51),
#  ('50', 51),
#  ('food', 51),
#  ('shower', 51),
#  ('특징', 50),
#  ('19', 49),
#  ('겨울', 49),
#  ('fool', 49),
#  ('강한', 49),
#  ('내리는', 47),
#  ('28', 47),
#  ('오뉴월', 47),
#  ('함께', 47),
#  ('무더운', 47),
#  ('불', 46),
#  ('관', 46),
#  ('모습', 46),
#  ('25', 45),
#  ('먹는다', 45),
#  ('값', 45),
#  ('내리고', 44),
#  ('하면', 44),
#  ('에서는', 44),
#  ('써주세요', 44),
#  ('!!!', 43),
#  ('[', 43),
#  (']', 43),
#  ('17', 43),
#  ('내일', 43),
#  ('밑', 43),
#  ('식', 42),
#  ('12', 42),
#  ('시나', 42),
#  ('브로', 42),
#  ('께서', 42),
#  ('기운', 42),
#  ('까닭', 42),
#  ('하여', 41),
#  ('한다', 41),
#  ('봄', 41),
#  ('하지만', 40),
#  ('이런', 40),
#  ('국', 40),
#  ('한글', 40),
#  ('29', 39),
#  ('자주', 39),
#  ('부탁드려요', 39),
#  ('~~', 39),
#  ('모이는', 39),
#  ('따라', 39),
#  ('13', 38),
#  ('보다', 38),
#  (',,', 38),
#  ('거', 38),
#  ('뭐', 38),
#  ('24', 38),
#  ('2007.09', 38),
#  ('논', 38),
#  ('박', 37),
#  ('번', 37),
#  ('같이', 37),
#  ('신고', 37),
#  ('낱말', 37),
#  ('가르쳐', 37),
#  ('갈', 36),
#  ('식품', 36),
#  ('지역', 35),
#  ('라고', 35),
#  ('너무', 35),
#  ('데', 35),
#  ('일본', 35),
#  ('해외여행', 35),
#  ('.....', 35),
#  ('뜨거운', 35),
#  ('삼', 35),
#  ('2008.10', 35),
#  ('음식물', 35),
#  ('09', 34),
#  ('ethn', 34),
#  ('ocam', 34),
#  ('어', 34),
#  ('가는', 34),
#  ('넘으려고', 34),
#  ('빌라', 33),
#  ('베트남', 33),
#  ('온다', 33),
#  ('ㅎ', 33),
#  ('0', 33),
#  ('과학', 33),
#  ('양', 33),
#  ('98', 33),
#  ('ㅜ', 32),
#  ('초', 32),
#  ('겁니다', 32),
#  ('사진', 32),
#  ('라도', 32),
#  ('학기', 32),
#  ('afternoon', 32),
#  ('바보', 32),
#  ('sunny', 32),
#  ('비치는', 32),
#  ('homework', 32),
#  ('sleep', 32),
#  ('▷', 32),
#  ('해외', 31),
#  ('섭취', 31),
#  ('준비', 31),
#  ('27', 31),
#  ('대표', 31),
#  ('21', 31),
#  ('공부', 31),
#  ('04', 31),
#  ('~~~', 31),
#  ('그런데', 31),
#  ('중복', 31),
#  ('가르쳐주세요', 31),
#  ('<', 31),
#  ('②', 31),
#  ('주의', 30),
#  ('점', 30),
#  ('01', 30),
#  ('생각', 30),
#  ('11', 30),
#  ('같은', 30),
#  ('책', 30),
#  ('국어', 30),
#  ('드림', 30),
#  ('더위', 30),
#  ('피', 30),
#  ('동반', 30),
#  ('치르고', 30),
#  ('경우', 30),
#  ('07', 29),
#  ('31', 29),
#  ('26', 29),
#  ('지금', 29),
#  ('되도록', 29),
#  ('가을', 29),
#  ('14', 29),
#  ('02', 29),
#  ('말복', 29),
#  ('~!', 29),
#  ('적어주세요', 29),
#  ('함', 29),
#  ('우수리', 29),
#  ('계속', 29),
#  ('08', 28),
#  ('때문', 28),
#  ('되고', 28),
#  ('글', 28),
#  ('있나요', 28),
#  ('주', 28),
#  ('끝', 28),
#  ('집', 28),
#  ('린다', 28),
#  ('머리', 28),
#  ('고유', 28),
#  ('냠냠', 28),
#  ('뭉게구름', 28),
#  ('제주도', 28),
#  ('과일', 28),
#  ('비는', 28),
#  ('여행지', 27),
#  ('우기', 27),
#  ('많고', 27),
#  ('까', 27),
#  ('글자', 27),
#  ('22', 27),
#  ('알려주세여', 27),
#  ('매우', 27),
#  ('세', 27),
#  ('알려', 27),
#  ('2007.12', 27),
#  ('에게', 27),
#  ('들면', 27),
#  ('지적', 27),
#  ('오지', 27),
#  ('때로는', 27),
#  ('현지', 26),
#  ('되는', 26),
#  ('_', 26),
#  ('23', 26),
#  ('말고', 26),
#  ('째', 26),
#  ('한랭전선', 26),
#  ('차', 26),
#  ('단순히', 26),
#  ('뜨면', 26),
#  ('대류', 26),
#  ('활발하여', 26),
#  ('잔등', 26),
#  ('가른다', 26),
#  ('후', 25),
#  ('있을까요', 25),
#  ('구', 25),
#  ('도와주세요', 25),
#  ('의미', 25),
#  ('두고', 25),
#  ('술', 25),
#  ('8월', 25),
#  ('새', 25),
#  ('쇠', 25),
#  ('아시', 25),
#  ('한자', 25),
#  ('기후', 25),
#  ('켜주세요', 25),
#  ('가봐야', 24),
#  ('열', 24),
#  ('론풀', 24),
#  ('관광', 24),
#  ('조금', 24),
#  ('부터', 24),
#  ('05', 24),
#  ('정말', 24),
#  ('처럼', 24),
#  ('특히', 24),
#  ('급해요', 24),
#  ('감사하겠습니다', 24),
#  ('가리켜', 24),
#  ('풀', 24),
#  ('적어', 24),
#  ('하면서', 24),
#  ('답', 24),
#  ('보내', 24),
#  ('돌풍', 24),
#  ('하므로', 24),
#  ('산이', 24),
#  ('운다고', 24),
#  ('먼저', 24),
#  ('어른', 24),
#  ('5일', 23),
#  ('06', 23),
#  ('엔', 23),
#  ('그냥', 23),
#  ('랑', 23),
#  ('하다', 23),
#  ('알려주시면', 23),
#  ('제일', 23),
#  ('이쁜', 23),
#  ('별로', 23),
#  ('셋', 23),
#  ('자료', 23),
#  ('미국', 23),
#  ('절기', 23),
#  ('영', 23),
#  ('빗물', 23),
#  ('놓인', 23),
#  ('있으며', 22),
#  ('9월', 22),
#  ('라서', 22),
#  ('자세하게', 22),
#  ('않고', 22),
#  ('빨리요', 22),
#  ('기온', 22),
#  ('다툰다', 22),
#  ('복절', 22),
#  ('초복', 22),
#  ('삼복', 22),
#  ('보신', 22),
#  ('여우비', 22),
#  ('2008.08', 22),
#  ('읽기', 22),
#  ('염', 22),
#  ('더운갈이', 22),
#  ('가물', 22),
#  ('인데요', 22),
#  ('뉴욕', 21),
#  ('선정', 21),
#  ('오른', 21),
#  ('드시는', 21),
#  ('비경', 21),
#  ('설명', 21),
#  ('시기', 21),
#  ('푸켓', 21),
#  ('없는', 21),
#  ('해야', 21),
#  ('있어요', 21),
#  ('이랑', 21),
#  ('올려주세요', 21),
#  ('최대한', 21),
#  ('캄보디아', 21),
#  ('이렇게', 21),
#  ('해요', 21),
#  ('줌', 21),
#  ('타임스', 20),
#  ('죽기전에', 20),
#  ('맛있기는', 20),
#  ('간혹', 20),
#  ('계시는데', 20),
#  ('문제', 20),
#  ('먹고', 20),
#  ('1월', 20),
#  ('요즘', 20),
#  ('저희', 20),
#  ('있는데', 20),
#  ('비행기', 20),
#  ('5월', 20),
#  ('오', 20),
#  ('약간', 20),
#  ('눈', 20),
#  ('거슬러', 20),
#  ('!!!!', 20),
#  ('옷', 20),
#  ('처음', 20),
#  ('하', 20),
#  ('국수', 20),
#  ('도리', 20),
#  ('도끼', 20),
#  ('마시면', 20),
#  ('코', 20),
#  ('좋아도', 20),
#  ('온', 20),
#  ('2007.10', 20),
#  ('관계', 20),
#  ('가옥', 20),
#  ('이라는', 20),
#  ('조사해', 20),
#  ('덜함', 20),
#  ('습관', 20),
#  ('발', 20),
#  ('2011.07', 20),
#  ('대', 19),
#  ('어느', 19),
#  ('곱다', 19),
#  ('붉어진다', 19),
#  ('싫은', 19),
#  ('심사', 19),
#  ('이웃집', 19),
#  ('붙는', 19),
#  ('드립니다', 19),
#  ('풍속', 19),
#  ('7', 19),
#  ('라', 19),
#  ('특색', 19),
#  ('구체', 19),
#  ('℃', 19),
#  ('위해', 19),
#  ('도라질', 19),
#  ('힘들여', 19),
#  ('갖춰', 19),
#  ('바라지', 19),
#  ('꾸수하다', 19),
#  ('조상', 19),
#  ('께', 19),
#  ('단원', 19),
#  ('정리', 19),
#  ('이고', 18),
#  ('치안', 18),
#  ('걸', 18),
#  ('싱가폴', 18),
#  ('에요', 18),
#  ('가진', 18),
#  ('님', 18),
#  ('사이', 18),
#  ('품앗이', 18),
#  ('두', 18),
#  ('별', 18),
#  ('갑자기', 18),
#  ('들어', 18),
#  ('감사', 18),
#  ('2009.09', 18),
#  ('준다는', 18),
#  ('소화', 18),
#  ('일정', 17),
#  ('한두', 17),
#  ('하는데요', 17),
#  ('......', 17),
#  ('있다', 17),
#  ('해주시', 17),
#  ('대한', 17),
#  ('이유', 17),
#  ('내용', 17),
#  ('용', 17),
#  ('03', 17),
#  ('되지', 17),
#  ('여울', 17),
#  ('러시아', 17),
#  ('밴', 17),
#  ('어리석은', 17),
#  ('foot', 17),
#  ('hotel', 17),
#  ('hour', 17),
#  ('shut', 17),
#  ('닫다', 17),
#  ('sick', 17),
#  ('아픈', 17),
#  ('지장', 17),
#  ('괜찮아서', 16),
#  ('외국인', 16),
#  ('요리', 16),
#  ('거든요', 16),
#  ('상', 16),
#  ('그것', 16),
#  ('농사', 16),
#  ('대하', 16),
#  ('2007.08', 16),
#  ('9', 16),
#  (';', 16),
#  ('찾기', 16),
#  ('여서', 16),
#  ('11월', 15),
#  ('신혼여행', 15),
#  ('개는게', 15),
#  ('슬기', 15),
#  ('패키지', 15),
#  ('등등', 15),
#  ('몇', 15),
#  ('산지', 15),
#  ('수도', 15),
#  ('천둥', 15),
#  ('바랍니다', 15),
#  ('현재', 15),
#  ('이번', 15),
#  ('공기', 15),
#  ('있습니다', 15),
#  ('밀가루', 15),
#  ('모르는', 15),
#  ('꿈', 15),
#  ('달', 15),
#  ('외래어', 15),
#  ('님들', 15),
#  ('월요일', 15),
#  ('엄마', 15),
#  ('초등학교', 15),
#  ('학생', 15),
#  ('채택', 15),
#  ('한자어', 15),
#  ('★', 15),
#  ('기초', 15),
#  ('옆', 15),
#  ('화창한', 15),
#  ('성', 14),
#  ('근데', 14),
#  ('휴양지', 14),
#  ('일반', 14),
#  ('볼거리', 14),
#  ('하루', 14),
#  ('걱정', 14),
#  ('얼', 14),
#  ('골자', 14),
#  ('만을', 14),
#  ('부모님', 14),
#  ('ㅋ', 14),
#  ('40', 14),
#  ('모두', 14),
#  ('숙소', 14),
#  ('써주시면', 14),
#  ('드려요', 14),
#  ('하려고', 14),
#  ('조금씩', 14),
#  ('이라고', 14),
#  ('개좀', 14),
#  ('2008.07', 14),
#  ('형성', 14),
#  ('지나가는', 14),
#  ('스콜', 14),
#  ('2008.01', 14),
#  ('둘째', 14),
#  ('비교', 14),
#  ('저기', 14),
#  ('주시', 14),
#  ('방법', 14),
#  ('김치', 14),
#  ('아주', 14),
#  ('비단', 14),
#  ('에만', 14),
#  ('국한', 14),
#  ('끓는', 14),
#  ('만큼', 14),
#  ('가게', 13),
#  ('반', 13),
#  ('됩니다', 13),
#  ('가려고', 13),
#  ('바다', 13),
#  ('관광객', 13),
#  ('자유롭게', 13),
#  ('경험', 13),
#  ('우산', 13),
#  ('래', 13),
#  (';;', 13),
#  ('사전', 13),
#  ('소설', 13),
#  ('일기', 13),
#  ('☞', 13),
#  ('지식인', 13),
#  ('가서', 13),
#  ('돈', 13),
#  ('에도', 13),
#  ('발음', 13),
#  ('준비물', 13),
#  ('급함', 13),
#  ('지방', 13),
#  ('참고', 13),
#  ('거기', 13),
#  ('네', 13),
#  ('대단하고', 13),
#  ('가야', 13),
#  ('켜', 13),
#  ('2007.07', 13),
#  ('빠른', 13),
#  ('어떻게', 13),
#  ('모르겠네요', 13),
#  ('지식', 13),
#  ('외', 13),
#  ('평균', 13),
#  ('∼', 13),
#  ('습한', 13),
#  ('멍', 13),
#  ('대거', 13),
#  ('빼기', 13),
#  ('방축', 13),
#  ('따위', 13),
#  ('마을', 13),
#  ('.(', 13),
#  ('재', 13),
#  ('평가', 13),
#  ('~~~~', 13),
#  ('라는', 13),
#  ('해오래요', 13),
#  ('자연환경', 13),
#  ('대륙', 13),
#  ('싶습니다', 13),
#  ('속', 13),
#  ('열대지방', 13),
#  ('신망', 13),
#  ('스럽다', 13),
#  ('계획', 12),
#  ('어디가', 12),
#  ('ㅎㅎ', 12),
#  ('보고', 12),
#  ('또한', 12),
#  ('해당', 12),
#  ('ㅜㅜ', 12),
#  ('올', 12),
#  ('분야', 12),
#  ('약', 12),
#  ('가족', 12),
#  ('명', 12),
#  ('친구', 12),
#  ('몰라서', 12),
#  ('동남아시아', 12),
#  ('인지', 12),
#  ('표현', 12),
#  ('기도', 12),
#  ('초등학생', 12),
#  ('잠', 12),
#  ('가르', 12),
#  ('스트레스', 12),
#  ('그럼', 12),
#  ('주변', 12),
#  ('맞은', 12),
#  ('2008.06', 12),
#  ('알려주세', 12),
#  ('for', 12),
#  ('house', 12),
#  ('how', 12),
#  ('side', 12),
#  ('이제', 12),
#  ('풀이', 12),
#  ('2009.03', 12),
#  ('지은', 12),
#  ('볼때', 12),
#  ('빵값', 12),
#  ('공산품', 12),
#  ('들이므로', 12),
#  ('데운', 12),
#  ('자다', 12),
#  ('쯤', 11),
#  ('자유여행', 11),
#  ('괜찮은', 11),
#  ('않은', 11),
#  ('있는데요', 11),
#  ('어디', 11),
#  ('태양열', 11),
#  ('현상', 11),
#  ('잠시', 11),
#  ('아니면', 11),
#  ('혹시', 11),
#  ('목연', 11),
#  ('사는', 11),
#  ('같아요', 11),
#  ('진짜', 11),
#  ('인터넷', 11),
#  ('없이', 11),
#  ('차례', 11),
#  ('보면', 11),
#  ('정보', 11),
#  ('문화', 11),
#  ('니', 11),
#  ('미', 11),
#  ('?...', 11),
#  ('35', 11),
#  ('문', 11),
#  ('자세히', 11),
#  ('初侯', 11),
#  ('불어오고', 11),
#  ('중후', 11),
#  ('中侯', 11),
#  ('나서', 11),
#  ('수제비', 11),
#  ('번개', 11),
#  ('무섭게', 11),
#  ('2007.04', 11),
#  ('있어서', 11),
#  ('nhha', 11),
#  ('순수', 11),
#  ('올려', 11),
#  ('예요', 11),
#  ('숙젠데', 11),
#  ('된다', 11),
#  ('연', 11),
#  ('강수', 11),
#  ('아는', 11),
#  ('여러분', 11),
#  ('가면', 11),
#  ('마다', 11),
#  ('쓰는', 11),
#  ('개정', 11),
#  ('차라리', 11),
#  ('나면', 11),
#  ('운동', 11),
#  ('있잖아', 11),
#  ('세상', 11),
#  ('접고', 11),
#  ('잔소리', 11),
#  ('아마도', 11),
#  ('해오', 11),
#  ('찾아주세요', 11),
#  ('방언', 11),
#  ('sign', 11),
#  ('그러나', 11),
#  ('풍습', 11),
#  ('되요', 11),
#  ('있는지', 11),
#  ('요점', 11),
#  ('위주', 10),
#  ('12월', 10),
#  ('다양한', 10),
#  ('싶으며', 10),
#  ('로움', 10),
#  ('하여야하지요', 10),
#  ('간간히', 10),
#  ('관광지', 10),
#  ('엄청', 10),
#  ('인가요', 10),
#  ('6월', 10),
#  ('예정', 10),
#  ('사실', 10),
#  ('ㅋㅋ', 10),
#  ('->', 10),
#  ('걸어요', 10),
#  ('간', 10),
#  ('경비', 10),
#  ('및', 10),
#  ('코스', 10),
#  ('간단한', 10),
#  ('추려', 10),
#  ('도둑', 10),
#  ('밤사이', 10),
#  ('스시', 10),
#  ('여우별', 10),
#  ('여러가지', 10),
#  ('써', 10),
#  ('2월', 10),
#  ('유럽', 10),
#  ('300', 10),
#  ('먹을', 10),
#  ('방콕', 10),
#  ('대만', 10),
#  ('관용', 10),
#  ('8', 10),
#  ('???', 10),
#  ('없어서', 10),
#  ('즐겨', 10),
#  ('쏟아지', 10),
#  ('알아야', 10),
#  ('물론', 10),
#  ('상승', 10),
#  ('날짜', 10),
#  ('행사', 10),
#  ('뒤', 10),
#  ('강', 10),
#  ('외국어', 10),
#  ('모르게', 10),
#  ('참', 10),
#  ('도움', 10),
#  ('되', 10),
#  ('ㅋㅋㅋ', 10),
#  ('야', 10),
#  ('초등', 10),
#  ('팍팍', 10),
#  ('있으면', 10),
#  ('초딩', 10),
#  ('...)', 10),
#  ('200', 10),
#  ('시험', 10),
#  ('달라지는', 10),
#  ('휴가', 9),
#  ('발생', 9),
#  ('2019.11', 9),
#  ('좋을까요', 9),
#  ('고민', 9),
#  ('휴양', 9),
#  ('소콜', 9),
#  ('깜짝', 9),
#  ('놀라게도', 9),
#  ('피하', 9),
#  ('언제', 9),
#  ('leek', 9),
#  ('싶은데요', 9),
#  ('7월', 9),
#  ('대부분', 9),
#  ('이에요', 9),
#  ('햇볕', 9),
#  ('모든', 9),
#  ('먹기', 9),
#  ('국가', 9),
#  ('찾고', 9),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='소나기 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='소나기 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='소나기 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='소나기 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='소나기 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='소나기 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [(':', 1631),
#  ('음식', 1063),
#  ('더운', 840),
#  ('닉네임', 838),
#  ('소나기', 741),
#  ('날', 721),
#  ('****', 647),
#  ('안', 496),
#  ('우리말', 454),
#  ('●', 437),
#  ('(', 436),
#  ('검색', 404),
#  ('등', 347),
#  (')', 341),
#  ('비', 326),
#  ('개', 318),
#  ('입력', 300),
#  ('내공', 278),
#  ('알려주세요', 273),
#  ('몸', 271),
#  ('밥', 261),
#  ('동남아', 248),
#  ('오는', 245),
#  ('여러', 243),
#  ('방', 243),
#  ('도르리', 237),
#  ('나라', 236),
#  ('돌아가며', 236),
#  ('제각기', 236),
#  ('내는', 236),
#  ('나무', 234),
#  ('날씨', 233),
#  ('에서', 230),
#  ('소', 230),
#  ('된', 226),
#  ('질', 226),
#  ('돌', 225),
#  ('마소', 224),
#  ('전', 223),
#  ('비비는', 220),
#  ('속담', 217),
#  ('숙제', 214),
#  ('뜻', 212),
#  ('포함', 206),
#  ('에는', 205),
#  ('위', 203),
#  ('합니다', 201),
#  ('순우리말', 201),
#  ('아이', 196),
#  ('모', 192),
#  ('꾼', 189),
#  ('나', 188),
#  ('짓', 186),
#  ('채', 186),
#  ('바로', 184),
#  ('아름다운', 180),
#  ('보꾹', 178),
#  ('지붕', 174),
#  ('산', 174),
#  ('여름', 168),
#  ('저', 162),
#  ('먹는', 161),
#  ('명절', 161),
#  ('다른', 160),
#  ('찬', 159),
#  ('학년', 159),
#  ('계절', 158),
#  ('이다', 149),
#  ('까지', 148),
#  ('여행', 147),
#  ('이나', 143),
#  ('사람', 142),
#  ('해서', 139),
#  ('4', 139),
#  ('많이', 139),
#  ('세계', 138),
#  ('말', 136),
#  ('부탁', 136),
#  ('와', 135),
#  ('만', 133),
#  ('거리', 133),
#  ('3', 132),
#  ('고유어', 131),
#  ('또', 130),
#  ('시간', 130),
#  ('입니다', 129),
#  ('다시', 129),
#  ('놀이', 127),
#  ('/', 125),
#  ('해', 125),
#  ('씩', 125),
#  ('-', 125),
#  ('①', 123),
#  ('사용', 122),
#  ('적', 122),
#  ('되지기', 120),
#  ('얹어', 120),
#  ('찌거나', 120),
#  ('영어', 119),
#  ('정도', 118),
#  ('쏟아지는', 118),
#  ('여름철', 118),
#  ('새참', 116),
#  ('핵심', 116),
#  ('관련', 115),
#  ('고갱', 115),
#  ('사물', 115),
#  ('인', 114),
#  ('기', 109),
#  ('그', 109),
#  ('이름', 109),
#  ('100', 109),
#  ('문장', 108),
#  ('제외', 105),
#  ('돌림', 105),
#  ('사방', 105),
#  ('돌아다니며', 105),
#  ('줄기', 105),
#  ('기념일', 105),
#  (')...', 105),
#  ('정확히', 104),
#  ('구분', 104),
#  ('하세요', 104),
#  ('전통', 104),
#  ('만든', 103),
#  ('본', 102),
#  ('상세', 101),
#  ('반드시', 101),
#  ('범위', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('결과', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('주세요', 100),
#  ('가지', 100),
#  ('우리나라', 99),
#  ('"', 97),
#  ('우리', 97),
#  ('소리', 97),
#  ('5', 96),
#  ('면', 95),
#  ('빨리', 95),
#  ('!', 93),
#  ('설날', 93),
#  ('하며', 93),
#  ('곳', 92),
#  ('성인', 92),
#  ('대해', 91),
#  ('즐거운', 91),
#  ('시원한', 90),
#  ('연날리기', 90),
#  ('보낸다', 90),
#  ('2010.12', 89),
#  ('成人の日', 89),
#  ('생활', 89),
#  ('83', 89),
#  ('안녕하세요', 88),
#  ("'", 86),
#  ('조사', 86),
#  ('지나가고', 86),
#  ('도래', 86),
#  ('순', 86),
#  ('맛', 85),
#  ('방학', 85),
#  ('필리핀', 84),
#  ('추천', 83),
#  ('ㅠㅠ', 83),
#  ('하고', 81),
#  ('30', 80),
#  ('선생님', 77),
#  ('내', 76),
#  ('제발', 75),
#  ('부탁드립니다', 74),
#  ('해주세요', 73),
#  ('꼭', 72),
#  ('^^', 72),
#  ('학교', 72),
#  ('여', 72),
#  ('바람', 72),
#  ('그리고', 71),
#  ('태국', 71),
#  ('예쁜', 71),
#  ('예', 71),
#  ('난', 70),
#  ('*', 70),
#  ('분', 69),
#  ('가장', 69),
#  ('하기', 68),
#  ('쪽', 67),
#  ('서', 67),
#  ('한국', 66),
#  ('알', 66),
#  ('하는데', 65),
#  ('사회', 65),
#  ('오늘', 64),
#  ('111', 64),
#  ('좋은', 63),
#  ('물', 63),
#  ('이면', 62),
#  ('순수한', 62),
#  ('15', 61),
#  ('호텔', 60),
#  ('오후', 60),
#  ('구름', 60),
#  ('2008.04', 59),
#  ('샤워', 59),
#  ('잠깐', 58),
#  ('많은', 58),
#  ('그래서', 57),
#  ('2008.03', 57),
#  ('이라', 56),
#  ('??', 56),
#  ('18', 56),
#  ('아', 56),
#  ('중국', 55),
#  ('ㅠ', 55),
#  ('2008.09', 55),
#  ('더', 54),
#  ('무엇', 53),
#  ('ag', 53),
#  ('16', 52),
#  ('물건', 52),
#  ('hot', 52),
#  ('아래', 51),
#  ('50', 51),
#  ('food', 51),
#  ('shower', 51),
#  ('특징', 50),
#  ('19', 49),
#  ('겨울', 49),
#  ('fool', 49),
#  ('강한', 49),
#  ('내리는', 47),
#  ('28', 47),
#  ('오뉴월', 47),
#  ('함께', 47),
#  ('무더운', 47),
#  ('불', 46),
#  ('관', 46),
#  ('모습', 46),
#  ('25', 45),
#  ('먹는다', 45),
#  ('값', 45),
#  ('내리고', 44),
#  ('하면', 44),
#  ('에서는', 44),
#  ('써주세요', 44),
#  ('!!!', 43),
#  ('[', 43),
#  (']', 43),
#  ('17', 43),
#  ('내일', 43),
#  ('밑', 43),
#  ('식', 42),
#  ('12', 42),
#  ('시나', 42),
#  ('브로', 42),
#  ('께서', 42),
#  ('기운', 42),
#  ('까닭', 42),
#  ('하여', 41),
#  ('한다', 41),
#  ('봄', 41),
#  ('하지만', 40),
#  ('이런', 40),
#  ('국', 40),
#  ('한글', 40),
#  ('29', 39),
#  ('자주', 39),
#  ('부탁드려요', 39),
#  ('~~', 39),
#  ('모이는', 39),
#  ('따라', 39),
#  ('13', 38),
#  ('보다', 38),
#  (',,', 38),
#  ('24', 38),
#  ('2007.09', 38),
#  ('논', 38),
#  ('박', 37),
#  ('번', 37),
#  ('같이', 37),
#  ('신고', 37),
#  ('낱말', 37),
#  ('가르쳐', 37),
#  ('갈', 36),
#  ('식품', 36),
#  ('지역', 35),
#  ('너무', 35),
#  ('일본', 35),
#  ('해외여행', 35),
#  ('.....', 35),
#  ('뜨거운', 35),
#  ('삼', 35),
#  ('2008.10', 35),
#  ('음식물', 35),
#  ('09', 34),
#  ('ethn', 34),
#  ('ocam', 34),
#  ('어', 34),
#  ('가는', 34),
#  ('넘으려고', 34),
#  ('빌라', 33),
#  ('베트남', 33),
#  ('온다', 33),
#  ('ㅎ', 33),
#  ('0', 33),
#  ('과학', 33),
#  ('양', 33),
#  ('98', 33),
#  ('ㅜ', 32),
#  ('초', 32),
#  ('겁니다', 32),
#  ('사진', 32),
#  ('라도', 32),
#  ('학기', 32),
#  ('afternoon', 32),
#  ('바보', 32),
#  ('sunny', 32),
#  ('비치는', 32),
#  ('homework', 32),
#  ('sleep', 32),
#  ('▷', 32),
#  ('해외', 31),
#  ('섭취', 31),
#  ('준비', 31),
#  ('27', 31),
#  ('대표', 31),
#  ('21', 31),
#  ('공부', 31),
#  ('04', 31),
#  ('~~~', 31),
#  ('그런데', 31),
#  ('중복', 31),
#  ('가르쳐주세요', 31),
#  ('<', 31),
#  ('②', 31),
#  ('주의', 30),
#  ('점', 30),
#  ('01', 30),
#  ('생각', 30),
#  ('11', 30),
#  ('같은', 30),
#  ('책', 30),
#  ('국어', 30),
#  ('드림', 30),
#  ('더위', 30),
#  ('피', 30),
#  ('동반', 30),
#  ('치르고', 30),
#  ('경우', 30),
#  ('07', 29),
#  ('31', 29),
#  ('26', 29),
#  ('지금', 29),
#  ('되도록', 29),
#  ('가을', 29),
#  ('14', 29),
#  ('02', 29),
#  ('말복', 29),
#  ('~!', 29),
#  ('적어주세요', 29),
#  ('함', 29),
#  ('우수리', 29),
#  ('계속', 29),
#  ('08', 28),
#  ('때문', 28),
#  ('되고', 28),
#  ('글', 28),
#  ('있나요', 28),
#  ('끝', 28),
#  ('집', 28),
#  ('린다', 28),
#  ('머리', 28),
#  ('고유', 28),
#  ('냠냠', 28),
#  ('뭉게구름', 28),
#  ('제주도', 28),
#  ('과일', 28),
#  ('비는', 28),
#  ('여행지', 27),
#  ('우기', 27),
#  ('많고', 27),
#  ('글자', 27),
#  ('22', 27),
#  ('알려주세여', 27),
#  ('매우', 27),
#  ('세', 27),
#  ('알려', 27),
#  ('2007.12', 27),
#  ('에게', 27),
#  ('들면', 27),
#  ('지적', 27),
#  ('오지', 27),
#  ('때로는', 27),
#  ('현지', 26),
#  ('되는', 26),
#  ('_', 26),
#  ('23', 26),
#  ('말고', 26),
#  ('째', 26),
#  ('한랭전선', 26),
#  ('차', 26),
#  ('단순히', 26),
#  ('뜨면', 26),
#  ('대류', 26),
#  ('활발하여', 26),
#  ('잔등', 26),
#  ('가른다', 26),
#  ('있을까요', 25),
#  ('구', 25),
#  ('도와주세요', 25),
#  ('의미', 25),
#  ('두고', 25),
#  ('술', 25),
#  ('8월', 25),
#  ('새', 25),
#  ('쇠', 25),
#  ('아시', 25),
#  ('한자', 25),
#  ('기후', 25),
#  ('켜주세요', 25),
#  ('가봐야', 24),
#  ('열', 24),
#  ('론풀', 24),
#  ('관광', 24),
#  ('조금', 24),
#  ('부터', 24),
#  ('05', 24),
#  ('정말', 24),
#  ('처럼', 24),
#  ('특히', 24),
#  ('급해요', 24),
#  ('감사하겠습니다', 24),
#  ('가리켜', 24),
#  ('풀', 24),
#  ('적어', 24),
#  ('하면서', 24),
#  ('답', 24),
#  ('보내', 24),
#  ('돌풍', 24),
#  ('하므로', 24),
#  ('산이', 24),
#  ('운다고', 24),
#  ('먼저', 24),
#  ('어른', 24),
#  ('5일', 23),
#  ('엔', 23),
#  ('그냥', 23),
#  ('랑', 23),
#  ('하다', 23),
#  ('알려주시면', 23),
#  ('제일', 23),
#  ('이쁜', 23),
#  ('별로', 23),
#  ('셋', 23),
#  ('자료', 23),
#  ('미국', 23),
#  ('절기', 23),
#  ('영', 23),
#  ('빗물', 23),
#  ('놓인', 23),
#  ('있으며', 22),
#  ('9월', 22),
#  ('라서', 22),
#  ('자세하게', 22),
#  ('않고', 22),
#  ('빨리요', 22),
#  ('기온', 22),
#  ('다툰다', 22),
#  ('복절', 22),
#  ('초복', 22),
#  ('삼복', 22),
#  ('보신', 22),
#  ('여우비', 22),
#  ('2008.08', 22),
#  ('읽기', 22),
#  ('염', 22),
#  ('더운갈이', 22),
#  ('가물', 22),
#  ('인데요', 22),
#  ('뉴욕', 21),
#  ('선정', 21),
#  ('오른', 21),
#  ('드시는', 21),
#  ('비경', 21),
#  ('설명', 21),
#  ('시기', 21),
#  ('푸켓', 21),
#  ('없는', 21),
#  ('해야', 21),
#  ('있어요', 21),
#  ('이랑', 21),
#  ('올려주세요', 21),
#  ('최대한', 21),
#  ('캄보디아', 21),
#  ('이렇게', 21),
#  ('해요', 21),
#  ('줌', 21),
#  ('타임스', 20),
#  ('죽기전에', 20),
#  ('맛있기는', 20),
#  ('간혹', 20),
#  ('계시는데', 20),
#  ('문제', 20),
#  ('먹고', 20),
#  ('1월', 20),
#  ('요즘', 20),
#  ('저희', 20),
#  ('있는데', 20),
#  ('비행기', 20),
#  ('5월', 20),
#  ('오', 20),
#  ('약간', 20),
#  ('눈', 20),
#  ('거슬러', 20),
#  ('!!!!', 20),
#  ('옷', 20),
#  ('처음', 20),
#  ('하', 20),
#  ('국수', 20),
#  ('도리', 20),
#  ('도끼', 20),
#  ('마시면', 20),
#  ('코', 20),
#  ('좋아도', 20),
#  ('온', 20),
#  ('2007.10', 20),
#  ('관계', 20),
#  ('가옥', 20),
#  ('이라는', 20),
#  ('조사해', 20),
#  ('덜함', 20),
#  ('습관', 20),
#  ('발', 20),
#  ('2011.07', 20),
#  ('어느', 19),
#  ('곱다', 19),
#  ('붉어진다', 19),
#  ('싫은', 19),
#  ('심사', 19),
#  ('이웃집', 19),
#  ('붙는', 19),
#  ('드립니다', 19),
#  ('풍속', 19),
#  ('7', 19),
#  ('라', 19),
#  ('특색', 19),
#  ('구체', 19),
#  ('℃', 19),
#  ('위해', 19),
#  ('도라질', 19),
#  ('힘들여', 19),
#  ('갖춰', 19),
#  ('바라지', 19),
#  ('꾸수하다', 19),
#  ('조상', 19),
#  ('께', 19),
#  ('단원', 19),
#  ('정리', 19),
#  ('이고', 18),
#  ('치안', 18),
#  ('걸', 18),
#  ('싱가폴', 18),
#  ('에요', 18),
#  ('가진', 18),
#  ('님', 18),
#  ('사이', 18),
#  ('품앗이', 18),
#  ('두', 18),
#  ('별', 18),
#  ('갑자기', 18),
#  ('들어', 18),
#  ('감사', 18),
#  ('2009.09', 18),
#  ('준다는', 18),
#  ('소화', 18),
#  ('일정', 17),
#  ('한두', 17),
#  ('하는데요', 17),
#  ('......', 17),
#  ('있다', 17),
#  ('해주시', 17),
#  ('대한', 17),
#  ('이유', 17),
#  ('내용', 17),
#  ('용', 17),
#  ('03', 17),
#  ('되지', 17),
#  ('여울', 17),
#  ('러시아', 17),
#  ('밴', 17),
#  ('어리석은', 17),
#  ('foot', 17),
#  ('hotel', 17),
#  ('hour', 17),
#  ('shut', 17),
#  ('닫다', 17),
#  ('sick', 17),
#  ('아픈', 17),
#  ('지장', 17),
#  ('괜찮아서', 16),
#  ('외국인', 16),
#  ('요리', 16),
#  ('거든요', 16),
#  ('상', 16),
#  ('그것', 16),
#  ('농사', 16),
#  ('대하', 16),
#  ('2007.08', 16),
#  ('9', 16),
#  (';', 16),
#  ('찾기', 16),
#  ('여서', 16),
#  ('11월', 15),
#  ('신혼여행', 15),
#  ('개는게', 15),
#  ('슬기', 15),
#  ('패키지', 15),
#  ('등등', 15),
#  ('몇', 15),
#  ('산지', 15),
#  ('수도', 15),
#  ('천둥', 15),
#  ('바랍니다', 15),
#  ('현재', 15),
#  ('이번', 15),
#  ('공기', 15),
#  ('있습니다', 15),
#  ('밀가루', 15),
#  ('모르는', 15),
#  ('꿈', 15),
#  ('달', 15),
#  ('외래어', 15),
#  ('님들', 15),
#  ('월요일', 15),
#  ('엄마', 15),
#  ('초등학교', 15),
#  ('학생', 15),
#  ('채택', 15),
#  ('한자어', 15),
#  ('★', 15),
#  ('기초', 15),
#  ('옆', 15),
#  ('화창한', 15),
#  ('성', 14),
#  ('근데', 14),
#  ('휴양지', 14),
#  ('일반', 14),
#  ('볼거리', 14),
#  ('하루', 14),
#  ('걱정', 14),
#  ('얼', 14),
#  ('골자', 14),
#  ('만을', 14),
#  ('부모님', 14),
#  ('ㅋ', 14),
#  ('40', 14),
#  ('모두', 14),
#  ('숙소', 14),
#  ('써주시면', 14),
#  ('드려요', 14),
#  ('하려고', 14),
#  ('조금씩', 14),
#  ('이라고', 14),
#  ('개좀', 14),
#  ('2008.07', 14),
#  ('형성', 14),
#  ('지나가는', 14),
#  ('스콜', 14),
#  ('2008.01', 14),
#  ('둘째', 14),
#  ('비교', 14),
#  ('저기', 14),
#  ('주시', 14),
#  ('방법', 14),
#  ('김치', 14),
#  ('아주', 14),
#  ('비단', 14),
#  ('에만', 14),
#  ('국한', 14),
#  ('끓는', 14),
#  ('만큼', 14),
#  ('가게', 13),
#  ('반', 13),
#  ('됩니다', 13),
#  ('가려고', 13),
#  ('바다', 13),
#  ('관광객', 13),
#  ('자유롭게', 13),
#  ('경험', 13),
#  ('우산', 13),
#  ('래', 13),
#  (';;', 13),
#  ('사전', 13),
#  ('소설', 13),
#  ('일기', 13),
#  ('☞', 13),
#  ('지식인', 13),
#  ('가서', 13),
#  ('돈', 13),
#  ('에도', 13),
#  ('발음', 13),
#  ('준비물', 13),
#  ('급함', 13),
#  ('지방', 13),
#  ('참고', 13),
#  ('거기', 13),
#  ('대단하고', 13),
#  ('가야', 13),
#  ('켜', 13),
#  ('2007.07', 13),
#  ('빠른', 13),
#  ('어떻게', 13),
#  ('모르겠네요', 13),
#  ('지식', 13),
#  ('외', 13),
#  ('평균', 13),
#  ('∼', 13),
#  ('습한', 13),
#  ('멍', 13),
#  ('대거', 13),
#  ('빼기', 13),
#  ('방축', 13),
#  ('따위', 13),
#  ('마을', 13),
#  ('.(', 13),
#  ('재', 13),
#  ('평가', 13),
#  ('~~~~', 13),
#  ('라는', 13),
#  ('해오래요', 13),
#  ('자연환경', 13),
#  ('대륙', 13),
#  ('싶습니다', 13),
#  ('속', 13),
#  ('열대지방', 13),
#  ('신망', 13),
#  ('스럽다', 13),
#  ('계획', 12),
#  ('어디가', 12),
#  ('보고', 12),
#  ('또한', 12),
#  ('해당', 12),
#  ('ㅜㅜ', 12),
#  ('올', 12),
#  ('분야', 12),
#  ('약', 12),
#  ('가족', 12),
#  ('명', 12),
#  ('친구', 12),
#  ('몰라서', 12),
#  ('동남아시아', 12),
#  ('인지', 12),
#  ('표현', 12),
#  ('기도', 12),
#  ('초등학생', 12),
#  ('잠', 12),
#  ('가르', 12),
#  ('스트레스', 12),
#  ('그럼', 12),
#  ('주변', 12),
#  ('맞은', 12),
#  ('2008.06', 12),
#  ('알려주세', 12),
#  ('for', 12),
#  ('house', 12),
#  ('how', 12),
#  ('side', 12),
#  ('이제', 12),
#  ('풀이', 12),
#  ('2009.03', 12),
#  ('지은', 12),
#  ('볼때', 12),
#  ('빵값', 12),
#  ('공산품', 12),
#  ('들이므로', 12),
#  ('데운', 12),
#  ('자다', 12),
#  ('쯤', 11),
#  ('자유여행', 11),
#  ('괜찮은', 11),
#  ('않은', 11),
#  ('있는데요', 11),
#  ('어디', 11),
#  ('태양열', 11),
#  ('현상', 11),
#  ('잠시', 11),
#  ('아니면', 11),
#  ('혹시', 11),
#  ('목연', 11),
#  ('사는', 11),
#  ('같아요', 11),
#  ('진짜', 11),
#  ('인터넷', 11),
#  ('없이', 11),
#  ('차례', 11),
#  ('보면', 11),
#  ('정보', 11),
#  ('문화', 11),
#  ('니', 11),
#  ('미', 11),
#  ('?...', 11),
#  ('35', 11),
#  ('문', 11),
#  ('자세히', 11),
#  ('初侯', 11),
#  ('불어오고', 11),
#  ('중후', 11),
#  ('中侯', 11),
#  ('나서', 11),
#  ('수제비', 11),
#  ('번개', 11),
#  ('무섭게', 11),
#  ('2007.04', 11),
#  ('있어서', 11),
#  ('nhha', 11),
#  ('순수', 11),
#  ('올려', 11),
#  ('예요', 11),
#  ('숙젠데', 11),
#  ('된다', 11),
#  ('연', 11),
#  ('강수', 11),
#  ('아는', 11),
#  ('여러분', 11),
#  ('가면', 11),
#  ('마다', 11),
#  ('쓰는', 11),
#  ('개정', 11),
#  ('차라리', 11),
#  ('나면', 11),
#  ('운동', 11),
#  ('있잖아', 11),
#  ('세상', 11),
#  ('접고', 11),
#  ('잔소리', 11),
#  ('아마도', 11),
#  ('해오', 11),
#  ('찾아주세요', 11),
#  ('방언', 11),
#  ('sign', 11),
#  ('그러나', 11),
#  ('풍습', 11),
#  ('되요', 11),
#  ('있는지', 11),
#  ('요점', 11),
#  ('위주', 10),
#  ('12월', 10),
#  ('다양한', 10),
#  ('싶으며', 10),
#  ('로움', 10),
#  ('하여야하지요', 10),
#  ('간간히', 10),
#  ('관광지', 10),
#  ('엄청', 10),
#  ('인가요', 10),
#  ('6월', 10),
#  ('예정', 10),
#  ('사실', 10),
#  ('ㅋㅋ', 10),
#  ('->', 10),
#  ('걸어요', 10),
#  ('간', 10),
#  ('경비', 10),
#  ('및', 10),
#  ('코스', 10),
#  ('간단한', 10),
#  ('추려', 10),
#  ('도둑', 10),
#  ('밤사이', 10),
#  ('스시', 10),
#  ('여우별', 10),
#  ('여러가지', 10),
#  ('써', 10),
#  ('2월', 10),
#  ('유럽', 10),
#  ('300', 10),
#  ('먹을', 10),
#  ('방콕', 10),
#  ('대만', 10),
#  ('관용', 10),
#  ('8', 10),
#  ('???', 10),
#  ('없어서', 10),
#  ('즐겨', 10),
#  ('쏟아지', 10),
#  ('알아야', 10),
#  ('물론', 10),
#  ('상승', 10),
#  ('날짜', 10),
#  ('행사', 10),
#  ('뒤', 10),
#  ('강', 10),
#  ('외국어', 10),
#  ('모르게', 10),
#  ('참', 10),
#  ('도움', 10),
#  ('되', 10),
#  ('ㅋㅋㅋ', 10),
#  ('야', 10),
#  ('초등', 10),
#  ('팍팍', 10),
#  ('있으면', 10),
#  ('초딩', 10),
#  ('...)', 10),
#  ('200', 10),
#  ('시험', 10),
#  ('달라지는', 10),
#  ('휴가', 9),
#  ('발생', 9),
#  ('2019.11', 9),
#  ('좋을까요', 9),
#  ('고민', 9),
#  ('휴양', 9),
#  ('소콜', 9),
#  ('깜짝', 9),
#  ('놀라게도', 9),
#  ('피하', 9),
#  ('언제', 9),
#  ('leek', 9),
#  ('싶은데요', 9),
#  ('7월', 9),
#  ('대부분', 9),
#  ('이에요', 9),
#  ('햇볕', 9),
#  ('모든', 9),
#  ('먹기', 9),
#  ('국가', 9),
#  ('찾고', 9),
#  ('궂', 9),
#  ('단', 9),
#  ('시', 9),
#  ('음식점', 9),
#  ('한번', 9),
#  ('ㅁ', 9),
#  ('밤', 9),
#  ('장소', 9),
#  ('일단', 9),
#  ('각', 9),
#  ('가까운', 9),
#  ('쌀', 9),
#  ('가는데', 9),
#  ('삼겹살', 9),
#  ('음', 9),
#  ('그런', 9),
#  ('수준', 9),
#  ('의식주', 9),
#  ('내고', 9),
#  ('미르', 9),
#  ('듯', 9),
#  ('찾아', 9),
#  ('한글날', 9),
#  ('기념', 9),
#  ('3월', 9),
#  ('성하', 9),
#  ('한여름', 9),
#  ('나타나게', 9),
#  ('분포', 9),
#  ('사면', 9),
#  ('계', 9),
#  ('^', 9),
#  ('많을수록', 9),
#  ('ㅇ', 9),
#  ('아무', 9),
#  ('2006.10', 9),
#  ('오라', 9),
#  ('이구', 9),
#  ('맑은', 9),
#  ('지내는', 9),
#  ('빨', 9),
#  ('또는', 9),
#  ('목요일', 9),
#  ('반죽', 9),
#  ('내리게', 9),
#  ('알수', 9),
#  ('북한', 9),
#  ('~~!!', 9),
#  ('+', 8),
#  ('4일', 8),
#  ('해도', 8),
#  ('좋고', 8),
#  ('남자', 8),
#  ('혼자', 8),
#  ('선택', 8),
#  ('같아서', 8),
#  ('오면', 8),
#  ('할것', 8),
#  ('1일', 8),
#  ('따뜻한', 8),
#  ('가격', 8),
#  ('욧', 8),
#  ('거의', 8),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9642 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9702 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9642 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9702 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 8228 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
