# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []

tmp1 = 'https://search.naver.com/search.naver?date_from=&date_option=0&date_to=&dup_remove=1'
html = tmp1 + '&nso=&post_blogurl=&post_blogurl_without=&query={key_word}&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'

for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('비 더운 날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
# 형태소 분석
tokens_ko = okt.morphs(present_text)
#중복제거
ko = nltk.Text(tokens_ko,name='비 더운 날 음식 한식')
ko.vocab().most_common()
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
ko = nltk.Text(tokens_ko,name='비 더운 날 음식 한식')
ko.vocab().most_common()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '2013년',
#  '한식',
#  '날',
#  '2013.01',
#  '.',
#  '02',
#  '.',
#  '저기',
#  '한식',
#  '날',
#  '날짜',
#  '가',
#  '어떻게',
#  '되나요',
#  '??',
#  '인터넷',
#  '찾아봐도',
#  '없어서요',
#  '.......',
#  '자세하게',
#  '답좀',
#  '해주세요',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어야',
#  '한다는',
#  '속',
#  '신',
#  '(',
#  '俗信',
#  ')...',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제',
#  '사',
#  '음식',
#  '을',
#  '마련',
#  '하여',
#  '제사',
#  '를',
#  '지내는데',
#  ',',
#  '이를',
#  '절사',
#  '(',
#  '節祀',
#  ')...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '한식',
#  '조사',
#  '여',
#  '.....',
#  '2016.06',
#  '.',
#  '01',
#  '.',
#  '뭐',
#  '가',
#  '우리나라',
#  '음식',
#  '인지',
#  '모르겠어서요',
#  '일단',
#  '1',
#  '.',
#  '한식',
#  '종류',
#  '!',
#  '를',
#  '알려주세요',
#  '2',
#  '.',
#  '그',
#  '음식',
#  '들',
#  '을',
#  '만드는',
#  '방법',
#  '도',
#  '알려주세요',
#  '오늘',
#  '안',
#  '에',
#  '알려주세요',
#  '.....',
#  '지금',
#  '엄청',
#  '급해서요',
#  '.....',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '및',
#  '비',
#  ')',
#  '와',
#  '각',
#  '능',
#  '원',
#  '에',
#  '제',
#  '향',
#  '하고',
#  ',',
#  '민간',
#  '에서는',
#  '여러',
#  '가지',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '2013.02',
#  '.',
#  '15',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '제발',
#  '부탁드림니다',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  '정답',
#  '질문',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '이',
#  '뭐',
#  '에요',
#  '?',
#  '2011.08',
#  '.',
#  '26',
#  '.',
#  '그',
#  '..',
#  '우리나라',
#  '음식',
#  '한식',
#  '말구요',
#  '..;;',
#  '차가울',
#  '한',
#  '?',
#  '그거',
#  '쓴',
#  '...',
#  '한',
#  '문',
#  '숙제',
#  '가',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '에',
#  '대해',
#  '서',
#  '조사',
#  '해오는건데',
#  '....',
#  '조사',
#  '를',
#  '해서',
#  '어떻게',
#  '해야',
#  '될지도',
#  '모르겠고',
#  '..',
#  '사전',
#  '같은',
#  '덴',
#  '너무',
#  '...',
#  '답변',
#  '더운',
#  '밥',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '밥',
#  '을',
#  '먹는다고는',
#  '하나',
#  '잘',
#  '지켜지지',
#  '않았다',
#  '.',
#  '한식',
#  '은',
#  '조선시대',
#  '에',
#  '설날',
#  '·',
#  '단오',
#  '·',
#  '추석',
#  '과',
#  '함께',
#  '사대',
#  '명절',
#  '(',
#  '四大名節',
#  ')',
#  '에',
#  '속',
#  '했다',
#  '.',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제사',
#  '음식',
#  '...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대하',
#  '여',
#  '2007.04',
#  '.',
#  '05',
#  '.',
#  '학교숙제',
#  '인대',
#  '요',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대한',
#  '조사',
#  '를',
#  '해',
#  '라',
#  '해서',
#  '하게',
#  '된것인데',
#  '제',
#  '말',
#  '도와주세요',
#  'ㅠㅠ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '...',
#  '및',
#  '비',
#  ')',
#  '와',
#  '각',
#  '능',
#  '원',
#  '에',
#  '제',
#  '향',
#  '하고',
#  ',',
#  '민간',
#  '에서는',
#  '여러',
#  '가지',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '되는',
#  '...',
#  '닉네임',
#  'han',
#  '0',
#  '****',
#  '질문',
#  '원일',
#  '/',
#  '한식',
#  '/',
#  '단오',
#  '/',
#  '추석',
#  '/',
#  '동지',
#  '때',
#  '풍습',
#  '과',
#  '음식',
#  '2008.09',
#  '.',
#  '28',
#  '.',
#  '원일',
#  '(',
#  '음력',
#  '1월',
#  '1일',
#  '),',
#  '한식',
#  '(',
#  '동지',
#  '부터',
#  '105일',
#  '),',
#  '단오',
#  '(',
#  '음력',
#  '5월',
#  '5일',
#  '),',
#  '추석',
#  '(',
#  '음력',
#  '8월',
#  '15일',
#  '),',
#  '동지',
#  '에',
#  '하는',
#  '풍습',
#  '과',
#  '그',
#  '때',
#  '에',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '~~',
#  '답변',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌리',
#  '기도',
#  '합니다',
#  '.',
#  '【',
#  '한식',
#  '날',
#  '음식',
#  '】',
#  '성묘',
#  '는',
#  '일',
#  '년',
#  '에',
#  '네',
#  '번',
#  '으로',
#  '정초',
#  ',',
#  '한식',
#  ',',
#  '단오',
#  ',',
#  '중추',
#  '에',
#  '한다',
#  '.',
#  '제물',
#  '은',
#  '술',
#  ',',
#  '과일',
#  ',',
#  '포',
#  ',',
#  '식혜',
#  ',',
#  '떡',
#  ',',
#  '국수',
#  ',',
#  '탕',
#  ',',
#  '적',
#  '...',
#  '닉네임',
#  'read',
#  '****',
#  '질문',
#  '세상',
#  '에서',
#  '가장',
#  '맛있는',
#  '음식',
#  '2020.07',
#  '.',
#  '12',
#  '.',
#  '세상',
#  '에서',
#  '가장',
#  '맛있는',
#  '음식',
#  '은',
#  '뭔가',
#  '요',
#  '?',
#  '답변',
#  '그런데',
#  ',',
#  '좋아',
#  '하는',
#  '음식',
#  '이',
#  '기분',
#  '따라',
#  '바뀌거든요',
#  '.',
#  '비오는',
#  '날',
#  '은',
#  '부침개',
#  ',',
#  '추운',
#  '날',
#  '은',
#  '뜨끈한',
#  '만두국',
#  ',',
#  '더운',
#  '날',
#  '에',
#  '차가운',
#  '콩국수',
#  ',',
#  '스트레스',
#  '받을',
#  '때',
#  '는',
#  '얼큰한',
#  '떡볶이',
#  ',',
#  '야외',
#  '에서는',
#  '...',
#  '닉네임',
#  '지팡이',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '(',
#  '월욜',
#  '까지',
#  ')',
#  '2007.02',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '좀',
#  '부탁',
#  '해요',
#  '!!!!',
#  '답변',
#  '바랍니다',
#  '한식',
#  '(',
#  '寒食',
#  ':',
#  '동지',
#  '후',
#  '105일',
#  '째',
#  '되는',
#  '날',
#  ')',
#  '한식',
#  '의',
#  '어원',
#  '에',
#  '대해',
#  '서는',
#  '알려진',
#  '바',
#  '가',
#  '...',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어',
#  '야',
#  '한다는',
#  '속',
#  '신',
#  '(',
#  '俗信',
#  ')',
#  '이',
#  '...',
#  '닉네임',
#  'yehr',
#  '****',
#  '질문',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는',
#  '음식',
#  '추천',
#  '!!(',
#  '한식',
#  ')',
#  '2007.08',
#  '.',
#  '04',
#  '.',
#  '질리',
#  '고',
#  '뭔가',
#  '색다른',
#  '것',
#  '먹고싶은데',
#  '뭐',
#  '가',
#  '있을까요',
#  '??',
#  '맛있는',
#  '메뉴',
#  '좀',
#  '추천',
#  '해주세요',
#  '.',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는것',
#  '뜨거운거',
#  '매운건',
#  '싫어요',
#  '~~',
#  '한식',
#  '으로',
#  '추천',
#  '부탁드립니다',
#  '.^^',
#  '답변',
#  '한식',
#  '은',
#  '아니지만',
#  '씨',
#  '푸드',
#  '뷔페',
#  '레스토랑',
#  '어때요',
#  '?',
#  '^',
#  'ㅡ',
#  '^',
#  '해산물',
#  '중',
#  '에서',
#  '장어',
#  ',',
#  '병어',
#  ',',
#  '농어',
#  '...',
#  '▦',
#  '찬',
#  '음식',
#  '에서',
#  '더운',
#  '음식',
#  '으로',
#  '=',
#  '뷔페',
#  '도',
#  '일종',
#  '의',
#  '코스',
#  '요리',
#  '로',
#  '생각',
#  '하고',
#  '음식',
#  '을',
#  '선택',
#  '해야',
#  '...',
#  '질문',
#  '전통',
#  '한식',
#  '상차림',
#  '2019.09',
#  '.',
#  '16',
#  '.',
#  '1',
#  '.',
#  '전통',
#  '한식',
#  '의',
#  '첩',
#  '반상',
#  '(',
#  '3',
#  ',',
#  '5',
#  ',',
#  '7',
#  ',',
#  '9',
#  ',',
#  '12',
#  ')',
#  '과',
#  '반찬',
#  '2',
#  '.',
#  '전통',
#  '밥상',
#  '차림',
#  '어떤',
#  '배열',
#  '을',
#  '하는가',
#  '3',
#  '.',
#  '전통',
#  '상',
#  '에',
#  '죽',
#  '상',
#  ',',
#  '장국상',
#  '주안상',
#  '교자상',
#  '다과상',
#  '등',
#  '이',
#  '것',
#  '들',
#  '좀',
#  '알려주세요',
#  '답변',
#  '숟가락',
#  '은',
#  '뜨거운',
#  '국물',
#  '음식',
#  '이',
#  '발달',
#  '한',
#  '한식',
#  '의',
#  '특성',
#  '에',
#  '잘',
#  '맞는',
#  '도구',
#  '이다',
#  '.',
#  '젓가락',
#  '은',
#  '...',
#  '오른쪽',
#  '에는',
#  '더운',
#  '반찬',
#  '을',
#  '놓아',
#  '오른손',
#  '으로',
#  '집어',
#  '먹기',
#  '편하게',
#  '배려',
#  '한',
#  '것',
#  '이',
#  '재미있다',
#  '....',
#  '닉네임',
#  '골드',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '비',
#  '오는',
#  '날',
#  '2019.08',
#  '.',
#  '06',
#  '.',
#  '아직',
#  '고등학생',
#  '인데',
#  '도',
#  '허리',
#  '랑',
#  '무릎',
#  '이',
#  '안',
#  '좋아서',
#  '평소',
#  '에',
#  '좀',
#  '아픈데',
#  '비',
#  '오는',
#  '날',
#  '에는',
#  '더',
#  '심해',
#  '요',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='비 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='비 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='비 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='비 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='비 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='비 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 93493
# 8224

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 3656),
#  ('이', 3194),
#  ('...', 2927),
#  (',', 1665),
#  ('을', 1554),
#  ('에', 1514),
#  ('땀', 1493),
#  ('음식', 1487),
#  ('답변', 1077),
#  ('질문', 1070),
#  ('를', 1062),
#  ('가', 1003),
#  ('닉네임', 972),
#  ('더운', 939),
#  ('의', 912),
#  ('날', 854),
#  ('은', 785),
#  ('적', 774),
#  ('때', 732),
#  ('으로', 662),
#  ('한', 617),
#  ('에서', 565),
#  ('단어', 531),
#  ('손', 511),
#  ('는', 502),
#  ('비', 499),
#  ('이나', 497),
#  ('하는', 480),
#  ('것', 448),
#  ('인', 445),
#  ('만', 437),
#  ('발', 419),
#  ('(', 417),
#  ('검색', 401),
#  (')', 386),
#  ('도', 381),
#  ('로', 353),
#  ('다한증', 343),
#  ('얼굴', 340),
#  ('?', 329),
#  ('****', 325),
#  ('많이', 324),
#  (':', 321),
#  ('머리', 319),
#  ('먹을', 318),
#  ('보통', 317),
#  ('좀', 316),
#  ('자극', 311),
#  ('임', 309),
#  ('한의사', 307),
#  ('..', 306),
#  ('피부질환', 305),
#  ('나며', 304),
#  ('심하면', 304),
#  ('오듯이', 303),
#  ('은교', 303),
#  ('요', 302),
#  ('입력', 300),
#  ('환경', 300),
#  ('먼저', 300),
#  ('아닌데', 293),
#  ('상황', 292),
#  ('나는지', 292),
#  ('분류', 290),
#  ('과', 289),
#  ('육체', 288),
#  ('들', 283),
#  ('제', 243),
#  ('할', 242),
#  ('나', 230),
#  ('운', 224),
#  ('동남아', 216),
#  ('하세요', 212),
#  ('포함', 208),
#  ('☞', 204),
#  ('너무', 196),
#  ('안', 193),
#  ('입니다', 188),
#  ('다', 182),
#  ('....', 174),
#  ('에는', 167),
#  ('중', 164),
#  ('알려주세요', 163),
#  ('합니다', 162),
#  ('고', 162),
#  ('기', 158),
#  ('여러', 154),
#  ('해서', 153),
#  ('/', 151),
#  ('여행', 151),
#  ('된', 145),
#  ('등', 142),
#  ('날씨', 141),
#  ('개', 140),
#  ('와', 138),
#  ('건강', 138),
#  ('인데', 137),
#  ('1', 135),
#  ('내공', 133),
#  ('3', 128),
#  ('하나', 127),
#  ('사주', 127),
#  ('정도', 125),
#  ('차고', 123),
#  ('사용', 122),
#  ('이상', 121),
#  ('서', 119),
#  ('몸', 116),
#  ('!', 116),
#  ('~', 113),
#  ('저', 110),
#  ('사람', 109),
#  ('곳', 108),
#  ('그', 108),
#  ('될', 106),
#  ('"', 105),
#  ('못', 105),
#  ('나라', 104),
#  ('차례', 104),
#  ('기본', 103),
#  ('본', 103),
#  ('여기', 103),
#  ('정확히', 102),
#  ('문장', 102),
#  ('반드시', 102),
#  ('결과', 102),
#  ('좋아', 102),
#  ('있으니', 102),
#  ('하고', 102),
#  ('잘', 102),
#  ('질병', 102),
#  ('애정', 102),
#  ('상세', 101),
#  ('제외', 101),
#  ('하실', 101),
#  ('구분', 101),
#  ('-', 101),
#  ('여름', 101),
#  ('인한', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('좋은', 100),
#  ('조심하는', 100),
#  ('보입니다', 100),
#  ('클릭', 100),
#  ('수', 99),
#  ('있는', 99),
#  ('필시', 99),
#  ('성공', 99),
#  ('거두게', 99),
#  ('징조', 99),
#  ('아니겠습니까', 99),
#  ('전', 98),
#  ('부터', 97),
#  ('추천', 93),
#  ('치료', 93),
#  ('다른', 93),
#  ('대해', 91),
#  ('전통', 89),
#  ('우리나라', 88),
#  ('생활', 88),
#  ('필리핀', 87),
#  ('분', 87),
#  ('ㅠㅠ', 87),
#  ('그리고', 87),
#  ('2019.10', 85),
#  ('여자', 84),
#  ('한식', 82),
#  ('게', 82),
#  ('놀이', 80),
#  ('가장', 79),
#  ('우리', 77),
#  ('2', 77),
#  ('방법', 77),
#  ('!!', 76),
#  ('꼭', 75),
#  ('4', 74),
#  ('때문', 74),
#  ('안녕하세요', 74),
#  ('부탁드립니다', 73),
#  ('10', 72),
#  ('까지', 72),
#  ('??', 71),
#  ('특히', 70),
#  ('20', 69),
#  ('5', 69),
#  ('옷', 69),
#  ('일', 68),
#  ('또', 68),
#  ('숙제', 68),
#  ('면', 67),
#  ('2019.08', 66),
#  ('명절', 66),
#  ('해', 65),
#  ('겨울', 64),
#  ('에도', 64),
#  ('계절', 63),
#  ('나요', 63),
#  ('말', 61),
#  ('위', 59),
#  ('쪽', 58),
#  ('열', 58),
#  ('찬', 58),
#  ('가지', 58),
#  ('이다', 58),
#  ('2019.09', 57),
#  ('동방', 57),
#  ('점', 56),
#  ('15', 56),
#  ('학년', 56),
#  ('하면', 55),
#  ('16', 55),
#  ('양력', 55),
#  ('옥', 55),
#  ('뭐', 54),
#  ('먹는', 54),
#  ('있습니다', 53),
#  ('어떤', 52),
#  ('방', 52),
#  ('한국', 51),
#  ('시간', 51),
#  ('정말', 51),
#  ('체질', 51),
#  ('여름철', 51),
#  ('14', 50),
#  ('어떻게', 50),
#  ('여', 50),
#  ('ㅠ', 50),
#  ("'", 50),
#  ('해주세요', 49),
#  ('많은', 49),
#  ('생각', 49),
#  ('남자', 49),
#  ('있나요', 49),
#  ('24', 49),
#  ('^^', 48),
#  ('2019.11', 48),
#  ('11', 48),
#  ('밥', 48),
#  ('하지만', 47),
#  ('인가요', 47),
#  ('오는', 47),
#  ('인지', 47),
#  ('하는데', 47),
#  ('05', 46),
#  ('손발', 46),
#  ('30', 46),
#  ('거', 46),
#  ('하여', 46),
#  ('속', 46),
#  ('이고', 45),
#  ('더', 45),
#  ('시원한', 45),
#  ('납니다', 45),
#  ('물', 45),
#  ('뜻', 45),
#  ('속담', 45),
#  ('풀이', 45),
#  ('13', 44),
#  ('에서는', 44),
#  ('조금', 44),
#  ('같은', 44),
#  ('아이', 44),
#  ('운동', 44),
#  ('약', 44),
#  ('예', 44),
#  ('조사', 44),
#  ('호텔', 43),
#  ('29', 43),
#  ('주세요', 43),
#  ('이랑', 43),
#  ('어느', 43),
#  ('빨리', 43),
#  ('맛', 42),
#  ('랑', 41),
#  ('요즘', 41),
#  ('02', 41),
#  ('살', 41),
#  ('편', 41),
#  ('18', 41),
#  ('식', 40),
#  ('지', 40),
#  ('07', 40),
#  ('09', 40),
#  ('관련', 40),
#  ('있다', 40),
#  ('봐주세요', 40),
#  ('종류', 40),
#  ('이라', 39),
#  ('겨드랑이', 39),
#  ('대', 39),
#  ('경우', 39),
#  ('수술', 39),
#  ('17', 39),
#  ('눈', 39),
#  (')...', 39),
#  ('추운', 38),
#  ('하', 38),
#  ('22', 38),
#  ('달', 38),
#  ('한다', 38),
#  ('세계', 38),
#  ('오늘', 37),
#  ('이런', 37),
#  ('부탁', 37),
#  ('그래서', 37),
#  ('25', 37),
#  ('바로', 37),
#  ('병원', 37),
#  ('냉면', 37),
#  ('12', 36),
#  ('하기', 36),
#  ('난', 36),
#  ('보다', 36),
#  ('28', 36),
#  ('2019.12', 36),
#  ('해외', 35),
#  ('무엇', 35),
#  ('아침', 35),
#  ('아', 35),
#  ('8월', 35),
#  ('보다는', 35),
#  ('궁금합니다', 35),
#  ('03', 35),
#  ('23', 35),
#  ('19', 34),
#  ('26', 34),
#  ('04', 34),
#  ('2020.01', 34),
#  ('원래', 34),
#  (']', 34),
#  ('집', 34),
#  ('베트남', 34),
#  ('처럼', 34),
#  ('갑자기', 34),
#  ('뜨거운', 34),
#  ('친구', 34),
#  ('지금', 34),
#  ('질', 34),
#  ('같이', 34),
#  ('기후', 34),
#  ('소', 34),
#  ('나무', 34),
#  ('의미', 34),
#  ('사회', 34),
#  ('에게', 34),
#  ('박', 33),
#  ('현지', 33),
#  ('2020.02', 33),
#  (',,', 33),
#  ('성', 33),
#  ('이번', 33),
#  ('해야', 33),
#  ('신', 33),
#  ('알', 33),
#  ('매운', 33),
#  ('술', 33),
#  ('지역', 32),
#  ('27', 32),
#  ('대표', 32),
#  ('계속', 32),
#  ('2019.07', 32),
#  ('6', 32),
#  ('진짜', 32),
#  ('돌', 32),
#  ('짓', 32),
#  ('우리말', 32),
#  ('있으며', 31),
#  ('왜', 31),
#  ('고민', 31),
#  ('많고', 31),
#  ('태국', 31),
#  ('있는데', 31),
#  ('등등', 31),
#  ('[', 31),
#  ('많아서', 31),
#  ('마소', 31),
#  ('비비는', 31),
#  ('설날', 31),
#  ('음력', 31),
#  ('가옥', 31),
#  ('여행지', 30),
#  ('스트레스', 30),
#  ('준비', 30),
#  ('06', 30),
#  ('걸', 30),
#  ('먹고', 30),
#  ('시작', 30),
#  ('2020.06', 30),
#  ('7월', 30),
#  ('하며', 30),
#  ('01', 30),
#  ('있을까요', 30),
#  ('많아요', 30),
#  ('밖에', 30),
#  ('먹으면', 30),
#  ('순우리말', 30),
#  ('우기', 29),
#  ('맛있는', 29),
#  ('엄청', 29),
#  ('그런', 29),
#  ('1월', 29),
#  ('세', 29),
#  ('부탁드려요', 29),
#  ('지식인', 29),
#  ('중국', 29),
#  ('몇', 29),
#  ('해외여행', 29),
#  ('2월', 29),
#  ('모', 29),
#  ('단오', 29),
#  ('만든', 29),
#  ('결혼', 29),
#  ('드시는', 28),
#  ('비경', 28),
#  ('드립니다', 28),
#  ('구', 28),
#  ('08', 28),
#  ('근데', 28),
#  ('별로', 28),
#  ('학교', 28),
#  ('내', 28),
#  ('되는', 28),
#  ('없이', 28),
#  ('성인', 28),
#  ('채', 27),
#  ('라고', 27),
#  ('증상', 27),
#  ('가족', 27),
#  ('라', 27),
#  ('영향', 27),
#  ('이유', 27),
#  ('21', 27),
#  ('.....', 27),
#  ('및', 27),
#  ('빈', 27),
#  ('법', 27),
#  ('100', 27),
#  ('일이', 27),
#  ('갈', 26),
#  ('뉴욕', 26),
#  ('가봐야', 26),
#  ('오른', 26),
#  ('맛있기는', 26),
#  ('간혹', 26),
#  ('그런데', 26),
#  ('분야', 26),
#  ('남', 26),
#  ('문화', 26),
#  ('후', 26),
#  ('온', 26),
#  ('제발', 26),
#  ('무더운', 26),
#  ('11월', 25),
#  ('타임스', 25),
#  ('선정', 25),
#  ('죽기전에', 25),
#  ('계시는데', 25),
#  ('어디', 25),
#  ('나서', 25),
#  ('그냥', 25),
#  ('먹어', 25),
#  ('오전', 25),
#  ('화', 25),
#  ('따라', 24),
#  ('오후', 24),
#  ('주', 24),
#  ('각', 24),
#  ('에요', 24),
#  ('대로', 24),
#  ('꾼', 24),
#  ('보꾹', 24),
#  ('지붕', 24),
#  ('요리', 24),
#  ('위해', 23),
#  ('엔', 23),
#  ('!!!', 23),
#  ('간', 23),
#  ('주로', 23),
#  ('31', 23),
#  ('얇은', 23),
#  ('특색', 23),
#  ('피하', 23),
#  ('ㅜㅜ', 23),
#  ('입고', 23),
#  ('평소', 22),
#  ('빌라', 22),
#  ('문제', 22),
#  ('않고', 22),
#  ('긴장', 22),
#  ('같아요', 22),
#  ('일본', 22),
#  ('신발', 22),
#  ('늘', 22),
#  ('학생', 22),
#  ('무슨', 22),
#  ('불편한', 22),
#  ('이름', 22),
#  ('글', 22),
#  ('연날리기', 22),
#  ('좋지', 22),
#  ('삼', 22),
#  ('국수', 22),
#  ('짱구', 22),
#  ('또한', 21),
#  ('10월', 21),
#  ('9월', 21),
#  ('걱정', 21),
#  ('싶은데', 21),
#  ('가요', 21),
#  ('발생', 21),
#  ('아주', 21),
#  ('혹시', 21),
#  ('다음', 21),
#  ('이렇게', 21),
#  ('준비물', 21),
#  ('국가', 21),
#  ('지속', 21),
#  ('냄새', 21),
#  ('한의원', 21),
#  ('사진', 21),
#  ('2020.03', 21),
#  ('더위', 21),
#  ('풍속', 21),
#  ('시', 21),
#  ('②', 21),
#  ('월', 21),
#  ('넣어', 21),
#  ('2010.12', 21),
#  ('즐거운', 21),
#  ('보낸다', 21),
#  ('成人の日', 21),
#  ('북한', 21),
#  ('먹던', 21),
#  ('말려', 21),
#  ('일정', 20),
#  ('초', 20),
#  ('명', 20),
#  ('에만', 20),
#  ('2008.04', 20),
#  ('지방', 20),
#  ('말고', 20),
#  ('아니라', 20),
#  ('글자', 20),
#  ('자의', 20),
#  ('효과', 20),
#  ('유래', 20),
#  ('예쁜', 20),
#  ('다시', 20),
#  ('젖고', 20),
#  ('공부', 20),
#  ('이집트', 20),
#  ('기념일', 20),
#  ('이라고', 20),
#  ('먹는다', 20),
#  ('주인', 20),
#  ('the', 20),
#  ('사투리', 20),
#  ('비오는', 19),
#  ('됩니다', 19),
#  ('저희', 19),
#  ('나고', 19),
#  ('잡고', 19),
#  ('없는', 19),
#  ('라면', 19),
#  ('하루', 19),
#  ('이며', 19),
#  ('도와주세요', 19),
#  ('기온', 19),
#  ('2020.04', 19),
#  ('나는데', 19),
#  ('음식점', 19),
#  ('연', 19),
#  ('●', 19),
#  ('겁니다', 19),
#  ('지나가고', 19),
#  ('도래', 19),
#  ('바람', 19),
#  ('평양', 19),
#  ('우산', 19),
#  ('캄보디아', 19),
#  ('조상', 19),
#  ('떡국', 19),
#  ('양', 19),
#  ('미치는', 19),
#  ('4일', 18),
#  ('휴양지', 18),
#  ('시기', 18),
#  ('데', 18),
#  ('6월', 18),
#  ('되도록', 18),
#  ('이구', 18),
#  ('이에요', 18),
#  ('거의', 18),
#  ('또는', 18),
#  ('가을', 18),
#  ('뭘', 18),
#  ('마루', 18),
#  ('모두', 18),
#  ('시키므로', 18),
#  ('있어서', 18),
#  ('세시', 18),
#  ('즐겨', 18),
#  ('해랑', 18),
#  ('올해', 18),
#  ('안나', 18),
#  ('맛집', 18),
#  ('사', 18),
#  ('새벽', 18),
#  ('?...', 18),
#  ('운세', 18),
#  ('음', 18),
#  ('가운데', 18),
#  ('영어', 18),
#  ('미국', 18),
#  ('공간', 18),
#  ('펴야하는', 18),
#  ('찾게', 18),
#  ('되며', 18),
#  ('5일', 17),
#  ('ㅜ', 17),
#  ('까', 17),
#  ('론풀', 17),
#  ('자주', 17),
#  ('푸켓', 17),
#  ('아니고', 17),
#  ('전체', 17),
#  ('신경', 17),
#  ('까요', 17),
#  ('두피', 17),
#  ('증가', 17),
#  ('현재', 17),
#  ('이마', 17),
#  ('제주도', 17),
#  ('여성', 17),
#  ('들어', 17),
#  ('한다는', 17),
#  ('신고', 17),
#  ('고유어', 17),
#  ('내일', 17),
#  ('떡', 17),
#  ('㉢', 17),
#  ('㉣', 17),
#  ('연중', 17),
#  ('2020.07', 16),
#  ('관광', 16),
#  ('해도', 16),
#  ('외국인', 16),
#  ('차', 16),
#  ('사실', 16),
#  ('이면', 16),
#  ('피', 16),
#  ('섭취', 16),
#  ('되면', 16),
#  ('씩', 16),
#  ('항상', 16),
#  ('이용', 16),
#  ('분비', 16),
#  ('달라질', 16),
#  ('오히려', 16),
#  ('의식주', 16),
#  ('소양인', 16),
#  ('되고', 16),
#  ('초등학교', 16),
#  ('상태', 16),
#  ('할까', 16),
#  ('감사하겠습니다', 16),
#  ('알려주시면', 16),
#  ('엄마', 16),
#  ('거든요', 16),
#  ('소개', 16),
#  ('상', 16),
#  ('만드는', 16),
#  ('된다', 16),
#  ('복절', 16),
#  ('운김', 16),
#  ('지역별', 16),
#  ('소음인', 16),
#  ('반', 15),
#  ('심해', 15),
#  ('치안', 15),
#  ('7', 15),
#  ('대부분', 15),
#  ('거나', 15),
#  ('니', 15),
#  ('시험', 15),
#  ('~~', 15),
#  ('가면', 15),
#  ('가는데', 15),
#  ('있고', 15),
#  ('살이', 15),
#  ('있어요', 15),
#  ('대하', 15),
#  ('해결', 15),
#  ('특징', 15),
#  ('할수', 15),
#  ('대한', 15),
#  ('키', 15),
#  ('俗信', 15),
#  ('수족', 15),
#  ('가서', 15),
#  ('온몸', 15),
#  ('얹어', 15),
#  ('나가서', 15),
#  ('쌀', 15),
#  ('급해요', 15),
#  ('보면', 15),
#  ('김치', 15),
#  ('먹지', 15),
#  ('ag', 15),
#  ('염', 15),
#  ('부엌', 15),
#  ('ethn', 15),
#  ('차거운', 15),
#  ('좋아해', 15),
#  ('계획', 14),
#  ('보고', 14),
#  ('가진', 14),
#  ('12월', 14),
#  ('모든', 14),
#  ('샤워', 14),
#  ('경험', 14),
#  ('하게', 14),
#  ('같은거', 14),
#  ('죠', 14),
#  ('ㅋㅋ', 14),
#  (';;', 14),
#  ('......', 14),
#  ('처음', 14),
#  ('두', 14),
#  ('사이', 14),
#  ('하나요', 14),
#  ('어렸을', 14),
#  ('과일', 14),
#  ('피부', 14),
#  ('부지런해야', 14),
#  ('30분', 14),
#  ('불', 14),
#  ('정보', 14),
#  ('문', 14),
#  ('궁합', 14),
#  ('자세히', 14),
#  ('선생님', 14),
#  ('고유', 14),
#  ('프랑스', 14),
#  ('한겨울', 14),
#  ('되었을', 14),
#  ('하였습니다', 14),
#  ('중순', 13),
#  ('만두국', 13),
#  ('티', 13),
#  ('만들어', 13),
#  ('괜찮아서', 13),
#  ('관광객', 13),
#  ('주의', 13),
#  ('식사', 13),
#  ('좋습니다', 13),
#  ('유독', 13),
#  ('쉽게', 13),
#  ('한번', 13),
#  ('님', 13),
#  ('제일', 13),
#  ('5월', 13),
#  ('1일', 13),
#  ('좋아하는', 13),
#  ('하려고', 13),
#  ('여학생', 13),
#  ('일단', 13),
#  ('폰', 13),
#  ('있으면', 13),
#  ('맞는', 13),
#  ('먹어야', 13),
#  ('날짜', 13),
#  ('적어주세요', 13),
#  ('50', 13),
#  ('민간', 13),
#  ('재료', 13),
#  ('4월', 13),
#  ('막', 13),
#  ('8', 13),
#  ('건선', 13),
#  ('없나요', 13),
#  ('내내', 13),
#  ('아름다운', 13),
#  ('~!', 13),
#  ('나와', 13),
#  ('방학', 13),
#  ('틀림없다', 13),
#  ('구차한', 13),
#  ('변명', 13),
#  ('잘못', 13),
#  ('추석', 13),
#  ('패키지', 12),
#  ('쯤', 12),
#  ('휴양', 12),
#  ('자유롭게', 12),
#  ('라서', 12),
#  ('수도', 12),
#  ('+', 12),
#  ('예정', 12),
#  ('약간', 12),
#  ('에어컨', 12),
#  ('배', 12),
#  ('입', 12),
#  ('발달', 12),
#  ('언제', 12),
#  ('알려', 12),
#  ('돈', 12),
#  ('싶습니다', 12),
#  ('병', 12),
#  ('동안', 12),
#  ('삼계탕', 12),
#  ('란', 12),
#  ('새', 12),
#  ('물론', 12),
#  ('보신', 12),
#  ('덥지', 12),
#  ('께서', 12),
#  ('먹거리', 12),
#  ('거리', 12),
#  ('큰', 12),
#  ('장만', 12),
#  ('순간', 12),
#  ('필수', 12),
#  ('전통의상', 12),
#  ('관', 12),
#  ('직업', 12),
#  ('인데요', 12),
#  ('번', 12),
#  ('채택', 12),
#  ('2009.04', 12),
#  ('6일', 12),
#  ('감사합니다', 12),
#  ('야', 12),
#  ('최', 12),
#  ('보고서', 12),
#  ('차가운', 11),
#  ('일반', 11),
#  ('자유여행', 11),
#  ('가능한', 11),
#  ('다양한', 11),
#  ('문의', 11),
#  ('설명', 11),
#  ('햇볕', 11),
#  ('첫', 11),
#  ('없고', 11),
#  ('오', 11),
#  ('이라서', 11),
#  ('바', 11),
#  ('10분', 11),
#  ('그것', 11),
#  ('->', 11),
#  ('우선', 11),
#  ('따라서', 11),
#  ('2008.03', 11),
#  ('덜', 11),
#  ('값', 11),
#  ('^', 11),
#  ('나기', 11),
#  ('뿐', 11),
#  ('10일', 11),
#  ('자', 11),
#  ('많습니다', 11),
#  ('게임', 11),
#  ('절기', 11),
#  ('있어', 11),
#  ('핸드폰', 11),
#  ('줄줄', 11),
#  ('왕초', 11),
#  ('겨땀', 11),
#  ('최대한', 11),
#  ('가위', 11),
#  ('가야', 11),
#  ('제목', 11),
#  ('편이', 11),
#  ('부분', 11),
#  ('땐', 11),
#  ('건가', 11),
#  ('한약', 11),
#  ('11시', 11),
#  ('ㅠㅠㅠ', 11),
#  ('즉', 11),
#  ('삼복', 11),
#  ('올려주세요', 11),
#  ('고추장', 11),
#  ('세찬', 11),
#  ('행사', 11),
#  ('서울', 11),
#  ('식목일', 11),
#  ('_', 11),
#  ('변비', 11),
#  ('0', 11),
#  ('이지만', 11),
#  ('ocam', 11),
#  ('ㅇ', 11),
#  ('정선', 11),
#  ('위주', 10),
#  ('혼자', 10),
#  ('아직', 10),
#  ('힘', 10),
#  ('신혼여행', 10),
#  ('있는데요', 10),
#  ('에서도', 10),
#  ('하는데요', 10),
#  ('알고싶어요', 10),
#  ('오면', 10),
#  ('아래', 10),
#  ('내리는', 10),
#  ('같습니다', 10),
#  ('보', 10),
#  ('그렇게', 10),
#  ('네', 10),
#  ('뚝뚝', 10),
#  ('어릴', 10),
#  ('비해', 10),
#  ('유럽', 10),
#  ('하던데', 10),
#  ('먹기', 10),
#  ('오지', 10),
#  ('저녁', 10),
#  ('전신', 10),
#  ('앞', 10),
#  ('심하게', 10),
#  ('안면', 10),
#  ('러시아', 10),
#  ('있는지', 10),
#  ('많은데', 10),
#  ('되나요', 10),
#  ('심해서', 10),
#  ('비용', 10),
#  ('클', 10),
#  ('한테', 10),
#  ('년', 10),
#  ('아닌', 10),
#  ('온도', 10),
#  ('가만히', 10),
#  ('a', 10),
#  ('뒤', 10),
#  ('제사', 10),
#  ('54', 10),
#  ('노래', 10),
#  ('조부', 10),
#  ('할아버지', 10),
#  ('준결승', 10),
#  ('하시는', 10),
#  ('단', 10),
#  ('역사', 10),
#  ('잠깐', 10),
#  ('임신', 10),
#  ('두꺼운', 10),
#  ('빨리요', 10),
#  ('태어난', 10),
#  ('2007.06', 10),
#  ('될까', 10),
#  ('대만', 10),
#  ('마시면', 10),
#  ('2007.04', 10),
#  ('방언', 10),
#  ('생', 10),
#  ('가르쳐', 10),
#  ('중복', 10),
#  ('말복', 10),
#  ('가리켜', 10),
#  ('순', 10),
#  ('감사', 10),
#  ('동지', 10),
#  ('7시', 10),
#  ('환전', 10),
#  ('과학', 10),
#  ('대보름날', 10),
#  ('메뉴', 9),
#  ('성질', 9),
#  ('좋을까요', 9),
#  ('물가', 9),
#  ('죽', 9),
#  ('평생', 9),
#  ('낮', 9),
#  ('한의학', 9),
#  ('보니', 9),
#  ('기간', 9),
#  ('얼마나', 9),
#  ('비행기', 9),
#  ('아니면', 9),
#  ('고생', 9),
#  ('니까', 9),
#  ('용', 9),
#  ('감기', 9),
#  ('이제', 9),
#  ('장마', 9),
#  ('엉덩이', 9),
#  ('3일', 9),
#  ('습도', 9),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='비 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='비 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='비 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='비 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='비 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='비 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [('땀', 1493),
#  ('음식', 1487),
#  ('닉네임', 972),
#  ('더운', 939),
#  ('날', 854),
#  ('적', 774),
#  ('에서', 565),
#  ('손', 511),
#  ('비', 499),
#  ('이나', 497),
#  ('인', 445),
#  ('만', 437),
#  ('발', 419),
#  ('(', 417),
#  ('검색', 401),
#  (')', 386),
#  ('다한증', 343),
#  ('얼굴', 340),
#  ('****', 325),
#  ('많이', 324),
#  (':', 321),
#  ('머리', 319),
#  ('먹을', 318),
#  ('보통', 317),
#  ('자극', 311),
#  ('임', 309),
#  ('한의사', 307),
#  ('피부질환', 305),
#  ('나며', 304),
#  ('심하면', 304),
#  ('오듯이', 303),
#  ('은교', 303),
#  ('입력', 300),
#  ('환경', 300),
#  ('먼저', 300),
#  ('아닌데', 293),
#  ('상황', 292),
#  ('나는지', 292),
#  ('분류', 290),
#  ('육체', 288),
#  ('나', 230),
#  ('운', 224),
#  ('동남아', 216),
#  ('하세요', 212),
#  ('포함', 208),
#  ('☞', 204),
#  ('너무', 196),
#  ('안', 193),
#  ('입니다', 188),
#  ('에는', 167),
#  ('알려주세요', 163),
#  ('합니다', 162),
#  ('기', 158),
#  ('여러', 154),
#  ('해서', 153),
#  ('/', 151),
#  ('여행', 151),
#  ('된', 145),
#  ('등', 142),
#  ('날씨', 141),
#  ('개', 140),
#  ('와', 138),
#  ('건강', 138),
#  ('내공', 133),
#  ('3', 128),
#  ('사주', 127),
#  ('정도', 125),
#  ('차고', 123),
#  ('사용', 122),
#  ('서', 119),
#  ('몸', 116),
#  ('!', 116),
#  ('저', 110),
#  ('사람', 109),
#  ('곳', 108),
#  ('그', 108),
#  ('될', 106),
#  ('"', 105),
#  ('나라', 104),
#  ('차례', 104),
#  ('본', 103),
#  ('여기', 103),
#  ('정확히', 102),
#  ('문장', 102),
#  ('반드시', 102),
#  ('결과', 102),
#  ('좋아', 102),
#  ('있으니', 102),
#  ('하고', 102),
#  ('질병', 102),
#  ('애정', 102),
#  ('상세', 101),
#  ('제외', 101),
#  ('하실', 101),
#  ('구분', 101),
#  ('-', 101),
#  ('여름', 101),
#  ('인한', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('좋은', 100),
#  ('조심하는', 100),
#  ('보입니다', 100),
#  ('클릭', 100),
#  ('필시', 99),
#  ('성공', 99),
#  ('거두게', 99),
#  ('징조', 99),
#  ('아니겠습니까', 99),
#  ('전', 98),
#  ('부터', 97),
#  ('추천', 93),
#  ('치료', 93),
#  ('다른', 93),
#  ('대해', 91),
#  ('전통', 89),
#  ('우리나라', 88),
#  ('생활', 88),
#  ('필리핀', 87),
#  ('분', 87),
#  ('ㅠㅠ', 87),
#  ('그리고', 87),
#  ('2019.10', 85),
#  ('여자', 84),
#  ('한식', 82),
#  ('놀이', 80),
#  ('가장', 79),
#  ('우리', 77),
#  ('방법', 77),
#  ('꼭', 75),
#  ('4', 74),
#  ('때문', 74),
#  ('안녕하세요', 74),
#  ('부탁드립니다', 73),
#  ('까지', 72),
#  ('??', 71),
#  ('특히', 70),
#  ('5', 69),
#  ('옷', 69),
#  ('또', 68),
#  ('숙제', 68),
#  ('면', 67),
#  ('2019.08', 66),
#  ('명절', 66),
#  ('해', 65),
#  ('겨울', 64),
#  ('에도', 64),
#  ('계절', 63),
#  ('나요', 63),
#  ('말', 61),
#  ('위', 59),
#  ('쪽', 58),
#  ('열', 58),
#  ('찬', 58),
#  ('가지', 58),
#  ('이다', 58),
#  ('2019.09', 57),
#  ('동방', 57),
#  ('점', 56),
#  ('15', 56),
#  ('학년', 56),
#  ('하면', 55),
#  ('16', 55),
#  ('양력', 55),
#  ('옥', 55),
#  ('먹는', 54),
#  ('있습니다', 53),
#  ('방', 52),
#  ('한국', 51),
#  ('시간', 51),
#  ('정말', 51),
#  ('체질', 51),
#  ('여름철', 51),
#  ('14', 50),
#  ('어떻게', 50),
#  ('여', 50),
#  ('ㅠ', 50),
#  ("'", 50),
#  ('해주세요', 49),
#  ('많은', 49),
#  ('생각', 49),
#  ('남자', 49),
#  ('있나요', 49),
#  ('24', 49),
#  ('^^', 48),
#  ('2019.11', 48),
#  ('11', 48),
#  ('밥', 48),
#  ('하지만', 47),
#  ('인가요', 47),
#  ('오는', 47),
#  ('인지', 47),
#  ('하는데', 47),
#  ('05', 46),
#  ('손발', 46),
#  ('30', 46),
#  ('하여', 46),
#  ('속', 46),
#  ('이고', 45),
#  ('더', 45),
#  ('시원한', 45),
#  ('납니다', 45),
#  ('물', 45),
#  ('뜻', 45),
#  ('속담', 45),
#  ('풀이', 45),
#  ('13', 44),
#  ('에서는', 44),
#  ('조금', 44),
#  ('같은', 44),
#  ('아이', 44),
#  ('운동', 44),
#  ('약', 44),
#  ('예', 44),
#  ('조사', 44),
#  ('호텔', 43),
#  ('29', 43),
#  ('주세요', 43),
#  ('이랑', 43),
#  ('어느', 43),
#  ('빨리', 43),
#  ('맛', 42),
#  ('랑', 41),
#  ('요즘', 41),
#  ('02', 41),
#  ('살', 41),
#  ('편', 41),
#  ('18', 41),
#  ('식', 40),
#  ('07', 40),
#  ('09', 40),
#  ('관련', 40),
#  ('있다', 40),
#  ('봐주세요', 40),
#  ('종류', 40),
#  ('이라', 39),
#  ('겨드랑이', 39),
#  ('경우', 39),
#  ('수술', 39),
#  ('17', 39),
#  ('눈', 39),
#  (')...', 39),
#  ('추운', 38),
#  ('하', 38),
#  ('22', 38),
#  ('달', 38),
#  ('한다', 38),
#  ('세계', 38),
#  ('오늘', 37),
#  ('이런', 37),
#  ('부탁', 37),
#  ('그래서', 37),
#  ('25', 37),
#  ('바로', 37),
#  ('병원', 37),
#  ('냉면', 37),
#  ('12', 36),
#  ('하기', 36),
#  ('난', 36),
#  ('보다', 36),
#  ('28', 36),
#  ('2019.12', 36),
#  ('해외', 35),
#  ('무엇', 35),
#  ('아침', 35),
#  ('아', 35),
#  ('8월', 35),
#  ('보다는', 35),
#  ('궁금합니다', 35),
#  ('03', 35),
#  ('23', 35),
#  ('19', 34),
#  ('26', 34),
#  ('04', 34),
#  ('2020.01', 34),
#  ('원래', 34),
#  (']', 34),
#  ('집', 34),
#  ('베트남', 34),
#  ('처럼', 34),
#  ('갑자기', 34),
#  ('뜨거운', 34),
#  ('친구', 34),
#  ('지금', 34),
#  ('질', 34),
#  ('같이', 34),
#  ('기후', 34),
#  ('소', 34),
#  ('나무', 34),
#  ('의미', 34),
#  ('사회', 34),
#  ('에게', 34),
#  ('박', 33),
#  ('현지', 33),
#  ('2020.02', 33),
#  (',,', 33),
#  ('성', 33),
#  ('이번', 33),
#  ('해야', 33),
#  ('신', 33),
#  ('알', 33),
#  ('매운', 33),
#  ('술', 33),
#  ('지역', 32),
#  ('27', 32),
#  ('대표', 32),
#  ('계속', 32),
#  ('2019.07', 32),
#  ('진짜', 32),
#  ('돌', 32),
#  ('짓', 32),
#  ('우리말', 32),
#  ('있으며', 31),
#  ('왜', 31),
#  ('고민', 31),
#  ('많고', 31),
#  ('태국', 31),
#  ('있는데', 31),
#  ('등등', 31),
#  ('[', 31),
#  ('많아서', 31),
#  ('마소', 31),
#  ('비비는', 31),
#  ('설날', 31),
#  ('음력', 31),
#  ('가옥', 31),
#  ('여행지', 30),
#  ('스트레스', 30),
#  ('준비', 30),
#  ('걸', 30),
#  ('먹고', 30),
#  ('시작', 30),
#  ('2020.06', 30),
#  ('7월', 30),
#  ('하며', 30),
#  ('01', 30),
#  ('있을까요', 30),
#  ('많아요', 30),
#  ('밖에', 30),
#  ('먹으면', 30),
#  ('순우리말', 30),
#  ('우기', 29),
#  ('맛있는', 29),
#  ('엄청', 29),
#  ('그런', 29),
#  ('1월', 29),
#  ('세', 29),
#  ('부탁드려요', 29),
#  ('지식인', 29),
#  ('중국', 29),
#  ('몇', 29),
#  ('해외여행', 29),
#  ('2월', 29),
#  ('모', 29),
#  ('단오', 29),
#  ('만든', 29),
#  ('결혼', 29),
#  ('드시는', 28),
#  ('비경', 28),
#  ('드립니다', 28),
#  ('구', 28),
#  ('08', 28),
#  ('근데', 28),
#  ('별로', 28),
#  ('학교', 28),
#  ('내', 28),
#  ('되는', 28),
#  ('없이', 28),
#  ('성인', 28),
#  ('채', 27),
#  ('증상', 27),
#  ('가족', 27),
#  ('라', 27),
#  ('영향', 27),
#  ('이유', 27),
#  ('21', 27),
#  ('.....', 27),
#  ('및', 27),
#  ('빈', 27),
#  ('법', 27),
#  ('100', 27),
#  ('일이', 27),
#  ('갈', 26),
#  ('뉴욕', 26),
#  ('가봐야', 26),
#  ('오른', 26),
#  ('맛있기는', 26),
#  ('간혹', 26),
#  ('그런데', 26),
#  ('분야', 26),
#  ('남', 26),
#  ('문화', 26),
#  ('온', 26),
#  ('제발', 26),
#  ('무더운', 26),
#  ('11월', 25),
#  ('타임스', 25),
#  ('선정', 25),
#  ('죽기전에', 25),
#  ('계시는데', 25),
#  ('어디', 25),
#  ('나서', 25),
#  ('그냥', 25),
#  ('먹어', 25),
#  ('오전', 25),
#  ('화', 25),
#  ('따라', 24),
#  ('오후', 24),
#  ('각', 24),
#  ('에요', 24),
#  ('대로', 24),
#  ('꾼', 24),
#  ('보꾹', 24),
#  ('지붕', 24),
#  ('요리', 24),
#  ('위해', 23),
#  ('엔', 23),
#  ('!!!', 23),
#  ('간', 23),
#  ('주로', 23),
#  ('31', 23),
#  ('얇은', 23),
#  ('특색', 23),
#  ('피하', 23),
#  ('ㅜㅜ', 23),
#  ('입고', 23),
#  ('평소', 22),
#  ('빌라', 22),
#  ('문제', 22),
#  ('않고', 22),
#  ('긴장', 22),
#  ('같아요', 22),
#  ('일본', 22),
#  ('신발', 22),
#  ('늘', 22),
#  ('학생', 22),
#  ('무슨', 22),
#  ('불편한', 22),
#  ('이름', 22),
#  ('글', 22),
#  ('연날리기', 22),
#  ('좋지', 22),
#  ('삼', 22),
#  ('국수', 22),
#  ('짱구', 22),
#  ('또한', 21),
#  ('10월', 21),
#  ('9월', 21),
#  ('걱정', 21),
#  ('싶은데', 21),
#  ('발생', 21),
#  ('아주', 21),
#  ('혹시', 21),
#  ('다음', 21),
#  ('이렇게', 21),
#  ('준비물', 21),
#  ('국가', 21),
#  ('지속', 21),
#  ('냄새', 21),
#  ('한의원', 21),
#  ('사진', 21),
#  ('2020.03', 21),
#  ('더위', 21),
#  ('풍속', 21),
#  ('시', 21),
#  ('②', 21),
#  ('월', 21),
#  ('넣어', 21),
#  ('2010.12', 21),
#  ('즐거운', 21),
#  ('보낸다', 21),
#  ('成人の日', 21),
#  ('북한', 21),
#  ('먹던', 21),
#  ('말려', 21),
#  ('일정', 20),
#  ('초', 20),
#  ('명', 20),
#  ('에만', 20),
#  ('2008.04', 20),
#  ('지방', 20),
#  ('말고', 20),
#  ('아니라', 20),
#  ('글자', 20),
#  ('자의', 20),
#  ('효과', 20),
#  ('유래', 20),
#  ('예쁜', 20),
#  ('다시', 20),
#  ('젖고', 20),
#  ('공부', 20),
#  ('이집트', 20),
#  ('기념일', 20),
#  ('이라고', 20),
#  ('먹는다', 20),
#  ('주인', 20),
#  ('the', 20),
#  ('사투리', 20),
#  ('비오는', 19),
#  ('됩니다', 19),
#  ('저희', 19),
#  ('나고', 19),
#  ('잡고', 19),
#  ('없는', 19),
#  ('라면', 19),
#  ('하루', 19),
#  ('이며', 19),
#  ('도와주세요', 19),
#  ('기온', 19),
#  ('2020.04', 19),
#  ('나는데', 19),
#  ('음식점', 19),
#  ('연', 19),
#  ('●', 19),
#  ('겁니다', 19),
#  ('지나가고', 19),
#  ('도래', 19),
#  ('바람', 19),
#  ('평양', 19),
#  ('우산', 19),
#  ('캄보디아', 19),
#  ('조상', 19),
#  ('떡국', 19),
#  ('양', 19),
#  ('미치는', 19),
#  ('4일', 18),
#  ('휴양지', 18),
#  ('시기', 18),
#  ('6월', 18),
#  ('되도록', 18),
#  ('이구', 18),
#  ('이에요', 18),
#  ('거의', 18),
#  ('또는', 18),
#  ('가을', 18),
#  ('뭘', 18),
#  ('마루', 18),
#  ('모두', 18),
#  ('시키므로', 18),
#  ('있어서', 18),
#  ('세시', 18),
#  ('즐겨', 18),
#  ('해랑', 18),
#  ('올해', 18),
#  ('안나', 18),
#  ('맛집', 18),
#  ('사', 18),
#  ('새벽', 18),
#  ('?...', 18),
#  ('운세', 18),
#  ('음', 18),
#  ('가운데', 18),
#  ('영어', 18),
#  ('미국', 18),
#  ('공간', 18),
#  ('펴야하는', 18),
#  ('찾게', 18),
#  ('되며', 18),
#  ('5일', 17),
#  ('ㅜ', 17),
#  ('론풀', 17),
#  ('자주', 17),
#  ('푸켓', 17),
#  ('아니고', 17),
#  ('전체', 17),
#  ('신경', 17),
#  ('까요', 17),
#  ('두피', 17),
#  ('증가', 17),
#  ('현재', 17),
#  ('이마', 17),
#  ('제주도', 17),
#  ('여성', 17),
#  ('들어', 17),
#  ('한다는', 17),
#  ('신고', 17),
#  ('고유어', 17),
#  ('내일', 17),
#  ('떡', 17),
#  ('㉢', 17),
#  ('㉣', 17),
#  ('연중', 17),
#  ('2020.07', 16),
#  ('관광', 16),
#  ('해도', 16),
#  ('외국인', 16),
#  ('차', 16),
#  ('사실', 16),
#  ('이면', 16),
#  ('피', 16),
#  ('섭취', 16),
#  ('되면', 16),
#  ('씩', 16),
#  ('항상', 16),
#  ('이용', 16),
#  ('분비', 16),
#  ('달라질', 16),
#  ('오히려', 16),
#  ('의식주', 16),
#  ('소양인', 16),
#  ('되고', 16),
#  ('초등학교', 16),
#  ('상태', 16),
#  ('할까', 16),
#  ('감사하겠습니다', 16),
#  ('알려주시면', 16),
#  ('엄마', 16),
#  ('거든요', 16),
#  ('소개', 16),
#  ('상', 16),
#  ('만드는', 16),
#  ('된다', 16),
#  ('복절', 16),
#  ('운김', 16),
#  ('지역별', 16),
#  ('소음인', 16),
#  ('반', 15),
#  ('심해', 15),
#  ('치안', 15),
#  ('7', 15),
#  ('대부분', 15),
#  ('거나', 15),
#  ('니', 15),
#  ('시험', 15),
#  ('~~', 15),
#  ('가면', 15),
#  ('가는데', 15),
#  ('있고', 15),
#  ('살이', 15),
#  ('있어요', 15),
#  ('대하', 15),
#  ('해결', 15),
#  ('특징', 15),
#  ('할수', 15),
#  ('대한', 15),
#  ('키', 15),
#  ('俗信', 15),
#  ('수족', 15),
#  ('가서', 15),
#  ('온몸', 15),
#  ('얹어', 15),
#  ('나가서', 15),
#  ('쌀', 15),
#  ('급해요', 15),
#  ('보면', 15),
#  ('김치', 15),
#  ('먹지', 15),
#  ('ag', 15),
#  ('염', 15),
#  ('부엌', 15),
#  ('ethn', 15),
#  ('차거운', 15),
#  ('좋아해', 15),
#  ('계획', 14),
#  ('보고', 14),
#  ('가진', 14),
#  ('12월', 14),
#  ('모든', 14),
#  ('샤워', 14),
#  ('경험', 14),
#  ('하게', 14),
#  ('같은거', 14),
#  ('죠', 14),
#  ('ㅋㅋ', 14),
#  (';;', 14),
#  ('......', 14),
#  ('처음', 14),
#  ('두', 14),
#  ('사이', 14),
#  ('하나요', 14),
#  ('어렸을', 14),
#  ('과일', 14),
#  ('피부', 14),
#  ('부지런해야', 14),
#  ('30분', 14),
#  ('불', 14),
#  ('정보', 14),
#  ('문', 14),
#  ('궁합', 14),
#  ('자세히', 14),
#  ('선생님', 14),
#  ('고유', 14),
#  ('프랑스', 14),
#  ('한겨울', 14),
#  ('되었을', 14),
#  ('하였습니다', 14),
#  ('중순', 13),
#  ('만두국', 13),
#  ('티', 13),
#  ('만들어', 13),
#  ('괜찮아서', 13),
#  ('관광객', 13),
#  ('주의', 13),
#  ('식사', 13),
#  ('좋습니다', 13),
#  ('유독', 13),
#  ('쉽게', 13),
#  ('한번', 13),
#  ('님', 13),
#  ('제일', 13),
#  ('5월', 13),
#  ('1일', 13),
#  ('좋아하는', 13),
#  ('하려고', 13),
#  ('여학생', 13),
#  ('일단', 13),
#  ('폰', 13),
#  ('있으면', 13),
#  ('맞는', 13),
#  ('먹어야', 13),
#  ('날짜', 13),
#  ('적어주세요', 13),
#  ('50', 13),
#  ('민간', 13),
#  ('재료', 13),
#  ('4월', 13),
#  ('막', 13),
#  ('8', 13),
#  ('건선', 13),
#  ('없나요', 13),
#  ('내내', 13),
#  ('아름다운', 13),
#  ('~!', 13),
#  ('나와', 13),
#  ('방학', 13),
#  ('틀림없다', 13),
#  ('구차한', 13),
#  ('변명', 13),
#  ('잘못', 13),
#  ('추석', 13),
#  ('패키지', 12),
#  ('쯤', 12),
#  ('휴양', 12),
#  ('자유롭게', 12),
#  ('라서', 12),
#  ('수도', 12),
#  ('+', 12),
#  ('예정', 12),
#  ('약간', 12),
#  ('에어컨', 12),
#  ('배', 12),
#  ('입', 12),
#  ('발달', 12),
#  ('언제', 12),
#  ('알려', 12),
#  ('돈', 12),
#  ('싶습니다', 12),
#  ('병', 12),
#  ('동안', 12),
#  ('삼계탕', 12),
#  ('란', 12),
#  ('새', 12),
#  ('물론', 12),
#  ('보신', 12),
#  ('덥지', 12),
#  ('께서', 12),
#  ('먹거리', 12),
#  ('거리', 12),
#  ('큰', 12),
#  ('장만', 12),
#  ('순간', 12),
#  ('필수', 12),
#  ('전통의상', 12),
#  ('관', 12),
#  ('직업', 12),
#  ('인데요', 12),
#  ('번', 12),
#  ('채택', 12),
#  ('2009.04', 12),
#  ('6일', 12),
#  ('감사합니다', 12),
#  ('야', 12),
#  ('최', 12),
#  ('보고서', 12),
#  ('차가운', 11),
#  ('일반', 11),
#  ('자유여행', 11),
#  ('가능한', 11),
#  ('다양한', 11),
#  ('문의', 11),
#  ('설명', 11),
#  ('햇볕', 11),
#  ('첫', 11),
#  ('없고', 11),
#  ('오', 11),
#  ('이라서', 11),
#  ('바', 11),
#  ('10분', 11),
#  ('그것', 11),
#  ('->', 11),
#  ('우선', 11),
#  ('따라서', 11),
#  ('2008.03', 11),
#  ('덜', 11),
#  ('값', 11),
#  ('^', 11),
#  ('나기', 11),
#  ('뿐', 11),
#  ('10일', 11),
#  ('자', 11),
#  ('많습니다', 11),
#  ('게임', 11),
#  ('절기', 11),
#  ('있어', 11),
#  ('핸드폰', 11),
#  ('줄줄', 11),
#  ('왕초', 11),
#  ('겨땀', 11),
#  ('최대한', 11),
#  ('가위', 11),
#  ('가야', 11),
#  ('제목', 11),
#  ('편이', 11),
#  ('부분', 11),
#  ('땐', 11),
#  ('건가', 11),
#  ('한약', 11),
#  ('11시', 11),
#  ('ㅠㅠㅠ', 11),
#  ('즉', 11),
#  ('삼복', 11),
#  ('올려주세요', 11),
#  ('고추장', 11),
#  ('세찬', 11),
#  ('행사', 11),
#  ('서울', 11),
#  ('식목일', 11),
#  ('_', 11),
#  ('변비', 11),
#  ('0', 11),
#  ('이지만', 11),
#  ('ocam', 11),
#  ('ㅇ', 11),
#  ('정선', 11),
#  ('위주', 10),
#  ('혼자', 10),
#  ('아직', 10),
#  ('힘', 10),
#  ('신혼여행', 10),
#  ('있는데요', 10),
#  ('에서도', 10),
#  ('하는데요', 10),
#  ('알고싶어요', 10),
#  ('오면', 10),
#  ('아래', 10),
#  ('내리는', 10),
#  ('같습니다', 10),
#  ('보', 10),
#  ('그렇게', 10),
#  ('뚝뚝', 10),
#  ('어릴', 10),
#  ('비해', 10),
#  ('유럽', 10),
#  ('하던데', 10),
#  ('먹기', 10),
#  ('오지', 10),
#  ('저녁', 10),
#  ('전신', 10),
#  ('앞', 10),
#  ('심하게', 10),
#  ('안면', 10),
#  ('러시아', 10),
#  ('있는지', 10),
#  ('많은데', 10),
#  ('되나요', 10),
#  ('심해서', 10),
#  ('비용', 10),
#  ('클', 10),
#  ('한테', 10),
#  ('년', 10),
#  ('아닌', 10),
#  ('온도', 10),
#  ('가만히', 10),
#  ('a', 10),
#  ('뒤', 10),
#  ('제사', 10),
#  ('54', 10),
#  ('노래', 10),
#  ('조부', 10),
#  ('할아버지', 10),
#  ('준결승', 10),
#  ('하시는', 10),
#  ('단', 10),
#  ('역사', 10),
#  ('잠깐', 10),
#  ('임신', 10),
#  ('두꺼운', 10),
#  ('빨리요', 10),
#  ('태어난', 10),
#  ('2007.06', 10),
#  ('될까', 10),
#  ('대만', 10),
#  ('마시면', 10),
#  ('2007.04', 10),
#  ('방언', 10),
#  ('생', 10),
#  ('가르쳐', 10),
#  ('중복', 10),
#  ('말복', 10),
#  ('가리켜', 10),
#  ('순', 10),
#  ('감사', 10),
#  ('동지', 10),
#  ('7시', 10),
#  ('환전', 10),
#  ('과학', 10),
#  ('대보름날', 10),
#  ('메뉴', 9),
#  ('성질', 9),
#  ('좋을까요', 9),
#  ('물가', 9),
#  ('죽', 9),
#  ('평생', 9),
#  ('낮', 9),
#  ('한의학', 9),
#  ('보니', 9),
#  ('기간', 9),
#  ('얼마나', 9),
#  ('비행기', 9),
#  ('아니면', 9),
#  ('고생', 9),
#  ('니까', 9),
#  ('용', 9),
#  ('감기', 9),
#  ('이제', 9),
#  ('장마', 9),
#  ('엉덩이', 9),
#  ('3일', 9),
#  ('습도', 9),
#  ('흘립니다', 9),
#  ('15일', 9),
#  ('둘', 9),
#  ('로는', 9),
#  ('마다', 9),
#  ('힘들어요', 9),
#  ('인터넷', 9),
#  ('방콕', 9),
#  ('남학생', 9),
#  ('재개', 9),
#  ('아는', 9),
#  ('내용', 9),
#  ('찾아', 9),
#  ('부위', 9),
#  ('kg', 9),
#  ('최근', 9),
#  ('장', 9),
#  ('애', 9),
#  ('실내', 9),
#  ('있어도', 9),
#  ('평균기온', 9),
#  ('전혀', 9),
#  ('자세하게', 9),
#  ('개도', 9),
#  ('목연', 9),
#  ('①', 9),
#  ('흘리는', 9),
#  ('자리', 9),
#  ('창포', 9),
#  (',,,', 9),
#  ('그대로', 9),
#  ('따뜻하게', 9),
#  ('양념', 9),
#  ('음식물', 9),
#  ('원피스', 9),
#  ('했는데', 9),
#  ('받고', 9),
#  ('60', 9),
#  ('주는', 9),
#  ('금', 9),
#  ('여서', 9),
#  ('강아지', 9),
#  ('이쁜', 9),
#  ('지내는', 9),
#  ('이라는', 9),
#  ('갈증', 9),
#  ('먹었다', 9),
#  ('국기', 9),
#  ('여러가지', 9),
#  ('초복', 9),
#  ('담', 9),
#  ('구름', 9),
#  ('장국', 9),
#  ('끓이기도', 9),
#  ('가자미', 9),
#  ('무쳐서', 9),
#  ('밑', 9),
#  ('유명한', 9),
#  ('한여름', 9),
#  ('탈', 9),
#  ('℃', 9),
#  ('교차', 9),
#  ('산', 9),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 774 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 776 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 863 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 41155 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 778 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 39118 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 39277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20040 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21834 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35831 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21543 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32461 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33410 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20010 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27185 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 774 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 776 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 863 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 41155 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 778 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 39118 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 39277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20040 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21834 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35831 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21543 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32461 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33410 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20010 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27185 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
