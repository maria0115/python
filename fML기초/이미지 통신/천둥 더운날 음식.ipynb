# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('천둥 더운 날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('천둥 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('천둥 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('천둥 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('천둥 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('천둥 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '날',
#  '먹는',
#  '음식',
#  '좀',
#  '가르쳐',
#  '주세요',
#  '.',
#  '2003.09',
#  '.',
#  '07',
#  '.',
#  '한식',
#  '날',
#  '에',
#  '먹는',
#  '음식',
#  '중',
#  '에는',
#  '어떤',
#  '것',
#  '들',
#  '이',
#  '있나요',
#  '?',
#  '오늘',
#  '안',
#  '에',
#  '해야',
#  '합니다',
#  '.',
#  '꼭',
#  '좀',
#  '부탁',
#  '드립니다',
#  '.',
#  '답변',
#  '이',
#  '날',
#  '농가',
#  '에서는',
#  '나무',
#  '를',
#  '심거나',
#  '채소',
#  '씨',
#  '를',
#  '뿌리',
#  '며',
#  '...',
#  '찬',
#  '음식',
#  '(',
#  '한식',
#  '(',
#  '寒食',
#  '))',
#  '을',
#  '먹는다',
#  '한다',
#  '.',
#  '이',
#  '하나',
#  '의',
#  '불',
#  '로써',
#  '온',
#  '...',
#  '한식',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '만',
#  '아니라',
#  '나라',
#  '에도',
#  '...',
#  '닉네임',
#  'drg',
#  '8',
#  '****',
#  '질문',
#  '2013년',
#  '한식',
#  '날',
#  '2013.01',
#  '.',
#  '02',
#  '.',
#  '저기',
#  '한식',
#  '날',
#  '날짜',
#  '가',
#  '어떻게',
#  '되나요',
#  '??',
#  '인터넷',
#  '찾아봐도',
#  '없어서요',
#  '.......',
#  '자세하게',
#  '답좀',
#  '해주세요',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '...',
#  '또',
#  '한식',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '아니라',
#  '나라',
#  '에도',
#  '...',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제',
#  '사',
#  '음식',
#  '을',
#  '마련',
#  '하여',
#  '제사',
#  '를',
#  '...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '한식',
#  '조사',
#  '여',
#  '.....',
#  '2016.06',
#  '.',
#  '01',
#  '.',
#  '뭐',
#  '가',
#  '우리나라',
#  '음식',
#  '인지',
#  '모르겠어서요',
#  '일단',
#  '1',
#  '.',
#  '한식',
#  '종류',
#  '!',
#  '를',
#  '알려주세요',
#  '2',
#  '.',
#  '그',
#  '음식',
#  '들',
#  '을',
#  '만드는',
#  '방법',
#  '도',
#  '알려주세요',
#  '오늘',
#  '안',
#  '에',
#  '알려주세요',
#  '.....',
#  '지금',
#  '엄청',
#  '급해서요',
#  '.....',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '을',
#  '...',
#  '흔히',
#  ',',
#  '이',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '만',
#  '아니라',
#  '국가',
#  '에',
#  '불상',
#  '사가',
#  '일어난다',
#  '고',
#  '믿어',
#  '매우',
#  '꺼린다',
#  '.',
#  '한식',
#  '날',
#  '음식',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '이',
#  '뭐',
#  '에요',
#  '?',
#  '2011.08',
#  '.',
#  '26',
#  '.',
#  '그',
#  '..',
#  '우리나라',
#  '음식',
#  '한식',
#  '말구요',
#  '..;;',
#  '차가울',
#  '한',
#  '?',
#  '그거',
#  '쓴',
#  '...',
#  '한',
#  '문',
#  '숙제',
#  '가',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '에',
#  '대해',
#  '서',
#  '조사',
#  '해오는건데',
#  '....',
#  '조사',
#  '를',
#  '해서',
#  '어떻게',
#  '해야',
#  '될지도',
#  '모르겠고',
#  '..',
#  '사전',
#  '같은',
#  '덴',
#  '너무',
#  '...',
#  '답변',
#  '더운',
#  '밥',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '밥',
#  '을',
#  '먹는다고는',
#  '하나',
#  '잘',
#  '지켜지지',
#  '않았다',
#  '.',
#  '한식',
#  '은',
#  '조선시대',
#  '에',
#  '설날',
#  '·',
#  '단오',
#  '·',
#  '추석',
#  '과',
#  '함께',
#  '사대',
#  '명절',
#  '(',
#  '四大名節',
#  ')',
#  '에',
#  '속',
#  '했다',
#  '.',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제사',
#  '음식',
#  '...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대하',
#  '여',
#  '2007.04',
#  '.',
#  '05',
#  '.',
#  '학교숙제',
#  '인대',
#  '요',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대한',
#  '조사',
#  '를',
#  '해',
#  '라',
#  '해서',
#  '하게',
#  '된것인데',
#  '제',
#  '말',
#  '도와주세요',
#  'ㅠㅠ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '을',
#  '...',
#  '흔히',
#  ',',
#  '이',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '만',
#  '아니라',
#  '국가',
#  '에',
#  '불상',
#  '사가',
#  '일어난다',
#  '고',
#  '믿어',
#  '매우',
#  '꺼린다',
#  '.',
#  '한식',
#  '날',
#  '음식',
#  '...',
#  '닉네임',
#  'han',
#  '0',
#  '****',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '2013.02',
#  '.',
#  '15',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '제발',
#  '부탁드림니다',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  '정답',
#  '질문',
#  '원일',
#  '/',
#  '한식',
#  '/',
#  '단오',
#  '/',
#  '추석',
#  '/',
#  '동지',
#  '때',
#  '풍습',
#  '과',
#  '음식',
#  '2008.09',
#  '.',
#  '28',
#  '.',
#  '원일',
#  '(',
#  '음력',
#  '1월',
#  '1일',
#  '),',
#  '한식',
#  '(',
#  '동지',
#  '부터',
#  '105일',
#  '),',
#  '단오',
#  '(',
#  '음력',
#  '5월',
#  '5일',
#  '),',
#  '추석',
#  '(',
#  '음력',
#  '8월',
#  '15일',
#  '),',
#  '동지',
#  '에',
#  '하는',
#  '풍습',
#  '과',
#  '그',
#  '때',
#  '에',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '~~',
#  '답변',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌리',
#  '기도',
#  '합니다',
#  '.',
#  '【',
#  '한식',
#  '날',
#  '음식',
#  '】',
#  '성묘',
#  '는',
#  '일',
#  '년',
#  '에',
#  '...',
#  '흔히',
#  ',',
#  '이',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '만',
#  '아니라',
#  '국가',
#  '에',
#  '불상',
#  '사가',
#  '일어난다',
#  '고',
#  '믿어',
#  '...',
#  '닉네임',
#  'read',
#  '****',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '(',
#  '월욜',
#  '까지',
#  ')',
#  '2007.02',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '좀',
#  '부탁',
#  '해요',
#  '!!!!',
#  '답변',
#  '바랍니다',
#  '한식',
#  '(',
#  '寒食',
#  ':',
#  '동지',
#  '후',
#  '105일',
#  '째',
#  '되는',
#  '날',
#  ')',
#  '한식',
#  '의',
#  '...',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '...',
#  '또',
#  '한식',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '아니라',
#  '나라',
#  '에도',
#  '...',
#  '닉네임',
#  'yehr',
#  '****',
#  '질문',
#  '이번',
#  '식목일',
#  '이',
#  '한식',
#  '이라고',
#  '하던데',
#  '..',
#  '2003.04',
#  '.',
#  '03',
#  '.',
#  '선생님',
#  '께서',
#  '이번',
#  '식목일',
#  '이',
#  '한식',
#  '이라고',
#  '하시던데',
#  '..',
#  '그게',
#  '도대체',
#  '뭐',
#  '고',
#  '뭐',
#  '하는',
#  '날인',
#  '지',
#  '(',
#  'ex',
#  ':',
#  '동지',
#  '_',
#  '팥죽',
#  '먹는',
#  '날',
#  ')',
#  '좀',
#  '알려주세요',
#  '.',
#  '내공',
#  '있습니다',
#  '.',
#  '답변',
#  '~~^^',
#  '한식',
#  '(',
#  '寒食',
#  ':',
#  '동지',
#  '후',
#  '105일',
#  '째',
#  '되는',
#  '날',
#  ')',
#  '1',
#  '.',
#  '한식',
#  '의',
#  '...',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어',
#  '...',
#  '또',
#  '한식',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '아니라',
#  '나라',
#  '에도',
#  '...',
#  '닉네임',
#  'blue',
#  '****',
#  '질문',
#  '식목일',
#  '다음',
#  '날',
#  '..',
#  '한식',
#  '인데',
#  '..',
#  '2007.03',
#  '.',
#  '23',
#  '.',
#  '한식',
#  '이',
#  '무슨',
#  '날',
#  '인가요',
#  '??',
#  '알려주세요',
#  '..',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '...',
#  '이',
#  '날',
#  '비',
#  '가',
#  '오면',
#  "'",
#  '물',
#  '한식',
#  "'",
#  '이라고',
#  '하여',
#  '그',
#  '해',
#  '에',
#  '풍년',
#  '이',
#  '...',
#  '또',
#  '한식',
#  '날',
#  '천둥',
#  '이',
#  '치면',
#  '흉년',
#  '이',
#  '들',
#  '뿐',
#  '아니라',
#  '나라',
#  '에도',
#  '...',
#  '닉네임',
#  '화웅',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '전통',
#  '한식',
#  '상차림',
#  '2019.09',
#  '.',
#  '16',
#  '.',
#  '1',
#  '.',
#  '전통',
#  '한식',
#  '의',
#  '첩',
#  '반상',
#  '(',
#  '3',
#  ',',
#  '5',
#  ',',
#  '7',
#  ',',
#  '9',
#  ',',
#  '12',
#  ')',
#  '과',
#  '반찬',
#  '2',
#  '.',
#  '전통',
#  '밥상',
#  '차림',
#  '어떤',
#  '배열',
#  '을',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='천둥 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='천둥 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='천둥 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='천둥 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='천둥 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='천둥 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 92211
# 7242

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 4379),
#  ('...', 2997),
#  ('이', 1909),
#  ('을', 1765),
#  ('에', 1764),
#  (',', 1547),
#  ('의', 1393),
#  ('음식', 1089),
#  ('답변', 1078),
#  ('질문', 1063),
#  ('를', 1014),
#  ('닉네임', 891),
#  ('가', 877),
#  (':', 821),
#  ('더운', 803),
#  ('날', 728),
#  ('은', 726),
#  ('●', 721),
#  ('****', 719),
#  ('하는', 614),
#  ('는', 553),
#  ('단어', 525),
#  ('로', 507),
#  ('과', 490),
#  ('들', 471),
#  ('때', 466),
#  ('(', 460),
#  ('도', 452),
#  ('고', 419),
#  ('좀', 418),
#  ('검색', 408),
#  ('..', 386),
#  ('천둥', 384),
#  ('밥', 382),
#  (')', 346),
#  ('에서', 344),
#  ('한', 343),
#  ('나라', 318),
#  ('요', 317),
#  ('속담', 311),
#  ('여러', 305),
#  ('입력', 300),
#  ('동남아', 297),
#  ('것', 276),
#  ('?', 268),
#  ('개', 250),
#  ('알려주세요', 245),
#  ('내공', 243),
#  ('찬', 241),
#  ('에는', 240),
#  ('명절', 240),
#  ('위', 239),
#  ('으로', 233),
#  ('않는', 222),
#  ('제', 222),
#  ('이다', 218),
#  ('사람', 217),
#  ('와', 213),
#  ('날씨', 212),
#  ('된', 211),
#  ('포함', 209),
#  ('....', 208),
#  ('나', 207),
#  ('다른', 207),
#  ('합니다', 202),
#  ('번개', 201),
#  ('또', 197),
#  ('숙제', 188),
#  ('세계', 187),
#  ('놀이', 184),
#  ('1', 182),
#  ('할', 181),
#  ('먹는', 180),
#  ('다시', 172),
#  ('①', 168),
#  ('말', 165),
#  ('봄', 164),
#  ('되지기', 163),
#  ('찌거나', 163),
#  ('얹어', 162),
#  ('20', 162),
#  ('인', 161),
#  ('땅', 160),
#  ('뜻', 160),
#  ('뇌우', 160),
#  ('일', 159),
#  ('거리', 159),
#  ('10', 158),
#  ('장이', 158),
#  ('저', 157),
#  ('그', 156),
#  ('무싯날', 155),
#  ('서지', 155),
#  ('무텅', 155),
#  ('거칠', 155),
#  ('새참', 154),
#  ('곳', 153),
#  ('한식', 153),
#  ('논밭', 152),
#  ('고갱', 151),
#  ('사물', 151),
#  ('핵심', 151),
#  ('시간', 150),
#  ('3', 147),
#  ('기념일', 147),
#  ('만든', 147),
#  ('계절', 145),
#  ('많이', 142),
#  ('이상', 140),
#  ('해서', 140),
#  ('정도', 140),
#  ('등', 140),
#  ('우리말', 139),
#  ('여름철', 138),
#  ('전통', 137),
#  ('게', 137),
#  ('까지', 131),
#  ('설날', 131),
#  ('학년', 130),
#  ('이나', 128),
#  ('빨리', 128),
#  ('관련', 127),
#  ('여행', 126),
#  ('하며', 126),
#  ('적', 125),
#  ('대해', 125),
#  ('오늘', 125),
#  (')...', 124),
#  ('/', 123),
#  ('중', 123),
#  ('2010.12', 123),
#  ('연날리기', 123),
#  ('즐거운', 123),
#  ('보낸다', 123),
#  ('성인', 123),
#  ('成人の日', 122),
#  ('하나', 121),
#  ('사용', 121),
#  ('~', 120),
#  ('입니다', 118),
#  ('소리', 117),
#  ('이라', 116),
#  ('하여', 115),
#  ('가지', 115),
#  ('인데', 114),
#  ('시원한', 113),
#  ('고유어', 113),
#  ('만', 112),
#  ('-', 112),
#  ('2', 111),
#  ('기본', 110),
#  ('본', 109),
#  ('지나가고', 109),
#  ('"', 108),
#  ('도래', 108),
#  ('기', 107),
#  ('<', 107),
#  ('하세요', 106),
#  ("'", 105),
#  ('주세요', 105),
#  ('왕관', 105),
#  ('정확히', 104),
#  ('태국', 104),
#  ('문장', 102),
#  ('제외', 102),
#  ('상세', 101),
#  ('반드시', 101),
#  ('구분', 101),
#  ('이름', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('결과', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('한국', 100),
#  ('서', 100),
#  ('우리나라', 100),
#  ('안', 99),
#  ('몸', 99),
#  ('5', 98),
#  ('물', 98),
#  ('4', 97),
#  ('해', 97),
#  ('여', 97),
#  ('필리핀', 96),
#  ('수', 94),
#  ('다', 93),
#  ('특히', 93),
#  ('에도', 93),
#  ('여름', 92),
#  ('지방', 92),
#  ('전선', 92),
#  ('바람', 89),
#  ('면', 88),
#  ('안녕하세요', 88),
#  ('30', 87),
#  ('!', 87),
#  ('순우리말', 87),
#  ('부탁', 87),
#  ('잘', 86),
#  ('??', 85),
#  ('정말', 84),
#  ('한다', 84),
#  ('산', 84),
#  ('하는데', 83),
#  ('하고', 83),
#  ('앵무새', 83),
#  ('없는', 82),
#  ('아', 82),
#  ('중국', 82),
#  ('알', 81),
#  ('*', 81),
#  ('이야기', 81),
#  ('조사', 80),
#  ('100', 80),
#  ('!!', 79),
#  ('꼭', 78),
#  ('그리고', 75),
#  ('비', 75),
#  ('생활', 75),
#  ('북한', 74),
#  ('사는', 73),
#  ('있는', 72),
#  ('못', 71),
#  ('살', 71),
#  ('추위', 71),
#  ('먹고', 70),
#  ('쉽게', 70),
#  ('>', 70),
#  ('감사', 69),
#  ('ㅠㅠ', 68),
#  ('ag', 68),
#  ('사회', 68),
#  ('먹이', 68),
#  ('강한', 67),
#  ('본래', 67),
#  ('항상', 67),
#  ('녀석', 66),
#  ('관', 65),
#  ('가져온다', 65),
#  ('이하', 65),
#  ('보이지', 65),
#  ('제발', 64),
#  ('놀라며', 64),
#  ('주기', 64),
#  ('당연한', 64),
#  ('겠지만', 64),
#  ('내려가면', 64),
#  ('^^', 63),
#  ('하루', 63),
#  ('분', 62),
#  ('이면', 62),
#  ('밤', 62),
#  ('구름', 62),
#  ('옛날', 62),
#  ('해주세요', 61),
#  ('맛', 61),
#  ('예', 60),
#  ('일본', 59),
#  ('03', 59),
#  ('전기', 58),
#  ('이르는', 58),
#  ('우리', 57),
#  ('치면', 57),
#  ('하면', 56),
#  ('맛있게', 56),
#  ('19', 56),
#  ('눈', 56),
#  ('leex', 56),
#  ('어떤', 55),
#  ('미국', 55),
#  ('방학', 55),
#  ('밑', 55),
#  ('아래', 55),
#  ('까닭', 55),
#  ('앵무', 55),
#  ('가장', 54),
#  ('예수님', 54),
#  ('기운', 54),
#  ('모이는', 54),
#  ('17', 53),
#  ('지', 53),
#  ('선생님', 53),
#  ('먹어', 53),
#  ('남미', 53),
#  ('전', 52),
#  ('부탁드립니다', 52),
#  ('의미', 52),
#  ('대인', 52),
#  ('캄캄한', 52),
#  ('mhos', 52),
#  ('아침', 51),
#  ('생명', 51),
#  ('추천', 50),
#  ('사진', 50),
#  ('아름다운', 50),
#  ('태어난', 50),
#  ('구원', 50),
#  ('15', 49),
#  ('흉년', 49),
#  ('겨울', 49),
#  ('18', 49),
#  ('특징', 49),
#  ('2016.10', 49),
#  ('•', 49),
#  ('쪽', 48),
#  ('뭐', 47),
#  ('사', 47),
#  ('ㅠ', 47),
#  ('대', 47),
#  ('무엇', 47),
#  ('제주도', 47),
#  ('식', 46),
#  ('너무', 46),
#  ('2008.04', 46),
#  ('새', 46),
#  ('16', 46),
#  ('24', 46),
#  ('종류', 46),
#  ('ethn', 46),
#  ('과일', 46),
#  ('학교', 45),
#  ('뿐', 45),
#  ('때문', 44),
#  ('있다', 44),
#  ('내', 44),
#  ('집', 44),
#  ('갈', 43),
#  ('6', 43),
#  ('에게', 43),
#  ('달', 43),
#  ('12', 43),
#  ('하기', 43),
#  ('함', 43),
#  ('세', 43),
#  ('26', 42),
#  ('좋은', 42),
#  ('캄보디아', 42),
#  ('과학', 42),
#  ('속', 41),
#  ('04', 41),
#  ('13', 40),
#  ('에서는', 40),
#  ('음식물', 40),
#  ('대한', 39),
#  ('지금', 39),
#  ('모습', 39),
#  ('넘으려고', 39),
#  ('같은', 38),
#  ('하', 38),
#  ('내일', 38),
#  ('감추듯', 38),
#  ('산이', 38),
#  ('운다고', 38),
#  ('더', 37),
#  ('11', 37),
#  ('가을', 37),
#  ('14', 37),
#  ('호텔', 36),
#  ('2008.03', 36),
#  ('25', 36),
#  ('생각', 36),
#  ('처럼', 36),
#  ('유래', 36),
#  ('요리', 36),
#  ('데', 36),
#  ('섭취', 35),
#  ('저희', 35),
#  ('피하', 35),
#  ('대하', 35),
#  ('어떻게', 35),
#  ('아니라', 35),
#  ('베트남', 35),
#  ('거', 35),
#  ('어느', 35),
#  ('가르쳐', 35),
#  ('시기', 35),
#  ('치움을', 35),
#  ('있나요', 34),
#  ('그런데', 34),
#  ('!!!', 34),
#  ('21', 34),
#  ('순', 34),
#  ('현지', 33),
#  ('점', 33),
#  ('그래서', 33),
#  (',,', 33),
#  ('02', 33),
#  ('1월', 33),
#  ('하나님', 33),
#  ('보다', 32),
#  ('인가요', 32),
#  ('써주세요', 32),
#  ('처음', 32),
#  ('.....', 32),
#  ('방법', 32),
#  (']', 32),
#  ('신고', 32),
#  ('삼', 32),
#  ('박', 31),
#  ('07', 31),
#  ('부탁드려요', 31),
#  ('~~', 31),
#  ('09', 31),
#  ('각', 31),
#  ('50', 31),
#  ('주', 31),
#  ('제사', 31),
#  ('이라고', 31),
#  ('방콕', 31),
#  ('[', 31),
#  ('ocam', 31),
#  ('하지만', 30),
#  ('해외', 30),
#  ('오', 30),
#  ('랑', 30),
#  ('함께', 30),
#  ('이유', 30),
#  ('약간', 29),
#  ('해외여행', 29),
#  ('올려주세요', 29),
#  ('초', 29),
#  ('인지', 29),
#  ('동안', 29),
#  ('비교', 29),
#  ('마음', 29),
#  ('비유', 29),
#  ('2011.10', 29),
#  ('설명', 28),
#  ('대로', 28),
#  ('가정', 28),
#  ('01', 28),
#  ('않고', 28),
#  ('글', 28),
#  ('0', 28),
#  ('들면', 28),
#  ('있으며', 27),
#  ('이런', 27),
#  ('해야', 27),
#  ('등등', 27),
#  ('글자', 27),
#  ('신', 27),
#  ('꿈', 27),
#  ('되도록', 27),
#  ('무더운', 27),
#  ('구체', 27),
#  ('단순히', 27),
#  ('성', 26),
#  ('근데', 26),
#  ('절기', 26),
#  ('많은', 26),
#  ('국수', 26),
#  ('23', 26),
#  ('있는데', 26),
#  ('걸음', 26),
#  ('가게', 25),
#  ('도와주세요', 25),
#  ('하늘', 25),
#  ('겁니다', 25),
#  ('있습니다', 25),
#  ('가르쳐주세요', 25),
#  ('차', 25),
#  ('허겁지겁', 25),
#  ('게도', 25),
#  ('지역', 24),
#  ('29', 24),
#  ('국가', 24),
#  ('자의', 24),
#  ('문화', 24),
#  ('부터', 24),
#  ('최대한', 24),
#  ('께서', 24),
#  ('켜주세요', 24),
#  ('책', 24),
#  ('적어', 24),
#  ('31', 24),
#  ('가리켜', 24),
#  ('7', 24),
#  ('러시아', 24),
#  ('살려라', 24),
#  ('달아날', 24),
#  ('조급한', 24),
#  ('발걸음', 24),
#  ('재촉', 24),
#  ('2011.07', 24),
#  ('걸', 23),
#  ('조금', 23),
#  ('풍속', 23),
#  ('옷', 23),
#  ('제일', 23),
#  ('이랑', 23),
#  ('급함', 23),
#  ('몇', 23),
#  ('냠냠', 23),
#  ('알려', 23),
#  ('여러가지', 23),
#  ('풀이', 23),
#  ('경우', 23),
#  ('손', 23),
#  ('일정', 22),
#  ('05', 22),
#  ('있을까요', 22),
#  ('마련', 22),
#  ('있어요', 22),
#  ('시', 22),
#  ('이번', 22),
#  ('왜', 22),
#  ('급해요', 22),
#  ('아시', 22),
#  ('값', 22),
#  ('오지', 22),
#  ('중복', 22),
#  ('보신', 22),
#  ('강', 22),
#  ('2009.03', 22),
#  ('뉴욕', 21),
#  ('가봐야', 21),
#  ('오른', 21),
#  ('드시는', 21),
#  ('비경', 21),
#  ('06', 21),
#  ('08', 21),
#  ('래', 21),
#  ('자료', 21),
#  ('데운', 21),
#  ('문', 21),
#  ('상식', 21),
#  ('풍습', 21),
#  ('않으면', 21),
#  ('농사짓는', 21),
#  ('어려움', 21),
#  ('복절', 21),
#  ('초복', 21),
#  ('말복', 21),
#  ('삼복', 21),
#  ('22', 21),
#  ('27', 21),
#  ('라는', 21),
#  ('낱말', 21),
#  ('타임스', 20),
#  ('선정', 20),
#  ('죽기전에', 20),
#  ('맛있기는', 20),
#  ('간혹', 20),
#  ('계시는데', 20),
#  ('라서', 20),
#  ('......', 20),
#  ('28', 20),
#  ('☞', 20),
#  ('k', 20),
#  ('하는데요', 20),
#  ('마을', 20),
#  ('조사해', 20),
#  ('열대지방', 20),
#  ('만큼', 20),
#  ('2011.06', 20),
#  ('이고', 19),
#  ('됩니다', 19),
#  ('그냥', 19),
#  ('ㅜ', 19),
#  ('및', 19),
#  ('모든', 19),
#  ('수도', 19),
#  ('정보', 19),
#  ('니', 19),
#  ('40', 19),
#  ('기후', 19),
#  ('드림', 19),
#  ('라', 19),
#  ('자세히', 19),
#  ('라고', 19),
#  ('조상', 19),
#  ('드립니다', 19),
#  ('답', 19),
#  ('올려', 19),
#  ('끓는', 19),
#  ('이란', 19),
#  ('2008.09', 19),
#  ('여행지', 18),
#  ('반', 18),
#  ('+', 18),
#  ('대표', 18),
#  ('아주', 18),
#  ('올', 18),
#  ('가서', 18),
#  ('가족', 18),
#  ('오면', 18),
#  ('거든요', 18),
#  ('구', 18),
#  ('적어주세요', 18),
#  ('ㅎ', 18),
#  ('~!', 18),
#  ('밖에', 18),
#  ('학기', 18),
#  ('께', 18),
#  ('아무리', 18),
#  ('염', 18),
#  ('관계', 18),
#  ('볼때', 18),
#  ('빵값', 18),
#  ('공산품', 18),
#  ('들이므로', 18),
#  ('·', 18),
#  ('5일', 17),
#  ('보고', 17),
#  ('아니면', 17),
#  ('자세하게', 17),
#  ('알려주세여', 17),
#  ('~~~', 17),
#  ('해요', 17),
#  ('감사하겠습니다', 17),
#  ('갑자기', 17),
#  ('되는', 17),
#  ('하면서', 17),
#  ('소화', 17),
#  ('994', 17),
#  ('되지', 17),
#  ('대륙', 17),
#  ('200', 17),
#  ('있는데요', 17),
#  ('수수께끼', 17),
#  ('에요', 16),
#  ('동남아시아', 16),
#  ('저기', 16),
#  ('같이', 16),
#  ('일기', 16),
#  ('명', 16),
#  ('풍년', 16),
#  ('쌀', 16),
#  ('가려고', 16),
#  ('상', 16),
#  ('불', 16),
#  ('이렇게', 16),
#  ('별', 16),
#  ('밀가루', 16),
#  ('되', 16),
#  ('계속', 16),
#  ('생선', 16),
#  ('지식', 16),
#  ('준다는', 16),
#  ('야채', 16),
#  ('15일', 16),
#  ('나타난다는', 16),
#  ('에만', 16),
#  ('입', 16),
#  ('혼자', 15),
#  ('비행기', 15),
#  ('5월', 15),
#  ('먹기', 15),
#  ('자유여행', 15),
#  ('날짜', 15),
#  ('없고', 15),
#  ('없이', 15),
#  ('유럽', 15),
#  ('돈', 15),
#  ('공기', 15),
#  ('다음', 15),
#  ('번', 15),
#  ('?...', 15),
#  ('주시', 15),
#  ('이제', 15),
#  ('좋고', 15),
#  ('해주시', 15),
#  ('켜', 15),
#  ('엔', 15),
#  ('9', 15),
#  ('2009.11', 15),
#  ('예요', 15),
#  ('님들', 15),
#  ('천둥소리', 15),
#  ('찌', 15),
#  ('삶아서', 15),
#  ('비단', 15),
#  ('국한', 15),
#  ('⑤', 15),
#  ('건너지', 15),
#  ('말라', 15),
#  ('생기는', 15),
#  ('지장', 15),
#  ('인데요', 15),
#  ('싶습니다', 15),
#  ('고유', 15),
#  ('순수한', 15),
#  ('단원', 15),
#  ('맵', 15),
#  ('가격', 14),
#  ('혹시', 14),
#  ('찾아', 14),
#  ('.......', 14),
#  ('②', 14),
#  ('별로', 14),
#  ('모두', 14),
#  ('든다는', 14),
#  ('말고', 14),
#  ('4월', 14),
#  ('지식인', 14),
#  ('재료', 14),
#  ('???', 14),
#  ('농사', 14),
#  ('끝', 14),
#  ('외래어', 14),
#  ('통해', 14),
#  ('지내는', 14),
#  ('가야', 14),
#  ('),', 14),
#  ('네', 14),
#  ('자', 14),
#  ('마파람', 14),
#  ('2008.10', 14),
#  ('소', 14),
#  ('새털', 14),
#  ('한자어', 14),
#  ('열', 13),
#  ('남자', 13),
#  ('패키지', 13),
#  ('선택', 13),
#  ('또한', 13),
#  ('바', 13),
#  (';;', 13),
#  ('요즘', 13),
#  ('간', 13),
#  ('하지', 13),
#  ('즐겨', 13),
#  ('ㅜㅜ', 13),
#  ('해양', 13),
#  ('알려주시면', 13),
#  ('난', 13),
#  ('국어', 13),
#  ('현재', 13),
#  ('빨리요', 13),
#  ('가는', 13),
#  ('뚜껑', 13),
#  ('음식점', 13),
#  ('많고', 13),
#  ('the', 13),
#  ('닭', 13),
#  ('2014.01', 13),
#  ('씩', 13),
#  ('위해', 13),
#  ('후', 13),
#  ('빨', 13),
#  ('양', 13),
#  ('아무', 13),
#  ('식품', 13),
#  ('그럼', 13),
#  ('2010.01', 13),
#  ('초등학교', 13),
#  ('그러는데', 13),
#  ('가요', 13),
#  ('2011.05', 13),
#  ('인도', 13),
#  ('반죽', 13),
#  ('수행평가', 13),
#  ('찬밥', 13),
#  ('매우', 13),
#  ('장', 13),
#  ('그리스', 13),
#  ('되요', 13),
#  ('분양', 13),
#  ('님', 13),
#  ('계획', 12),
#  ('문제', 12),
#  ('자주', 12),
#  ('되어', 12),
#  ('경험', 12),
#  ('니까', 12),
#  ('국', 12),
#  ('예쁜', 12),
#  ('진짜', 12),
#  ('학교숙제', 12),
#  ('소나기', 12),
#  ('이며', 12),
#  ('ㅋㅋ', 12),
#  ('보면', 12),
#  ('추운', 12),
#  ('무슨', 12),
#  ('이용', 12),
#  ('분야', 12),
#  ('법', 12),
#  ('무척', 12),
#  ('캐나다', 12),
#  ('있으면', 12),
#  ('내용', 12),
#  ('7월', 12),
#  ('하려고', 12),
#  ('나서', 12),
#  ('개월', 12),
#  ('아이', 12),
#  ('이구', 12),
#  ('2011.11', 12),
#  ('가면', 12),
#  ('모르겠네요', 12),
#  ('외국어', 12),
#  ('거지', 12),
#  ('그것', 12),
#  ('교회', 12),
#  ('어려운', 12),
#  ('조', 12),
#  ('천국', 12),
#  ('동물', 12),
#  ('이라는', 12),
#  ('찾기', 12),
#  ('표현', 12),
#  ('용법', 12),
#  ('나무', 12),
#  ('ㅡ', 12),
#  ('11월', 11),
#  ('쯤', 11),
#  ('해도', 11),
#  ('엄청', 11),
#  ('ㅎㅎ', 11),
#  ('관광', 11),
#  ('이에요', 11),
#  ('써', 11),
#  ('!!!!', 11),
#  ('있고', 11),
#  ('준비물', 11),
#  ('친구', 11),
#  ('_', 11),
#  ('60', 11),
#  ('2007.08', 11),
#  ('죠', 11),
#  ('정리', 11),
#  ('대만', 11),
#  ('단오', 11),
#  ('검', 11),
#  ('일이', 11),
#  ('시작', 11),
#  ('치는', 11),
#  ('우엉', 11),
#  ('조림', 11),
#  ('아람', 11),
#  ('농산', 11),
#  ('안녕하세여', 11),
#  ('용', 11),
#  ('두', 11),
#  ('불어오고', 11),
#  ('수제비', 11),
#  ('이라도', 11),
#  ('맑은', 11),
#  ('가는데', 11),
#  ('8', 11),
#  ('머리', 11),
#  ('빠른', 11),
#  ('어', 11),
#  ('예절', 11),
#  ('직하게', 11),
#  ('바로', 11),
#  ('2008.08', 11),
#  ('어쩔', 11),
#  ('형', 11),
#  ('물론', 11),
#  ('모르는', 11),
#  ('2009.09', 11),
#  ('63', 11),
#  ('한랭', 11),
#  ('통과', 11),
#  ('쇠', 11),
#  ('원', 11),
#  ('자꾸', 11),
#  ('남한', 11),
#  ('우기', 10),
#  ('12월', 10),
#  ('4일', 10),
#  ('어디가', 10),
#  ('환경', 10),
#  ('발생', 10),
#  ('주의', 10),
#  ('일반', 10),
#  ('준비', 10),
#  ('걸어요', 10),
#  ('대충', 10),
#  ('전체', 10),
#  ('여름날', 10),
#  ('맞는', 10),
#  ('늘', 10),
#  ('드릴게요', 10),
#  ('인터넷', 10),
#  ('주는', 10),
#  ('약', 10),
#  ('매운', 10),
#  ('2월', 10),
#  ('그게', 10),
#  ('몰라서', 10),
#  ('일단', 10),
#  ('그러던', 10),
#  ('ㅋ', 10),
#  ('며', 10),
#  ('역사', 10),
#  ('스시', 10),
#  ('참고', 10),
#  ('도의', 10),
#  ('드려요', 10),
#  ('고맙겠습니다', 10),
#  ('치고', 10),
#  ('없어서', 10),
#  ('떡', 10),
#  ('받아', 10),
#  ('려고', 10),
#  ('2007.04', 10),
#  ('기도', 10),
#  ('온', 10),
#  ('날개', 10),
#  ('찾아주세요', 10),
#  ('8월', 10),
#  ('학생', 10),
#  ('팍팍', 10),
#  ('알아오래요', 10),
#  ('2008.02', 10),
#  ('2008.06', 10),
#  ('편', 10),
#  ('★', 10),
#  ('거기', 10),
#  ('존재', 10),
#  ('담고', 10),
#  ('수저', 10),
#  ('키우는', 10),
#  ('먹은', 10),
#  ('있는지', 10),
#  ('인간', 10),
#  ('숙젠데', 10),
#  ('샌', 10),
#  ('올빼미', 10),
#  ('신세', 10),
#  ('세력', 10),
#  ('없어져', 10),
#  ('외로운', 10),
#  ('같은데', 10),
#  ('인가', 10),
#  ('장단점', 10),
#  ('호주', 10),
#  ('미역', 10),
#  ('싸하다', 10),
#  ('동', 10),
#  ('좋을까요', 9),
#  ('싶은데요', 9),
#  ('메뉴', 9),
#  ('걱정', 9),
#  ('얼마나', 9),
#  ('한낮', 9),
#  ('햇볕', 9),
#  ('ad', 9),
#  ('71', 9),
#  ('코스', 9),
#  ('따뜻한', 9),
#  ('거의', 9),
#  ('이라서', 9),
#  ('되면', 9),
#  ('부모님', 9),
#  ('되고', 9),
#  ('말씀', 9),
#  ('내리는', 9),
#  ('저가', 9),
#  ('한글', 9),
#  ('공부', 9),
#  ('술', 9),
#  ('바랍니다', 9),
#  ('휴양지', 9),
#  ('시원하게', 9),
#  ('먹을', 9),
#  ('사랑', 9),
#  ('금', 9),
#  ('넘', 9),
#  ('써주시면', 9),
#  ('음', 9),
#  ('각국', 9),
#  ('in', 9),
#  ('막', 9),
#  ('눈물', 9),
#  ('가르', 9),
#  ('이해', 9),
#  ('A', 9),
#  ('하나요', 9),
#  ('영어', 9),
#  ('한자', 9),
#  ('채택', 9),
#  ('프랑스', 9),
#  ('부지런하면', 9),
#  ('먹는다', 9),
#  ('간다', 9),
#  ('초딩', 9),
#  ('다양한', 9),
#  ('2007.12', 9),
#  ('사투리', 9),
#  ('검다', 9),
#  ('알려주세', 9),
#  ('딸', 9),
#  ('줄', 9),
#  ('또는', 9),
#  ('예수', 9),
#  ('야', 9),
#  ('와의', 9),
#  ('해산', 9),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='천둥 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='천둥 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='천둥 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='천둥 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='천둥 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='천둥 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [('음식', 1089),
#  ('닉네임', 891),
#  (':', 821),
#  ('더운', 803),
#  ('날', 728),
#  ('●', 721),
#  ('****', 719),
#  ('(', 460),
#  ('검색', 408),
#  ('천둥', 384),
#  ('밥', 382),
#  (')', 346),
#  ('에서', 344),
#  ('나라', 318),
#  ('속담', 311),
#  ('여러', 305),
#  ('입력', 300),
#  ('동남아', 297),
#  ('개', 250),
#  ('알려주세요', 245),
#  ('내공', 243),
#  ('찬', 241),
#  ('에는', 240),
#  ('명절', 240),
#  ('위', 239),
#  ('않는', 222),
#  ('이다', 218),
#  ('사람', 217),
#  ('와', 213),
#  ('날씨', 212),
#  ('된', 211),
#  ('포함', 209),
#  ('나', 207),
#  ('다른', 207),
#  ('합니다', 202),
#  ('번개', 201),
#  ('또', 197),
#  ('숙제', 188),
#  ('세계', 187),
#  ('놀이', 184),
#  ('먹는', 180),
#  ('다시', 172),
#  ('①', 168),
#  ('말', 165),
#  ('봄', 164),
#  ('되지기', 163),
#  ('찌거나', 163),
#  ('얹어', 162),
#  ('인', 161),
#  ('땅', 160),
#  ('뜻', 160),
#  ('뇌우', 160),
#  ('거리', 159),
#  ('장이', 158),
#  ('저', 157),
#  ('그', 156),
#  ('무싯날', 155),
#  ('서지', 155),
#  ('무텅', 155),
#  ('거칠', 155),
#  ('새참', 154),
#  ('곳', 153),
#  ('한식', 153),
#  ('논밭', 152),
#  ('고갱', 151),
#  ('사물', 151),
#  ('핵심', 151),
#  ('시간', 150),
#  ('3', 147),
#  ('기념일', 147),
#  ('만든', 147),
#  ('계절', 145),
#  ('많이', 142),
#  ('해서', 140),
#  ('정도', 140),
#  ('등', 140),
#  ('우리말', 139),
#  ('여름철', 138),
#  ('전통', 137),
#  ('까지', 131),
#  ('설날', 131),
#  ('학년', 130),
#  ('이나', 128),
#  ('빨리', 128),
#  ('관련', 127),
#  ('여행', 126),
#  ('하며', 126),
#  ('적', 125),
#  ('대해', 125),
#  ('오늘', 125),
#  (')...', 124),
#  ('/', 123),
#  ('2010.12', 123),
#  ('연날리기', 123),
#  ('즐거운', 123),
#  ('보낸다', 123),
#  ('성인', 123),
#  ('成人の日', 122),
#  ('사용', 121),
#  ('입니다', 118),
#  ('소리', 117),
#  ('이라', 116),
#  ('하여', 115),
#  ('가지', 115),
#  ('시원한', 113),
#  ('고유어', 113),
#  ('만', 112),
#  ('-', 112),
#  ('본', 109),
#  ('지나가고', 109),
#  ('"', 108),
#  ('도래', 108),
#  ('기', 107),
#  ('<', 107),
#  ('하세요', 106),
#  ("'", 105),
#  ('주세요', 105),
#  ('왕관', 105),
#  ('정확히', 104),
#  ('태국', 104),
#  ('문장', 102),
#  ('제외', 102),
#  ('상세', 101),
#  ('반드시', 101),
#  ('구분', 101),
#  ('이름', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('결과', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('한국', 100),
#  ('서', 100),
#  ('우리나라', 100),
#  ('안', 99),
#  ('몸', 99),
#  ('5', 98),
#  ('물', 98),
#  ('4', 97),
#  ('해', 97),
#  ('여', 97),
#  ('필리핀', 96),
#  ('특히', 93),
#  ('에도', 93),
#  ('여름', 92),
#  ('지방', 92),
#  ('전선', 92),
#  ('바람', 89),
#  ('면', 88),
#  ('안녕하세요', 88),
#  ('30', 87),
#  ('!', 87),
#  ('순우리말', 87),
#  ('부탁', 87),
#  ('??', 85),
#  ('정말', 84),
#  ('한다', 84),
#  ('산', 84),
#  ('하는데', 83),
#  ('하고', 83),
#  ('앵무새', 83),
#  ('없는', 82),
#  ('아', 82),
#  ('중국', 82),
#  ('알', 81),
#  ('*', 81),
#  ('이야기', 81),
#  ('조사', 80),
#  ('100', 80),
#  ('꼭', 78),
#  ('그리고', 75),
#  ('비', 75),
#  ('생활', 75),
#  ('북한', 74),
#  ('사는', 73),
#  ('살', 71),
#  ('추위', 71),
#  ('먹고', 70),
#  ('쉽게', 70),
#  ('>', 70),
#  ('감사', 69),
#  ('ㅠㅠ', 68),
#  ('ag', 68),
#  ('사회', 68),
#  ('먹이', 68),
#  ('강한', 67),
#  ('본래', 67),
#  ('항상', 67),
#  ('녀석', 66),
#  ('관', 65),
#  ('가져온다', 65),
#  ('이하', 65),
#  ('보이지', 65),
#  ('제발', 64),
#  ('놀라며', 64),
#  ('주기', 64),
#  ('당연한', 64),
#  ('겠지만', 64),
#  ('내려가면', 64),
#  ('^^', 63),
#  ('하루', 63),
#  ('분', 62),
#  ('이면', 62),
#  ('밤', 62),
#  ('구름', 62),
#  ('옛날', 62),
#  ('해주세요', 61),
#  ('맛', 61),
#  ('예', 60),
#  ('일본', 59),
#  ('03', 59),
#  ('전기', 58),
#  ('이르는', 58),
#  ('우리', 57),
#  ('치면', 57),
#  ('하면', 56),
#  ('맛있게', 56),
#  ('19', 56),
#  ('눈', 56),
#  ('leex', 56),
#  ('미국', 55),
#  ('방학', 55),
#  ('밑', 55),
#  ('아래', 55),
#  ('까닭', 55),
#  ('앵무', 55),
#  ('가장', 54),
#  ('예수님', 54),
#  ('기운', 54),
#  ('모이는', 54),
#  ('17', 53),
#  ('선생님', 53),
#  ('먹어', 53),
#  ('남미', 53),
#  ('전', 52),
#  ('부탁드립니다', 52),
#  ('의미', 52),
#  ('대인', 52),
#  ('캄캄한', 52),
#  ('mhos', 52),
#  ('아침', 51),
#  ('생명', 51),
#  ('추천', 50),
#  ('사진', 50),
#  ('아름다운', 50),
#  ('태어난', 50),
#  ('구원', 50),
#  ('15', 49),
#  ('흉년', 49),
#  ('겨울', 49),
#  ('18', 49),
#  ('특징', 49),
#  ('2016.10', 49),
#  ('•', 49),
#  ('쪽', 48),
#  ('사', 47),
#  ('ㅠ', 47),
#  ('무엇', 47),
#  ('제주도', 47),
#  ('식', 46),
#  ('너무', 46),
#  ('2008.04', 46),
#  ('새', 46),
#  ('16', 46),
#  ('24', 46),
#  ('종류', 46),
#  ('ethn', 46),
#  ('과일', 46),
#  ('학교', 45),
#  ('뿐', 45),
#  ('때문', 44),
#  ('있다', 44),
#  ('내', 44),
#  ('집', 44),
#  ('갈', 43),
#  ('에게', 43),
#  ('달', 43),
#  ('12', 43),
#  ('하기', 43),
#  ('함', 43),
#  ('세', 43),
#  ('26', 42),
#  ('좋은', 42),
#  ('캄보디아', 42),
#  ('과학', 42),
#  ('속', 41),
#  ('04', 41),
#  ('13', 40),
#  ('에서는', 40),
#  ('음식물', 40),
#  ('대한', 39),
#  ('지금', 39),
#  ('모습', 39),
#  ('넘으려고', 39),
#  ('같은', 38),
#  ('하', 38),
#  ('내일', 38),
#  ('감추듯', 38),
#  ('산이', 38),
#  ('운다고', 38),
#  ('더', 37),
#  ('11', 37),
#  ('가을', 37),
#  ('14', 37),
#  ('호텔', 36),
#  ('2008.03', 36),
#  ('25', 36),
#  ('생각', 36),
#  ('처럼', 36),
#  ('유래', 36),
#  ('요리', 36),
#  ('섭취', 35),
#  ('저희', 35),
#  ('피하', 35),
#  ('대하', 35),
#  ('어떻게', 35),
#  ('아니라', 35),
#  ('베트남', 35),
#  ('어느', 35),
#  ('가르쳐', 35),
#  ('시기', 35),
#  ('치움을', 35),
#  ('있나요', 34),
#  ('그런데', 34),
#  ('!!!', 34),
#  ('21', 34),
#  ('순', 34),
#  ('현지', 33),
#  ('점', 33),
#  ('그래서', 33),
#  (',,', 33),
#  ('02', 33),
#  ('1월', 33),
#  ('하나님', 33),
#  ('보다', 32),
#  ('인가요', 32),
#  ('써주세요', 32),
#  ('처음', 32),
#  ('.....', 32),
#  ('방법', 32),
#  (']', 32),
#  ('신고', 32),
#  ('삼', 32),
#  ('박', 31),
#  ('07', 31),
#  ('부탁드려요', 31),
#  ('~~', 31),
#  ('09', 31),
#  ('각', 31),
#  ('50', 31),
#  ('제사', 31),
#  ('이라고', 31),
#  ('방콕', 31),
#  ('[', 31),
#  ('ocam', 31),
#  ('하지만', 30),
#  ('해외', 30),
#  ('오', 30),
#  ('랑', 30),
#  ('함께', 30),
#  ('이유', 30),
#  ('약간', 29),
#  ('해외여행', 29),
#  ('올려주세요', 29),
#  ('초', 29),
#  ('인지', 29),
#  ('동안', 29),
#  ('비교', 29),
#  ('마음', 29),
#  ('비유', 29),
#  ('2011.10', 29),
#  ('설명', 28),
#  ('대로', 28),
#  ('가정', 28),
#  ('01', 28),
#  ('않고', 28),
#  ('글', 28),
#  ('0', 28),
#  ('들면', 28),
#  ('있으며', 27),
#  ('이런', 27),
#  ('해야', 27),
#  ('등등', 27),
#  ('글자', 27),
#  ('신', 27),
#  ('꿈', 27),
#  ('되도록', 27),
#  ('무더운', 27),
#  ('구체', 27),
#  ('단순히', 27),
#  ('성', 26),
#  ('근데', 26),
#  ('절기', 26),
#  ('많은', 26),
#  ('국수', 26),
#  ('23', 26),
#  ('있는데', 26),
#  ('걸음', 26),
#  ('가게', 25),
#  ('도와주세요', 25),
#  ('하늘', 25),
#  ('겁니다', 25),
#  ('있습니다', 25),
#  ('가르쳐주세요', 25),
#  ('차', 25),
#  ('허겁지겁', 25),
#  ('게도', 25),
#  ('지역', 24),
#  ('29', 24),
#  ('국가', 24),
#  ('자의', 24),
#  ('문화', 24),
#  ('부터', 24),
#  ('최대한', 24),
#  ('께서', 24),
#  ('켜주세요', 24),
#  ('책', 24),
#  ('적어', 24),
#  ('31', 24),
#  ('가리켜', 24),
#  ('7', 24),
#  ('러시아', 24),
#  ('살려라', 24),
#  ('달아날', 24),
#  ('조급한', 24),
#  ('발걸음', 24),
#  ('재촉', 24),
#  ('2011.07', 24),
#  ('걸', 23),
#  ('조금', 23),
#  ('풍속', 23),
#  ('옷', 23),
#  ('제일', 23),
#  ('이랑', 23),
#  ('급함', 23),
#  ('몇', 23),
#  ('냠냠', 23),
#  ('알려', 23),
#  ('여러가지', 23),
#  ('풀이', 23),
#  ('경우', 23),
#  ('손', 23),
#  ('일정', 22),
#  ('05', 22),
#  ('있을까요', 22),
#  ('마련', 22),
#  ('있어요', 22),
#  ('시', 22),
#  ('이번', 22),
#  ('왜', 22),
#  ('급해요', 22),
#  ('아시', 22),
#  ('값', 22),
#  ('오지', 22),
#  ('중복', 22),
#  ('보신', 22),
#  ('강', 22),
#  ('2009.03', 22),
#  ('뉴욕', 21),
#  ('가봐야', 21),
#  ('오른', 21),
#  ('드시는', 21),
#  ('비경', 21),
#  ('08', 21),
#  ('래', 21),
#  ('자료', 21),
#  ('데운', 21),
#  ('문', 21),
#  ('상식', 21),
#  ('풍습', 21),
#  ('않으면', 21),
#  ('농사짓는', 21),
#  ('어려움', 21),
#  ('복절', 21),
#  ('초복', 21),
#  ('말복', 21),
#  ('삼복', 21),
#  ('22', 21),
#  ('27', 21),
#  ('라는', 21),
#  ('낱말', 21),
#  ('타임스', 20),
#  ('선정', 20),
#  ('죽기전에', 20),
#  ('맛있기는', 20),
#  ('간혹', 20),
#  ('계시는데', 20),
#  ('라서', 20),
#  ('......', 20),
#  ('28', 20),
#  ('☞', 20),
#  ('k', 20),
#  ('하는데요', 20),
#  ('마을', 20),
#  ('조사해', 20),
#  ('열대지방', 20),
#  ('만큼', 20),
#  ('2011.06', 20),
#  ('이고', 19),
#  ('됩니다', 19),
#  ('그냥', 19),
#  ('ㅜ', 19),
#  ('및', 19),
#  ('모든', 19),
#  ('수도', 19),
#  ('정보', 19),
#  ('니', 19),
#  ('40', 19),
#  ('기후', 19),
#  ('드림', 19),
#  ('라', 19),
#  ('자세히', 19),
#  ('조상', 19),
#  ('드립니다', 19),
#  ('답', 19),
#  ('올려', 19),
#  ('끓는', 19),
#  ('이란', 19),
#  ('2008.09', 19),
#  ('여행지', 18),
#  ('반', 18),
#  ('+', 18),
#  ('대표', 18),
#  ('아주', 18),
#  ('올', 18),
#  ('가서', 18),
#  ('가족', 18),
#  ('오면', 18),
#  ('거든요', 18),
#  ('구', 18),
#  ('적어주세요', 18),
#  ('ㅎ', 18),
#  ('~!', 18),
#  ('밖에', 18),
#  ('학기', 18),
#  ('께', 18),
#  ('아무리', 18),
#  ('염', 18),
#  ('관계', 18),
#  ('볼때', 18),
#  ('빵값', 18),
#  ('공산품', 18),
#  ('들이므로', 18),
#  ('·', 18),
#  ('5일', 17),
#  ('보고', 17),
#  ('아니면', 17),
#  ('자세하게', 17),
#  ('알려주세여', 17),
#  ('~~~', 17),
#  ('해요', 17),
#  ('감사하겠습니다', 17),
#  ('갑자기', 17),
#  ('되는', 17),
#  ('하면서', 17),
#  ('소화', 17),
#  ('994', 17),
#  ('되지', 17),
#  ('대륙', 17),
#  ('200', 17),
#  ('있는데요', 17),
#  ('수수께끼', 17),
#  ('에요', 16),
#  ('동남아시아', 16),
#  ('저기', 16),
#  ('같이', 16),
#  ('일기', 16),
#  ('명', 16),
#  ('풍년', 16),
#  ('쌀', 16),
#  ('가려고', 16),
#  ('상', 16),
#  ('불', 16),
#  ('이렇게', 16),
#  ('별', 16),
#  ('밀가루', 16),
#  ('되', 16),
#  ('계속', 16),
#  ('생선', 16),
#  ('지식', 16),
#  ('준다는', 16),
#  ('야채', 16),
#  ('15일', 16),
#  ('나타난다는', 16),
#  ('에만', 16),
#  ('입', 16),
#  ('혼자', 15),
#  ('비행기', 15),
#  ('5월', 15),
#  ('먹기', 15),
#  ('자유여행', 15),
#  ('날짜', 15),
#  ('없고', 15),
#  ('없이', 15),
#  ('유럽', 15),
#  ('돈', 15),
#  ('공기', 15),
#  ('다음', 15),
#  ('번', 15),
#  ('?...', 15),
#  ('주시', 15),
#  ('이제', 15),
#  ('좋고', 15),
#  ('해주시', 15),
#  ('켜', 15),
#  ('엔', 15),
#  ('9', 15),
#  ('2009.11', 15),
#  ('예요', 15),
#  ('님들', 15),
#  ('천둥소리', 15),
#  ('찌', 15),
#  ('삶아서', 15),
#  ('비단', 15),
#  ('국한', 15),
#  ('⑤', 15),
#  ('건너지', 15),
#  ('말라', 15),
#  ('생기는', 15),
#  ('지장', 15),
#  ('인데요', 15),
#  ('싶습니다', 15),
#  ('고유', 15),
#  ('순수한', 15),
#  ('단원', 15),
#  ('맵', 15),
#  ('가격', 14),
#  ('혹시', 14),
#  ('찾아', 14),
#  ('.......', 14),
#  ('②', 14),
#  ('별로', 14),
#  ('모두', 14),
#  ('든다는', 14),
#  ('말고', 14),
#  ('4월', 14),
#  ('지식인', 14),
#  ('재료', 14),
#  ('???', 14),
#  ('농사', 14),
#  ('끝', 14),
#  ('외래어', 14),
#  ('통해', 14),
#  ('지내는', 14),
#  ('가야', 14),
#  ('),', 14),
#  ('자', 14),
#  ('마파람', 14),
#  ('2008.10', 14),
#  ('소', 14),
#  ('새털', 14),
#  ('한자어', 14),
#  ('열', 13),
#  ('남자', 13),
#  ('패키지', 13),
#  ('선택', 13),
#  ('또한', 13),
#  ('바', 13),
#  (';;', 13),
#  ('요즘', 13),
#  ('간', 13),
#  ('하지', 13),
#  ('즐겨', 13),
#  ('ㅜㅜ', 13),
#  ('해양', 13),
#  ('알려주시면', 13),
#  ('난', 13),
#  ('국어', 13),
#  ('현재', 13),
#  ('빨리요', 13),
#  ('가는', 13),
#  ('뚜껑', 13),
#  ('음식점', 13),
#  ('많고', 13),
#  ('the', 13),
#  ('닭', 13),
#  ('2014.01', 13),
#  ('씩', 13),
#  ('위해', 13),
#  ('빨', 13),
#  ('양', 13),
#  ('아무', 13),
#  ('식품', 13),
#  ('그럼', 13),
#  ('2010.01', 13),
#  ('초등학교', 13),
#  ('그러는데', 13),
#  ('2011.05', 13),
#  ('인도', 13),
#  ('반죽', 13),
#  ('수행평가', 13),
#  ('찬밥', 13),
#  ('매우', 13),
#  ('장', 13),
#  ('그리스', 13),
#  ('되요', 13),
#  ('분양', 13),
#  ('님', 13),
#  ('계획', 12),
#  ('문제', 12),
#  ('자주', 12),
#  ('되어', 12),
#  ('경험', 12),
#  ('니까', 12),
#  ('국', 12),
#  ('예쁜', 12),
#  ('진짜', 12),
#  ('학교숙제', 12),
#  ('소나기', 12),
#  ('이며', 12),
#  ('ㅋㅋ', 12),
#  ('보면', 12),
#  ('추운', 12),
#  ('무슨', 12),
#  ('이용', 12),
#  ('분야', 12),
#  ('법', 12),
#  ('무척', 12),
#  ('캐나다', 12),
#  ('있으면', 12),
#  ('내용', 12),
#  ('7월', 12),
#  ('하려고', 12),
#  ('나서', 12),
#  ('개월', 12),
#  ('아이', 12),
#  ('이구', 12),
#  ('2011.11', 12),
#  ('가면', 12),
#  ('모르겠네요', 12),
#  ('외국어', 12),
#  ('거지', 12),
#  ('그것', 12),
#  ('교회', 12),
#  ('어려운', 12),
#  ('조', 12),
#  ('천국', 12),
#  ('동물', 12),
#  ('이라는', 12),
#  ('찾기', 12),
#  ('표현', 12),
#  ('용법', 12),
#  ('나무', 12),
#  ('ㅡ', 12),
#  ('11월', 11),
#  ('쯤', 11),
#  ('해도', 11),
#  ('엄청', 11),
#  ('관광', 11),
#  ('이에요', 11),
#  ('써', 11),
#  ('!!!!', 11),
#  ('있고', 11),
#  ('준비물', 11),
#  ('친구', 11),
#  ('_', 11),
#  ('60', 11),
#  ('2007.08', 11),
#  ('죠', 11),
#  ('정리', 11),
#  ('대만', 11),
#  ('단오', 11),
#  ('검', 11),
#  ('일이', 11),
#  ('시작', 11),
#  ('치는', 11),
#  ('우엉', 11),
#  ('조림', 11),
#  ('아람', 11),
#  ('농산', 11),
#  ('안녕하세여', 11),
#  ('용', 11),
#  ('두', 11),
#  ('불어오고', 11),
#  ('수제비', 11),
#  ('이라도', 11),
#  ('맑은', 11),
#  ('가는데', 11),
#  ('8', 11),
#  ('머리', 11),
#  ('빠른', 11),
#  ('어', 11),
#  ('예절', 11),
#  ('직하게', 11),
#  ('바로', 11),
#  ('2008.08', 11),
#  ('어쩔', 11),
#  ('형', 11),
#  ('물론', 11),
#  ('모르는', 11),
#  ('2009.09', 11),
#  ('63', 11),
#  ('한랭', 11),
#  ('통과', 11),
#  ('쇠', 11),
#  ('원', 11),
#  ('자꾸', 11),
#  ('남한', 11),
#  ('우기', 10),
#  ('12월', 10),
#  ('4일', 10),
#  ('어디가', 10),
#  ('환경', 10),
#  ('발생', 10),
#  ('주의', 10),
#  ('일반', 10),
#  ('준비', 10),
#  ('걸어요', 10),
#  ('대충', 10),
#  ('전체', 10),
#  ('여름날', 10),
#  ('맞는', 10),
#  ('늘', 10),
#  ('드릴게요', 10),
#  ('인터넷', 10),
#  ('주는', 10),
#  ('약', 10),
#  ('매운', 10),
#  ('2월', 10),
#  ('그게', 10),
#  ('몰라서', 10),
#  ('일단', 10),
#  ('그러던', 10),
#  ('ㅋ', 10),
#  ('며', 10),
#  ('역사', 10),
#  ('스시', 10),
#  ('참고', 10),
#  ('도의', 10),
#  ('드려요', 10),
#  ('고맙겠습니다', 10),
#  ('치고', 10),
#  ('없어서', 10),
#  ('떡', 10),
#  ('받아', 10),
#  ('2007.04', 10),
#  ('기도', 10),
#  ('온', 10),
#  ('날개', 10),
#  ('찾아주세요', 10),
#  ('8월', 10),
#  ('학생', 10),
#  ('팍팍', 10),
#  ('알아오래요', 10),
#  ('2008.02', 10),
#  ('2008.06', 10),
#  ('편', 10),
#  ('★', 10),
#  ('거기', 10),
#  ('존재', 10),
#  ('담고', 10),
#  ('수저', 10),
#  ('키우는', 10),
#  ('먹은', 10),
#  ('있는지', 10),
#  ('인간', 10),
#  ('숙젠데', 10),
#  ('샌', 10),
#  ('올빼미', 10),
#  ('신세', 10),
#  ('세력', 10),
#  ('없어져', 10),
#  ('외로운', 10),
#  ('같은데', 10),
#  ('인가', 10),
#  ('장단점', 10),
#  ('호주', 10),
#  ('미역', 10),
#  ('싸하다', 10),
#  ('동', 10),
#  ('좋을까요', 9),
#  ('싶은데요', 9),
#  ('메뉴', 9),
#  ('걱정', 9),
#  ('얼마나', 9),
#  ('한낮', 9),
#  ('햇볕', 9),
#  ('ad', 9),
#  ('71', 9),
#  ('코스', 9),
#  ('따뜻한', 9),
#  ('거의', 9),
#  ('이라서', 9),
#  ('되면', 9),
#  ('부모님', 9),
#  ('되고', 9),
#  ('말씀', 9),
#  ('내리는', 9),
#  ('저가', 9),
#  ('한글', 9),
#  ('공부', 9),
#  ('술', 9),
#  ('바랍니다', 9),
#  ('휴양지', 9),
#  ('시원하게', 9),
#  ('먹을', 9),
#  ('사랑', 9),
#  ('금', 9),
#  ('넘', 9),
#  ('써주시면', 9),
#  ('음', 9),
#  ('각국', 9),
#  ('in', 9),
#  ('막', 9),
#  ('눈물', 9),
#  ('가르', 9),
#  ('이해', 9),
#  ('A', 9),
#  ('하나요', 9),
#  ('영어', 9),
#  ('한자', 9),
#  ('채택', 9),
#  ('프랑스', 9),
#  ('부지런하면', 9),
#  ('먹는다', 9),
#  ('간다', 9),
#  ('초딩', 9),
#  ('다양한', 9),
#  ('2007.12', 9),
#  ('사투리', 9),
#  ('검다', 9),
#  ('알려주세', 9),
#  ('딸', 9),
#  ('또는', 9),
#  ('예수', 9),
#  ('야', 9),
#  ('와의', 9),
#  ('해산', 9),
#  ('산모', 9),
#  ('해주었던', 9),
#  ('보릿가루', 9),
#  ('몇개', 9),
#  ('짧은', 9),
#  ('중국인', 9),
#  ('매', 9),
#  ('2005.08', 9),
#  ('듯', 9),
#  ('재미있는', 9),
#  ('여러분', 9),
#  ('알수', 9),
#  ('그러나', 9),
#  ('많다', 9),
#  ('남', 9),
#  ('먹지도', 9),
#  ('꾀꼬리', 9),
#  ('문과', 9),
#  ('지나서', 9),
#  ('아직', 9),
#  ('홍삼', 9),
#  ('증상', 8),
#  ('바다', 8),
#  ('보통', 8),
#  ('배낭여행', 8),
#  ('경비', 8),
#  ('나가면', 8),
#  ('53', 8),
#  ('저렴한', 8),
#  ('괜찮은', 8),
#  ('대부분', 8),
#  ('거나', 8),
#  ('차례', 8),
#  ('요란한', 8),
#  ('위치', 8),
#  ('김', 8),
#  ('먹지', 8),
#  ('2006.08', 8),
#  ('흔히', 8),
#  ('년', 8),
#  ('2012.12', 8),
#  ('파스타', 8),
#  ('먹는데', 8),
#  ('남쪽', 8),
#  ('쫌', 8),
#  ('바가지', 8),
#  ('2007.03', 8),
#  ('필수', 8),
#  ('기온', 8),
#  ('올라가면', 8),
#  ('아시아', 8),
#  ('9월', 8),
#  ('여자', 8),
#  ('미', 8),
#  ('서요', 8),
#  ('죽', 8),
#  ('지구', 8),
#  ('2004.12', 8),
#  ('영', 8),
#  ('여기', 8),
#  ('이상한', 8),
#  ('건강', 8),
#  ('고생', 8),
#  ('나쁜', 8),
#  ('그런', 8),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9702 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9642 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9702 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9642 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
