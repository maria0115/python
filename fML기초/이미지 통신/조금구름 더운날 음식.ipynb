# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('조금구름 더운날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('조금구름 더운날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('조금구름 더운날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('조금구름 더운날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('조금구름 더운날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('조금구름 더운날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '의',
#  '종류',
#  '가르쳐주세요',
#  '2017.10',
#  '.',
#  '28',
#  '.',
#  '한식',
#  '의',
#  '종류',
#  '와',
#  '특징',
#  '을',
#  '가르쳐주세요',
#  '답변',
#  '한식',
#  '에',
#  '대한',
#  '모든',
#  '것',
#  ',',
#  '한식',
#  '의',
#  '종류',
#  ',',
#  '한식',
#  '의',
#  '특징',
#  '...',
#  '식사',
#  '예절',
#  '식사',
#  '예절',
#  '은',
#  '지역',
#  '이나',
#  '가정',
#  '에',
#  '따라',
#  '조금씩',
#  '다를',
#  '...',
#  '것',
#  '이다',
#  '.',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '방향',
#  '을',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '퍼져요',
#  'ㅜㅜㅜ',
#  '음식',
#  '알러지',
#  '는',
#  '없는데',
#  '병원',
#  '에선',
#  '음식',
#  '알러지',
#  '...',
#  '2020.06',
#  '.',
#  '16',
#  '.',
#  '이틀',
#  '전',
#  '부터',
#  '두드러기',
#  '가',
#  '올라와서요',
#  '간지러워서',
#  '긁으면',
#  '저렇게',
#  '빨갛게',
#  '퍼져요',
#  'ㅜㅜㅜ',
#  '음식',
#  '알러지',
#  '는',
#  '없는데',
#  '병원',
#  '에선',
#  '음식',
#  '알러지',
#  '같다고',
#  '그냥',
#  '가려울',
#  '때',
#  '먹는',
#  '약',
#  '만',
#  '주시네요',
#  '...',
#  '답변',
#  '증상만',
#  '조금',
#  '가라앉힐',
#  '수',
#  '있을',
#  '뿐',
#  '이며',
#  ',',
#  '그',
#  '마저도',
#  '듣지',
#  '...',
#  '특히',
#  '요즘',
#  '처럼',
#  '더운',
#  '날씨',
#  '에는',
#  '익히지',
#  '않은',
#  '음식',
#  '이나',
#  '...',
#  '위주',
#  ',',
#  '한식',
#  ')',
#  '로',
#  '바꿔',
#  '보시기',
#  '바랍니다',
#  '.',
#  '그',
#  '이유',
#  '는',
#  ',',
#  '현재',
#  '몸',
#  '에',
#  '...',
#  '한의사',
#  '답변',
#  '닉네임',
#  '이종우',
#  '질문',
#  '한식',
#  '의',
#  '유래',
#  '점',
#  '알려주세여',
#  '2015.09',
#  '.',
#  '23',
#  '.',
#  '제',
#  '가',
#  '파워포인트',
#  '주제',
#  '로',
#  '한식',
#  '을',
#  '했는데',
#  '뭔',
#  '지',
#  '를',
#  '모르겟음',
#  '여',
#  '답변',
#  '따라',
#  '조금씩',
#  '다를',
#  '수',
#  '있으나',
#  '대체로',
#  '다음',
#  '과',
#  '같다',
#  '....',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '방향',
#  '을',
#  '...',
#  '것',
#  '이',
#  '한식',
#  '의',
#  '원칙',
#  '이다',
#  '.',
#  '밥',
#  '의',
#  '종류',
#  '는',
#  '매우',
#  '다양한데',
#  ',',
#  '우선',
#  '...',
#  '닉네임',
#  'soft',
#  '****',
#  '질문',
#  '한국',
#  '요리',
#  '가',
#  '왜',
#  '대부분',
#  '궁',
#  '중',
#  '음식',
#  '인가요',
#  '?',
#  '2019.05',
#  '.',
#  '07',
#  '.',
#  '한국',
#  '요리',
#  '가',
#  '왜',
#  '대부분',
#  '궁',
#  '중',
#  '음식',
#  '인가요',
#  '?',
#  '한식',
#  '조리사',
#  '자격증',
#  '딸때',
#  '나',
#  '학교',
#  '급식',
#  ',',
#  '한식당',
#  ',',
#  '집밥',
#  '으로',
#  '나오는',
#  '한식',
#  '이',
#  '잡채',
#  ',',
#  '불고기',
#  ',',
#  '순두부',
#  ',',
#  '떡갈비',
#  '뭐',
#  '전부',
#  '다',
#  '조선시대',
#  '엔',
#  '왕족',
#  '만',
#  '먹던',
#  '...',
#  '답변',
#  '잎',
#  '숟가락',
#  '은',
#  '버들잎',
#  '처럼',
#  '조금',
#  '길쭉하게',
#  '생긴',
#  '것',
#  '을',
#  '말',
#  '한다',
#  '.',
#  '옛날',
#  '숟가락',
#  '의',
#  '모습',
#  '이다',
#  '....',
#  '반상기',
#  '뚜껑',
#  '은',
#  '종지',
#  '부터',
#  '찬',
#  '그릇',
#  '·',
#  '김치',
#  '그릇',
#  '·',
#  '더운',
#  '음식',
#  '의',
#  '순서',
#  '로',
#  '연',
#  '다',
#  '.',
#  '책상',
#  '반',
#  '앞',
#  '에',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '부산',
#  '뚜벅',
#  '이',
#  '여행',
#  '갈만',
#  '한',
#  '곳',
#  '6일',
#  '전',
#  '부산여행',
#  '1',
#  '박',
#  '2일',
#  '친구',
#  '랑',
#  '가는데',
#  '첫날',
#  '은',
#  '광안',
#  '리',
#  '에서',
#  '놀거고',
#  '2',
#  '째',
#  '날',
#  '국제',
#  '시장',
#  '갔다가',
#  '놀다',
#  '집',
#  '갈건데',
#  '갈만',
#  '한',
#  '곳',
#  '추천',
#  '좀',
#  '해주세요',
#  '답변',
#  '금액',
#  '은',
#  '조금',
#  '비싼',
#  '편',
#  '인데',
#  '맛',
#  '은',
#  '일품',
#  '이',
#  '예요',
#  '#남포동',
#  '...',
#  '남포동',
#  '데이트',
#  '핫플',
#  '이라고',
#  '하면',
#  '다',
#  '알',
#  '정도',
#  '구',
#  '요',
#  '한식',
#  '일식',
#  '...',
#  '오픈',
#  '한',
#  '#송도구름다리',
#  '까지',
#  '.....',
#  '진짜',
#  '놀게',
#  '많다',
#  '.....',
#  '닉네임',
#  'rhkd',
#  '****',
#  '질문',
#  '부산여행',
#  '2',
#  '박',
#  '3일',
#  '대중교통',
#  '6일',
#  '전',
#  '이번',
#  '에',
#  '여자친구',
#  '랑',
#  '수',
#  '목금',
#  '2',
#  '박',
#  '3일',
#  '로',
#  '부산',
#  '여행',
#  '을',
#  '가는데',
#  '차',
#  '없이',
#  '대중교통',
#  '으로',
#  '돌아다닐',
#  '예정',
#  '입니다',
#  '숙소',
#  '는',
#  '광안',
#  '리',
#  '수',
#  '영',
#  '구이구',
#  '요',
#  '둘다',
#  '물들어가는건',
#  '별로',
#  '안',
#  '좋아해서',
#  '그냥',
#  '...',
#  '답변',
#  '금액',
#  '은',
#  '조금',
#  '비싼',
#  '편',
#  '인데',
#  '맛',
#  '은',
#  '일품',
#  '이',
#  '예요',
#  '#남포동',
#  '...',
#  '남포동',
#  '데이트',
#  '핫플',
#  '이라고',
#  '하면',
#  '다',
#  '알',
#  '정도',
#  '구',
#  '요',
#  '한식',
#  '일식',
#  '...',
#  '오픈',
#  '한',
#  '#송도구름다리',
#  '까지',
#  '.....',
#  '진짜',
#  '놀게',
#  '많다',
#  '.....',
#  '닉네임',
#  'rhkd',
#  '****',
#  '질문',
#  '비올',
#  '때',
#  '부산여행',
#  '2020.07',
#  '.',
#  '22',
#  '.',
#  '제',
#  '가',
#  '2',
#  '박',
#  '3일',
#  '부산여행',
#  '을',
#  '가는데',
#  '장마철',
#  '이라',
#  '하필',
#  '3일',
#  '내내',
#  '비',
#  '가',
#  '온다네요',
#  '...',
#  '그래서',
#  '몇',
#  '가지',
#  '묻고싶어용',
#  'ㅠㅠ',
#  '1',
#  '.',
#  '비올',
#  '때',
#  '부산',
#  '에서',
#  '갈만',
#  '한',
#  '곳',
#  '있을까요',
#  '?',
#  '2',
#  '.',
#  '부산',
#  '태종대',
#  '...',
#  '답변',
#  '금액',
#  '은',
#  '조금',
#  '비싼',
#  '편',
#  '인데',
#  '맛',
#  '은',
#  '일품',
#  '이',
#  '예요',
#  '#남포동',
#  '...',
#  '남포동',
#  '데이트',
#  '핫플',
#  '이라고',
#  '하면',
#  '다',
#  '알',
#  '정도',
#  '구',
#  '요',
#  '한식',
#  '일식',
#  '...',
#  '오픈',
#  '한',
#  '#송도구름다리',
#  '까지',
#  '.....',
#  '진짜',
#  '놀게',
#  '많다',
#  '.....',
#  '닉네임',
#  'rhkd',
#  '****',
#  '질문',
#  '2',
#  '박',
#  '3일',
#  '부산',
#  '여행',
#  '루트',
#  '!!',
#  '2020.07',
#  '.',
#  '19',
#  '.',
#  '비행기',
#  '타고',
#  '가서',
#  '김해',
#  '공항',
#  '에서',
#  '시작',
#  '해서',
#  '1',
#  '박은',
#  '해운대',
#  '쪽',
#  '에서',
#  '할거고',
#  '2',
#  '박은',
#  '남포동',
#  '자갈치역',
#  '?',
#  '쪽',
#  '에서',
#  '할',
#  '겁니다',
#  '!',
#  '뚜벅',
#  '이라',
#  '택시',
#  '아니면',
#  '지하철',
#  '이나',
#  '버스',
#  '이용',
#  '하려구여',
#  'ㅠ',
#  '...',
#  '답변',
#  '금액',
#  '은',
#  '조금',
#  '비싼',
#  '편',
#  '인데',
#  '맛',
#  '은',
#  '일품',
#  '이',
#  '예요',
#  '#남포동',
#  '...',
#  '남포동',
#  '데이트',
#  '핫플',
#  '이라고',
#  '하면',
#  '다',
#  '알',
#  '정도',
#  '구',
#  '요',
#  '한식',
#  '일식',
#  '...',
#  '오픈',
#  '한',
#  '#송도구름다리',
#  '까지',
#  '.....',
#  '진짜',
#  '놀게',
#  '많다',
#  '.....',
#  '닉네임',
#  'rhkd',
#  '****',
#  '질문',
#  '저',
#  '랑',
#  '친구',
#  '랑',
#  '오랜',
#  '만',
#  '에',
#  '같이',
#  '여행',
#  '을',
#  '가',
#  '2020.07',
#  '.',
#  '07',
#  '.',
#  '제주도',
#  '향토',
#  '음식점',
#  '같은',
#  '곳',
#  '이나',
#  '다니면서',
#  '신나게',
#  '먹고',
#  '오려구',
#  '해',
#  '요',
#  '.',
#  '제주도',
#  '가',
#  '색다른',
#  '음식',
#  '같은게',
#  '많다고',
#  '하길래요',
#  '.',
#  '제주',
#  '향토',
#  '음식점',
#  '중',
#  '에',
#  '가볼만',
#  '한',
#  '곳좀',
#  '부탁드려요',
#  '.',
#  '답변',
#  '지금',
#  '은',
#  '장마철',
#  '이라서',
#  '비오는',
#  '날',
#  '이나',
#  '구름',
#  '낀',
#  '날',
#  '은',
#  '...',
#  '고구려',
#  '한식',
#  '(',
#  '064-738',
#  '-',
#  '7380',
#  ')',
#  ':',
#  '흑',
#  '돼지',
#  '구이',
#  ',',
#  '갈치',
#  '구이',
#  '...',
#  '중문',
#  '에',
#  '있는',
#  '컨벤션',
#  '센터',
#  '를',
#  '조금',
#  '지나',
#  '대포항',
#  '이라는',
#  '작은',
#  '포구',
#  '...',
#  '닉네임',
#  'alak',
#  '****',
#  '질문',
#  '부산',
#  '부산',
#  '여행',
#  '!!!',
#  '2',
#  '박',
#  '3일',
#  '2020.07',
#  '.',
#  '21',
#  '.',
#  '이번',
#  '7월',
#  '28',
#  ',',
#  '29',
#  ',',
#  '30',
#  '에',
#  '부산',
#  '으로',
#  '여자친구',
#  '와',
#  '여행',
#  '을',
#  '다녀올',
#  '생각',
#  '인데',
#  '요',
#  '!',
#  '시국',
#  '이',
#  '시국',
#  '인',
#  '만큼',
#  '그',
#  '동안',
#  '제대로',
#  '만나지도',
#  '놀지도',
#  '못',
#  '해서',
#  '이번',
#  '에',
#  '살짝',
#  '다녀오려고',
#  '합니다',
#  '!!',
#  '당연히',
#  '...',
#  '답변',
#  '금액',
#  '은',
#  '조금',
#  '비싼',
#  '편',
#  '인데',
#  '맛',
#  '은',
#  '일품',
#  '이',
#  '예요',
#  '#남포동',
#  '...',
#  '남포동',
#  '데이트',
#  '핫플',
#  '이라고',
#  '하면',
#  '다',
#  '알',
#  '정도',
#  '구',
#  '요',
#  '한식',
#  '일식',
#  '...',
#  '오픈',
#  '한',
#  '#송도구름다리',
#  '까지',
#  '.....',
#  '진짜',
#  '놀게',
#  '많다',
#  '.....',
#  '닉네임',
#  'rhkd',
#  '****',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '우리나라',
#  '전통',
#  '생활',
#  '의복',
#  ',',
#  '음식',
#  ',',
#  '주거',
#  '이',
#  '2019.03',
#  '.',
#  '18',
#  '.',
#  '우리나라',
#  '전통',
#  '생활',
#  '의복',
#  ',',
#  '음식',
#  ',',
#  '주거',
#  '이',
#  '세',
#  '가지',
#  '가',
#  '뭔',
#  '지',
#  '알려주세요',
#  '.',
#  '많이',
#  '써주세요',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='조금구름 더운날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='조금구름 더운날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='조금구름 더운날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='조금구름 더운날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='조금구름 더운날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='조금구름 더운날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 89807
# 7982

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 4290),
#  ('...', 2932),
#  ('이', 1746),
#  ('을', 1381),
#  ('의', 1299),
#  (',', 1299),
#  ('를', 1241),
#  ('에', 1229),
#  ('답변', 1086),
#  ('질문', 1051),
#  ('가', 1048),
#  ('닉네임', 932),
#  (':', 888),
#  ('음식', 879),
#  ('은', 758),
#  ('더운', 725),
#  ('조금', 691),
#  ('****', 651),
#  ('단어', 646),
#  ('구름', 610),
#  ('는', 494),
#  ('하는', 485),
#  ('것', 467),
#  ('때', 456),
#  ('(', 440),
#  ('좀', 439),
#  ('로', 426),
#  ('검색', 404),
#  ('들', 397),
#  ('으로', 382),
#  ('말', 376),
#  ('도', 365),
#  ('날', 362),
#  ('과', 350),
#  ('나라', 323),
#  (')', 318),
#  ('입력', 300),
#  ('비', 298),
#  ('..', 296),
#  ('한', 289),
#  ('요', 286),
#  ('다', 282),
#  ('우리말', 280),
#  ('개', 270),
#  ('알려주세요', 266),
#  ('등', 262),
#  ('바깥', 262),
#  ('나', 257),
#  ('사람', 257),
#  ('만든', 250),
#  ('●', 249),
#  ('여러', 241),
#  ('내공', 234),
#  ('합니다', 226),
#  ('안', 224),
#  ('만', 220),
#  ('속담', 214),
#  ('하세요', 212),
#  ('포함', 208),
#  ('?', 206),
#  ('제', 204),
#  ('고', 199),
#  ('뜻', 198),
#  ('에서', 189),
#  ('속', 178),
#  ('너무', 177),
#  ('밥', 171),
#  ('그', 169),
#  ('게', 169),
#  ('된', 160),
#  ('해서', 157),
#  ('학년', 157),
#  ('명절', 156),
#  ('숙제', 156),
#  ('사주', 154),
#  ('1', 148),
#  ('입니다', 147),
#  ('열', 147),
#  ('할', 146),
#  ('에는', 146),
#  ('기', 145),
#  ('까지', 144),
#  ('....', 143),
#  ('다른', 142),
#  ('시간', 142),
#  ('운', 141),
#  ('나무', 140),
#  ('쓰는', 139),
#  ('몸', 138),
#  ('순우리말', 138),
#  ('방', 138),
#  ('~', 135),
#  ('질', 135),
#  ('이상', 134),
#  ('저', 134),
#  ('세계', 133),
#  ('순대', 133),
#  ('피', 131),
#  ('돼지', 130),
#  ('와', 129),
#  ('파골집', 129),
#  ('창자', 129),
#  ('섞어서', 129),
#  ('삶아', 129),
#  ('/', 128),
#  ('이다', 128),
#  ('내', 127),
#  ('돌', 127),
#  ('될', 126),
#  ('마소', 126),
#  ('비비는', 126),
#  ('말고', 124),
#  ('20', 124),
#  ('건강', 123),
#  ('전통', 122),
#  ('하나', 121),
#  ('동남아', 120),
#  ('☞', 120),
#  ('사용', 119),
#  ('햄스터', 119),
#  ('보는', 118),
#  ('-', 118),
#  ('대해', 117),
#  ('차고', 117),
#  ('조금씩', 117),
#  ('놀이', 116),
#  ('위', 115),
#  ('그렇다고', 115),
#  ('클릭', 115),
#  ('있으니', 114),
#  ('차례', 114),
#  ('필시', 113),
#  ('성공', 113),
#  ('거두게', 113),
#  ('급하게', 113),
#  ('서둘지', 113),
#  ('느긋하게', 113),
#  ('기다려', 113),
#  ('중요합니다', 113),
#  ('인한', 113),
#  ('못', 112),
#  ('본', 111),
#  ('이나', 111),
#  ('!', 111),
#  ('먹는', 111),
#  ('5', 111),
#  ('계절', 110),
#  ('또', 110),
#  ('문장', 109),
#  ('짓', 109),
#  (')...', 109),
#  ('여기', 107),
#  ('기본', 105),
#  ('결과', 104),
#  ('구분', 104),
#  ('정확히', 102),
#  ('반드시', 102),
#  ('제외', 102),
#  ('많이', 102),
#  ('3', 102),
#  ('상세', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('알', 100),
#  ('10', 98),
#  ('100', 98),
#  ('기념일', 98),
#  ('인데', 97),
#  ('서', 96),
#  ('하', 95),
#  ('영어', 95),
#  ('이름', 94),
#  ('빨리', 94),
#  ('하며', 94),
#  ('아', 93),
#  ('해', 92),
#  ('아름다운', 92),
#  ('여름철', 92),
#  ('중', 90),
#  ('30', 90),
#  ('부탁', 90),
#  ('즐거운', 90),
#  ('정도', 88),
#  ('안녕하세요', 88),
#  ('2', 88),
#  ('부탁드립니다', 87),
#  ('일', 86),
#  ('2010.12', 86),
#  ('설날', 86),
#  ('연날리기', 86),
#  ('보낸다', 86),
#  ('성인', 86),
#  ('成人の日', 86),
#  ('내리는', 85),
#  ('시원한', 85),
#  ('인', 84),
#  ('지나가고', 84),
#  ('도래', 84),
#  ('잘', 83),
#  ('주세요', 83),
#  ('우리', 82),
#  ('가지', 82),
#  ('매', 80),
#  ('다시', 79),
#  ('찬', 78),
#  ('!!', 77),
#  ('핵심', 76),
#  ('거리', 76),
#  ('적', 75),
#  ('날씨', 75),
#  ('여', 74),
#  ('수', 71),
#  ('고유어', 71),
#  ('[', 71),
#  ('목', 70),
#  ('여자', 70),
#  (']', 70),
#  ('있는', 70),
#  ('우리나라', 70),
#  ('나서', 69),
#  ('조사', 69),
#  ('전', 68),
#  ('산', 68),
#  ('얹어', 67),
#  ('찌거나', 67),
#  ('조각', 67),
#  ('캐', 67),
#  ('하고', 67),
#  ('소리', 66),
#  ('사물', 66),
#  ('되지기', 66),
#  ('①', 66),
#  ('연기', 66),
#  ('곰', 66),
#  ('팡', 66),
#  ('15', 66),
#  ('어떤', 66),
#  ('면', 65),
#  ('하는데', 65),
#  ('새참', 65),
#  ('고갱', 65),
#  ("'", 65),
#  ('그리고', 65),
#  ('모두', 65),
#  ('농가월령가', 65),
#  ('풀이', 64),
#  ('방학', 64),
#  ('4', 62),
#  ('꼭', 62),
#  ('양력', 62),
#  ('오늘', 62),
#  ('^^', 60),
#  ('거의', 60),
#  ('학교', 60),
#  ('ag', 59),
#  ('좋은', 58),
#  ('하여', 58),
#  ('13', 57),
#  ('해주세요', 57),
#  ('14', 57),
#  ('밤', 57),
#  ('ㅠㅠ', 56),
#  ('곳', 55),
#  ('간', 55),
#  ('생활', 55),
#  ('부지런해야', 55),
#  ('??', 54),
#  ('맛', 54),
#  ('순', 54),
#  ('"', 53),
#  ('남자', 53),
#  ('분', 52),
#  ('처럼', 52),
#  ('중국', 52),
#  ('물', 52),
#  ('아주', 52),
#  ('예쁜', 51),
#  ('!!!', 51),
#  ('12', 51),
#  ('주어', 51),
#  ('야', 51),
#  ('일본', 50),
#  ('있다', 50),
#  ('17', 49),
#  ('예', 49),
#  ('사회', 49),
#  ('하면', 47),
#  ('.....', 47),
#  ('더', 46),
#  ('없고', 46),
#  ('제발', 46),
#  ('오는', 46),
#  ('밑', 46),
#  ('여행', 45),
#  ('봐주세요', 45),
#  ('11', 45),
#  ('한다', 45),
#  ('16', 45),
#  ('과학', 45),
#  ('히', 45),
#  ('관련', 44),
#  ('보리', 44),
#  ('개도', 44),
#  ('두고', 44),
#  ('24', 43),
#  ('예수님', 43),
#  ('19', 43),
#  ('대부분', 42),
#  ('바람', 42),
#  ('6', 42),
#  ('씨', 42),
#  ('mhos', 42),
#  ('보세', 42),
#  ('03', 41),
#  ('살코기', 41),
#  ('밀', 41),
#  ('심어', 41),
#  ('09', 40),
#  ('그래서', 40),
#  ('나누어서', 40),
#  ('나머지', 40),
#  ('켜오리라', 40),
#  ('자애', 40),
#  ('능', 40),
#  ('지어', 40),
#  ('뭉게뭉게', 40),
#  ('미쳐', 40),
#  ('급한', 40),
#  ('26', 39),
#  ('뭐', 39),
#  ('타고', 39),
#  ('기록', 39),
#  ('뉘', 39),
#  ('베어', 39),
#  ('갈이', 39),
#  ('끝끝', 39),
#  ('익어도', 39),
#  ('83', 39),
#  ('간혹', 38),
#  ('25', 38),
#  ('오후', 38),
#  ('달', 38),
#  ('세', 38),
#  ('경우', 37),
#  ('21', 37),
#  ('지', 37),
#  ('내일', 37),
#  ('양', 37),
#  ('관', 37),
#  ('거', 37),
#  ('몇', 37),
#  ('적어주세요', 37),
#  ('가르쳐', 37),
#  ('철장', 37),
#  ('한국', 36),
#  ('개미', 36),
#  ('이면', 36),
#  ('여름', 36),
#  ('50', 36),
#  ('재림', 36),
#  ('전혀', 36),
#  ('사이', 36),
#  ('신고', 36),
#  ('써주세요', 36),
#  ('hot', 36),
#  ('이라도', 36),
#  ('아메리카', 35),
#  ('모른다', 35),
#  ('지금', 35),
#  ('같은', 35),
#  ('주', 35),
#  ('뜨거운', 35),
#  ('부분', 35),
#  ('소금', 35),
#  ('사다리타기', 35),
#  ('묘기', 35),
#  ('부리곤', 35),
#  ('한답니다', 35),
#  ('특징', 34),
#  ('29', 34),
#  ('음력', 34),
#  ('무엇', 34),
#  ('2016.11', 34),
#  ('차지', 34),
#  ('내용', 34),
#  ('07', 33),
#  ('때문', 33),
#  ('맞히지는', 33),
#  ('28', 33),
#  ('대', 33),
#  ('많은', 33),
#  ('얻어먹는다', 33),
#  ('ocam', 33),
#  ('필리핀', 32),
#  ('전체', 32),
#  ('강한', 32),
#  ('*', 32),
#  ('되고', 32),
#  ('선생님', 32),
#  ('큰', 31),
#  ('2008.03', 31),
#  ('쪽', 31),
#  ('04', 31),
#  ('북한', 31),
#  ('눈', 31),
#  ('강', 31),
#  ('정말', 30),
#  ('랑', 30),
#  ('부탁드려요', 30),
#  ('기운', 30),
#  ('순수한', 30),
#  ('23', 29),
#  ('부터', 29),
#  ('태어난', 29),
#  ('땅', 29),
#  ('책', 29),
#  ('ethn', 29),
#  ('18', 29),
#  ('아래', 29),
#  ('방법', 29),
#  ('월령', 29),
#  ('같이', 28),
#  ('별', 28),
#  ('하면서', 28),
#  ('음', 28),
#  ('고유', 28),
#  ('교회', 28),
#  ('농가', 28),
#  ('바다', 27),
#  ('마음', 27),
#  ('겁니다', 27),
#  ('바로', 27),
#  ('까닭', 27),
#  ('보통', 27),
#  ('냠냠', 27),
#  ('떠', 27),
#  ('석빙고', 27),
#  ('없다', 26),
#  ('22', 26),
#  ('인지', 26),
#  ('하늘', 26),
#  ('미국', 26),
#  ('모이는', 26),
#  ('네', 26),
#  ('0', 26),
#  ('있나요', 26),
#  ('^', 26),
#  ('98', 26),
#  ('05', 25),
#  ('저희', 25),
#  ('왜', 25),
#  ('님', 25),
#  ('듯', 25),
#  ('지식인', 25),
#  ('점', 25),
#  ('새', 25),
#  ('세상', 25),
#  ('2008.04', 25),
#  ('정리', 25),
#  ('11월', 24),
#  ('해야', 24),
#  (',,', 24),
#  ('27', 24),
#  ('이번', 24),
#  ('한글', 24),
#  ('글', 24),
#  ('드림', 24),
#  ('않', 24),
#  ('초등학교', 24),
#  ('길', 24),
#  ('가랑비', 24),
#  ('여름방학', 24),
#  ('걸', 23),
#  ('등등', 23),
#  ('가장', 23),
#  ('이런', 23),
#  ('오전', 23),
#  ('에게', 23),
#  ('의미', 23),
#  ('맑은', 23),
#  ('아이', 23),
#  ('초', 23),
#  ('최대한', 23),
#  ('있습니다', 23),
#  ('성경', 23),
#  ('이유', 23),
#  ('천국', 23),
#  ('~~', 23),
#  ('타', 23),
#  ('먹어서', 23),
#  ('낱말', 23),
#  ('2008.09', 23),
#  ('가온', 23),
#  ('추천', 22),
#  ('지만', 22),
#  ('국', 22),
#  ('문화', 22),
#  ('시', 22),
#  ('운세', 22),
#  ('드립니다', 22),
#  ('그런데', 22),
#  ('대한', 22),
#  ('명', 22),
#  ('어느', 22),
#  ('food', 22),
#  ('태국', 22),
#  ('과는', 22),
#  ('이렇게', 22),
#  ('사례', 22),
#  ('형식', 22),
#  ('구름다리', 22),
#  ('자세히', 22),
#  ('남아', 22),
#  ('......', 22),
#  ('가르쳐주세요', 22),
#  ('최고', 22),
#  ('라서', 22),
#  ('않는다는', 22),
#  ('똥', 22),
#  ('만들', 22),
#  ('학기', 22),
#  ('먹어', 22),
#  ('∼', 22),
#  ('인가요', 21),
#  ('없는', 21),
#  ('정', 21),
#  ('ㅜㅜ', 21),
#  ('1월', 21),
#  ('06', 21),
#  ('구', 21),
#  ('식물', 21),
#  ('흰', 21),
#  ('모양', 21),
#  ('아시', 21),
#  ('감사하겠습니다', 21),
#  ('작은', 21),
#  ('8월', 21),
#  ('두', 21),
#  ('급해요', 21),
#  ('올려주세요', 21),
#  ('생각', 21),
#  ('에도', 21),
#  ('있다면', 21),
#  ('씩', 21),
#  ('08', 21),
#  ('사투리', 21),
#  ('접대', 21),
#  ('받는다', 21),
#  ('2008.08', 21),
#  ('신세', 21),
#  ('마는', 21),
#  ('2008.10', 21),
#  ('A', 21),
#  ('되는', 20),
#  ('식품', 20),
#  ('천지창조', 20),
#  ('세째', 20),
#  ('01', 20),
#  ('형용사', 20),
#  ('궁금합니다', 20),
#  ('분야', 20),
#  ('시나', 20),
#  ('브로', 20),
#  ('설명', 20),
#  ('어떻게', 20),
#  ('겨울', 20),
#  ('옷', 20),
#  ('답', 20),
#  ('02', 20),
#  ('2012.04', 20),
#  ('원리', 20),
#  ('),', 20),
#  ('신도', 20),
#  ('삼', 20),
#  ('데', 20),
#  ('이르는', 20),
#  ('ㅡ', 20),
#  ('인도', 20),
#  ('갈', 19),
#  ('1일', 19),
#  ('도와주세요', 19),
#  ('에요', 19),
#  ('학생', 19),
#  ('ㅠ', 19),
#  ('이란', 19),
#  ('처음', 19),
#  ('2007.10', 19),
#  ('스', 19),
#  ('알려', 19),
#  ('대하', 19),
#  ('남', 19),
#  ('친구', 19),
#  ('문', 19),
#  ('내부', 19),
#  ('공기', 19),
#  ('빼내는', 19),
#  ('일종', 19),
#  ('냉장', 19),
#  ('고문', 19),
#  ('열려', 19),
#  ('그러므로', 19),
#  ('아치로', 19),
#  ('성문', 19),
#  ('보다는', 19),
#  (';', 19),
#  ('<', 19),
#  ('외래어', 19),
#  ('2006.09', 19),
#  ('이야기', 19),
#  ('말함', 19),
#  ('바보', 19),
#  ('개념', 19),
#  ('요즘', 18),
#  ('오', 18),
#  ('그런', 18),
#  ('산이', 18),
#  ('길게', 18),
#  ('31', 18),
#  ('결혼', 18),
#  ('전통의상', 18),
#  ('6월', 18),
#  ('라고', 18),
#  ('찾기', 18),
#  ('cloud', 18),
#  ('빨리요', 18),
#  ('별로', 18),
#  ('소', 18),
#  ('라는', 18),
#  ('조사해', 18),
#  ('거지', 18),
#  ('아무', 18),
#  ('9', 18),
#  ('멸망', 18),
#  ('구원', 18),
#  ('모습', 18),
#  ('켜주세요', 18),
#  ('않다', 18),
#  ('의상', 18),
#  ('에서는', 17),
#  ('ㅜ', 17),
#  ('약간', 17),
#  ('운다고', 17),
#  ('7월', 17),
#  ('글자', 17),
#  ('만들고', 17),
#  ('???', 17),
#  ('남북', 17),
#  ('베트남', 17),
#  ('~~~', 17),
#  ('되도록', 17),
#  ('사', 17),
#  ('라', 17),
#  ('이랑', 17),
#  ('염', 17),
#  ('드려요', 17),
#  ('7', 17),
#  ('ㅎ', 17),
#  ('따라서', 17),
#  ('방언', 17),
#  ('크롤', 17),
#  ('내리면', 17),
#  ('남미', 17),
#  ('걸음', 17),
#  ('EBS', 17),
#  ('컬러', 17),
#  ('민소매', 17),
#  ('작', 16),
#  ('얼마나', 16),
#  ('차', 16),
#  ('이구', 16),
#  ('알려주시면', 16),
#  ('문제', 16),
#  ('있어요', 16),
#  ('~!', 16),
#  ('가진', 16),
#  ('공부', 16),
#  ('알려주세여', 16),
#  ('함께', 16),
#  ('있는데', 16),
#  ('보다', 16),
#  ('했는데', 16),
#  ('둘', 16),
#  ('급함', 16),
#  ('이요', 16),
#  ('단원', 16),
#  ('2009.08', 16),
#  ('니', 16),
#  ('밖에', 16),
#  ('기타', 16),
#  ('들어', 16),
#  ('집', 16),
#  ('2016.10', 16),
#  ('제주도', 16),
#  ('인데요', 16),
#  ('자극', 16),
#  ('먹혀', 16),
#  ('들지', 16),
#  ('감추듯', 16),
#  ('허겁지겁', 16),
#  ('치움을', 16),
#  ('적은', 16),
#  ('요점', 16),
#  ('★', 16),
#  ('이라', 15),
#  ('2월', 15),
#  ('성', 15),
#  ('궁합', 15),
#  ('채택', 15),
#  ('생', 15),
#  ('빠른', 15),
#  ('싱거운', 15),
#  ('은하', 15),
#  ('유래', 15),
#  ('12월', 15),
#  ('계속', 15),
#  ('새벽', 15),
#  ('그냥', 15),
#  ('근데', 15),
#  ('사진', 15),
#  ('가을', 15),
#  ('인들', 15),
#  ('엄마', 15),
#  ('2019.09', 15),
#  ('의식주', 15),
#  ('잠', 15),
#  ('시기', 15),
#  ('외국어', 15),
#  ('넘으려고', 15),
#  ('않는다', 15),
#  ('2009.09', 15),
#  ('>', 15),
#  (',,,', 15),
#  ('이라는', 15),
#  ('교', 15),
#  ('예쁘게', 15),
#  ('살려라', 15),
#  ('달아날', 15),
#  ('조급한', 15),
#  ('줄거리', 15),
#  ('이제', 15),
#  ('끝', 15),
#  ('푸드', 15),
#  ('Color', 15),
#  ('fool', 15),
#  ('체', 15),
#  ('특이', 15),
#  ('부정', 15),
#  ('까다롭게', 15),
#  ('잘못', 15),
#  ('지역', 14),
#  ('2020.06', 14),
#  ('지방', 14),
#  ('입', 14),
#  ('아침', 14),
#  ('있을까요', 14),
#  ('쯤', 14),
#  ('특히', 14),
#  ('자세하게', 14),
#  ('해주시', 14),
#  ('30분', 14),
#  ('2007.08', 14),
#  ('맛있는', 14),
#  ('물건', 14),
#  ('40', 14),
#  ('볼', 14),
#  ('이라고', 14),
#  ('현재', 14),
#  ('봐도', 14),
#  ('한자', 14),
#  ('※', 14),
#  ('아직', 14),
#  ('식', 14),
#  ('고기', 14),
#  ('이든', 14),
#  ('coat', 14),
#  ('함', 14),
#  ('2008.01', 14),
#  ('2010.08', 14),
#  ('도와주거나', 14),
#  ('받는게', 14),
#  (';;', 14),
#  ('2007.12', 14),
#  ('k', 14),
#  ('2009.03', 14),
#  ('•', 14),
#  ('색', 14),
#  ('//', 14),
#  ('34', 14),
#  ('wonderful', 14),
#  ('afternoon', 14),
#  ('sunny', 14),
#  ('비치는', 14),
#  ('에게는', 14),
#  ('이황', 14),
#  ('2019.10', 13),
#  ('되어', 13),
#  ('주로', 13),
#  ('한자어', 13),
#  ('먹고', 13),
#  ('낀', 13),
#  ('3월', 13),
#  ('비유', 13),
#  ('_', 13),
#  ('생선', 13),
#  ('돈', 13),
#  ('몇개', 13),
#  ('매일', 13),
#  ('대표', 13),
#  ('올해', 13),
#  ('신', 13),
#  ('봉동읍', 13),
#  ('ltah', 13),
#  ('용', 13),
#  ('싶습니다', 13),
#  ('써주시면', 13),
#  ('여러가지', 13),
#  ('토론', 13),
#  ('번', 13),
#  ('높은', 13),
#  ('2010.01', 13),
#  ('2009.04', 13),
#  ('asleep', 13),
#  ('clown', 13),
#  ('어릿', 13),
#  ('광대', 13),
#  ('재', 13),
#  ('편이', 13),
#  ('영', 13),
#  ('하지', 13),
#  ('하기', 13),
#  ('해요', 13),
#  ('8', 13),
#  ('지나가는', 13),
#  ('모', 13),
#  ('2008.06', 13),
#  ('있는데요', 13),
#  ('②', 13),
#  ('2007.09', 13),
#  ('노력', 13),
#  ('신장', 13),
#  ('ebs', 13),
#  ('오비는', 13),
#  ('일본인', 13),
#  ('구를', 13),
#  ('나눠', 13),
#  ('박', 12),
#  ('반', 12),
#  ('되면', 12),
#  ('각', 12),
#  ('없이', 12),
#  ('운동', 12),
#  ('-->', 12),
#  ('네째', 12),
#  ('찾고', 12),
#  ('엔', 12),
#  ('한번', 12),
#  ('2020.03', 12),
#  ('직업', 12),
#  ('국어', 12),
#  ('여우비', 12),
#  ('온', 12),
#  ('2006.08', 12),
#  ('비용', 12),
#  ('언제나', 12),
#  ('어', 12),
#  ('사이트', 12),
#  ('음식물', 12),
#  ('날짜', 12),
#  ('huge', 12),
#  ('거대한', 12),
#  ('상의', 12),
#  ('하게', 12),
#  ('하는데요', 12),
#  ('러시아', 12),
#  ('따라', 12),
#  ('놈', 12),
#  ('키우는', 12),
#  ('께서', 12),
#  ('nhha', 12),
#  ('키우기', 12),
#  ('마리', 12),
#  ('님들', 12),
#  ('대접', 12),
#  ('케이', 12),
#  ('994', 12),
#  ('알아야', 12),
#  ('대회', 12),
#  ('이쁜', 12),
#  ('FIVE', 12),
#  ('DAY', 12),
#  ('캠페인', 12),
#  ('Food', 12),
#  ('소지', 12),
#  ('손톱', 12),
#  ('알수있다', 12),
#  ('합쳐져서', 12),
#  ('화창한', 12),
#  ('가에', 12),
#  ('「', 12),
#  ('」', 12),
#  ('이고', 11),
#  ('하지만', 11),
#  ('및', 11),
#  ('없어', 11),
#  ('니까', 11),
#  ('ryul', 11),
#  ('알려주세', 11),
#  ('제목', 11),
#  ('드릴게요', 11),
#  ('4월', 11),
#  ('무슨', 11),
#  ('무료', 11),
#  ('2020.04', 11),
#  ('없어서', 11),
#  ('잠깐', 11),
#  ('사실', 11),
#  ('하다', 11),
#  ('역사', 11),
#  ('스시', 11),
#  ('불', 11),
#  ('종류', 11),
#  ('감사합니다', 11),
#  ('꿈', 11),
#  ('가요', 11),
#  ('간다', 11),
#  ('=', 11),
#  ('정보', 11),
#  ('간단히', 11),
#  ('채', 11),
#  ('ㅋ', 11),
#  ('지구', 11),
#  ('가르', 11),
#  ('예요', 11),
#  ('배', 11),
#  ('가는', 11),
#  ('hungry', 11),
#  ('배고픈', 11),
#  ('ill', 11),
#  ('coin', 11),
#  ('동전', 11),
#  ('주화', 11),
#  ('아는', 11),
#  ('소설', 11),
#  ('요약', 11),
#  ('1000', 11),
#  ('빨', 11),
#  ('의복', 11),
#  ('.......', 11),
#  ('금지', 11),
#  ('팍팍', 11),
#  ('스키', 11),
#  ('200', 11),
#  ('중학교', 11),
#  ('바랍니다', 11),
#  ('하나님', 11),
#  ('친척', 11),
#  ('선생', 11),
#  ('민', 11),
#  ('퇴계', 11),
#  ('원령', 11),
#  ('보고', 10),
#  ('겨울방학', 10),
#  ('이용', 10),
#  ('11시', 10),
#  ('올라간', 10),
#  ('표현', 10),
#  ('좋아요', 10),
#  ('2020.02', 10),
#  ('목연', 10),
#  ('마다', 10),
#  ('언제', 10),
#  ('햇빛', 10),
#  ('조', 10),
#  ('학교숙제', 10),
#  ('기후', 10),
#  ('맞는', 10),
#  ('ㅋㅋ', 10),
#  ('있어서', 10),
#  ('알려주', 10),
#  ('전부', 10),
#  ('이며', 10),
#  ('태어났습니다', 10),
#  ('아무리', 10),
#  ('프랑스', 10),
#  ('2019.08', 10),
#  ('무더운', 10),
#  ('미', 10),
#  ('유명한', 10),
#  ('행사', 10),
#  ('후', 10),
#  ('거든요', 10),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='조금구름 더운날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='조금구름 더운날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='조금구름 더운날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='조금구름 더운날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='조금구름 더운날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='조금구름 더운날 음식 동남아')
ko2.vocab().most_common()
# Out:
# [('닉네임', 923),
#  (':', 882),
#  ('조금', 798),
#  ('음식', 718),
#  ('****', 643),
#  ('(', 625),
#  ('더운', 595),
#  (')', 587),
#  ('구름', 523),
#  ('나라', 472),
#  ('개', 429),
#  ('검색', 404),
#  ('날', 394),
#  ('말', 386),
#  ('입력', 300),
#  ('뜻', 295),
#  ('알려주세요', 291),
#  ('비', 280),
#  ('여러', 268),
#  ('내공', 266),
#  ('바깥', 262),
#  ('우리말', 262),
#  ('등', 245),
#  ('속담', 241),
#  ('고사성어', 241),
#  ('차례', 233),
#  ('만', 231),
#  ('사람', 227),
#  ('합니다', 220),
#  ('하세요', 212),
#  ('안', 208),
#  ('포함', 207),
#  ('에서', 205),
#  ('●', 198),
#  ('와', 185),
#  ('순', 179),
#  ('속', 174),
#  ('나', 173),
#  ('너무', 170),
#  ('된', 168),
#  ('까지', 164),
#  ('만든', 164),
#  ('숙제', 163),
#  ('어느', 157),
#  ('기', 150),
#  ('해서', 150),
#  ('그', 150),
#  ('열', 150),
#  ('사주', 147),
#  ('나무', 144),
#  ('쓰는', 144),
#  ('밥', 142),
#  ('초', 141),
#  ('모습', 141),
#  ('몸', 140),
#  ('방', 139),
#  ('/', 138),
#  ('-', 138),
#  ('운', 137),
#  ('질', 135),
#  ('입니다', 134),
#  ('순대', 132),
#  ('학년', 132),
#  ('순우리말', 131),
#  ('돼지', 131),
#  ('섞어서', 130),
#  ('유래', 130),
#  ('30', 129),
#  ('파골집', 129),
#  ('창자', 129),
#  ('피', 129),
#  ('삶아', 129),
#  ('유명한', 129),
#  ('돌', 127),
#  ('마소', 126),
#  ('비비는', 126),
#  ('우', 125),
#  ('보이지', 125),
#  ('않았다', 125),
#  ('楚', 125),
#  ('침략', 125),
#  ('곤', 124),
#  ('될', 123),
#  ('말고', 123),
#  ('춘추전국시대', 123),
#  ('齊', 123),
#  ('해학가', 123),
#  ('언변', 123),
#  ('뛰어나', 123),
#  ('사신', 123),
#  ('파견', 123),
#  ('되었지만', 123),
#  ('비굴한', 123),
#  ('햄스터', 122),
#  ('문서', 121),
#  ('!', 120),
#  ('사용', 119),
#  ('건강', 118),
#  ('보는', 117),
#  ('☞', 116),
#  ('차고', 113),
#  ('조금씩', 113),
#  ('클릭', 111),
#  ('저', 111),
#  ('본', 110),
#  ('있으니', 110),
#  ('필시', 110),
#  ('성공', 110),
#  ('거두게', 110),
#  ('그렇다고', 110),
#  ('급하게', 110),
#  ('서둘지', 110),
#  ('느긋하게', 110),
#  ('기다려', 110),
#  ('중요합니다', 110),
#  ('인한', 110),
#  ('여기', 110),
#  ('100', 110),
#  ('문장', 109),
#  ('내', 108),
#  ('구분', 106),
#  ('짓', 105),
#  ('5', 105),
#  ('상세', 104),
#  ('반드시', 104),
#  ('결과', 103),
#  ('정도', 103),
#  ('정확히', 102),
#  ('많이', 102),
#  ('일치', 101),
#  ('제외', 101),
#  ('알', 101),
#  ('부탁드립니다', 101),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('먹는', 100),
#  ('이나', 98),
#  ('아', 96),
#  ('가지', 95),
#  ('빨리', 95),
#  ('위', 94),
#  ('대해', 91),
#  ('아름다운', 90),
#  ('방학', 89),
#  ('내리는', 88),
#  ('부탁', 86),
#  ('일식', 85),
#  ('50', 85),
#  ('우리', 84),
#  ('해', 84),
#  ('하', 83),
#  ('3', 83),
#  ('영어', 83),
#  ('풀이', 82),
#  ('사자성어', 82),
#  ('주세요', 81),
#  ('여', 80),
#  ('서', 79),
#  (']', 79),
#  ('[', 79),
#  ('4', 76),
#  ('아주', 76),
#  ('퀘스트', 76),
#  ('안녕하세요', 75),
#  ('.....', 73),
#  ('한자', 73),
#  ('모두', 72),
#  ('소리', 72),
#  ('해주세요', 70),
#  ('면', 70),
#  ('이름', 70),
#  ('인', 69),
#  ('날씨', 69),
#  ('바람', 67),
#  ('찬', 67),
#  ('산', 66),
#  ('맛', 65),
#  ('ㅠㅠ', 65),
#  ('다시', 65),
#  ('조사', 65),
#  ('간', 65),
#  ('여자', 64),
#  ('우리나라', 64),
#  ('전', 63),
#  ('하는데', 63),
#  ('거리', 63),
#  ('매', 63),
#  ('음', 63),
#  ('밤', 61),
#  ('하고', 61),
#  ('15', 60),
#  ('양력', 60),
#  ('거의', 60),
#  ('예', 59),
#  ("'", 58),
#  ('써주세요', 57),
#  ('고유어', 56),
#  ('나서', 55),
#  ('한다', 55),
#  ('13', 55),
#  ('전통', 54),
#  ('조각', 54),
#  ('목', 54),
#  ('그리고', 54),
#  ('학교', 53),
#  ('얹어', 53),
#  ('찌거나', 53),
#  ('캐', 53),
#  ('부지런해야', 53),
#  ('농가월령가', 53),
#  ('!!!', 52),
#  ('핵심', 52),
#  ('되지기', 52),
#  ('①', 52),
#  ('연기', 52),
#  ('곰', 52),
#  ('팡', 52),
#  ('적', 52),
#  ('처럼', 52),
#  ('관련', 52),
#  ('12', 52),
#  ('주어', 52),
#  ('좋은', 51),
#  ('새참', 51),
#  ('고갱', 51),
#  ('사물', 51),
#  ('시간', 51),
#  ('야', 50),
#  ('곳', 49),
#  ('14', 49),
#  ('그래서', 48),
#  ('ag', 48),
#  ('경우', 47),
#  ('^^', 47),
#  ('꼭', 47),
#  ('랑', 46),
#  ('예쁜', 46),
#  ('"', 46),
#  ('대부분', 46),
#  ('양', 46),
#  ('11', 45),
#  ('보다', 45),
#  ('25', 44),
#  ('제발', 44),
#  ('두', 44),
#  ('지식인', 44),
#  ('관', 44),
#  ('16', 44),
#  ('밑', 44),
#  ('개도', 44),
#  ('살코기', 44),
#  ('개미', 43),
#  ('봐주세요', 43),
#  ('24', 43),
#  ('하여', 43),
#  ('26', 42),
#  ('17', 42),
#  ('오늘', 42),
#  ('세계', 42),
#  ('속뜻', 42),
#  ('과학', 42),
#  ('장군', 42),
#  ('19', 41),
#  ('있다', 41),
#  ('더', 41),
#  ('철장', 41),
#  ('이면', 40),
#  ('부탁드려요', 40),
#  ('생활', 40),
#  ('차지', 40),
#  ('눈', 40),
#  ('되고', 39),
#  ('21', 39),
#  ('하면', 39),
#  ('*', 39),
#  ('분야', 39),
#  ('소금', 39),
#  ('사다리타기', 39),
#  ('간혹', 39),
#  ('묘기', 39),
#  ('부리곤', 39),
#  ('한답니다', 39),
#  ('83', 39),
#  ('에는', 38),
#  ('몇', 38),
#  ('오후', 38),
#  ('분', 38),
#  ('사이', 38),
#  ('07', 38),
#  ('적어주세요', 38),
#  ('이다', 38),
#  ('가르쳐', 38),
#  ('09', 37),
#  ('맞히지는', 37),
#  ('물', 37),
#  ('부터', 36),
#  ('~~', 36),
#  ('같은', 36),
#  ('세', 36),
#  ('이라도', 36),
#  ('강', 36),
#  ('바람의나라', 36),
#  ('28', 35),
#  ('강한', 35),
#  ('여름', 35),
#  ('뜨거운', 35),
#  ('음력', 35),
#  ('지금', 35),
#  ('??', 35),
#  ('hot', 35),
#  ('내용', 35),
#  ('오는', 35),
#  ('두고', 35),
#  ('히', 35),
#  ('남자', 34),
#  ('04', 34),
#  ('씨', 34),
#  ('내일', 34),
#  ('부분', 34),
#  ('보리', 34),
#  ('많은', 34),
#  ('겁니다', 33),
#  ('큰', 33),
#  ('없다', 33),
#  ('ocam', 33),
#  ('9', 33),
#  ('18', 32),
#  ('03', 32),
#  ('봉동읍', 32),
#  ('ltah', 32),
#  ('아래', 32),
#  ('얻어먹는다', 32),
#  ('급한', 32),
#  ('밀', 32),
#  ('심어', 32),
#  ('보세', 32),
#  ('이랑', 31),
#  ('이번', 31),
#  ('추천', 31),
#  ('전체', 31),
#  ('기운', 31),
#  ('나누어서', 31),
#  ('나머지', 31),
#  ('켜오리라', 31),
#  ('자애', 31),
#  ('지어', 31),
#  ('집', 30),
#  ('29', 30),
#  ('27', 30),
#  ('같이', 30),
#  ('한글', 30),
#  ('책', 30),
#  ('이렇게', 30),
#  ('까닭', 30),
#  ('걸', 30),
#  ('뭉게뭉게', 30),
#  ('미쳐', 30),
#  ('뉘', 30),
#  ('능', 30),
#  ('베어', 30),
#  ('갈이', 30),
#  ('끝끝', 30),
#  ('익어도', 30),
#  ('22', 29),
#  ('달', 29),
#  ('02', 29),
#  ('무엇', 29),
#  ('0', 29),
#  ('석빙고', 29),
#  ('천', 29),
#  ('ㅠ', 28),
#  ('01', 28),
#  ('최대한', 28),
#  ('점', 28),
#  ('해야', 28),
#  ('다른', 28),
#  ('모이는', 28),
#  ('마법', 28),
#  ('듯', 27),
#  ('하면서', 27),
#  ('글', 27),
#  (')...', 27),
#  ('바로', 27),
#  ('이런', 27),
#  ('부연', 27),
#  ('신고', 27),
#  ('선택', 27),
#  ('^', 27),
#  ('98', 27),
#  ('에도', 26),
#  ('일본', 26),
#  ('아이', 26),
#  ('그런데', 26),
#  ('선생님', 26),
#  ('2010.08', 26),
#  ('2008.03', 26),
#  ('떠', 26),
#  ('순수한', 26),
#  ('길', 26),
#  ('진짜', 25),
#  ('23', 25),
#  ('구', 25),
#  ('공격', 25),
#  ('글자', 25),
#  ('감사하겠습니다', 25),
#  ('ethn', 25),
#  ('겉뜻', 25),
#  ('답', 25),
#  ('<', 25),
#  ('냠냠', 25),
#  ('먹어서', 25),
#  ('밖에', 25),
#  ('고유', 25),
#  ('쪽', 24),
#  ('드립니다', 24),
#  ('때문', 24),
#  ('대한', 24),
#  ('있습니다', 24),
#  ('마음', 24),
#  (',,', 24),
#  ('저희', 24),
#  ('않', 24),
#  ('방법', 24),
#  ('이야기', 24),
#  ('가랑비', 24),
#  ('여름방학', 24),
#  ('먹어', 23),
#  ('오전', 23),
#  ('문화', 23),
#  ('맑은', 23),
#  ('흰', 23),
#  ('05', 23),
#  ('드림', 23),
#  ('>', 23),
#  ('가르쳐주세요', 23),
#  ('삼', 23),
#  ('2008.09', 23),
#  ('사회', 23),
#  ('정리', 23),
#  ('가온', 23),
#  ('정', 22),
#  ('부산', 22),
#  ('국', 22),
#  ('8월', 22),
#  ('ㅜㅜ', 22),
#  ('길게', 22),
#  ('아시', 22),
#  ('직업', 22),
#  ('명', 22),
#  ('된장', 22),
#  ('공기', 22),
#  ('구름다리', 22),
#  ('남아', 22),
#  ('않는다는', 22),
#  ('마는', 22),
#  ('똥', 22),
#  ('이르는', 22),
#  ('2006.08', 22),
#  ('•', 22),
#  ('력', 22),
#  ('11월', 21),
#  ('31', 21),
#  ('시', 21),
#  ('운세', 21),
#  ('인지', 21),
#  ('궁금합니다', 21),
#  ('따라서', 21),
#  ('사', 21),
#  ('대하', 21),
#  ('여러가지', 21),
#  ('과는', 21),
#  ('사투리', 21),
#  (';', 21),
#  ('2008.04', 21),
#  ('신세', 21),
#  ('인도', 21),
#  ('A', 21),
#  ('초등학교', 21),
#  ('상어', 21),
#  ('약하다', 21),
#  ('쎄다', 21),
#  ('㉢', 21),
#  ('해파리', 21),
#  ('잡으면', 21),
#  ('화창', 21),
#  ('뜨고', 21),
#  ('동자', 21),
#  ('누군지', 21),
#  ('전략', 21),
#  ('어딨는지', 21),
#  ('화면', 21),
#  ('생각', 20),
#  ('산이', 20),
#  ('특징', 20),
#  ('라는', 20),
#  ('형용사', 20),
#  ('설명', 20),
#  ('요리', 20),
#  ('함께', 20),
#  ('새', 20),
#  ('2008.10', 20),
#  ('2012.04', 20),
#  ('원리', 20),
#  ('있다면', 20),
#  ('씩', 20),
#  ('라서', 20),
#  ('......', 20),
#  ('빨리요', 20),
#  ('낱말', 20),
#  ('2008.08', 20),
#  ('2006.09', 20),
#  ('있나요', 20),
#  ('ㅡ', 20),
#  ('걸음', 20),
#  ('무기', 20),
#  ('fire', 20),
#  ('이라고', 19),
#  ('여행', 19),
#  ('7월', 19),
#  ('운다고', 19),
#  ('도와주세요', 19),
#  ('모양', 19),
#  ('알려주세여', 19),
#  ('근데', 19),
#  ('한국', 19),
#  ('갈', 19),
#  ('08', 19),
#  ('이고', 19),
#  ('food', 19),
#  ('한테', 19),
#  ('염', 19),
#  ('내부', 19),
#  ('빼내는', 19),
#  ('일종', 19),
#  ('냉장', 19),
#  ('고문', 19),
#  ('열려', 19),
#  ('그러므로', 19),
#  ('형식', 19),
#  ('아치로', 19),
#  ('성문', 19),
#  ('),', 19),
#  ('라', 19),
#  ('북한', 19),
#  ('개념', 19),
#  ('의상', 19),
#  ('농가', 19),
#  ('친구', 18),
#  ('왜', 18),
#  ('그런', 18),
#  ('성', 18),
#  ('채택', 18),
#  ('있어요', 18),
#  ('작은', 18),
#  ('시나', 18),
#  ('브로', 18),
#  ('어떻게', 18),
#  ('미국', 18),
#  ('8', 18),
#  ('남', 18),
#  ('7', 18),
#  ('자세히', 18),
#  ('식', 18),
#  ('외래어', 18),
#  ('2009.08', 18),
#  ('들어', 18),
#  ('어', 18),
#  ('2010.07', 18),
#  ('학기', 18),
#  ('자극', 18),
#  ('먹혀', 18),
#  ('들지', 18),
#  ('살려라', 18),
#  ('달아날', 18),
#  ('조급한', 18),
#  ('감추듯', 18),
#  ('허겁지겁', 18),
#  ('치움을', 18),
#  ('지만', 18),
#  ('2007.07', 18),
#  ('말함', 18),
#  ('전통의상', 18),
#  ('부정', 18),
#  ('민소매', 18),
#  ('월령', 18),
#  ('ㅋㅋ', 17),
#  ('제목', 17),
#  ('1월', 17),
#  ('에게', 17),
#  ('식품', 17),
#  ('학생', 17),
#  ('별', 17),
#  ('싱거운', 17),
#  ('은하', 17),
#  ('남북', 17),
#  ('1일', 17),
#  ('중국', 17),
#  ('2007.08', 17),
#  ('급해요', 17),
#  ('되도록', 17),
#  ('이란', 17),
#  ('꿈', 17),
#  ('cloud', 17),
#  ('간다', 17),
#  ('둘', 17),
#  ('알려', 17),
#  ('2007.10', 17),
#  ('올려주세요', 17),
#  ('소', 17),
#  ('요즘', 17),
#  ('개좀', 17),
#  ('방언', 17),
#  ('따라', 17),
#  ('연', 17),
#  ('∼', 17),
#  ('예요', 16),
#  ('3일', 16),
#  ('차', 16),
#  ('입', 16),
#  ('에요', 16),
#  ('이구', 16),
#  ('정말', 16),
#  ('결혼', 16),
#  ('등등', 16),
#  ('작', 16),
#  ('공부', 16),
#  ('없는', 16),
#  ('있는데', 16),
#  ('베트남', 16),
#  ('계절', 16),
#  ('나눠', 16),
#  ('크게', 16),
#  (';;', 16),
#  ('거지', 16),
#  ('ㅎ', 16),
#  ('이요', 16),
#  ('넘으려고', 16),
#  ('않는다', 16),
#  ('2008.01', 16),
#  ('2009.09', 16),
#  ('옷', 16),
#  ('놈', 16),
#  ('가장', 16),
#  ('켜주세요', 16),
#  ('알아야', 16),
#  ('※', 16),
#  ('색', 16),
#  ('34', 16),
#  ('특이', 16),
#  ('까다롭게', 16),
#  ('체', 16),
#  ('한자성어', 16),
#  ('2020.06', 15),
#  ('영', 15),
#  ('별로', 15),
#  ('각', 15),
#  ('2월', 15),
#  ('님', 15),
#  ('궁합', 15),
#  ('알려주시면', 15),
#  ('문제', 15),
#  ('해주시', 15),
#  ('~!', 15),
#  ('하늘', 15),
#  ('또', 15),
#  ('고기', 15),
#  ('약간', 15),
#  ('전부', 15),
#  ('물론', 15),
#  ('2019.09', 15),
#  ('감사', 15),
#  ('문', 15),
#  ('모', 15),
#  ('함', 15),
#  ('예쁘게', 15),
#  ('모든', 15),
#  ('k', 15),
#  ('적어', 15),
#  ('EBS', 15),
#  ('컬러', 15),
#  ('푸드', 15),
#  ('않다', 15),
#  ('이황', 15),
#  ('박', 14),
#  ('2일', 14),
#  ('편', 14),
#  ('한식', 14),
#  ('그냥', 14),
#  ('있을까요', 14),
#  ('이용', 14),
#  ('하는데요', 14),
#  ('찾기', 14),
#  ('그대로', 14),
#  ('아침', 14),
#  ('의미', 14),
#  ('30분', 14),
#  ('새벽', 14),
#  ('~~~', 14),
#  ('감사합니다', 14),
#  ('신', 14),
#  ('겨울', 14),
#  ('봐도', 14),
#  ('인데요', 14),
#  ('엄마', 14),
#  ('이제', 14),
#  ('뜻좀', 14),
#  ('가르', 14),
#  ('장', 14),
#  ('40', 14),
#  ('먹지', 14),
#  ('fine', 14),
#  ('공', 14),
#  ('욤', 14),
#  ('니', 14),
#  ('2011.08', 14),
#  ('2007.05', 14),
#  ('Color', 14),
#  ('적은', 14),
#  ('wonderful', 14),
#  ('afternoon', 14),
#  ('fool', 14),
#  ('바보', 14),
#  ('sunny', 14),
#  ('비치는', 14),
#  ('오비는', 14),
#  ('일본인', 14),
#  ('구를', 14),
#  ('보다는', 14),
#  ('찾아주세요', 14),
#  ('처음', 13),
#  ('쯤', 13),
#  ('운동', 13),
#  ('3월', 13),
#  ('생', 13),
#  ('12월', 13),
#  ('몇개', 13),
#  ('계속', 13),
#  ('6월', 13),
#  ('ㅜ', 13),
#  ('인가요', 13),
#  ('했는데', 13),
#  ('자', 13),
#  ('수행평가', 13),
#  ('채', 13),
#  ('토론', 13),
#  ('있는데요', 13),
#  ('하지만', 13),
#  ('가는', 13),
#  ('잠', 13),
#  ('이든', 13),
#  ('coat', 13),
#  ('마을', 13),
#  ('하게', 13),
#  (',,,', 13),
#  ('조사해', 13),
#  ('쉬운', 13),
#  ('하기', 13),
#  ('마리', 13),
#  ('올려', 13),
#  ('!!!!', 13),
#  ('얼마나', 13),
#  ('노력', 13),
#  ('2007.09', 13),
#  ('신장', 13),
#  ('//', 13),
#  ('ebs', 13),
#  ('잘못', 13),
#  ('입니당', 12),
#  ('에서는', 12),
#  ('태어난', 12),
#  ('되는', 12),
#  ('낀', 12),
#  ('없어서', 12),
#  ('한번', 12),
#  ('2020.03', 12),
#  ('가진', 12),
#  ('맛있는', 12),
#  ('올해', 12),
#  ('자세하게', 12),
#  ('온', 12),
#  ('빠른', 12),
#  ('용', 12),
#  ('언제나', 12),
#  ('조정', 12),
#  ('2019.10', 12),
#  ('생선', 12),
#  ('★', 12),
#  ('간단히', 12),
#  ('아직', 12),
#  ('음식물', 12),
#  ('외국어', 12),
#  ('주로', 12),
#  ('asleep', 12),
#  ('clown', 12),
#  ('어릿', 12),
#  ('광대', 12),
#  ('_', 12),
#  ('좋아하는', 12),
#  ('배', 12),
#  ('반찬', 12),
#  ('편이', 12),
#  ('이라는', 12),
#  ('2007.12', 12),
#  ('지나가는', 12),
#  ('nhha', 12),
#  ('2005.08', 12),
#  ('2009.03', 12),
#  ('994', 12),
#  ('발걸음', 12),
#  ('바랍니다', 12),
#  ('②', 12),
#  ('주세여', 12),
#  ('FIVE', 12),
#  ('DAY', 12),
#  ('캠페인', 12),
#  ('소지', 12),
#  ('손톱', 12),
#  ('알수있다', 12),
#  ('합쳐져서', 12),
#  ('끝', 12),
#  ('화창한', 12),
#  ('「', 12),
#  ('」', 12),
#  ('10만', 12),
#  ('에게는', 12),
#  ('퇴계', 12),
#  ('굴', 12),
#  ('없이', 11),
#  ('이라', 11),
#  ('가면', 11),
#  ('지방', 11),
#  ('ryul', 11),
#  ('먹고', 11),
#  ('기술', 11),
#  ('2020.04', 11),
#  ('찾고', 11),
#  ('돈', 11),
#  ('여우비', 11),
#  ('종류', 11),
#  ('???', 11),
#  ('마다', 11),
#  ('사진', 11),
#  ('특히', 11),
#  ('머리', 11),
#  ('비용', 11),
#  ('한문', 11),
#  ('선생', 11),
#  ('2011.07', 11),
#  ('법', 11),
#  ('되어', 11),
#  ('걱정', 11),
#  ('음식점', 11),
#  ('번', 11),
#  ('huge', 11),
#  ('거대한', 11),
#  ('상의', 11),
#  ('자식', 11),
#  ('소설', 11),
#  ('볼', 11),
#  ('하지', 11),
#  ('1000', 11),
#  ('써주시면', 11),
#  ('대회', 11),
#  ('+', 11),
#  ('걸어요', 11),
#  ('조', 11),
#  ('기별', 11),
#  ('숙젠데', 11),
#  ('키우는', 11),
#  ('께서', 11),
#  ('꾼', 11),
#  ('님들', 11),
#  ('키우기', 11),
#  ('대접', 11),
#  ('의복', 11),
#  ('아무', 11),
#  ('2010.01', 11),
#  ('판타지', 11),
#  ('줄거리', 11),
#  ('나오는', 11),
#  ('검', 11),
#  ('Food', 11),
#  ('2010.06', 11),
#  ('렙', 11),
#  ('도적', 11),
#  ('퀘', 11),
#  ('어디', 10),
#  ('6일', 10),
#  ('금액', 10),
#  ('비싼', 10),
#  ('남포동', 10),
#  ('오픈', 10),
#  ('많다', 10),
#  ('rhkd', 10),
#  ('2020.07', 10),
#  ('니까', 10),
#  ('소나기', 10),
#  ('한자어', 10),
#  ('알려주세', 10),
#  ('같다', 10),
#  ('사전', 10),
#  ('역사', 10),
#  ('화', 10),
#  ('여서', 10),
#  ('하기에', 10),
#  ('4월', 10),
#  ('좋아요', 10),
#  ('잠깐', 10),
#  ('2020.02', 10),
#  ('목연', 10),
#  ('엔', 10),
#  ('하다', 10),
#  ('보고', 10),
#  ('써', 10),
#  ('먹을', 10),
#  ('없고', 10),
#  ('맞는', 10),
#  ('10시', 10),
#  ('=', 10),
#  ('이유', 10),
#  ('대로', 10),
#  ('2019.08', 10),
#  ('사이트', 10),
#  ('호텔', 10),
#  ('찾아', 10),
#  ('조선', 10),
#  ('드려요', 10),
#  ('반', 10),
#  ('정보', 10),
#  ('해도', 10),
#  ('hungry', 10),
#  ('배고픈', 10),
#  ('ill', 10),
#  ('coin', 10),
#  ('동전', 10),
#  ('주화', 10),
#  ('들어서', 10),
#  ('라도', 10),
#  ('하루', 10),
#  ('단원', 10),
#  ('해석', 10),
#  ('않은', 10),
#  ('관심', 10),
#  ('겨울방학', 10),
#  ('옛날', 10),
#  ('해요', 10),
#  ('하자', 10),
#  ('개정', 10),
#  ('주시', 10),
#  ('래', 10),
#  ('가을', 10),
#  ('2009.04', 10),
#  ('위로', 10),
#  ('곡', 10),
#  ('새끼', 10),
#  ('케이', 10),
#  ('200', 10),
#  ('2010.04', 10),
#  ('이쁜', 10),
#  ('중학교', 10),
#  ('2009.07', 10),
#  ('마니', 10),
#  ('초등', 10),
#  ('친척', 10),
#  ('요점', 10),
#  ('가에', 10),
#  ('맛집', 9),
#  ('부산여행', 9),
#  ('일품', 9),
#  ('#남포동', 9),
#  ('넘버원', 9),
#  ('술집', 9),
#  ('!!...', 9),
#  ('#송도구름다리', 9),
#  ('놀게', 9),
#  ('가서', 9),
#  ('저녁', 9),
#  ('몰라서', 9),
#  ('보', 9),
#  ('살', 9),
#  ('인터넷', 9),
#  ('무료', 9),
#  ('2시', 9),
#  ('11시', 9),
#  ('음악', 9),
#  ('정확하게', 9),
#  ('일기', 9),
#  ('물건', 9),
#  ('여름철', 9),
#  ('욕설', 9),
#  ('기후', 9),
#  ('부탁드릴게요', 9),
#  ('번호', 9),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9642 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9786 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65378 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9642 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9786 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 65378 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
