# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('안개 더운 날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('안개 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('안개 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('안개 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('안개 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('안개 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '2013.02',
#  '.',
#  '15',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '제발',
#  '부탁드림니다',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  '정답',
#  '질문',
#  '전통',
#  '한식',
#  '상차림',
#  '2019.09',
#  '.',
#  '16',
#  '.',
#  '1',
#  '.',
#  '전통',
#  '한식',
#  '의',
#  '첩',
#  '반상',
#  '(',
#  '3',
#  ',',
#  '5',
#  ',',
#  '7',
#  ',',
#  '9',
#  ',',
#  '12',
#  ')',
#  '과',
#  '반찬',
#  '2',
#  '.',
#  '전통',
#  '밥상',
#  '차림',
#  '어떤',
#  '배열',
#  '을',
#  '하는가',
#  '3',
#  '.',
#  '전통',
#  '상',
#  '에',
#  '죽',
#  '상',
#  ',',
#  '장국상',
#  '주안상',
#  '교자상',
#  '다과상',
#  '등',
#  '이',
#  '것',
#  '들',
#  '좀',
#  '알려주세요',
#  '답변',
#  '숟가락',
#  '은',
#  '뜨거운',
#  '국물',
#  '음식',
#  '이',
#  '발달',
#  '한',
#  '한식',
#  '의',
#  '특성',
#  '에',
#  '잘',
#  '맞는',
#  '도구',
#  '이다',
#  '.',
#  '젓가락',
#  '은',
#  '...',
#  '오른쪽',
#  '에는',
#  '더운',
#  '반찬',
#  '을',
#  '놓아',
#  '오른손',
#  '으로',
#  '집어',
#  '먹기',
#  '편하게',
#  '배려',
#  '한',
#  '것',
#  '이',
#  '재미있다',
#  '....',
#  '닉네임',
#  '골드',
#  '질문',
#  '2013년',
#  '한식',
#  '날',
#  '2013.01',
#  '.',
#  '02',
#  '.',
#  '저기',
#  '한식',
#  '날',
#  '날짜',
#  '가',
#  '어떻게',
#  '되나요',
#  '??',
#  '인터넷',
#  '찾아봐도',
#  '없어서요',
#  '.......',
#  '자세하게',
#  '답좀',
#  '해주세요',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어야',
#  '한다는',
#  '속',
#  '신',
#  '(',
#  '俗信',
#  ')...',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제',
#  '사',
#  '음식',
#  '을',
#  '마련',
#  '하여',
#  '제사',
#  '를',
#  '지내는데',
#  ',',
#  '이를',
#  '절사',
#  '(',
#  '節祀',
#  ')...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는',
#  '음식',
#  '추천',
#  '!!(',
#  '한식',
#  ')',
#  '2007.08',
#  '.',
#  '04',
#  '.',
#  '질리',
#  '고',
#  '뭔가',
#  '색다른',
#  '것',
#  '먹고싶은데',
#  '뭐',
#  '가',
#  '있을까요',
#  '??',
#  '맛있는',
#  '메뉴',
#  '좀',
#  '추천',
#  '해주세요',
#  '.',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는것',
#  '뜨거운거',
#  '매운건',
#  '싫어요',
#  '~~',
#  '한식',
#  '으로',
#  '추천',
#  '부탁드립니다',
#  '.^^',
#  '답변',
#  '한식',
#  '은',
#  '아니지만',
#  '씨',
#  '푸드',
#  '뷔페',
#  '레스토랑',
#  '어때요',
#  '?',
#  '^',
#  'ㅡ',
#  '^',
#  '해산물',
#  '중',
#  '에서',
#  '장어',
#  ',',
#  '병어',
#  ',',
#  '농어',
#  '...',
#  '▦',
#  '찬',
#  '음식',
#  '에서',
#  '더운',
#  '음식',
#  '으로',
#  '=',
#  '뷔페',
#  '도',
#  '일종',
#  '의',
#  '코스',
#  '요리',
#  '로',
#  '생각',
#  '하고',
#  '음식',
#  '을',
#  '선택',
#  '해야',
#  '...',
#  '질문',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '2005.04',
#  '.',
#  '05',
#  '.',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '작은',
#  '사진',
#  '을',
#  '올려주셔도',
#  '괜찮습니다',
#  '.',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '한식',
#  '조사',
#  '여',
#  '.....',
#  '2016.06',
#  '.',
#  '01',
#  '.',
#  '뭐',
#  '가',
#  '우리나라',
#  '음식',
#  '인지',
#  '모르겠어서요',
#  '일단',
#  '1',
#  '.',
#  '한식',
#  '종류',
#  '!',
#  '를',
#  '알려주세요',
#  '2',
#  '.',
#  '그',
#  '음식',
#  '들',
#  '을',
#  '만드는',
#  '방법',
#  '도',
#  '알려주세요',
#  '오늘',
#  '안',
#  '에',
#  '알려주세요',
#  '.....',
#  '지금',
#  '엄청',
#  '급해서요',
#  '.....',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '이',
#  '뭐',
#  '에요',
#  '?',
#  '2011.08',
#  '.',
#  '26',
#  '.',
#  '그',
#  '..',
#  '우리나라',
#  '음식',
#  '한식',
#  '말구요',
#  '..;;',
#  '차가울',
#  '한',
#  '?',
#  '그거',
#  '쓴',
#  '...',
#  '한',
#  '문',
#  '숙제',
#  '가',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '에',
#  '대해',
#  '서',
#  '조사',
#  '해오는건데',
#  '....',
#  '조사',
#  '를',
#  '해서',
#  '어떻게',
#  '해야',
#  '될지도',
#  '모르겠고',
#  '..',
#  '사전',
#  '같은',
#  '덴',
#  '너무',
#  '...',
#  '답변',
#  '더운',
#  '밥',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '밥',
#  '을',
#  '먹는다고는',
#  '하나',
#  '잘',
#  '지켜지지',
#  '않았다',
#  '.',
#  '한식',
#  '은',
#  '조선시대',
#  '에',
#  '설날',
#  '·',
#  '단오',
#  '·',
#  '추석',
#  '과',
#  '함께',
#  '사대',
#  '명절',
#  '(',
#  '四大名節',
#  ')',
#  '에',
#  '속',
#  '했다',
#  '.',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제사',
#  '음식',
#  '...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대하',
#  '여',
#  '2007.04',
#  '.',
#  '05',
#  '.',
#  '학교숙제',
#  '인대',
#  '요',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대한',
#  '조사',
#  '를',
#  '해',
#  '라',
#  '해서',
#  '하게',
#  '된것인데',
#  '제',
#  '말',
#  '도와주세요',
#  'ㅠㅠ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '닉네임',
#  'han',
#  '0',
#  '****',
#  '질문',
#  '한식',
#  '에',
#  '관',
#  '한',
#  '여러가지',
#  '알려주세요',
#  '2005.04',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '이란',
#  '?',
#  '시기',
#  '유래',
#  '풍습',
#  '속담',
#  '한식',
#  '날',
#  '먹는',
#  '음식',
#  '이',
#  '것좀',
#  '간단하게',
#  '알려주세요',
#  '할것이',
#  '너무',
#  '많아서',
#  '여기저기',
#  '찾아볼',
#  '시간',
#  '이',
#  '없네요',
#  'ㅋ',
#  '꼭좀',
#  '알려주세요',
#  'ㅋ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '한식',
#  '의',
#  '종류',
#  '가르쳐주세요',
#  '2017.10',
#  '.',
#  '28',
#  '.',
#  '한식',
#  '의',
#  '종류',
#  '와',
#  '특징',
#  '을',
#  '가르쳐주세요',
#  '답변',
#  '한식',
#  '에',
#  '대한',
#  '모든',
#  '것',
#  ',',
#  '한식',
#  '의',
#  '종류',
#  ',',
#  '한식',
#  '의',
#  '특징',
#  '...',
#  '것',
#  '이다',
#  '.',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '...',
#  '굴',
#  '이나',
#  '조갯살',
#  '로',
#  '국물',
#  '을',
#  '내어',
#  '날',
#  '떡국',
#  '이나',
#  '칼국수',
#  '를',
#  '끓이며',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '(',
#  '월욜',
#  '까지',
#  ')',
#  '2007.02',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '좀',
#  '부탁',
#  '해요',
#  '!!!!',
#  '답변',
#  '바랍니다',
#  '한식',
#  '(',
#  '寒食',
#  ':',
#  '동지',
#  '후',
#  '105일',
#  '째',
#  '되는',
#  '날',
#  ')',
#  '한식',
#  '의',
#  '어원',
#  '에',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='안개 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='안개 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='안개 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='안개 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='안개 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='안개 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 92323
# 7727

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 4129),
#  ('...', 2686),
#  ('이', 1710),
#  ('에', 1584),
#  ('을', 1448),
#  ('의', 1301),
#  (',', 1280),
#  ('답변', 1127),
#  (':', 1092),
#  ('가', 1053),
#  ('질문', 1048),
#  ('음식', 1026),
#  ('닉네임', 897),
#  ('는', 835),
#  ('더운', 835),
#  ('안개', 821),
#  ('를', 730),
#  ('****', 725),
#  ('단어', 621),
#  ('때', 568),
#  ('(', 560),
#  ('은', 552),
#  ('좀', 546),
#  ('하는', 507),
#  ('로', 479),
#  ('고', 477),
#  ('과', 461),
#  ('●', 421),
#  ('여러', 417),
#  ('개', 414),
#  ('검색', 408),
#  ('우리말', 401),
#  ('날', 378),
#  ('밥', 370),
#  ('위', 362),
#  ('비', 359),
#  (')', 353),
#  ('할', 349),
#  ('....', 342),
#  ('..', 332),
#  ('안', 329),
#  ('입력', 300),
#  ('한', 299),
#  ('등', 299),
#  ('에는', 294),
#  ('도', 290),
#  ('사람', 290),
#  ('내공', 288),
#  ('알려주세요', 286),
#  ('일', 285),
#  ('에서', 281),
#  ('해', 279),
#  ('요', 277),
#  ('으로', 265),
#  ('게', 259),
#  ('들', 250),
#  ('방', 236),
#  ('함께', 230),
#  ('?', 226),
#  ('짙은', 226),
#  ('날씨', 224),
#  (')...', 224),
#  ('숙제', 220),
#  ('낀', 213),
#  ('바다', 211),
#  ('몸', 211),
#  ('아주', 211),
#  ('포함', 210),
#  ('제', 210),
#  ('나무', 208),
#  ('나라', 207),
#  ('미', 203),
#  ('것', 203),
#  ('질', 197),
#  ('까지', 196),
#  ('섶', 196),
#  ('돌', 196),
#  ('합니다', 195),
#  ('마소', 195),
#  ('비비는', 195),
#  ('짓', 195),
#  ('된', 194),
#  ('맛있는', 193),
#  ('힘', 193),
#  ('1', 192),
#  ('운김', 191),
#  ('한창', 191),
#  ('우러나', 191),
#  ('학년', 190),
#  ('이다', 189),
#  ('저', 186),
#  ('뜻', 186),
#  ('와', 179),
#  ('3', 176),
#  ('밤', 176),
#  ('아침', 175),
#  ('속담', 174),
#  ('순우리말', 173),
#  ('이상', 168),
#  ('적', 167),
#  ('나', 166),
#  ('아름다운', 166),
#  ('면', 161),
#  ('대해', 158),
#  ('명절', 157),
#  ('중', 152),
#  ('동남아', 151),
#  ('이나', 150),
#  ('찬', 150),
#  ('5', 149),
#  ('처럼', 146),
#  ('다른', 145),
#  ('해서', 144),
#  ('못', 143),
#  ('그', 143),
#  ('[', 143),
#  ('먹는', 142),
#  ('-', 141),
#  ('부탁', 137),
#  (']', 137),
#  ('하나', 135),
#  ('정도', 135),
#  ('20', 133),
#  ('세계', 133),
#  ('또', 132),
#  ('계절', 131),
#  ('농가월령가', 131),
#  ('고유어', 130),
#  ('기', 128),
#  ('만', 128),
#  ('가는', 128),
#  ('10', 127),
#  ('곳', 126),
#  ('/', 124),
#  ('!!', 124),
#  ('이름', 124),
#  ('거리', 123),
#  ('①', 123),
#  ('가지', 123),
#  ('다시', 122),
#  ('맛', 121),
#  ('서', 120),
#  ('물', 120),
#  ('수', 118),
#  ('내리는', 118),
#  ('사용', 117),
#  ('얹어', 117),
#  ('찌거나', 117),
#  ('되지기', 116),
#  ('데운', 116),
#  ('인데', 115),
#  ('부옇게', 115),
#  ('연우', 115),
#  ('~', 114),
#  ('놀이', 114),
#  ('끼', 114),
#  ('2', 113),
#  ('사물', 113),
#  ('煉雨', 112),
#  ('새참', 111),
#  ('고갱', 111),
#  ('핵심', 111),
#  ('시간', 111),
#  ('본', 110),
#  ('있는', 109),
#  ('문장', 108),
#  ('생활', 108),
#  ('4', 107),
#  ('30', 106),
#  ('하세요', 105),
#  ('입니다', 104),
#  ('많이', 104),
#  ('여', 104),
#  ('기본', 103),
#  ('결과', 103),
#  ('빨리', 103),
#  ('잘', 103),
#  ('정확히', 102),
#  ('제외', 102),
#  ('구분', 102),
#  ('문서', 101),
#  ('기념일', 101),
#  ('상세', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('반드시', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('우리', 99),
#  ('만든', 99),
#  ('전통', 97),
#  ('여름철', 96),
#  ('하며', 94),
#  ('안녕하세요', 93),
#  ('"', 92),
#  ('100', 92),
#  ('시원한', 91),
#  ('주세요', 91),
#  ('다', 89),
#  ('2010.12', 89),
#  ('좋은', 89),
#  ('즐거운', 88),
#  ('사회', 88),
#  ('설날', 87),
#  ('연날리기', 87),
#  ('보낸다', 87),
#  ('성인', 87),
#  ('成人の日', 87),
#  ('말', 87),
#  ('인', 86),
#  ('지나가고', 86),
#  ('도래', 86),
#  ('관련', 86),
#  ('소리', 86),
#  ('지역', 84),
#  ('!', 83),
#  ('우리나라', 83),
#  ('이슬', 80),
#  ('방학', 79),
#  ('학교', 78),
#  ('조사', 78),
#  ('백', 78),
#  ('제발', 77),
#  ('내려', 77),
#  ('순', 76),
#  ('하는데', 75),
#  ('보리', 75),
#  ('일반', 74),
#  ('부탁드립니다', 73),
#  ('0', 73),
#  ('곡', 73),
#  ('그리고', 72),
#  ('밀', 72),
#  ('심어', 72),
#  ('보세', 72),
#  ('아', 71),
#  ('중국', 71),
#  ('여행', 70),
#  ('꼭', 70),
#  ('가을', 69),
#  ('선생님', 69),
#  ('끝끝', 69),
#  ('익어도', 69),
#  ('필리핀', 68),
#  ('2008.03', 68),
#  ('맺고', 68),
#  ('16', 67),
#  ('겨울', 67),
#  ('영어', 67),
#  ('베어', 67),
#  ('열매', 66),
#  ('갈이', 66),
#  ('^^', 65),
#  ('15', 65),
#  ('해주세요', 64),
#  ('??', 64),
#  ('내', 64),
#  ("'", 64),
#  ('산', 64),
#  ('하려니와', 64),
#  ('나네', 64),
#  ('방아', 64),
#  ('찧어', 64),
#  ('밥살', 64),
#  ('여름', 63),
#  ('예쁜', 63),
#  ('예', 63),
#  ('18', 63),
#  ('분', 62),
#  ('내일', 62),
#  ('ㅠㅠ', 61),
#  ('6', 59),
#  ('하고', 59),
#  ('<', 59),
#  ('ㅠ', 58),
#  ('어떤', 57),
#  ('2008.04', 57),
#  ('알', 57),
#  ('화로', 57),
#  ('*', 57),
#  ('많은', 55),
#  ('오늘', 55),
#  ('모습', 55),
#  ('한국', 54),
#  ('때문', 54),
#  ('!!!', 53),
#  ('자주', 52),
#  ('ag', 52),
#  ('13', 51),
#  ('바람', 50),
#  ('풍년', 50),
#  ('급해요', 49),
#  ('든다', 49),
#  ('가장', 48),
#  ('12', 48),
#  ('특징', 48),
#  ('추천', 47),
#  ('50', 47),
#  ('구름', 47),
#  ('2008.09', 47),
#  ('하', 46),
#  ('무더운', 46),
#  ('강한', 46),
#  ('29', 45),
#  ('전', 45),
#  ('이면', 45),
#  ('순수한', 45),
#  ('하지만', 44),
#  ('조금', 44),
#  ('19', 44),
#  ('신고', 44),
#  ('써주세요', 44),
#  ('관', 44),
#  ('태국', 44),
#  ('쪽', 43),
#  ('거', 43),
#  ('알려주세여', 42),
#  ('14', 42),
#  ('기후', 42),
#  ('달', 42),
#  ('밑', 42),
#  ('음식물', 42),
#  ('기운', 42),
#  ('라서', 41),
#  ('.....', 41),
#  ('가르쳐주세요', 41),
#  ('아래', 41),
#  ('^', 41),
#  ('17', 40),
#  ('겁니다', 40),
#  ('거든요', 40),
#  ('월령', 40),
#  ('2007.09', 40),
#  ('자매', 40),
#  ('보다', 39),
#  ('무엇', 39),
#  ('들어', 39),
#  ('한다', 39),
#  ('학기', 39),
#  ('까닭', 39),
#  ('볼', 38),
#  ('떡', 38),
#  ('낱말', 38),
#  ('결연', 38),
#  ('ㅜ', 37),
#  ('11', 37),
#  ('hot', 37),
#  ('모이는', 37),
#  ('농가', 37),
#  ('제주도', 37),
#  ('부탁드려요', 36),
#  ('~~', 36),
#  ('28', 36),
#  ('24', 36),
#  ('같은', 36),
#  ('책', 36),
#  ('한글', 36),
#  ('가르쳐', 36),
#  ('문제', 35),
#  ('07', 35),
#  ('25', 35),
#  ('경우', 35),
#  ('계속', 35),
#  ('대', 35),
#  ('적어주세요', 35),
#  ('데', 35),
#  ('그래서', 34),
#  ('09', 34),
#  ('뜨거운', 34),
#  ('과학', 34),
#  ('글', 34),
#  ('발생', 33),
#  ('재', 33),
#  ('일본', 33),
#  ('04', 33),
#  ('ethn', 33),
#  ('시나', 33),
#  ('브로', 33),
#  ('ocam', 33),
#  ('정리', 33),
#  ('갈', 32),
#  ('점', 32),
#  ('한편', 32),
#  ('에서는', 32),
#  ('27', 32),
#  ('차', 32),
#  ('복사', 32),
#  ('더', 31),
#  ('②', 31),
#  ('미국', 31),
#  ('마련', 31),
#  ('넘으려고', 31),
#  ('주로', 30),
#  ('구', 30),
#  ('이렇게', 30),
#  ('지', 30),
#  ('냠냠', 30),
#  ('부터', 30),
#  ('께서', 30),
#  ('|', 30),
#  ('호텔', 29),
#  ('이런', 29),
#  ('26', 29),
#  ('주', 29),
#  ('뭐', 29),
#  ('......', 29),
#  ('ㅜㅜ', 29),
#  ('사이', 29),
#  ('종류', 29),
#  ('새', 29),
#  ('각', 29),
#  ('9월', 29),
#  ('감사하겠습니다', 29),
#  ('23', 29),
#  ('다음', 29),
#  ('현지', 28),
#  ('대부분', 28),
#  ('어느', 28),
#  ('내용', 28),
#  ('사진', 28),
#  ('하여', 28),
#  (';', 28),
#  ('알려', 28),
#  ('2008.10', 28),
#  ('12월', 27),
#  ('설명', 27),
#  ('05', 27),
#  (',,', 27),
#  ('알려주시면', 27),
#  ('대한', 27),
#  ('염', 27),
#  ('21', 27),
#  ('대하', 27),
#  ('에게', 27),
#  ('앞', 27),
#  ('먹는다', 27),
#  ('숯불', 27),
#  ('담아', 27),
#  ('퀴즈', 27),
#  ('08', 26),
#  ('생각', 26),
#  ('같이', 26),
#  ('별로', 26),
#  ('빨리요', 26),
#  ('최대한', 26),
#  ('강수량', 26),
#  ('food', 26),
#  ('이동성', 26),
#  ('고기압', 26),
#  ('했다', 26),
#  ('또한', 25),
#  ('되고', 25),
#  ('있나요', 25),
#  ('지식인', 25),
#  ('자세히', 25),
#  ('2008.08', 25),
#  ('fog', 25),
#  ('아시', 25),
#  ('이야기', 25),
#  ('고유', 25),
#  ('엷은', 25),
#  ('피워', 25),
#  ('도록', 25),
#  ('하기도', 25),
#  ('3월', 25),
#  ('맺은', 25),
#  ('너무', 24),
#  ('제일', 24),
#  ('드림', 24),
#  ('지금', 24),
#  ('이유', 24),
#  ('각국', 24),
#  ('~!', 24),
#  ('기온', 24),
#  ('주변', 24),
#  ('·', 24),
#  ('어려운', 24),
#  ('초', 24),
#  ('속', 24),
#  ('라고', 24),
#  ('6월', 24),
#  ('세', 24),
#  ('해외', 23),
#  ('저희', 23),
#  ('에요', 23),
#  ('대표', 23),
#  ('베트남', 23),
#  ('의미', 23),
#  ('몇', 23),
#  ('올려주세요', 23),
#  ('과일', 23),
#  ('먼저', 23),
#  ('많고', 23),
#  ('문', 23),
#  ('02', 23),
#  ('2010.06', 23),
#  ('위해', 23),
#  ('중심부', 23),
#  ('맑게', 23),
#  ('갠', 23),
#  ('산이', 23),
#  ('운다고', 23),
#  ('따라', 23),
#  ('있다', 23),
#  ('한자', 23),
#  ('넌센스', 23),
#  ('오른', 22),
#  ('도시', 22),
#  ('오', 22),
#  ('01', 22),
#  ('이랑', 22),
#  ('받고', 22),
#  ('가옥', 22),
#  ('봄', 22),
#  ('초등학교', 22),
#  ('조상', 22),
#  ('여우비', 22),
#  ('따뜻하게', 22),
#  ('있으며', 21),
#  ('정말', 21),
#  ('있을까요', 21),
#  ('~~~', 21),
#  ('이번', 21),
#  ('분야', 21),
#  ('채택', 21),
#  ('>', 21),
#  ('집', 21),
#  ('2011.07', 21),
#  ('이라는', 21),
#  ('2008.06', 21),
#  ('2007.10', 21),
#  ('덥히기', 21),
#  ('아궁이', 21),
#  ('불씨', 21),
#  ('하였다', 21),
#  ('끝', 21),
#  ('해주세여', 21),
#  ('뉴욕', 20),
#  ('드시는', 20),
#  ('비경', 20),
#  ('06', 20),
#  ('식', 20),
#  ('걸', 20),
#  ('얼마나', 20),
#  ('1월', 20),
#  ('있어요', 20),
#  ('ㅁ', 20),
#  ('있는데', 20),
#  ('하기', 20),
#  ('두', 20),
#  ('22', 20),
#  ('일이', 20),
#  ('조사해', 20),
#  ('2009.04', 20),
#  ('대전', 20),
#  ('7', 20),
#  ('막', 20),
#  ('놓인', 20),
#  ('께', 20),
#  ('큰', 20),
#  ('이쁜', 20),
#  ('찾기', 20),
#  ('2008.01', 20),
#  ('으로는', 20),
#  ('여행지', 19),
#  ('타임스', 19),
#  ('선정', 19),
#  ('죽기전에', 19),
#  ('가봐야', 19),
#  ('맛있기는', 19),
#  ('간혹', 19),
#  ('계시는데', 19),
#  ('열', 19),
#  ('하면', 19),
#  ('랑', 19),
#  ('도와주세요', 19),
#  ('명', 19),
#  ('자세하게', 19),
#  ('31', 19),
#  ('입', 19),
#  ('그런', 19),
#  ('특색', 19),
#  ('삼', 19),
#  ('금', 19),
#  ('켜주세요', 19),
#  ('9', 19),
#  ('말고', 19),
#  ('답', 19),
#  ('별', 19),
#  ('수수께끼', 19),
#  ('해요', 19),
#  ('봉동읍', 19),
#  ('ltah', 19),
#  ('쓰임', 19),
#  ('그냥', 18),
#  ('이라', 18),
#  ('없는', 18),
#  ('않고', 18),
#  ('급함', 18),
#  ('시', 18),
#  ('인데요', 18),
#  ('번', 18),
#  ('2007.08', 18),
#  ('관계', 18),
#  ('온', 18),
#  ('씩', 18),
#  ('a', 18),
#  ('수수', 18),
#  ('외래어', 18),
#  ('2009.03', 18),
#  ('단원', 18),
#  ('옛날', 18),
#  ('<<', 18),
#  ('살', 18),
#  ('▶', 18),
#  ('물이', 18),
#  ('역', 18),
#  ('.,', 18),
#  ('남자', 17),
#  ('해야', 17),
#  ('모든', 17),
#  ('약간', 17),
#  ('네', 17),
#  ('보다는', 17),
#  ('되도록', 17),
#  ('추운', 17),
#  ('자료', 17),
#  ('day', 17),
#  ('fool', 17),
#  ('발', 17),
#  ('거기', 17),
#  ('학생', 17),
#  ('적어', 17),
#  ('그런데', 17),
#  ('여울', 17),
#  ('어떻게', 17),
#  ('..>', 17),
#  ('김', 17),
#  ('시애틀', 17),
#  ('유명하고', 17),
#  ('모노레일', 17),
#  ('요점', 17),
#  ('언제나', 17),
#  ('처음', 16),
#  ('탈', 16),
#  ('쓰는', 16),
#  ('세상', 16),
#  ('03', 16),
#  ('옷', 16),
#  ('지방', 16),
#  ('님들', 16),
#  ('바보', 16),
#  ('식품', 16),
#  ('곡식', 16),
#  ('비교', 16),
#  ('소화', 16),
#  ('준다는', 16),
#  ('???', 16),
#  ('길마', 16),
#  ('.........?', 16),
#  ('/...', 16),
#  ('삼월', 16),
#  ('친척', 16),
#  ('대접', 16),
#  ('비용', 16),
#  ('노력', 16),
#  ('들겠는가', 16),
#  ('거지', 16),
#  ('부지런해야', 16),
#  ('얻어먹는다', 16),
#  ('부지런해야만', 16),
#  ('복', 16),
#  ('관광지', 15),
#  (';;', 15),
#  ('요즘', 15),
#  ('좋아하는', 15),
#  ('글자', 15),
#  ('해외여행', 15),
#  ('부드럽고', 15),
#  ('특히', 15),
#  ('바랍니다', 15),
#  ('정보', 15),
#  ('먹을', 15),
#  ('어디', 15),
#  ('_', 15),
#  ('써주시면', 15),
#  ('영', 15),
#  ('시기', 15),
#  ('해주시', 15),
#  ('값', 15),
#  ('님', 15),
#  ('2009.09', 15),
#  ('음식점', 15),
#  ('권', 15),
#  ('표현', 15),
#  ('이제', 15),
#  ('지장', 15),
#  ('국어', 15),
#  ('그럼', 15),
#  ('지식', 15),
#  ('2008.02', 15),
#  ('자연환경', 15),
#  ('조금씩', 15),
#  ('높은', 15),
#  ('.(', 15),
#  ('ㅇ', 15),
#  ('가에', 15),
#  ('소', 15),
#  ('낀다', 15),
#  ('박', 14),
#  ('이고', 14),
#  ('성', 14),
#  ('근데', 14),
#  ('보고', 14),
#  ('간', 14),
#  ('친구', 14),
#  ('없어서', 14),
#  ('!!!!', 14),
#  ('참고', 14),
#  ('후', 14),
#  ('연', 14),
#  ('습도', 14),
#  ('가진', 14),
#  ('사막', 14),
#  ('방법', 14),
#  ('마다', 14),
#  ('되지', 14),
#  ('논', 14),
#  ('초딩', 14),
#  ('어', 14),
#  ('2006.09', 14),
#  ('따위', 14),
#  ('적지', 14),
#  ('83', 14),
#  ('한자어', 14),
#  ('끊이지', 14),
#  ('않을', 14),
#  ('선택', 13),
#  ('및', 13),
#  ('먹기', 13),
#  ('194', 13),
#  ('재개', 13),
#  ('약', 13),
#  ('유럽', 13),
#  ('캄보디아', 13),
#  ('?...', 13),
#  ('유래', 13),
#  ('2010.03', 13),
#  ('드려요', 13),
#  ('아는', 13),
#  ('된다', 13),
#  ('∼', 13),
#  ('여러가지', 13),
#  ('형', 13),
#  ('러시아', 13),
#  ('라', 13),
#  ('아이', 13),
#  ('아무', 13),
#  ('절', 13),
#  ('에만', 13),
#  ('공부', 13),
#  ('가사', 13),
#  ('하늘', 13),
#  ('외국어', 13),
#  ('2007.03', 13),
#  ('빠른', 13),
#  ('하는데요', 13),
#  ('알려주세', 13),
#  ('맑은', 13),
#  ('멍', 13),
#  ('대거', 13),
#  ('빼기', 13),
#  ('방축', 13),
#  ('해오래요', 13),
#  ('섬', 13),
#  ('폐백', 13),
#  ('이바지', 13),
#  ('쓴다', 13),
#  ('벙거지', 13),
#  ('곶감', 13),
#  ('너으', 13),
#  ('풀어질', 13),
#  ('구체', 13),
#  ('원령', 13),
#  ('될', 13),
#  ('등등', 12),
#  ('써', 12),
#  ('쉬운', 12),
#  ('찾고', 12),
#  ('느낌', 12),
#  ('40', 12),
#  ('하다', 12),
#  ('또는', 12),
#  ('소설', 12),
#  ('영국', 12),
#  ('늘', 12),
#  ('줄', 12),
#  ('인지', 12),
#  ('8', 12),
#  ('비단', 12),
#  ('국한', 12),
#  ('나올', 12),
#  ('무슨', 12),
#  ('주시', 12),
#  ('용', 12),
#  ('저기', 12),
#  ('내는', 12),
#  ('모', 12),
#  ('8월', 12),
#  ('해석', 12),
#  ('드립니다', 12),
#  ('검', 12),
#  ('먼', 12),
#  ('무지개', 12),
#  ('찾아', 12),
#  ('물건', 12),
#  ('코끼리', 12),
#  ('외워야', 12),
#  ('일정', 11),
#  ('반', 11),
#  ('해도', 11),
#  ('ㅎㅎ', 11),
#  ('겨울방학', 11),
#  ('욧', 11),
#  ('니까', 11),
#  ('먹고', 11),
#  ('사전', 11),
#  ('가서', 11),
#  ('이슬비', 11),
#  ('이며', 11),
#  ('문화', 11),
#  ('니', 11),
#  ('모두', 11),
#  ('보면', 11),
#  ('동남아시아', 11),
#  ('한여름', 11),
#  ('평균', 11),
#  ('℃', 11),
#  ('높고', 11),
#  ('죽음', 11),
#  ('foot', 11),
#  (',(', 11),
#  ('풀', 11),
#  ('그것', 11),
#  ('손', 11),
#  ('들어가는', 11),
#  ('싶습니다', 11),
#  ('알수있는', 11),
#  ('까지요', 11),
#  ('중학교', 11),
#  ('있으면', 11),
#  ('감사', 11),
#  ('눈', 11),
#  ('2008.07', 11),
#  ('여러분', 11),
#  ('되는', 11),
#  ('.......', 11),
#  ('무서운', 11),
#  ('단', 11),
#  ('2007.11', 11),
#  ('사이트', 11),
#  ('유명한', 11),
#  ('변화', 11),
#  ('찾아주세요', 11),
#  ('양', 11),
#  ('라는', 11),
#  ('바로', 11),
#  ('2006.10', 11),
#  ('굵고', 11),
#  ('볼때', 11),
#  ('드래곤', 11),
#  ('전라북도', 11),
#  ('가게', 10),
#  ('래', 10),
#  ('싶은', 10),
#  ('비행기', 10),
#  ('5월', 10),
#  ('국가', 10),
#  ('란', 10),
#  ('같아요', 10),
#  ('진짜', 10),
#  ('목연', 10),
#  ('있고', 10),
#  ('알려주', 10),
#  ('요리', 10),
#  ('몰라서', 10),
#  ('여자', 10),
#  ('시작', 10),
#  ('하려', 10),
#  ('눈물', 10),
#  ('성하', 10),
#  ('나타나게', 10),
#  ('분포', 10),
#  ('운량', 10),
#  ('반면', 10),
#  ('ㅋ', 10),
#  ('아무리', 10),
#  (',,,', 10),
#  ('대낮', 10),
#  ('death', 10),
#  ('desert', 10),
#  ('공', 10),
#  ('배', 10),
#  ('강', 10),
#  ('~~!!', 10),
#  ('개월', 10),
#  ('조', 10),
#  ('월요일', 10),
#  ('날짜', 10),
#  ('가르', 10),
#  ('좋아도', 10),
#  ('숙젠데', 10),
#  ('많을수록', 10),
#  ('있습니다', 10),
#  ('foggy', 10),
#  ('),', 10),
#  ('관용', 10),
#  ('~~~~', 10),
#  ('1000', 10),
#  ('써오라고', 10),
#  ('현상', 10),
#  ('달라지는', 10),
#  ('모르는', 10),
#  ('그림', 10),
#  ('개좀', 10),
#  ('대륙', 10),
#  ('모르겠어요', 10),
#  ('의식주', 10),
#  ('만큼', 10),
#  ('과는', 10),
#  ('도구', 10),
#  ('도르리', 10),
#  ('돌아가며', 10),
#  ('제각기', 10),
#  ('마중', 10),
#  ('펌프', 10),
#  ('하면서', 10),
#  ('):', 10),
#  ('방언', 10),
#  ('해오', 10),
#  ('환경', 9),
#  ('얼마', 9),
#  ('아니면', 9),
#  ('추가', 9),
#  ('ㅋㅋㅋ', 9),
#  ('배탈', 9),
#  ('여름날', 9),
#  ('드릴게요', 9),
#  ('없고', 9),
#  ('학교숙제', 9),
#  ('노래', 9),
#  ('가족', 9),
#  ('2월', 9),
#  ('돈', 9),
#  ('서도', 9),
#  ('국수', 9),
#  ('편이', 9),
#  ('가려고', 9),
#  ('지구', 9),
#  ('사는', 9),
#  ('정확하게', 9),
#  ('왜', 9),
#  ('음', 9),
#  ('수도', 9),
#  ('경상북도', 9),
#  ('2007.04', 9),
#  ('huge', 9),
#  ('거대한', 9),
#  ('desk', 9),
#  ('기슭', 9),
#  ('football', 9),
#  ('사', 9),
#  ('하셔서', 9),
#  ('말구요', 9),
#  ('It', 9),
#  ('남', 9),
#  ('했는데', 9),
#  ('피부', 9),
#  ('써서', 9),
#  ('않', 9),
#  ('시험', 9),
#  ('이라도', 9),
#  ('하시면', 9),
#  ('냉면', 9),
#  ('에도', 9),
#  ('동물', 9),
#  ('일기', 9),
#  ('풀이', 9),
#  ('안녕하세여', 9),
#  ('머리', 9),
#  ('예요', 9),
#  ('여서', 9),
#  ('북한', 9),
#  ('없을까요', 9),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='안개 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='안개 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='안개 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='안개 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='안개 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='안개 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [(':', 1092),
#  ('음식', 1026),
#  ('닉네임', 897),
#  ('더운', 835),
#  ('안개', 821),
#  ('****', 725),
#  ('(', 560),
#  ('●', 421),
#  ('여러', 417),
#  ('개', 414),
#  ('검색', 408),
#  ('우리말', 401),
#  ('날', 378),
#  ('밥', 370),
#  ('위', 362),
#  ('비', 359),
#  (')', 353),
#  ('안', 329),
#  ('입력', 300),
#  ('등', 299),
#  ('에는', 294),
#  ('사람', 290),
#  ('내공', 288),
#  ('알려주세요', 286),
#  ('에서', 281),
#  ('해', 279),
#  ('방', 236),
#  ('함께', 230),
#  ('짙은', 226),
#  ('날씨', 224),
#  (')...', 224),
#  ('숙제', 220),
#  ('낀', 213),
#  ('바다', 211),
#  ('몸', 211),
#  ('아주', 211),
#  ('포함', 210),
#  ('나무', 208),
#  ('나라', 207),
#  ('미', 203),
#  ('질', 197),
#  ('까지', 196),
#  ('섶', 196),
#  ('돌', 196),
#  ('합니다', 195),
#  ('마소', 195),
#  ('비비는', 195),
#  ('짓', 195),
#  ('된', 194),
#  ('맛있는', 193),
#  ('힘', 193),
#  ('운김', 191),
#  ('한창', 191),
#  ('우러나', 191),
#  ('학년', 190),
#  ('이다', 189),
#  ('저', 186),
#  ('뜻', 186),
#  ('와', 179),
#  ('3', 176),
#  ('밤', 176),
#  ('아침', 175),
#  ('속담', 174),
#  ('순우리말', 173),
#  ('적', 167),
#  ('나', 166),
#  ('아름다운', 166),
#  ('면', 161),
#  ('대해', 158),
#  ('명절', 157),
#  ('동남아', 151),
#  ('이나', 150),
#  ('찬', 150),
#  ('5', 149),
#  ('처럼', 146),
#  ('다른', 145),
#  ('해서', 144),
#  ('그', 143),
#  ('[', 143),
#  ('먹는', 142),
#  ('-', 141),
#  ('부탁', 137),
#  (']', 137),
#  ('정도', 135),
#  ('세계', 133),
#  ('또', 132),
#  ('계절', 131),
#  ('농가월령가', 131),
#  ('고유어', 130),
#  ('기', 128),
#  ('만', 128),
#  ('가는', 128),
#  ('곳', 126),
#  ('/', 124),
#  ('이름', 124),
#  ('거리', 123),
#  ('①', 123),
#  ('가지', 123),
#  ('다시', 122),
#  ('맛', 121),
#  ('서', 120),
#  ('물', 120),
#  ('내리는', 118),
#  ('사용', 117),
#  ('얹어', 117),
#  ('찌거나', 117),
#  ('되지기', 116),
#  ('데운', 116),
#  ('부옇게', 115),
#  ('연우', 115),
#  ('놀이', 114),
#  ('끼', 114),
#  ('사물', 113),
#  ('煉雨', 112),
#  ('새참', 111),
#  ('고갱', 111),
#  ('핵심', 111),
#  ('시간', 111),
#  ('본', 110),
#  ('문장', 108),
#  ('생활', 108),
#  ('4', 107),
#  ('30', 106),
#  ('하세요', 105),
#  ('입니다', 104),
#  ('많이', 104),
#  ('여', 104),
#  ('결과', 103),
#  ('빨리', 103),
#  ('정확히', 102),
#  ('제외', 102),
#  ('구분', 102),
#  ('문서', 101),
#  ('기념일', 101),
#  ('상세', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('반드시', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('우리', 99),
#  ('만든', 99),
#  ('전통', 97),
#  ('여름철', 96),
#  ('하며', 94),
#  ('안녕하세요', 93),
#  ('"', 92),
#  ('100', 92),
#  ('시원한', 91),
#  ('주세요', 91),
#  ('2010.12', 89),
#  ('좋은', 89),
#  ('즐거운', 88),
#  ('사회', 88),
#  ('설날', 87),
#  ('연날리기', 87),
#  ('보낸다', 87),
#  ('성인', 87),
#  ('成人の日', 87),
#  ('말', 87),
#  ('인', 86),
#  ('지나가고', 86),
#  ('도래', 86),
#  ('관련', 86),
#  ('소리', 86),
#  ('지역', 84),
#  ('!', 83),
#  ('우리나라', 83),
#  ('이슬', 80),
#  ('방학', 79),
#  ('학교', 78),
#  ('조사', 78),
#  ('백', 78),
#  ('제발', 77),
#  ('내려', 77),
#  ('순', 76),
#  ('하는데', 75),
#  ('보리', 75),
#  ('일반', 74),
#  ('부탁드립니다', 73),
#  ('0', 73),
#  ('곡', 73),
#  ('그리고', 72),
#  ('밀', 72),
#  ('심어', 72),
#  ('보세', 72),
#  ('아', 71),
#  ('중국', 71),
#  ('여행', 70),
#  ('꼭', 70),
#  ('가을', 69),
#  ('선생님', 69),
#  ('끝끝', 69),
#  ('익어도', 69),
#  ('필리핀', 68),
#  ('2008.03', 68),
#  ('맺고', 68),
#  ('16', 67),
#  ('겨울', 67),
#  ('영어', 67),
#  ('베어', 67),
#  ('열매', 66),
#  ('갈이', 66),
#  ('^^', 65),
#  ('15', 65),
#  ('해주세요', 64),
#  ('??', 64),
#  ('내', 64),
#  ("'", 64),
#  ('산', 64),
#  ('하려니와', 64),
#  ('나네', 64),
#  ('방아', 64),
#  ('찧어', 64),
#  ('밥살', 64),
#  ('여름', 63),
#  ('예쁜', 63),
#  ('예', 63),
#  ('18', 63),
#  ('분', 62),
#  ('내일', 62),
#  ('ㅠㅠ', 61),
#  ('하고', 59),
#  ('<', 59),
#  ('ㅠ', 58),
#  ('2008.04', 57),
#  ('알', 57),
#  ('화로', 57),
#  ('*', 57),
#  ('많은', 55),
#  ('오늘', 55),
#  ('모습', 55),
#  ('한국', 54),
#  ('때문', 54),
#  ('!!!', 53),
#  ('자주', 52),
#  ('ag', 52),
#  ('13', 51),
#  ('바람', 50),
#  ('풍년', 50),
#  ('급해요', 49),
#  ('든다', 49),
#  ('가장', 48),
#  ('12', 48),
#  ('특징', 48),
#  ('추천', 47),
#  ('50', 47),
#  ('구름', 47),
#  ('2008.09', 47),
#  ('하', 46),
#  ('무더운', 46),
#  ('강한', 46),
#  ('29', 45),
#  ('전', 45),
#  ('이면', 45),
#  ('순수한', 45),
#  ('하지만', 44),
#  ('조금', 44),
#  ('19', 44),
#  ('신고', 44),
#  ('써주세요', 44),
#  ('관', 44),
#  ('태국', 44),
#  ('쪽', 43),
#  ('알려주세여', 42),
#  ('14', 42),
#  ('기후', 42),
#  ('달', 42),
#  ('밑', 42),
#  ('음식물', 42),
#  ('기운', 42),
#  ('라서', 41),
#  ('.....', 41),
#  ('가르쳐주세요', 41),
#  ('아래', 41),
#  ('^', 41),
#  ('17', 40),
#  ('겁니다', 40),
#  ('거든요', 40),
#  ('월령', 40),
#  ('2007.09', 40),
#  ('자매', 40),
#  ('보다', 39),
#  ('무엇', 39),
#  ('들어', 39),
#  ('한다', 39),
#  ('학기', 39),
#  ('까닭', 39),
#  ('볼', 38),
#  ('떡', 38),
#  ('낱말', 38),
#  ('결연', 38),
#  ('ㅜ', 37),
#  ('11', 37),
#  ('hot', 37),
#  ('모이는', 37),
#  ('농가', 37),
#  ('제주도', 37),
#  ('부탁드려요', 36),
#  ('~~', 36),
#  ('28', 36),
#  ('24', 36),
#  ('같은', 36),
#  ('책', 36),
#  ('한글', 36),
#  ('가르쳐', 36),
#  ('문제', 35),
#  ('07', 35),
#  ('25', 35),
#  ('경우', 35),
#  ('계속', 35),
#  ('적어주세요', 35),
#  ('그래서', 34),
#  ('09', 34),
#  ('뜨거운', 34),
#  ('과학', 34),
#  ('글', 34),
#  ('발생', 33),
#  ('재', 33),
#  ('일본', 33),
#  ('04', 33),
#  ('ethn', 33),
#  ('시나', 33),
#  ('브로', 33),
#  ('ocam', 33),
#  ('정리', 33),
#  ('갈', 32),
#  ('점', 32),
#  ('한편', 32),
#  ('에서는', 32),
#  ('27', 32),
#  ('차', 32),
#  ('복사', 32),
#  ('더', 31),
#  ('②', 31),
#  ('미국', 31),
#  ('마련', 31),
#  ('넘으려고', 31),
#  ('주로', 30),
#  ('구', 30),
#  ('이렇게', 30),
#  ('냠냠', 30),
#  ('부터', 30),
#  ('께서', 30),
#  ('|', 30),
#  ('호텔', 29),
#  ('이런', 29),
#  ('26', 29),
#  ('......', 29),
#  ('ㅜㅜ', 29),
#  ('사이', 29),
#  ('종류', 29),
#  ('새', 29),
#  ('각', 29),
#  ('9월', 29),
#  ('감사하겠습니다', 29),
#  ('23', 29),
#  ('다음', 29),
#  ('현지', 28),
#  ('대부분', 28),
#  ('어느', 28),
#  ('내용', 28),
#  ('사진', 28),
#  ('하여', 28),
#  (';', 28),
#  ('알려', 28),
#  ('2008.10', 28),
#  ('12월', 27),
#  ('설명', 27),
#  ('05', 27),
#  (',,', 27),
#  ('알려주시면', 27),
#  ('대한', 27),
#  ('염', 27),
#  ('21', 27),
#  ('대하', 27),
#  ('에게', 27),
#  ('앞', 27),
#  ('먹는다', 27),
#  ('숯불', 27),
#  ('담아', 27),
#  ('퀴즈', 27),
#  ('08', 26),
#  ('생각', 26),
#  ('같이', 26),
#  ('별로', 26),
#  ('빨리요', 26),
#  ('최대한', 26),
#  ('강수량', 26),
#  ('food', 26),
#  ('이동성', 26),
#  ('고기압', 26),
#  ('했다', 26),
#  ('또한', 25),
#  ('되고', 25),
#  ('있나요', 25),
#  ('지식인', 25),
#  ('자세히', 25),
#  ('2008.08', 25),
#  ('fog', 25),
#  ('아시', 25),
#  ('이야기', 25),
#  ('고유', 25),
#  ('엷은', 25),
#  ('피워', 25),
#  ('도록', 25),
#  ('하기도', 25),
#  ('3월', 25),
#  ('맺은', 25),
#  ('너무', 24),
#  ('제일', 24),
#  ('드림', 24),
#  ('지금', 24),
#  ('이유', 24),
#  ('각국', 24),
#  ('~!', 24),
#  ('기온', 24),
#  ('주변', 24),
#  ('·', 24),
#  ('어려운', 24),
#  ('초', 24),
#  ('속', 24),
#  ('6월', 24),
#  ('세', 24),
#  ('해외', 23),
#  ('저희', 23),
#  ('에요', 23),
#  ('대표', 23),
#  ('베트남', 23),
#  ('의미', 23),
#  ('몇', 23),
#  ('올려주세요', 23),
#  ('과일', 23),
#  ('먼저', 23),
#  ('많고', 23),
#  ('문', 23),
#  ('02', 23),
#  ('2010.06', 23),
#  ('위해', 23),
#  ('중심부', 23),
#  ('맑게', 23),
#  ('갠', 23),
#  ('산이', 23),
#  ('운다고', 23),
#  ('따라', 23),
#  ('있다', 23),
#  ('한자', 23),
#  ('넌센스', 23),
#  ('오른', 22),
#  ('도시', 22),
#  ('오', 22),
#  ('01', 22),
#  ('이랑', 22),
#  ('받고', 22),
#  ('가옥', 22),
#  ('봄', 22),
#  ('초등학교', 22),
#  ('조상', 22),
#  ('여우비', 22),
#  ('따뜻하게', 22),
#  ('있으며', 21),
#  ('정말', 21),
#  ('있을까요', 21),
#  ('~~~', 21),
#  ('이번', 21),
#  ('분야', 21),
#  ('채택', 21),
#  ('>', 21),
#  ('집', 21),
#  ('2011.07', 21),
#  ('이라는', 21),
#  ('2008.06', 21),
#  ('2007.10', 21),
#  ('덥히기', 21),
#  ('아궁이', 21),
#  ('불씨', 21),
#  ('하였다', 21),
#  ('끝', 21),
#  ('해주세여', 21),
#  ('뉴욕', 20),
#  ('드시는', 20),
#  ('비경', 20),
#  ('식', 20),
#  ('걸', 20),
#  ('얼마나', 20),
#  ('1월', 20),
#  ('있어요', 20),
#  ('ㅁ', 20),
#  ('있는데', 20),
#  ('하기', 20),
#  ('두', 20),
#  ('22', 20),
#  ('일이', 20),
#  ('조사해', 20),
#  ('2009.04', 20),
#  ('대전', 20),
#  ('7', 20),
#  ('막', 20),
#  ('놓인', 20),
#  ('께', 20),
#  ('큰', 20),
#  ('이쁜', 20),
#  ('찾기', 20),
#  ('2008.01', 20),
#  ('으로는', 20),
#  ('여행지', 19),
#  ('타임스', 19),
#  ('선정', 19),
#  ('죽기전에', 19),
#  ('가봐야', 19),
#  ('맛있기는', 19),
#  ('간혹', 19),
#  ('계시는데', 19),
#  ('열', 19),
#  ('하면', 19),
#  ('랑', 19),
#  ('도와주세요', 19),
#  ('명', 19),
#  ('자세하게', 19),
#  ('31', 19),
#  ('입', 19),
#  ('그런', 19),
#  ('특색', 19),
#  ('삼', 19),
#  ('금', 19),
#  ('켜주세요', 19),
#  ('9', 19),
#  ('말고', 19),
#  ('답', 19),
#  ('별', 19),
#  ('수수께끼', 19),
#  ('해요', 19),
#  ('봉동읍', 19),
#  ('ltah', 19),
#  ('쓰임', 19),
#  ('그냥', 18),
#  ('이라', 18),
#  ('없는', 18),
#  ('않고', 18),
#  ('급함', 18),
#  ('시', 18),
#  ('인데요', 18),
#  ('번', 18),
#  ('2007.08', 18),
#  ('관계', 18),
#  ('온', 18),
#  ('씩', 18),
#  ('a', 18),
#  ('수수', 18),
#  ('외래어', 18),
#  ('2009.03', 18),
#  ('단원', 18),
#  ('옛날', 18),
#  ('<<', 18),
#  ('살', 18),
#  ('▶', 18),
#  ('물이', 18),
#  ('역', 18),
#  ('.,', 18),
#  ('남자', 17),
#  ('해야', 17),
#  ('모든', 17),
#  ('약간', 17),
#  ('보다는', 17),
#  ('되도록', 17),
#  ('추운', 17),
#  ('자료', 17),
#  ('day', 17),
#  ('fool', 17),
#  ('발', 17),
#  ('거기', 17),
#  ('학생', 17),
#  ('적어', 17),
#  ('그런데', 17),
#  ('여울', 17),
#  ('어떻게', 17),
#  ('..>', 17),
#  ('김', 17),
#  ('시애틀', 17),
#  ('유명하고', 17),
#  ('모노레일', 17),
#  ('요점', 17),
#  ('언제나', 17),
#  ('처음', 16),
#  ('탈', 16),
#  ('쓰는', 16),
#  ('세상', 16),
#  ('03', 16),
#  ('옷', 16),
#  ('지방', 16),
#  ('님들', 16),
#  ('바보', 16),
#  ('식품', 16),
#  ('곡식', 16),
#  ('비교', 16),
#  ('소화', 16),
#  ('준다는', 16),
#  ('???', 16),
#  ('길마', 16),
#  ('.........?', 16),
#  ('/...', 16),
#  ('삼월', 16),
#  ('친척', 16),
#  ('대접', 16),
#  ('비용', 16),
#  ('노력', 16),
#  ('들겠는가', 16),
#  ('거지', 16),
#  ('부지런해야', 16),
#  ('얻어먹는다', 16),
#  ('부지런해야만', 16),
#  ('복', 16),
#  ('관광지', 15),
#  (';;', 15),
#  ('요즘', 15),
#  ('좋아하는', 15),
#  ('글자', 15),
#  ('해외여행', 15),
#  ('부드럽고', 15),
#  ('특히', 15),
#  ('바랍니다', 15),
#  ('정보', 15),
#  ('먹을', 15),
#  ('어디', 15),
#  ('_', 15),
#  ('써주시면', 15),
#  ('영', 15),
#  ('시기', 15),
#  ('해주시', 15),
#  ('값', 15),
#  ('님', 15),
#  ('2009.09', 15),
#  ('음식점', 15),
#  ('권', 15),
#  ('표현', 15),
#  ('이제', 15),
#  ('지장', 15),
#  ('국어', 15),
#  ('그럼', 15),
#  ('지식', 15),
#  ('2008.02', 15),
#  ('자연환경', 15),
#  ('조금씩', 15),
#  ('높은', 15),
#  ('.(', 15),
#  ('ㅇ', 15),
#  ('가에', 15),
#  ('소', 15),
#  ('낀다', 15),
#  ('박', 14),
#  ('이고', 14),
#  ('성', 14),
#  ('근데', 14),
#  ('보고', 14),
#  ('간', 14),
#  ('친구', 14),
#  ('없어서', 14),
#  ('!!!!', 14),
#  ('참고', 14),
#  ('연', 14),
#  ('습도', 14),
#  ('가진', 14),
#  ('사막', 14),
#  ('방법', 14),
#  ('마다', 14),
#  ('되지', 14),
#  ('논', 14),
#  ('초딩', 14),
#  ('어', 14),
#  ('2006.09', 14),
#  ('따위', 14),
#  ('적지', 14),
#  ('83', 14),
#  ('한자어', 14),
#  ('끊이지', 14),
#  ('않을', 14),
#  ('선택', 13),
#  ('및', 13),
#  ('먹기', 13),
#  ('194', 13),
#  ('재개', 13),
#  ('약', 13),
#  ('유럽', 13),
#  ('캄보디아', 13),
#  ('?...', 13),
#  ('유래', 13),
#  ('2010.03', 13),
#  ('드려요', 13),
#  ('아는', 13),
#  ('된다', 13),
#  ('∼', 13),
#  ('여러가지', 13),
#  ('형', 13),
#  ('러시아', 13),
#  ('라', 13),
#  ('아이', 13),
#  ('아무', 13),
#  ('절', 13),
#  ('에만', 13),
#  ('공부', 13),
#  ('가사', 13),
#  ('하늘', 13),
#  ('외국어', 13),
#  ('2007.03', 13),
#  ('빠른', 13),
#  ('하는데요', 13),
#  ('알려주세', 13),
#  ('맑은', 13),
#  ('멍', 13),
#  ('대거', 13),
#  ('빼기', 13),
#  ('방축', 13),
#  ('해오래요', 13),
#  ('섬', 13),
#  ('폐백', 13),
#  ('이바지', 13),
#  ('쓴다', 13),
#  ('벙거지', 13),
#  ('곶감', 13),
#  ('너으', 13),
#  ('풀어질', 13),
#  ('구체', 13),
#  ('원령', 13),
#  ('될', 13),
#  ('등등', 12),
#  ('써', 12),
#  ('쉬운', 12),
#  ('찾고', 12),
#  ('느낌', 12),
#  ('40', 12),
#  ('하다', 12),
#  ('또는', 12),
#  ('소설', 12),
#  ('영국', 12),
#  ('늘', 12),
#  ('인지', 12),
#  ('8', 12),
#  ('비단', 12),
#  ('국한', 12),
#  ('나올', 12),
#  ('무슨', 12),
#  ('주시', 12),
#  ('용', 12),
#  ('저기', 12),
#  ('내는', 12),
#  ('모', 12),
#  ('8월', 12),
#  ('해석', 12),
#  ('드립니다', 12),
#  ('검', 12),
#  ('먼', 12),
#  ('무지개', 12),
#  ('찾아', 12),
#  ('물건', 12),
#  ('코끼리', 12),
#  ('외워야', 12),
#  ('일정', 11),
#  ('반', 11),
#  ('해도', 11),
#  ('겨울방학', 11),
#  ('욧', 11),
#  ('니까', 11),
#  ('먹고', 11),
#  ('사전', 11),
#  ('가서', 11),
#  ('이슬비', 11),
#  ('이며', 11),
#  ('문화', 11),
#  ('니', 11),
#  ('모두', 11),
#  ('보면', 11),
#  ('동남아시아', 11),
#  ('한여름', 11),
#  ('평균', 11),
#  ('℃', 11),
#  ('높고', 11),
#  ('죽음', 11),
#  ('foot', 11),
#  (',(', 11),
#  ('풀', 11),
#  ('그것', 11),
#  ('손', 11),
#  ('들어가는', 11),
#  ('싶습니다', 11),
#  ('알수있는', 11),
#  ('까지요', 11),
#  ('중학교', 11),
#  ('있으면', 11),
#  ('감사', 11),
#  ('눈', 11),
#  ('2008.07', 11),
#  ('여러분', 11),
#  ('되는', 11),
#  ('.......', 11),
#  ('무서운', 11),
#  ('단', 11),
#  ('2007.11', 11),
#  ('사이트', 11),
#  ('유명한', 11),
#  ('변화', 11),
#  ('찾아주세요', 11),
#  ('양', 11),
#  ('라는', 11),
#  ('바로', 11),
#  ('2006.10', 11),
#  ('굵고', 11),
#  ('볼때', 11),
#  ('드래곤', 11),
#  ('전라북도', 11),
#  ('가게', 10),
#  ('래', 10),
#  ('싶은', 10),
#  ('비행기', 10),
#  ('5월', 10),
#  ('국가', 10),
#  ('란', 10),
#  ('같아요', 10),
#  ('진짜', 10),
#  ('목연', 10),
#  ('있고', 10),
#  ('알려주', 10),
#  ('요리', 10),
#  ('몰라서', 10),
#  ('여자', 10),
#  ('시작', 10),
#  ('하려', 10),
#  ('눈물', 10),
#  ('성하', 10),
#  ('나타나게', 10),
#  ('분포', 10),
#  ('운량', 10),
#  ('반면', 10),
#  ('ㅋ', 10),
#  ('아무리', 10),
#  (',,,', 10),
#  ('대낮', 10),
#  ('death', 10),
#  ('desert', 10),
#  ('공', 10),
#  ('배', 10),
#  ('강', 10),
#  ('~~!!', 10),
#  ('개월', 10),
#  ('조', 10),
#  ('월요일', 10),
#  ('날짜', 10),
#  ('가르', 10),
#  ('좋아도', 10),
#  ('숙젠데', 10),
#  ('많을수록', 10),
#  ('있습니다', 10),
#  ('foggy', 10),
#  ('),', 10),
#  ('관용', 10),
#  ('~~~~', 10),
#  ('1000', 10),
#  ('써오라고', 10),
#  ('현상', 10),
#  ('달라지는', 10),
#  ('모르는', 10),
#  ('그림', 10),
#  ('개좀', 10),
#  ('대륙', 10),
#  ('모르겠어요', 10),
#  ('의식주', 10),
#  ('만큼', 10),
#  ('과는', 10),
#  ('도구', 10),
#  ('도르리', 10),
#  ('돌아가며', 10),
#  ('제각기', 10),
#  ('마중', 10),
#  ('펌프', 10),
#  ('하면서', 10),
#  ('):', 10),
#  ('방언', 10),
#  ('해오', 10),
#  ('환경', 9),
#  ('얼마', 9),
#  ('아니면', 9),
#  ('추가', 9),
#  ('ㅋㅋㅋ', 9),
#  ('배탈', 9),
#  ('여름날', 9),
#  ('드릴게요', 9),
#  ('없고', 9),
#  ('학교숙제', 9),
#  ('노래', 9),
#  ('가족', 9),
#  ('2월', 9),
#  ('돈', 9),
#  ('서도', 9),
#  ('국수', 9),
#  ('편이', 9),
#  ('가려고', 9),
#  ('지구', 9),
#  ('사는', 9),
#  ('정확하게', 9),
#  ('왜', 9),
#  ('음', 9),
#  ('수도', 9),
#  ('경상북도', 9),
#  ('2007.04', 9),
#  ('huge', 9),
#  ('거대한', 9),
#  ('desk', 9),
#  ('기슭', 9),
#  ('football', 9),
#  ('사', 9),
#  ('하셔서', 9),
#  ('말구요', 9),
#  ('It', 9),
#  ('남', 9),
#  ('했는데', 9),
#  ('피부', 9),
#  ('써서', 9),
#  ('않', 9),
#  ('시험', 9),
#  ('이라도', 9),
#  ('하시면', 9),
#  ('냉면', 9),
#  ('에도', 9),
#  ('동물', 9),
#  ('일기', 9),
#  ('풀이', 9),
#  ('안녕하세여', 9),
#  ('머리', 9),
#  ('예요', 9),
#  ('여서', 9),
#  ('북한', 9),
#  ('없을까요', 9),
#  ('★', 9),
#  ('편', 9),
#  ('알고싶어요', 9),
#  ('nhha', 9),
#  ('한글날', 9),
#  ('올려', 9),
#  ('않는', 9),
#  ('야', 9),
#  ('읽기', 9),
#  ('피', 9),
#  ('모르게', 9),
#  ('옛', 9),
#  ('와인', 9),
#  ('얼', 9),
#  ('->', 9),
#  ('놀라서', 9),
#  ('꾀꼬리', 9),
#  ('문과', 9),
#  ('쇠', 9),
#  ('지나서', 9),
#  ('먹지도', 9),
#  ('그슬리', 9),
#  ('부지', 9),
#  ('깽', 9),
#  ('우물', 9),
#  ('경기도', 9),
#  ('빵값', 9),
#  ('공산품', 9),
#  ('들이므로', 9),
#  ('열대지방', 9),
#  ('랜드', 9),
#  ('파리', 9),
#  ('명언', 9),
#  ('11월', 8),
#  ('중순', 8),
#  ('5일', 8),
#  ('어디가', 8),
#  ('+', 8),
#  ('혼자', 8),
#  ('싶은데요', 8),
#  ('관광', 8),
#  ('걸어요', 8),
#  ('거의', 8),
#  ('현재', 8),
#  ('카톡', 8),
#  ('다리미', 8),
#  ('피자', 8),
#  ('193', 8),
#  ('허수아비', 8),
#  ('치약', 8),
#  ('286', 8),
#  ('덥군', 8),
#  ('287', 8),
#  ('신경통', 8),
#  ('든', 8),
#  ('라면', 8),
#  ('음악', 8),
#  ('2006.08', 8),
#  ('ㅋㅋ', 8),
#  ('일단', 8),
#  ('좋습니다', 8),
#  ('가까운', 8),
#  ('해주시길', 8),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9642 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65378 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9642 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 65378 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
