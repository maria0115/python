# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('눈 더운 날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('눈 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('눈 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('눈 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('눈 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('눈 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는',
#  '음식',
#  '추천',
#  '!!(',
#  '한식',
#  ')',
#  '2007.08',
#  '.',
#  '04',
#  '.',
#  '질리',
#  '고',
#  '뭔가',
#  '색다른',
#  '것',
#  '먹고싶은데',
#  '뭐',
#  '가',
#  '있을까요',
#  '??',
#  '맛있는',
#  '메뉴',
#  '좀',
#  '추천',
#  '해주세요',
#  '.',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는것',
#  '뜨거운거',
#  '매운건',
#  '싫어요',
#  '~~',
#  '한식',
#  '으로',
#  '추천',
#  '부탁드립니다',
#  '.^^',
#  '답변',
#  '한식',
#  '은',
#  '아니지만',
#  '씨',
#  '푸드',
#  '뷔페',
#  '레스토랑',
#  '어때요',
#  '?',
#  '^',
#  'ㅡ',
#  '^',
#  '해산물',
#  '중',
#  '에서',
#  '장어',
#  ',',
#  '병어',
#  ',',
#  '농어',
#  '...',
#  '▦',
#  '찬',
#  '음식',
#  '에서',
#  '더운',
#  '음식',
#  '으로',
#  '=',
#  '뷔페',
#  '도',
#  '일종',
#  '의',
#  '코스',
#  '요리',
#  '로',
#  '생각',
#  '하고',
#  '음식',
#  '을',
#  '선택',
#  '해야',
#  '...',
#  '질문',
#  '전통',
#  '한식',
#  '상차림',
#  '2019.09',
#  '.',
#  '16',
#  '.',
#  '1',
#  '.',
#  '전통',
#  '한식',
#  '의',
#  '첩',
#  '반상',
#  '(',
#  '3',
#  ',',
#  '5',
#  ',',
#  '7',
#  ',',
#  '9',
#  ',',
#  '12',
#  ')',
#  '과',
#  '반찬',
#  '2',
#  '.',
#  '전통',
#  '밥상',
#  '차림',
#  '어떤',
#  '배열',
#  '을',
#  '하는가',
#  '3',
#  '.',
#  '전통',
#  '상',
#  '에',
#  '죽',
#  '상',
#  ',',
#  '장국상',
#  '주안상',
#  '교자상',
#  '다과상',
#  '등',
#  '이',
#  '것',
#  '들',
#  '좀',
#  '알려주세요',
#  '답변',
#  '숟가락',
#  '은',
#  '뜨거운',
#  '국물',
#  '음식',
#  '이',
#  '발달',
#  '한',
#  '한식',
#  '의',
#  '특성',
#  '에',
#  '잘',
#  '맞는',
#  '도구',
#  '이다',
#  '.',
#  '젓가락',
#  '은',
#  '...',
#  '오른쪽',
#  '에는',
#  '더운',
#  '반찬',
#  '을',
#  '놓아',
#  '오른손',
#  '으로',
#  '집어',
#  '먹기',
#  '편하게',
#  '배려',
#  '한',
#  '것',
#  '이',
#  '재미있다',
#  '....',
#  '닉네임',
#  '골드',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '2013.02',
#  '.',
#  '15',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '제발',
#  '부탁드림니다',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  '정답',
#  '질문',
#  '건강',
#  '을',
#  '위해',
#  '서',
#  '더운',
#  '여름철',
#  '의',
#  '건강',
#  '법',
#  '알',
#  '6일',
#  '전',
#  '건강',
#  '을',
#  '위해',
#  '서',
#  '더운',
#  '여름철',
#  '의',
#  '건강',
#  '법',
#  '알려주세요',
#  '~',
#  '답변',
#  '건강',
#  '을',
#  '위해',
#  '서',
#  '더운',
#  '여름철',
#  '의',
#  '건강',
#  '법',
#  '알려주세요',
#  '~',
#  '여름철',
#  '건강',
#  '법',
#  '사계절',
#  '중',
#  '에서',
#  '여름',
#  '이',
#  '...',
#  '고춧가루',
#  '를',
#  '듬뿍',
#  '넣은',
#  '음식',
#  '을',
#  '먹고',
#  '땀',
#  '을',
#  '흘리면',
#  '감기',
#  '초기',
#  '에',
#  '고열',
#  '이',
#  '날',
#  '때',
#  '사용',
#  '하는',
#  '...',
#  '닉네임',
#  '건강한',
#  '삶도전',
#  '질문',
#  '원일',
#  '/',
#  '한식',
#  '/',
#  '단오',
#  '/',
#  '추석',
#  '/',
#  '동지',
#  '때',
#  '풍습',
#  '과',
#  '음식',
#  '2008.09',
#  '.',
#  '28',
#  '.',
#  '원일',
#  '(',
#  '음력',
#  '1월',
#  '1일',
#  '),',
#  '한식',
#  '(',
#  '동지',
#  '부터',
#  '105일',
#  '),',
#  '단오',
#  '(',
#  '음력',
#  '5월',
#  '5일',
#  '),',
#  '추석',
#  '(',
#  '음력',
#  '8월',
#  '15일',
#  '),',
#  '동지',
#  '에',
#  '하는',
#  '풍습',
#  '과',
#  '그',
#  '때',
#  '에',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '~~',
#  '답변',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌리',
#  '기도',
#  '합니다',
#  '.',
#  '【',
#  '한식',
#  '날',
#  '음식',
#  '】',
#  '성묘',
#  '는',
#  '일',
#  '년',
#  '에',
#  '네',
#  '번',
#  '으로',
#  '정초',
#  ',',
#  '한식',
#  ',',
#  '단오',
#  ',',
#  '중추',
#  '에',
#  '한다',
#  '.',
#  '제물',
#  '은',
#  '술',
#  ',',
#  '과일',
#  ',',
#  '포',
#  ',',
#  '식혜',
#  ',',
#  '떡',
#  ',',
#  '국수',
#  ',',
#  '탕',
#  ',',
#  '적',
#  '...',
#  '닉네임',
#  'read',
#  '****',
#  '질문',
#  '한식',
#  '의',
#  '종류',
#  '가르쳐주세요',
#  '2017.10',
#  '.',
#  '28',
#  '.',
#  '한식',
#  '의',
#  '종류',
#  '와',
#  '특징',
#  '을',
#  '가르쳐주세요',
#  '답변',
#  '한식',
#  '에',
#  '대한',
#  '모든',
#  '것',
#  ',',
#  '한식',
#  '의',
#  '종류',
#  ',',
#  '한식',
#  '의',
#  '특징',
#  '...',
#  '것',
#  '이다',
#  '.',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '...',
#  '굴',
#  '이나',
#  '조갯살',
#  '로',
#  '국물',
#  '을',
#  '내어',
#  '날',
#  '떡국',
#  '이나',
#  '칼국수',
#  '를',
#  '끓이며',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '2013년',
#  '한식',
#  '날',
#  '2013.01',
#  '.',
#  '02',
#  '.',
#  '저기',
#  '한식',
#  '날',
#  '날짜',
#  '가',
#  '어떻게',
#  '되나요',
#  '??',
#  '인터넷',
#  '찾아봐도',
#  '없어서요',
#  '.......',
#  '자세하게',
#  '답좀',
#  '해주세요',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어야',
#  '한다는',
#  '속',
#  '신',
#  '(',
#  '俗信',
#  ')...',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제',
#  '사',
#  '음식',
#  '을',
#  '마련',
#  '하여',
#  '제사',
#  '를',
#  '지내는데',
#  ',',
#  '이를',
#  '절사',
#  '(',
#  '節祀',
#  ')...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '2005.04',
#  '.',
#  '05',
#  '.',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '작은',
#  '사진',
#  '을',
#  '올려주셔도',
#  '괜찮습니다',
#  '.',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '1',
#  '.',
#  '여름',
#  '에',
#  '더운',
#  '곳',
#  '에서',
#  '10분',
#  '정도만',
#  '2020.05',
#  '.',
#  '18',
#  '.',
#  '여름',
#  '에',
#  '더운',
#  '곳',
#  '에서',
#  '10분',
#  '정도만',
#  '있으면',
#  '얼굴',
#  '이',
#  '불타는것',
#  '마냥',
#  '뜨거워지고',
#  '...',
#  '맵',
#  '고',
#  '뜨거운',
#  '음식',
#  '을',
#  '먹으면',
#  '눈물',
#  '콧',
#  '물나고',
#  '눈',
#  '도',
#  '빨개져요',
#  '.',
#  '234',
#  '는',
#  '참고',
#  '해주십',
#  '사하는것이고',
#  '1',
#  '번은',
#  '...',
#  '답변',
#  '담백한',
#  '한식',
#  '위주',
#  '로',
#  '규칙',
#  '적',
#  '이고',
#  '담백한',
#  '식사',
#  '와',
#  '유',
#  '산소',
#  '운동',
#  '을',
#  '꾸준히',
#  '하는',
#  '것',
#  '이',
#  '도움',
#  '이',
#  '될',
#  '것',
#  '입니다',
#  '.',
#  '과식',
#  '보다는',
#  '소식',
#  '하는',
#  '것',
#  '이',
#  '좋으며',
#  '맵거나',
#  '자극',
#  '적',
#  '인',
#  '음식',
#  ',',
#  '기름진',
#  '...',
#  '한의사',
#  '답변',
#  '닉네임',
#  '이종우',
#  '질문',
#  '한식',
#  '조사',
#  '여',
#  '.....',
#  '2016.06',
#  '.',
#  '01',
#  '.',
#  '뭐',
#  '가',
#  '우리나라',
#  '음식',
#  '인지',
#  '모르겠어서요',
#  '일단',
#  '1',
#  '.',
#  '한식',
#  '종류',
#  '!',
#  '를',
#  '알려주세요',
#  '2',
#  '.',
#  '그',
#  '음식',
#  '들',
#  '을',
#  '만드는',
#  '방법',
#  '도',
#  '알려주세요',
#  '오늘',
#  '안',
#  '에',
#  '알려주세요',
#  '.....',
#  '지금',
#  '엄청',
#  '급해서요',
#  '.....',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '의',
#  '유래',
#  '점',
#  '알려주세여',
#  '2015.09',
#  '.',
#  '23',
#  '.',
#  '제',
#  '가',
#  '파워포인트',
#  '주제',
#  '로',
#  '한식',
#  '을',
#  '했는데',
#  '뭔',
#  '지',
#  '를',
#  '모르겟음',
#  '여',
#  '답변',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '방향',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='눈 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='눈 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='눈 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='눈 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='눈 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='눈 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 95333
# 8701

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 3622),
#  ('이', 3063),
#  ('...', 2468),
#  ('음식', 1697),
#  ('을', 1654),
#  (',', 1512),
#  ('땀', 1475),
#  ('를', 1462),
#  ('에', 1265),
#  ('날', 1141),
#  ('답변', 1080),
#  ('질문', 1068),
#  ('닉네임', 982),
#  ('가', 800),
#  ('으로', 798),
#  ('적', 762),
#  ('더운', 758),
#  ('때', 752),
#  ('은', 736),
#  ('의', 699),
#  ('는', 699),
#  ('하는', 594),
#  ('에서', 582),
#  ('한', 576),
#  ('단어', 516),
#  ('합니다', 509),
#  ('과', 460),
#  ('만', 443),
#  ('치료', 421),
#  ('로', 415),
#  ('인', 415),
#  ('검색', 411),
#  ('....', 411),
#  ('하고', 405),
#  ('좋은', 381),
#  ('(', 378),
#  ('****', 375),
#  ('입니다', 356),
#  ('다한증', 350),
#  ('도', 343),
#  ('?', 334),
#  ('고사', 333),
#  ('머리', 328),
#  ('해야', 321),
#  ('요', 320),
#  ('한의사', 317),
#  ('먼저', 315),
#  ('이나', 311),
#  ('자극', 309),
#  ('상황', 309),
#  ('아닌데', 309),
#  ('먹을', 308),
#  ('임', 305),
#  ('손', 304),
#  ('동남아', 303),
#  ('나는지', 303),
#  ('피부질환', 303),
#  ('환경', 302),
#  ('전신', 302),
#  ('할', 301),
#  ('분류', 301),
#  ('은교', 301),
#  ('입력', 300),
#  ('와', 300),
#  (')', 299),
#  ('혹은', 298),
#  ('나라', 297),
#  ('육체', 291),
#  ('비오듯', 291),
#  ('것', 267),
#  ('많이', 265),
#  ('제', 251),
#  ('들', 249),
#  ('좀', 249),
#  ('나', 238),
#  ('차', 237),
#  ('..', 233),
#  ('중국', 232),
#  ('집', 227),
#  ('너무', 218),
#  ('등', 204),
#  ('ryul', 204),
#  ('포함', 203),
#  ('마시고', 193),
#  ('지낸', 192),
#  ('일대', 191),
#  ('가져가지', 190),
#  ('일행', 190),
#  ('나누어', 190),
#  ('먹고', 188),
#  ('수', 186),
#  ('하', 181),
#  ('몸', 180),
#  ('다른', 180),
#  ('에는', 176),
#  ('눈', 172),
#  ('거나', 169),
#  ('일본', 167),
#  ('곳', 166),
#  ('신', 165),
#  ('/', 162),
#  ('여러', 160),
#  ('고', 160),
#  ('알려주세요', 154),
#  ('홍조', 154),
#  (':', 149),
#  ('해서', 148),
#  ('기', 147),
#  ('1', 143),
#  ('새', 140),
#  ('숭배', 140),
#  ('개', 133),
#  ('인데', 130),
#  ('된', 128),
#  ('정도', 128),
#  ('중', 126),
#  ('하나', 122),
#  ('유럽', 120),
#  ('얼굴', 118),
#  ('한의원', 118),
#  ('저', 117),
#  ('꼭', 116),
#  ('발', 116),
#  ('국가', 116),
#  ('대', 115),
#  ('이상', 113),
#  ('명절', 112),
#  ('안', 111),
#  ('사용', 110),
#  ('잘', 109),
#  ('중동', 108),
#  ('없는', 107),
#  ('외', 107),
#  ('하세요', 106),
#  ('긴장', 105),
#  ('본', 104),
#  ('3', 104),
#  ('제외', 103),
#  ('안면', 103),
#  ('시간', 103),
#  ('상세', 102),
#  ('문장', 102),
#  ('부터', 102),
#  ('기본', 101),
#  ('정확히', 101),
#  ('반드시', 101),
#  ('결과', 101),
#  ('그', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('구분', 100),
#  ('놀이', 99),
#  ('"', 98),
#  ('일', 95),
#  ('토', 95),
#  ('때문', 94),
#  ('방법', 94),
#  ('날짜', 94),
#  ('ㅠㅠ', 93),
#  ('있는', 93),
#  ('내공', 93),
#  ('안녕하세요', 93),
#  ('못', 92),
#  ('피하', 92),
#  ('추운', 91),
#  ('전', 89),
#  ('사람', 89),
#  ('기름진', 87),
#  ('~', 86),
#  ('높은', 86),
#  ('2', 86),
#  ('체적', 85),
#  ('가공', 85),
#  ('점성', 85),
#  ('경희', 85),
#  ('피레', 85),
#  ('서', 84),
#  ('전통', 82),
#  ('음력', 81),
#  ('또', 80),
#  ('중고차', 80),
#  ('2019.10', 77),
#  ('열', 77),
#  ('지내기', 77),
#  ('장소', 76),
#  ('겨울', 75),
#  ('에서도', 75),
#  (')...', 75),
#  ('이동', 74),
#  ('20', 74),
#  ('한편', 74),
#  ('필리핀', 73),
#  ('그리거나', 72),
#  ('남자', 71),
#  ('부탁드립니다', 71),
#  ('!', 71),
#  ('다', 71),
#  ('구입', 71),
#  ('물', 70),
#  ('하셔서', 70),
#  ('길일', 69),
#  ('나요', 68),
#  ('택', 68),
#  ('위', 67),
#  ('하는데', 67),
#  ('까지', 67),
#  ('지내시기', 65),
#  ('날씨', 64),
#  ('에도', 63),
#  ('양력', 63),
#  ('그리고', 62),
#  ('피부', 61),
#  ('16', 61),
#  ('이다', 61),
#  ('지내는', 61),
#  ('생활', 60),
#  ('면', 60),
#  ('말', 60),
#  ('하면', 58),
#  ('??', 57),
#  ('특히', 57),
#  ('10', 57),
#  ('여자', 57),
#  ('2019.08', 56),
#  ('우리', 55),
#  ('여름', 54),
#  ('-', 54),
#  ('언제', 54),
#  ('세계', 54),
#  ('약', 53),
#  ('설날', 53),
#  ('조금', 52),
#  ('하며', 52),
#  ('계절', 52),
#  ('갑자기', 52),
#  ('14', 52),
#  ('차량', 52),
#  ('생', 52),
#  ('여', 51),
#  ('11', 51),
#  ('추천', 50),
#  ('오늘', 50),
#  ('정말', 50),
#  ('에게', 50),
#  ('지금', 50),
#  ('15', 50),
#  ('님', 50),
#  ('어떤', 49),
#  ('21', 49),
#  ('게', 49),
#  ('7월', 49),
#  ('하여', 49),
#  ('^^', 48),
#  ('이랑', 48),
#  ('2019.09', 48),
#  ('5', 48),
#  ('만든', 48),
#  ('법', 47),
#  ('여행', 47),
#  ('2019.11', 47),
#  ('어느', 47),
#  ('17', 47),
#  ('같이', 47),
#  ('종류', 47),
#  ('더', 46),
#  ('있나요', 46),
#  ('01', 46),
#  ('4', 45),
#  ('분', 45),
#  ('손발', 45),
#  ('왜', 45),
#  ('우리나라', 45),
#  ('신차', 45),
#  ('대해', 44),
#  ('이유', 44),
#  ('어떻게', 44),
#  ('성인', 44),
#  ('8월', 44),
#  ('13', 43),
#  ('29', 43),
#  ('05', 43),
#  ('했습니다', 43),
#  ('차고', 43),
#  ('19', 43),
#  ('겨드랑이', 43),
#  ('즐거운', 43),
#  ('27', 43),
#  ('2월', 43),
#  ('의미', 43),
#  ('여름철', 42),
#  ('이고', 42),
#  ('거', 42),
#  ('남', 42),
#  ('먹는', 42),
#  ('ㅠ', 42),
#  ('수술', 42),
#  ('연날리기', 42),
#  ('보낸다', 42),
#  ('成人の日', 42),
#  ('1월', 42),
#  ('남은', 42),
#  ('항상', 41),
#  ('코', 41),
#  ('관련', 41),
#  ('많은', 41),
#  ('병원', 41),
#  ('찬', 41),
#  ('2018.12', 41),
#  ('드립니다', 41),
#  ('시원한', 40),
#  ('증상', 40),
#  ('납니다', 40),
#  ('요리', 40),
#  ('바랍니다', 40),
#  ('요즘', 39),
#  ('그래서', 39),
#  ('진짜', 39),
#  ('2010.12', 39),
#  ('계속', 38),
#  ('해주세요', 37),
#  ('2020.01', 37),
#  ('인가요', 37),
#  ('처럼', 37),
#  ('숙제', 37),
#  ('하기', 37),
#  ('있는데', 37),
#  ('2019.12', 37),
#  ('12월', 36),
#  ('07', 36),
#  ('두드러기', 36),
#  ('09', 36),
#  ('지', 36),
#  ('밥', 36),
#  ('18', 36),
#  ('기념일', 36),
#  ('11월', 35),
#  ('26', 35),
#  ('30', 35),
#  ('뭐', 35),
#  ('많아요', 35),
#  ('22', 35),
#  ('경우', 35),
#  ('빨리', 35),
#  ('사', 35),
#  ('해', 34),
#  ('06', 34),
#  ('아침', 34),
#  ('가장', 34),
#  ('운동', 34),
#  ('체질', 34),
#  ('편', 34),
#  ('주', 34),
#  ('하지만', 33),
#  ('문의', 33),
#  ('엔', 33),
#  ('생각', 33),
#  ('원래', 33),
#  ('문화', 33),
#  ('평소', 33),
#  ('3월', 33),
#  ('08', 32),
#  ('엄청', 32),
#  ('2020.06', 32),
#  ('점', 32),
#  ('쪽', 32),
#  ('이라', 32),
#  ('아', 32),
#  ('내일', 32),
#  ('!!', 32),
#  ('음', 32),
#  ('몇', 31),
#  ('같은', 31),
#  ('살', 31),
#  ('02', 31),
#  ('이름', 31),
#  ('24', 31),
#  ('이번', 30),
#  ('간', 30),
#  ('28', 30),
#  ('차는', 30),
#  ('내', 30),
#  ('친구', 30),
#  ('있습니다', 30),
#  ('이야기', 30),
#  ('먹으면', 30),
#  ('03', 30),
#  ('인지', 30),
#  ('그런', 30),
#  ('좋을까요', 29),
#  ('식', 29),
#  ('학교', 29),
#  ('랑', 29),
#  ('23', 29),
#  ('04', 29),
#  ('학년', 29),
#  ('인수', 29),
#  ('그래도', 29),
#  ('?...', 29),
#  ('해외', 28),
#  ('한국', 28),
#  ('저희', 28),
#  ('나서', 28),
#  ('2019.07', 28),
#  ('스트레스', 28),
#  ('지나가고', 28),
#  ('도래', 28),
#  ('신랑', 28),
#  ('12', 28),
#  ('타고', 28),
#  ('날좀', 28),
#  ('번', 28),
#  ('사고', 28),
#  ('건강', 27),
#  ('호텔', 27),
#  ('자주', 27),
#  ('샤워', 27),
#  ('25', 27),
#  ('시작', 27),
#  ('심해', 27),
#  ('있을까요', 27),
#  ('뜨거운', 27),
#  ('후', 27),
#  ('옷', 27),
#  ('고민', 27),
#  ('효과', 27),
#  ('있어요', 27),
#  ('데', 27),
#  ('구매', 27),
#  ('공부', 27),
#  ('지식인', 26),
#  ('달', 26),
#  ('가지', 26),
#  ('.....', 26),
#  ('말고', 26),
#  ('2019년', 26),
#  ('자동차', 26),
#  ('알', 25),
#  ('지역', 25),
#  ('있으며', 25),
#  ('그런데', 25),
#  ('막', 25),
#  ('2020.02', 25),
#  ('없이', 25),
#  ('제일', 25),
#  ('없으면', 25),
#  ('아이', 25),
#  ('더위', 25),
#  ('6월', 25),
#  ('차주', 25),
#  ('반', 24),
#  ('해도', 24),
#  ('걸', 24),
#  ('혹시', 24),
#  ('부탁', 24),
#  ('많아서', 24),
#  ('입', 24),
#  ('하는게', 24),
#  ('귀', 24),
#  ('가요', 24),
#  ('아저씨', 24),
#  ('주세요', 24),
#  ('31', 24),
#  ('밤', 24),
#  ('가봐야', 23),
#  ('현지', 23),
#  ('드시는', 23),
#  ('비경', 23),
#  ('있다', 23),
#  ('이런', 23),
#  ('->', 23),
#  ('부탁드려요', 23),
#  ('양', 23),
#  ('맛', 23),
#  ('알려주시면', 23),
#  ('냄새', 23),
#  ('두', 23),
#  ('6', 23),
#  ('여드름', 23),
#  ('궁금합니다', 23),
#  ('않고', 23),
#  ('2018년', 23),
#  ('20일', 23),
#  ('뉴욕', 22),
#  ('타임스', 22),
#  ('선정', 22),
#  ('죽기전에', 22),
#  ('오른', 22),
#  ('맛있기는', 22),
#  ('간혹', 22),
#  ('계시는데', 22),
#  ('쯤', 22),
#  ('있으면', 22),
#  ('에어컨', 22),
#  ('한번', 22),
#  ('시', 22),
#  ('처음', 22),
#  ('싶은데', 22),
#  ('예', 22),
#  ('하게', 22),
#  ('지방', 22),
#  ('볼', 22),
#  ('제발', 22),
#  ('순간', 22),
#  ('잠', 22),
#  ('남편', 22),
#  ('가슴', 22),
#  ('화', 22),
#  ('부분', 21),
#  ('에만', 21),
#  ('같아요', 21),
#  ('앞', 21),
#  ('도와주세요', 21),
#  ('100', 21),
#  ('속', 21),
#  ('기해년', 21),
#  ('운전자', 21),
#  ('조심해서', 21),
#  ('다니시다가', 21),
#  ('비', 21),
#  ('5일', 20),
#  ('갈', 20),
#  ('4일', 20),
#  ('보다', 20),
#  ('성', 20),
#  ('근데', 20),
#  ('2019.02', 20),
#  ('중요한', 20),
#  ('이에요', 20),
#  ('등등', 20),
#  ('할까', 20),
#  ('감사하겠습니다', 20),
#  ('절기', 20),
#  ('학생', 20),
#  ('않은', 20),
#  ('상', 20),
#  ('순우리말', 20),
#  ('목', 20),
#  ('까요', 20),
#  ('겁니다', 20),
#  ('지내고', 20),
#  ('가옥', 20),
#  ('짱구', 20),
#  ('한식', 19),
#  ('보면', 19),
#  ('좋습니다', 19),
#  (',,', 19),
#  ('40', 19),
#  ('하루', 19),
#  ('이렇게', 19),
#  ('미국', 19),
#  ('밖에', 19),
#  ('별로', 19),
#  ('이마', 19),
#  ('조상', 19),
#  ('ag', 19),
#  ('많고', 19),
#  ('2020.04', 19),
#  ('ㅜㅜ', 19),
#  ('신고', 19),
#  ('물론', 19),
#  ('수족', 19),
#  ('생일', 19),
#  ('나는데', 19),
#  ('어제', 19),
#  ('운행', 19),
#  ('감기', 18),
#  ('나고', 18),
#  ('및', 18),
#  ('그냥', 18),
#  ('시험', 18),
#  ('신경', 18),
#  ('없고', 18),
#  ('보다는', 18),
#  ('최대한', 18),
#  ('알려', 18),
#  ('되고', 18),
#  ('시기', 18),
#  ('방', 18),
#  ('매우', 18),
#  ('먹지', 18),
#  ('따라', 18),
#  ('예정', 18),
#  ('바보', 18),
#  ('새벽', 18),
#  ('26일', 18),
#  ('받고', 18),
#  ('영향', 18),
#  ('2019.01', 18),
#  ('택일', 18),
#  ('말려', 18),
#  ('보고', 17),
#  ('전체', 17),
#  ('하는데요', 17),
#  ('죠', 17),
#  ('해외여행', 17),
#  ('매운', 17),
#  ('또는', 17),
#  ('7일', 17),
#  ('쉽게', 17),
#  ('이구', 17),
#  ('모두', 17),
#  ('뜻', 17),
#  ('되는', 17),
#  ('마다', 17),
#  ('소개', 17),
#  ('분야', 17),
#  ('애', 17),
#  ('경제', 17),
#  ('4월', 17),
#  ('2018.07', 17),
#  ('기후', 17),
#  ('선생님', 17),
#  ('지내면', 17),
#  ('됩니다', 16),
#  ('2020.07', 16),
#  ('섭취', 16),
#  ('상태', 16),
#  ('걱정', 16),
#  ('5월', 16),
#  ('니까', 16),
#  ('한약', 16),
#  ('심하게', 16),
#  ('에서는', 16),
#  ('현재', 16),
#  ('바로', 16),
#  ('피', 16),
#  ('어렸을', 16),
#  ('출고', 16),
#  ('10월', 16),
#  ('23일', 16),
#  ('2019.04', 16),
#  ('행복해서요', 16),
#  ('."', 16),
#  ('vs', 16),
#  ('아토피', 16),
#  ('차이', 16),
#  ('다시', 16),
#  ('운전', 16),
#  ('사회', 16),
#  ('술', 16),
#  ('지속', 16),
#  ("'", 16),
#  ('준비', 15),
#  ('알레르기', 15),
#  ('아니고', 15),
#  ('안정', 15),
#  ('거의', 15),
#  ('각', 15),
#  ('선풍기', 15),
#  ('온몸', 15),
#  ('부위', 15),
#  ('음식점', 15),
#  ('라고', 15),
#  ('......', 15),
#  ('빨', 15),
#  ('심해서', 15),
#  ('한다', 15),
#  ('먹어', 15),
#  ('①', 15),
#  ('지내시면', 15),
#  ('어디', 15),
#  ('했는데', 15),
#  ('약물', 15),
#  ('째', 15),
#  ('역사', 15),
#  ('없어요', 15),
#  ('2017년', 15),
#  ('베트남', 15),
#  ('지내야', 15),
#  ('조사', 15),
#  ('관용', 15),
#  ('위해', 14),
#  ('또한', 14),
#  ('문제', 14),
#  ('발생', 14),
#  ('설명', 14),
#  ('법도', 14),
#  ('차지', 14),
#  ('1일', 14),
#  ('로는', 14),
#  ('주로', 14),
#  ('오', 14),
#  ('약간', 14),
#  ('영어', 14),
#  ('틀', 14),
#  ('자꾸', 14),
#  ('명', 14),
#  ('2020.05', 14),
#  ('느낌', 14),
#  ('사진', 14),
#  ('이라도', 14),
#  ('살이', 14),
#  ('이런거', 14),
#  ('회사', 14),
#  ('가서', 14),
#  ('심한', 14),
#  ('대표', 14),
#  ('향신료', 14),
#  ('7', 14),
#  ('활동', 14),
#  ('뒤', 14),
#  ('있고', 14),
#  ('안나', 14),
#  ('인도', 14),
#  ('건가', 14),
#  ('자', 14),
#  ('참고', 14),
#  ('니', 14),
#  ('지내려고', 14),
#  ('여성', 14),
#  ('왕', 14),
#  ('ethn', 14),
#  ('도움', 14),
#  ('될까', 14),
#  ('수능', 14),
#  ('고혈압', 14),
#  ('여행지', 13),
#  ('포지션', 13),
#  ('규칙', 13),
#  ('잘못', 13),
#  ('보니', 13),
#  ('무엇', 13),
#  ('씩', 13),
#  ('에요', 13),
#  ('24일', 13),
#  ('가면', 13),
#  ('힘', 13),
#  ('라', 13),
#  ('있다고', 13),
#  ('다양한', 13),
#  ('이용', 13),
#  ('병', 13),
#  ('받아', 13),
#  ('즐겨', 13),
#  ('키', 13),
#  ('원인', 13),
#  ('덜', 13),
#  ('2019.05', 13),
#  ('거리', 13),
#  ('그대로', 13),
#  ('특징', 13),
#  ('형', 13),
#  ('무슨', 13),
#  ('글', 13),
#  ('유래', 13),
#  ('난', 13),
#  ('2일', 13),
#  ('11일', 13),
#  ('첫', 13),
#  ('개월', 13),
#  ('냉증', 13),
#  ('발라주거나', 13),
#  ('王', 13),
#  ('ocam', 13),
#  ('떡', 13),
#  ('무더운', 13),
#  ('박', 12),
#  ('30분', 12),
#  ('가끔', 12),
#  ('ㅜ', 12),
#  ('따뜻한', 12),
#  ('같고', 12),
#  ('되면', 12),
#  ('2008.04', 12),
#  ('~~', 12),
#  ('우선', 12),
#  ('3일', 12),
#  ('배', 12),
#  ('50', 12),
#  ('일단', 12),
#  ('빨개져요', 12),
#  ('예요', 12),
#  ('2020.03', 12),
#  ('있어서', 12),
#  ('.)', 12),
#  ('나기', 12),
#  ('두피', 12),
#  ('하지', 12),
#  ('온도', 12),
#  ('편이', 12),
#  ('없습니다', 12),
#  ('뭘', 12),
#  ('러시아', 12),
#  ('비해', 12),
#  ('유독', 12),
#  ('폰', 12),
#  ('하나요', 12),
#  ('증가', 12),
#  ('게임', 12),
#  ('기도', 12),
#  ('있어도', 12),
#  ('없나요', 12),
#  ('재료', 12),
#  ('하다', 12),
#  ('따로', 12),
#  ('아무', 12),
#  ('사이', 12),
#  ('대한', 12),
#  ('●', 12),
#  ('19일', 12),
#  ('31일', 12),
#  ('의사', 12),
#  ('탕', 12),
#  ('감사합니다', 12),
#  ('해결', 12),
#  ('이집트', 12),
#  ('오는', 12),
#  ('임신', 12),
#  ('당황', 12),
#  ('!!!', 12),
#  ('오전', 12),
#  ('9월', 12),
#  ('따른', 12),
#  ('쌀', 12),
#  ('2018.02', 12),
#  ('일이', 12),
#  ('좋지', 12),
#  ('햄스터', 12),
#  ('·', 12),
#  ('다리', 11),
#  ('이라서', 11),
#  ('엉덩이', 11),
#  ('있어', 11),
#  ('될', 11),
#  ('이라고', 11),
#  ('없애는', 11),
#  ('가을', 11),
#  ('하려고', 11),
#  ('주실', 11),
#  ('들어', 11),
#  ('가야', 11),
#  ('핸드폰', 11),
#  ('가만히', 11),
#  ('있을', 11),
#  ('자세히', 11),
#  ('문', 11),
#  ('맛집', 11),
#  ('25일', 11),
#  ('아니라', 11),
#  ('초', 11),
#  ('너', 11),
#  ('찬물', 11),
#  ('예쁜', 11),
#  ('1980년', 11),
#  ('언', 11),
#  ('냉면', 11),
#  ('삼', 11),
#  ('16일', 11),
#  ('의한', 11),
#  ('가려워', 11),
#  ('처방', 11),
#  ('수가', 11),
#  ('감정', 11),
#  ('이면', 11),
#  ('표현', 11),
#  ('21일', 11),
#  ('있으나', 11),
#  ('저녁', 11),
#  ('입고', 11),
#  ('싶습니다', 11),
#  ('가루', 11),
#  ('되나요', 11),
#  ('지내려', 11),
#  ('조건', 11),
#  ('22일', 11),
#  ('분비', 11),
#  ('시키므로', 11),
#  ('달라질', 11),
#  ('국수', 11),
#  ('춥고', 11),
#  ('1974년', 11),
#  ('6일', 10),
#  ('팔', 10),
#  ('위주', 10),
#  ('선택', 10),
#  ('되어', 10),
#  ('아무리', 10),
#  ('좋을지', 10),
#  ('대부분', 10),
#  ('라면', 10),
#  ('보통', 10),
#  ('중학교', 10),
#  ('초등학교', 10),
#  ('고생', 10),
#  ('우', 10),
#  ('좋아하는', 10),
#  ('큰', 10),
#  ('예전', 10),
#  ('대로', 10),
#  ('하였습니다', 10),
#  ('넣어', 10),
#  ('짠', 10),
#  ('a', 10),
#  ('되며', 10),
#  ('오래', 10),
#  ('발달', 10),
#  ('빼고', 10),
#  ('할수', 10),
#  ('여학생', 10),
#  ('프랑스', 10),
#  ('있는지', 10),
#  ('클', 10),
#  ('구', 10),
#  ('그럼', 10),
#  ('오히려', 10),
#  ('아주', 10),
#  ('안나는데', 10),
#  ('동남아시아', 10),
#  ('왕초', 10),
#  ('생년', 10),
#  ('월일', 10),
#  ('10일', 10),
#  ('54', 10),
#  ('뚝뚝', 10),
#  ('햇빛', 10),
#  ('②', 10),
#  ('개짐', 10),
#  ('2018.08', 10),
#  ('15일', 10),
#  ('29일', 10),
#  ('어릴', 10),
#  ('2018.06', 10),
#  ('그런게', 10),
#  ('12일', 10),
#  ('동안', 10),
#  ('눈물', 10),
#  ('인데요', 10),
#  ('질환', 10),
#  ('28일', 10),
#  ('증', 10),
#  ('껍질', 10),
#  ('마늘', 10),
#  ('2016.08', 10),
#  ('되도록', 10),
#  ('아내', 10),
#  ('건', 10),
#  ('2017.01', 10),
#  ('17일', 10),
#  ('이전', 10),
#  ('특색', 10),
#  ('했고', 10),
#  ('사일', 10),
#  ('아들', 9),
#  ('식사', 9),
#  ('쉬', 9),
#  ('주변', 9),
#  ('알고싶어요', 9),
#  ('2018.03', 9),
#  ('주문', 9),
#  ('+', 9),
#  ('아니면', 9),
#  ('먹기', 9),
#  ('보', 9),
#  ('써', 9),
#  ('낮', 9),
#  ('_', 9),
#  ('매일', 9),
#  ('내용', 9),
#  ('전혀', 9),
#  ('비타민', 9),
#  ('않는', 9),
#  ('대하', 9),
#  ('2016.10', 9),
#  ('간단히', 9),
#  ('제목', 9),
#  ('실내', 9),
#  ('변화', 9),
#  ('근처', 9),
#  ('급해요', 9),
#  ('종이', 9),
#  ('힘들어요', 9),
#  ('밀가루', 9),
#  ('다이어트', 9),
#  ('그런지', 9),
#  ('돈', 9),
#  ('재개', 9),
#  ('먹거나', 9),
#  ('세시', 9),
#  ('고기', 9),
#  ('많습니다', 9),
#  ('간단하게', 9),
#  ('영', 9),
#  ('체온', 9),
#  ('국', 9),
#  ('같은데', 9),
#  ('봄', 9),
#  ('각각', 9),
#  ('줄줄', 9),
#  ('2019.03', 9),
#  ('음식물', 9),
#  ('기온', 9),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='눈 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='눈 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='눈 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='눈 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='눈 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='눈 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [('음식', 1697),
#  ('땀', 1475),
#  ('날', 1141),
#  ('닉네임', 982),
#  ('적', 762),
#  ('더운', 758),
#  ('에서', 582),
#  ('합니다', 509),
#  ('만', 443),
#  ('치료', 421),
#  ('인', 415),
#  ('검색', 411),
#  ('하고', 405),
#  ('좋은', 381),
#  ('(', 378),
#  ('****', 375),
#  ('입니다', 356),
#  ('다한증', 350),
#  ('고사', 333),
#  ('머리', 328),
#  ('해야', 321),
#  ('한의사', 317),
#  ('먼저', 315),
#  ('이나', 311),
#  ('자극', 309),
#  ('상황', 309),
#  ('아닌데', 309),
#  ('먹을', 308),
#  ('임', 305),
#  ('손', 304),
#  ('동남아', 303),
#  ('나는지', 303),
#  ('피부질환', 303),
#  ('환경', 302),
#  ('전신', 302),
#  ('분류', 301),
#  ('은교', 301),
#  ('입력', 300),
#  ('와', 300),
#  (')', 299),
#  ('혹은', 298),
#  ('나라', 297),
#  ('육체', 291),
#  ('비오듯', 291),
#  ('많이', 265),
#  ('나', 238),
#  ('차', 237),
#  ('중국', 232),
#  ('집', 227),
#  ('너무', 218),
#  ('등', 204),
#  ('ryul', 204),
#  ('포함', 203),
#  ('마시고', 193),
#  ('지낸', 192),
#  ('일대', 191),
#  ('가져가지', 190),
#  ('일행', 190),
#  ('나누어', 190),
#  ('먹고', 188),
#  ('하', 181),
#  ('몸', 180),
#  ('다른', 180),
#  ('에는', 176),
#  ('눈', 172),
#  ('거나', 169),
#  ('일본', 167),
#  ('곳', 166),
#  ('신', 165),
#  ('/', 162),
#  ('여러', 160),
#  ('알려주세요', 154),
#  ('홍조', 154),
#  (':', 149),
#  ('해서', 148),
#  ('기', 147),
#  ('새', 140),
#  ('숭배', 140),
#  ('개', 133),
#  ('된', 128),
#  ('정도', 128),
#  ('유럽', 120),
#  ('얼굴', 118),
#  ('한의원', 118),
#  ('저', 117),
#  ('꼭', 116),
#  ('발', 116),
#  ('국가', 116),
#  ('명절', 112),
#  ('안', 111),
#  ('사용', 110),
#  ('중동', 108),
#  ('없는', 107),
#  ('외', 107),
#  ('하세요', 106),
#  ('긴장', 105),
#  ('본', 104),
#  ('3', 104),
#  ('제외', 103),
#  ('안면', 103),
#  ('시간', 103),
#  ('상세', 102),
#  ('문장', 102),
#  ('부터', 102),
#  ('정확히', 101),
#  ('반드시', 101),
#  ('결과', 101),
#  ('그', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('구분', 100),
#  ('놀이', 99),
#  ('"', 98),
#  ('토', 95),
#  ('때문', 94),
#  ('방법', 94),
#  ('날짜', 94),
#  ('ㅠㅠ', 93),
#  ('내공', 93),
#  ('안녕하세요', 93),
#  ('피하', 92),
#  ('추운', 91),
#  ('전', 89),
#  ('사람', 89),
#  ('기름진', 87),
#  ('높은', 86),
#  ('체적', 85),
#  ('가공', 85),
#  ('점성', 85),
#  ('경희', 85),
#  ('피레', 85),
#  ('서', 84),
#  ('전통', 82),
#  ('음력', 81),
#  ('또', 80),
#  ('중고차', 80),
#  ('2019.10', 77),
#  ('열', 77),
#  ('지내기', 77),
#  ('장소', 76),
#  ('겨울', 75),
#  ('에서도', 75),
#  (')...', 75),
#  ('이동', 74),
#  ('한편', 74),
#  ('필리핀', 73),
#  ('그리거나', 72),
#  ('남자', 71),
#  ('부탁드립니다', 71),
#  ('!', 71),
#  ('구입', 71),
#  ('물', 70),
#  ('하셔서', 70),
#  ('길일', 69),
#  ('나요', 68),
#  ('택', 68),
#  ('위', 67),
#  ('하는데', 67),
#  ('까지', 67),
#  ('지내시기', 65),
#  ('날씨', 64),
#  ('에도', 63),
#  ('양력', 63),
#  ('그리고', 62),
#  ('피부', 61),
#  ('16', 61),
#  ('이다', 61),
#  ('지내는', 61),
#  ('생활', 60),
#  ('면', 60),
#  ('말', 60),
#  ('하면', 58),
#  ('??', 57),
#  ('특히', 57),
#  ('여자', 57),
#  ('2019.08', 56),
#  ('우리', 55),
#  ('여름', 54),
#  ('-', 54),
#  ('언제', 54),
#  ('세계', 54),
#  ('약', 53),
#  ('설날', 53),
#  ('조금', 52),
#  ('하며', 52),
#  ('계절', 52),
#  ('갑자기', 52),
#  ('14', 52),
#  ('차량', 52),
#  ('생', 52),
#  ('여', 51),
#  ('11', 51),
#  ('추천', 50),
#  ('오늘', 50),
#  ('정말', 50),
#  ('에게', 50),
#  ('지금', 50),
#  ('15', 50),
#  ('님', 50),
#  ('21', 49),
#  ('7월', 49),
#  ('하여', 49),
#  ('^^', 48),
#  ('이랑', 48),
#  ('2019.09', 48),
#  ('5', 48),
#  ('만든', 48),
#  ('법', 47),
#  ('여행', 47),
#  ('2019.11', 47),
#  ('어느', 47),
#  ('17', 47),
#  ('같이', 47),
#  ('종류', 47),
#  ('더', 46),
#  ('있나요', 46),
#  ('01', 46),
#  ('4', 45),
#  ('분', 45),
#  ('손발', 45),
#  ('왜', 45),
#  ('우리나라', 45),
#  ('신차', 45),
#  ('대해', 44),
#  ('이유', 44),
#  ('어떻게', 44),
#  ('성인', 44),
#  ('8월', 44),
#  ('13', 43),
#  ('29', 43),
#  ('05', 43),
#  ('했습니다', 43),
#  ('차고', 43),
#  ('19', 43),
#  ('겨드랑이', 43),
#  ('즐거운', 43),
#  ('27', 43),
#  ('2월', 43),
#  ('의미', 43),
#  ('여름철', 42),
#  ('이고', 42),
#  ('남', 42),
#  ('먹는', 42),
#  ('ㅠ', 42),
#  ('수술', 42),
#  ('연날리기', 42),
#  ('보낸다', 42),
#  ('成人の日', 42),
#  ('1월', 42),
#  ('남은', 42),
#  ('항상', 41),
#  ('코', 41),
#  ('관련', 41),
#  ('많은', 41),
#  ('병원', 41),
#  ('찬', 41),
#  ('2018.12', 41),
#  ('드립니다', 41),
#  ('시원한', 40),
#  ('증상', 40),
#  ('납니다', 40),
#  ('요리', 40),
#  ('바랍니다', 40),
#  ('요즘', 39),
#  ('그래서', 39),
#  ('진짜', 39),
#  ('2010.12', 39),
#  ('계속', 38),
#  ('해주세요', 37),
#  ('2020.01', 37),
#  ('인가요', 37),
#  ('처럼', 37),
#  ('숙제', 37),
#  ('하기', 37),
#  ('있는데', 37),
#  ('2019.12', 37),
#  ('12월', 36),
#  ('07', 36),
#  ('두드러기', 36),
#  ('09', 36),
#  ('밥', 36),
#  ('18', 36),
#  ('기념일', 36),
#  ('11월', 35),
#  ('26', 35),
#  ('30', 35),
#  ('많아요', 35),
#  ('22', 35),
#  ('경우', 35),
#  ('빨리', 35),
#  ('사', 35),
#  ('해', 34),
#  ('아침', 34),
#  ('가장', 34),
#  ('운동', 34),
#  ('체질', 34),
#  ('편', 34),
#  ('하지만', 33),
#  ('문의', 33),
#  ('엔', 33),
#  ('생각', 33),
#  ('원래', 33),
#  ('문화', 33),
#  ('평소', 33),
#  ('3월', 33),
#  ('08', 32),
#  ('엄청', 32),
#  ('2020.06', 32),
#  ('점', 32),
#  ('쪽', 32),
#  ('이라', 32),
#  ('아', 32),
#  ('내일', 32),
#  ('음', 32),
#  ('몇', 31),
#  ('같은', 31),
#  ('살', 31),
#  ('02', 31),
#  ('이름', 31),
#  ('24', 31),
#  ('이번', 30),
#  ('간', 30),
#  ('28', 30),
#  ('차는', 30),
#  ('내', 30),
#  ('친구', 30),
#  ('있습니다', 30),
#  ('이야기', 30),
#  ('먹으면', 30),
#  ('03', 30),
#  ('인지', 30),
#  ('그런', 30),
#  ('좋을까요', 29),
#  ('식', 29),
#  ('학교', 29),
#  ('랑', 29),
#  ('23', 29),
#  ('04', 29),
#  ('학년', 29),
#  ('인수', 29),
#  ('그래도', 29),
#  ('?...', 29),
#  ('해외', 28),
#  ('한국', 28),
#  ('저희', 28),
#  ('나서', 28),
#  ('2019.07', 28),
#  ('스트레스', 28),
#  ('지나가고', 28),
#  ('도래', 28),
#  ('신랑', 28),
#  ('12', 28),
#  ('타고', 28),
#  ('날좀', 28),
#  ('번', 28),
#  ('사고', 28),
#  ('건강', 27),
#  ('호텔', 27),
#  ('자주', 27),
#  ('샤워', 27),
#  ('25', 27),
#  ('시작', 27),
#  ('심해', 27),
#  ('있을까요', 27),
#  ('뜨거운', 27),
#  ('옷', 27),
#  ('고민', 27),
#  ('효과', 27),
#  ('있어요', 27),
#  ('구매', 27),
#  ('공부', 27),
#  ('지식인', 26),
#  ('달', 26),
#  ('가지', 26),
#  ('.....', 26),
#  ('말고', 26),
#  ('2019년', 26),
#  ('자동차', 26),
#  ('알', 25),
#  ('지역', 25),
#  ('있으며', 25),
#  ('그런데', 25),
#  ('막', 25),
#  ('2020.02', 25),
#  ('없이', 25),
#  ('제일', 25),
#  ('없으면', 25),
#  ('아이', 25),
#  ('더위', 25),
#  ('6월', 25),
#  ('차주', 25),
#  ('반', 24),
#  ('해도', 24),
#  ('걸', 24),
#  ('혹시', 24),
#  ('부탁', 24),
#  ('많아서', 24),
#  ('입', 24),
#  ('하는게', 24),
#  ('귀', 24),
#  ('아저씨', 24),
#  ('주세요', 24),
#  ('31', 24),
#  ('밤', 24),
#  ('가봐야', 23),
#  ('현지', 23),
#  ('드시는', 23),
#  ('비경', 23),
#  ('있다', 23),
#  ('이런', 23),
#  ('->', 23),
#  ('부탁드려요', 23),
#  ('양', 23),
#  ('맛', 23),
#  ('알려주시면', 23),
#  ('냄새', 23),
#  ('두', 23),
#  ('여드름', 23),
#  ('궁금합니다', 23),
#  ('않고', 23),
#  ('2018년', 23),
#  ('20일', 23),
#  ('뉴욕', 22),
#  ('타임스', 22),
#  ('선정', 22),
#  ('죽기전에', 22),
#  ('오른', 22),
#  ('맛있기는', 22),
#  ('간혹', 22),
#  ('계시는데', 22),
#  ('쯤', 22),
#  ('있으면', 22),
#  ('에어컨', 22),
#  ('한번', 22),
#  ('시', 22),
#  ('처음', 22),
#  ('싶은데', 22),
#  ('예', 22),
#  ('하게', 22),
#  ('지방', 22),
#  ('볼', 22),
#  ('제발', 22),
#  ('순간', 22),
#  ('잠', 22),
#  ('남편', 22),
#  ('가슴', 22),
#  ('화', 22),
#  ('부분', 21),
#  ('에만', 21),
#  ('같아요', 21),
#  ('앞', 21),
#  ('도와주세요', 21),
#  ('100', 21),
#  ('속', 21),
#  ('기해년', 21),
#  ('운전자', 21),
#  ('조심해서', 21),
#  ('다니시다가', 21),
#  ('비', 21),
#  ('5일', 20),
#  ('갈', 20),
#  ('4일', 20),
#  ('보다', 20),
#  ('성', 20),
#  ('근데', 20),
#  ('2019.02', 20),
#  ('이에요', 20),
#  ('등등', 20),
#  ('할까', 20),
#  ('감사하겠습니다', 20),
#  ('절기', 20),
#  ('학생', 20),
#  ('않은', 20),
#  ('상', 20),
#  ('순우리말', 20),
#  ('목', 20),
#  ('까요', 20),
#  ('겁니다', 20),
#  ('지내고', 20),
#  ('가옥', 20),
#  ('짱구', 20),
#  ('한식', 19),
#  ('보면', 19),
#  ('좋습니다', 19),
#  (',,', 19),
#  ('40', 19),
#  ('하루', 19),
#  ('이렇게', 19),
#  ('미국', 19),
#  ('밖에', 19),
#  ('별로', 19),
#  ('이마', 19),
#  ('조상', 19),
#  ('ag', 19),
#  ('많고', 19),
#  ('2020.04', 19),
#  ('ㅜㅜ', 19),
#  ('신고', 19),
#  ('물론', 19),
#  ('수족', 19),
#  ('생일', 19),
#  ('나는데', 19),
#  ('어제', 19),
#  ('운행', 19),
#  ('감기', 18),
#  ('나고', 18),
#  ('및', 18),
#  ('그냥', 18),
#  ('시험', 18),
#  ('신경', 18),
#  ('없고', 18),
#  ('보다는', 18),
#  ('최대한', 18),
#  ('알려', 18),
#  ('되고', 18),
#  ('시기', 18),
#  ('방', 18),
#  ('매우', 18),
#  ('먹지', 18),
#  ('따라', 18),
#  ('예정', 18),
#  ('바보', 18),
#  ('새벽', 18),
#  ('26일', 18),
#  ('받고', 18),
#  ('영향', 18),
#  ('2019.01', 18),
#  ('택일', 18),
#  ('말려', 18),
#  ('보고', 17),
#  ('전체', 17),
#  ('하는데요', 17),
#  ('죠', 17),
#  ('해외여행', 17),
#  ('매운', 17),
#  ('또는', 17),
#  ('7일', 17),
#  ('쉽게', 17),
#  ('이구', 17),
#  ('모두', 17),
#  ('뜻', 17),
#  ('되는', 17),
#  ('마다', 17),
#  ('소개', 17),
#  ('분야', 17),
#  ('애', 17),
#  ('경제', 17),
#  ('4월', 17),
#  ('2018.07', 17),
#  ('기후', 17),
#  ('선생님', 17),
#  ('지내면', 17),
#  ('됩니다', 16),
#  ('2020.07', 16),
#  ('섭취', 16),
#  ('상태', 16),
#  ('걱정', 16),
#  ('5월', 16),
#  ('니까', 16),
#  ('한약', 16),
#  ('심하게', 16),
#  ('에서는', 16),
#  ('현재', 16),
#  ('바로', 16),
#  ('피', 16),
#  ('어렸을', 16),
#  ('출고', 16),
#  ('10월', 16),
#  ('23일', 16),
#  ('2019.04', 16),
#  ('행복해서요', 16),
#  ('."', 16),
#  ('vs', 16),
#  ('아토피', 16),
#  ('차이', 16),
#  ('다시', 16),
#  ('운전', 16),
#  ('사회', 16),
#  ('술', 16),
#  ('지속', 16),
#  ("'", 16),
#  ('준비', 15),
#  ('알레르기', 15),
#  ('아니고', 15),
#  ('안정', 15),
#  ('거의', 15),
#  ('각', 15),
#  ('선풍기', 15),
#  ('온몸', 15),
#  ('부위', 15),
#  ('음식점', 15),
#  ('......', 15),
#  ('빨', 15),
#  ('심해서', 15),
#  ('한다', 15),
#  ('먹어', 15),
#  ('①', 15),
#  ('지내시면', 15),
#  ('어디', 15),
#  ('했는데', 15),
#  ('약물', 15),
#  ('째', 15),
#  ('역사', 15),
#  ('없어요', 15),
#  ('2017년', 15),
#  ('베트남', 15),
#  ('지내야', 15),
#  ('조사', 15),
#  ('관용', 15),
#  ('위해', 14),
#  ('또한', 14),
#  ('문제', 14),
#  ('발생', 14),
#  ('설명', 14),
#  ('법도', 14),
#  ('차지', 14),
#  ('1일', 14),
#  ('로는', 14),
#  ('주로', 14),
#  ('오', 14),
#  ('약간', 14),
#  ('영어', 14),
#  ('틀', 14),
#  ('자꾸', 14),
#  ('명', 14),
#  ('2020.05', 14),
#  ('느낌', 14),
#  ('사진', 14),
#  ('이라도', 14),
#  ('살이', 14),
#  ('이런거', 14),
#  ('회사', 14),
#  ('가서', 14),
#  ('심한', 14),
#  ('대표', 14),
#  ('향신료', 14),
#  ('7', 14),
#  ('활동', 14),
#  ('뒤', 14),
#  ('있고', 14),
#  ('안나', 14),
#  ('인도', 14),
#  ('건가', 14),
#  ('자', 14),
#  ('참고', 14),
#  ('니', 14),
#  ('지내려고', 14),
#  ('여성', 14),
#  ('왕', 14),
#  ('ethn', 14),
#  ('도움', 14),
#  ('될까', 14),
#  ('수능', 14),
#  ('고혈압', 14),
#  ('여행지', 13),
#  ('포지션', 13),
#  ('규칙', 13),
#  ('잘못', 13),
#  ('보니', 13),
#  ('무엇', 13),
#  ('씩', 13),
#  ('에요', 13),
#  ('24일', 13),
#  ('가면', 13),
#  ('힘', 13),
#  ('라', 13),
#  ('있다고', 13),
#  ('다양한', 13),
#  ('이용', 13),
#  ('병', 13),
#  ('받아', 13),
#  ('즐겨', 13),
#  ('키', 13),
#  ('원인', 13),
#  ('덜', 13),
#  ('2019.05', 13),
#  ('거리', 13),
#  ('그대로', 13),
#  ('특징', 13),
#  ('형', 13),
#  ('무슨', 13),
#  ('글', 13),
#  ('유래', 13),
#  ('난', 13),
#  ('2일', 13),
#  ('11일', 13),
#  ('첫', 13),
#  ('개월', 13),
#  ('냉증', 13),
#  ('발라주거나', 13),
#  ('王', 13),
#  ('ocam', 13),
#  ('떡', 13),
#  ('무더운', 13),
#  ('박', 12),
#  ('30분', 12),
#  ('가끔', 12),
#  ('ㅜ', 12),
#  ('따뜻한', 12),
#  ('같고', 12),
#  ('되면', 12),
#  ('2008.04', 12),
#  ('~~', 12),
#  ('우선', 12),
#  ('3일', 12),
#  ('배', 12),
#  ('50', 12),
#  ('일단', 12),
#  ('빨개져요', 12),
#  ('예요', 12),
#  ('2020.03', 12),
#  ('있어서', 12),
#  ('.)', 12),
#  ('나기', 12),
#  ('두피', 12),
#  ('하지', 12),
#  ('온도', 12),
#  ('편이', 12),
#  ('없습니다', 12),
#  ('뭘', 12),
#  ('러시아', 12),
#  ('비해', 12),
#  ('유독', 12),
#  ('폰', 12),
#  ('하나요', 12),
#  ('증가', 12),
#  ('게임', 12),
#  ('기도', 12),
#  ('있어도', 12),
#  ('없나요', 12),
#  ('재료', 12),
#  ('하다', 12),
#  ('따로', 12),
#  ('아무', 12),
#  ('사이', 12),
#  ('대한', 12),
#  ('●', 12),
#  ('19일', 12),
#  ('31일', 12),
#  ('의사', 12),
#  ('탕', 12),
#  ('감사합니다', 12),
#  ('해결', 12),
#  ('이집트', 12),
#  ('오는', 12),
#  ('임신', 12),
#  ('당황', 12),
#  ('!!!', 12),
#  ('오전', 12),
#  ('9월', 12),
#  ('따른', 12),
#  ('쌀', 12),
#  ('2018.02', 12),
#  ('일이', 12),
#  ('좋지', 12),
#  ('햄스터', 12),
#  ('·', 12),
#  ('다리', 11),
#  ('이라서', 11),
#  ('엉덩이', 11),
#  ('있어', 11),
#  ('될', 11),
#  ('이라고', 11),
#  ('없애는', 11),
#  ('가을', 11),
#  ('하려고', 11),
#  ('주실', 11),
#  ('들어', 11),
#  ('가야', 11),
#  ('핸드폰', 11),
#  ('가만히', 11),
#  ('있을', 11),
#  ('자세히', 11),
#  ('문', 11),
#  ('맛집', 11),
#  ('25일', 11),
#  ('아니라', 11),
#  ('초', 11),
#  ('너', 11),
#  ('찬물', 11),
#  ('예쁜', 11),
#  ('1980년', 11),
#  ('언', 11),
#  ('냉면', 11),
#  ('삼', 11),
#  ('16일', 11),
#  ('의한', 11),
#  ('가려워', 11),
#  ('처방', 11),
#  ('수가', 11),
#  ('감정', 11),
#  ('이면', 11),
#  ('표현', 11),
#  ('21일', 11),
#  ('있으나', 11),
#  ('저녁', 11),
#  ('입고', 11),
#  ('싶습니다', 11),
#  ('가루', 11),
#  ('되나요', 11),
#  ('지내려', 11),
#  ('조건', 11),
#  ('22일', 11),
#  ('분비', 11),
#  ('시키므로', 11),
#  ('달라질', 11),
#  ('국수', 11),
#  ('춥고', 11),
#  ('1974년', 11),
#  ('6일', 10),
#  ('팔', 10),
#  ('위주', 10),
#  ('선택', 10),
#  ('되어', 10),
#  ('아무리', 10),
#  ('좋을지', 10),
#  ('대부분', 10),
#  ('라면', 10),
#  ('보통', 10),
#  ('중학교', 10),
#  ('초등학교', 10),
#  ('고생', 10),
#  ('우', 10),
#  ('좋아하는', 10),
#  ('큰', 10),
#  ('예전', 10),
#  ('대로', 10),
#  ('하였습니다', 10),
#  ('넣어', 10),
#  ('짠', 10),
#  ('a', 10),
#  ('되며', 10),
#  ('오래', 10),
#  ('발달', 10),
#  ('빼고', 10),
#  ('할수', 10),
#  ('여학생', 10),
#  ('프랑스', 10),
#  ('있는지', 10),
#  ('클', 10),
#  ('구', 10),
#  ('그럼', 10),
#  ('오히려', 10),
#  ('아주', 10),
#  ('안나는데', 10),
#  ('동남아시아', 10),
#  ('왕초', 10),
#  ('생년', 10),
#  ('월일', 10),
#  ('10일', 10),
#  ('54', 10),
#  ('뚝뚝', 10),
#  ('햇빛', 10),
#  ('②', 10),
#  ('개짐', 10),
#  ('2018.08', 10),
#  ('15일', 10),
#  ('29일', 10),
#  ('어릴', 10),
#  ('2018.06', 10),
#  ('그런게', 10),
#  ('12일', 10),
#  ('동안', 10),
#  ('눈물', 10),
#  ('인데요', 10),
#  ('질환', 10),
#  ('28일', 10),
#  ('증', 10),
#  ('껍질', 10),
#  ('마늘', 10),
#  ('2016.08', 10),
#  ('되도록', 10),
#  ('아내', 10),
#  ('건', 10),
#  ('2017.01', 10),
#  ('17일', 10),
#  ('이전', 10),
#  ('특색', 10),
#  ('했고', 10),
#  ('사일', 10),
#  ('아들', 9),
#  ('식사', 9),
#  ('쉬', 9),
#  ('주변', 9),
#  ('알고싶어요', 9),
#  ('2018.03', 9),
#  ('주문', 9),
#  ('+', 9),
#  ('아니면', 9),
#  ('먹기', 9),
#  ('보', 9),
#  ('써', 9),
#  ('낮', 9),
#  ('_', 9),
#  ('매일', 9),
#  ('내용', 9),
#  ('전혀', 9),
#  ('비타민', 9),
#  ('않는', 9),
#  ('대하', 9),
#  ('2016.10', 9),
#  ('간단히', 9),
#  ('제목', 9),
#  ('실내', 9),
#  ('변화', 9),
#  ('근처', 9),
#  ('급해요', 9),
#  ('종이', 9),
#  ('힘들어요', 9),
#  ('밀가루', 9),
#  ('다이어트', 9),
#  ('그런지', 9),
#  ('돈', 9),
#  ('재개', 9),
#  ('먹거나', 9),
#  ('세시', 9),
#  ('고기', 9),
#  ('많습니다', 9),
#  ('간단하게', 9),
#  ('영', 9),
#  ('체온', 9),
#  ('국', 9),
#  ('같은데', 9),
#  ('봄', 9),
#  ('각각', 9),
#  ('줄줄', 9),
#  ('2019.03', 9),
#  ('음식물', 9),
#  ('기온', 9),
#  ('인가', 9),
#  ('쿡', 9),
#  ('불행함', 9),
#  ('부모님', 9),
#  ('겨땀', 9),
#  ('마찬가지', 9),
#  ('없을까요', 9),
#  ('마시면', 9),
#  ('가르쳐', 9),
#  ('받은', 9),
#  ('10분', 9),
#  ('알려주세여', 9),
#  ('십', 9),
#  ('쳐', 9),
#  ('이후', 9),
#  ('전통의상', 9),
#  ('2017.03', 9),
#  ('따라서', 9),
#  ('지내는게', 9),
#  ('평가', 9),
#  ('2017.11', 9),
#  ('2018.01', 9),
#  ('유난히', 9),
#  ('해주시', 9),
#  ('2017.10', 9),
#  ('여쭤', 9),
#  ('거든요', 9),
#  ('만들어', 9),
#  ('받았습니다', 9),
#  ('가르쳐주세요', 9),
#  ('아기', 9),
#  ('차고사', 9),
#  ('어', 9),
#  ('배우자', 9),
#  ('18일', 9),
#  ('43', 9),
#  ('화물차', 9),
#  ('추석', 9),
#  ('미치는', 9),
#  ('둘', 8),
#  ('관광', 8),
#  ('오후', 8),
#  ('2008.03', 8),
#  ('교통', 8),
#  ('she', 8),
#  (']', 8),
#  ('백', 8),
#  ('발표', 8),
#  ('맞는', 8),
#  ('뿐', 8),
#  ('까지는', 8),
#  ('딱', 8),
#  ('인중', 8),
#  ('>', 8),
#  ('들어가면', 8),
#  ('무서운', 8),
#  ('알수', 8),
#  ('탈', 8),
#  ('억제', 8),
#  ('비슷한', 8),
#  ('겨울철', 8),
#  ('지낼', 8),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 774 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 776 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 863 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 10004 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65039 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 778 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 8228 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 774 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 776 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 863 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 10004 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 65039 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 778 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
