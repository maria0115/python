# %% [markdown]
# cnn_model.py 파일에 함수를 선언하고 호출하는 방식으로 진행

# %%
# Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

#!pip install tensorflow

# %%
import cnn_model

# %%
from tensorflow.python import keras
# import keras

import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# 입력과 출력 지정하기 --- (*1)
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 3

# 사진 데이터 읽어 들이기 --- (*2)
photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

# 읽어들인 데이터를 3차원 배열로 변환하기 --- (*3)
x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255
# 레이블 데이터를 One-hot 형식으로 변환하기 --- (*4)
y = keras.utils.np_utils.to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기 --- (*5)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size=0.8)

# CNN 모델 만들기 (위에 선언한 함수) --- (*6)
model = cnn_model.get_model(in_shape, nb_classes)

# 학습 실행하기 --- (*7)
hist = model.fit(x_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(x_test, y_test))

# 모델 평가하기 --- (*8)
score = model.evaluate(x_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# Epoch 1/20
# 7/7 [==============================] - 0s 48ms/step - loss: 1.1340 - accuracy: 0.3816 - val_loss: 1.0853 - val_accuracy: 0.3462
# Epoch 2/20
# 7/7 [==============================] - 0s 34ms/step - loss: 1.2582 - accuracy: 0.3865 - val_loss: 1.0533 - val_accuracy: 0.4808
# Epoch 3/20
# 7/7 [==============================] - 0s 34ms/step - loss: 1.0567 - accuracy: 0.3720 - val_loss: 1.0514 - val_accuracy: 0.4231
# Epoch 4/20
# 7/7 [==============================] - 0s 34ms/step - loss: 1.0135 - accuracy: 0.4203 - val_loss: 1.0576 - val_accuracy: 0.4808
# Epoch 5/20
# 7/7 [==============================] - 0s 34ms/step - loss: 1.0088 - accuracy: 0.4928 - val_loss: 1.2013 - val_accuracy: 0.4615
# Epoch 6/20
# 7/7 [==============================] - 0s 34ms/step - loss: 1.0455 - accuracy: 0.4348 - val_loss: 1.0165 - val_accuracy: 0.4038
# Epoch 7/20
# 7/7 [==============================] - 0s 33ms/step - loss: 0.9620 - accuracy: 0.5411 - val_loss: 0.9628 - val_accuracy: 0.5192
# Epoch 8/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.9984 - accuracy: 0.4783 - val_loss: 1.0449 - val_accuracy: 0.4231
# Epoch 9/20
# 7/7 [==============================] - 0s 36ms/step - loss: 0.8887 - accuracy: 0.5894 - val_loss: 1.0749 - val_accuracy: 0.3269
# Epoch 10/20
# 7/7 [==============================] - 0s 36ms/step - loss: 0.9316 - accuracy: 0.5217 - val_loss: 1.0722 - val_accuracy: 0.4231
# Epoch 11/20
# 7/7 [==============================] - 0s 35ms/step - loss: 0.9034 - accuracy: 0.5942 - val_loss: 1.0851 - val_accuracy: 0.4038
# Epoch 12/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.8985 - accuracy: 0.6135 - val_loss: 1.0034 - val_accuracy: 0.4231
# Epoch 13/20
# 7/7 [==============================] - 0s 35ms/step - loss: 0.7997 - accuracy: 0.6667 - val_loss: 1.0359 - val_accuracy: 0.5769
# Epoch 14/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.8036 - accuracy: 0.6232 - val_loss: 1.0025 - val_accuracy: 0.4231
# Epoch 15/20
# 7/7 [==============================] - 0s 36ms/step - loss: 0.7858 - accuracy: 0.6570 - val_loss: 1.0415 - val_accuracy: 0.3654
# Epoch 16/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.7309 - accuracy: 0.6908 - val_loss: 1.0298 - val_accuracy: 0.5192
# Epoch 17/20
# 7/7 [==============================] - 0s 33ms/step - loss: 0.6988 - accuracy: 0.7150 - val_loss: 1.3840 - val_accuracy: 0.3462
# Epoch 18/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.6444 - accuracy: 0.7295 - val_loss: 1.2011 - val_accuracy: 0.3654
# Epoch 19/20
# 7/7 [==============================] - 0s 34ms/step - loss: 0.6890 - accuracy: 0.7295 - val_loss: 1.0917 - val_accuracy: 0.5000
# Epoch 20/20
# 7/7 [==============================] - 0s 33ms/step - loss: 0.6923 - accuracy: 0.7246 - val_loss: 1.0834 - val_accuracy: 0.4038
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0834 - accuracy: 0.4038
# 정답률= 0.4038461446762085 loss= 1.083425760269165

# %%
# 학습 상태를 그래프로 그리기 --- (*9)
# 정답률 추이를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# 손실 추이를 그래프로 그리기
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

model.save_weights('./image/photos-model-light.hdf5')

# %% [markdown]
# [ 결과 ]
#
# 정답률이 70% 정도 나온다 하더라도 좋은 결과가 아니다.
#
# 만일 값이 너무 안 좋으면 데이타클리닝 작업으로 필요없는 사진을 제거해야 한다.
#
# 정답률의 차이는 대부분 데이터의 품질에서 발생한다.
