# %% [markdown]
# 정답률을 높이고자 '데이타 수량 늘리기'를 자주 사용한다.
#
# 사진을 회전하거나 반전하는 것이다.
#
# 왜냐하면 사람이 보기에 같은 그림이라도 컴퓨터는 사진을 조금만 회전해도 다른 이미지로 인식한다.
#
# ## 그러나 이번 이미지로는 정답률이 현저히 더 낮게 나온다.
# 다른 그림으로 다시 확인하길

# %%
# 동일한 모델

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size=(3, 3),
              activation='relu',
              input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

# 컴파일하고 모델 반환하기
def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    return model

# %% [markdown]
# cnn_model.py 파일에 함수를 선언하고 호출하는 방식으로 진행

# %%
import cnn_model

from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import cv2


# 입력과 출력 지정하기
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 6

# 사진 데이터 읽어 들이기
photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

# 읽어들인 데이터를 3차원 배열로 변환하기
x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255
# 레이블 데이터를 One-hot 형식으로 변환하기
y = to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기
x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size=0.8)

# 학습 전용 데이터 수 늘리기 --- (*1)
x_new = []
y_new = []
for i, xi in enumerate(x_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        # 회전 시키기 --- (*2)
        center = (16, 16) # 회전 중심
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (32, 32))
        x_new.append(xi2)
        y_new.append(yi)
        # 좌우 반전 --- (*3)
        xi3 = cv2.flip(xi2, 1)
        x_new.append(xi3)
        y_new.append(yi)

# 이미지를 늘린 데이터를 학습 데이터로 사용하기
print('수량을 늘리기 전=', len(y_train))
x_train = np.array(x_new)
y_train = np.array(y_new)
print('수량을 늘린 후=', len(y_train))
# Out:
# 수량을 늘리기 전= 497
# 수량을 늘린 후= 11928

# %%
# CNN 모델 만들기 --- (*6)
model = cnn_model.get_model(in_shape, nb_classes)

# 학습 실행하기 --- (*8)
hist = model.fit(x_train, y_train,
          batch_size=64,
          epochs=50,
          verbose=1,
          validation_data=(x_test, y_test))

# 모델 평가하기 --- (*9)
score = model.evaluate(x_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# Epoch 1/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.9726 - accuracy: 0.5922 - val_loss: 1.1328 - val_accuracy: 0.5600
# Epoch 2/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.5274 - accuracy: 0.7891 - val_loss: 1.0074 - val_accuracy: 0.6400
# Epoch 3/50
# 150/150 [==============================] - 10s 63ms/step - loss: 0.3336 - accuracy: 0.8729 - val_loss: 0.8637 - val_accuracy: 0.7700
# Epoch 4/50
# 150/150 [==============================] - 10s 64ms/step - loss: 0.2262 - accuracy: 0.9241 - val_loss: 1.1514 - val_accuracy: 0.7000
# Epoch 5/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.1588 - accuracy: 0.9511 - val_loss: 1.6971 - val_accuracy: 0.6900
# Epoch 6/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.1319 - accuracy: 0.9621 - val_loss: 1.6682 - val_accuracy: 0.7100
# Epoch 7/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0987 - accuracy: 0.9713 - val_loss: 1.7893 - val_accuracy: 0.7000
# Epoch 8/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0663 - accuracy: 0.9799 - val_loss: 1.7460 - val_accuracy: 0.7100
# Epoch 9/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0670 - accuracy: 0.9816 - val_loss: 2.5424 - val_accuracy: 0.6900
# Epoch 10/50
# 150/150 [==============================] - 9s 61ms/step - loss: 0.0811 - accuracy: 0.9798 - val_loss: 1.7518 - val_accuracy: 0.7000
# Epoch 11/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0787 - accuracy: 0.9835 - val_loss: 2.0848 - val_accuracy: 0.7600
# Epoch 12/50
# 150/150 [==============================] - 10s 64ms/step - loss: 0.0757 - accuracy: 0.9820 - val_loss: 1.9495 - val_accuracy: 0.6800
# Epoch 13/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0456 - accuracy: 0.9879 - val_loss: 2.2291 - val_accuracy: 0.7700
# Epoch 14/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0535 - accuracy: 0.9879 - val_loss: 2.3341 - val_accuracy: 0.7800
# Epoch 15/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0466 - accuracy: 0.9891 - val_loss: 2.8813 - val_accuracy: 0.7400
# Epoch 16/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0623 - accuracy: 0.9876 - val_loss: 2.5219 - val_accuracy: 0.7500
# Epoch 17/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0443 - accuracy: 0.9898 - val_loss: 2.6864 - val_accuracy: 0.7600
# Epoch 18/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0827 - accuracy: 0.9865 - val_loss: 3.4904 - val_accuracy: 0.6400
# Epoch 19/50
# 150/150 [==============================] - 10s 64ms/step - loss: 0.0368 - accuracy: 0.9909 - val_loss: 2.5541 - val_accuracy: 0.7400
# Epoch 20/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0359 - accuracy: 0.9918 - val_loss: 2.9656 - val_accuracy: 0.7200
# Epoch 21/50
# 150/150 [==============================] - 10s 63ms/step - loss: 0.0379 - accuracy: 0.9909 - val_loss: 2.6482 - val_accuracy: 0.7400
# Epoch 22/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0396 - accuracy: 0.9929 - val_loss: 3.4464 - val_accuracy: 0.7600
# Epoch 23/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0282 - accuracy: 0.9939 - val_loss: 3.7807 - val_accuracy: 0.7400
# Epoch 24/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0694 - accuracy: 0.9880 - val_loss: 4.1813 - val_accuracy: 0.7100
# Epoch 25/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0500 - accuracy: 0.9918 - val_loss: 3.4770 - val_accuracy: 0.7600
# Epoch 26/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0279 - accuracy: 0.9926 - val_loss: 5.5357 - val_accuracy: 0.7300
# Epoch 27/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0408 - accuracy: 0.9921 - val_loss: 4.4401 - val_accuracy: 0.7400
# Epoch 28/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0367 - accuracy: 0.9928 - val_loss: 4.0132 - val_accuracy: 0.7500
# Epoch 29/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0390 - accuracy: 0.9930 - val_loss: 3.2416 - val_accuracy: 0.7600
# Epoch 30/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0440 - accuracy: 0.9944 - val_loss: 4.0893 - val_accuracy: 0.7500
# Epoch 31/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0341 - accuracy: 0.9922 - val_loss: 3.5090 - val_accuracy: 0.7500
# Epoch 32/50
# 150/150 [==============================] - 10s 64ms/step - loss: 0.0246 - accuracy: 0.9949 - val_loss: 3.3603 - val_accuracy: 0.7300
# Epoch 33/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0333 - accuracy: 0.9946 - val_loss: 4.3108 - val_accuracy: 0.7900
# Epoch 34/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0688 - accuracy: 0.9909 - val_loss: 3.1750 - val_accuracy: 0.7700
# Epoch 35/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0352 - accuracy: 0.9928 - val_loss: 3.7694 - val_accuracy: 0.7700
# Epoch 36/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0358 - accuracy: 0.9934 - val_loss: 6.3174 - val_accuracy: 0.7100
# Epoch 37/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0336 - accuracy: 0.9935 - val_loss: 4.4410 - val_accuracy: 0.7700
# Epoch 38/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0266 - accuracy: 0.9940 - val_loss: 4.7423 - val_accuracy: 0.7500
# Epoch 39/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0362 - accuracy: 0.9944 - val_loss: 4.8204 - val_accuracy: 0.8200
# Epoch 40/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0400 - accuracy: 0.9936 - val_loss: 4.6408 - val_accuracy: 0.7500
# Epoch 41/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0277 - accuracy: 0.9955 - val_loss: 4.3901 - val_accuracy: 0.7000
# Epoch 42/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0293 - accuracy: 0.9958 - val_loss: 10.7311 - val_accuracy: 0.6500
# Epoch 43/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0467 - accuracy: 0.9935 - val_loss: 4.5623 - val_accuracy: 0.7500
# Epoch 44/50
# 150/150 [==============================] - 9s 62ms/step - loss: 0.0422 - accuracy: 0.9923 - val_loss: 4.8928 - val_accuracy: 0.7100
# Epoch 45/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0342 - accuracy: 0.9937 - val_loss: 4.9771 - val_accuracy: 0.7000
# Epoch 46/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0393 - accuracy: 0.9933 - val_loss: 4.0833 - val_accuracy: 0.7400
# Epoch 47/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0667 - accuracy: 0.9924 - val_loss: 4.6164 - val_accuracy: 0.7600
# Epoch 48/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0328 - accuracy: 0.9947 - val_loss: 7.2270 - val_accuracy: 0.6800
# Epoch 49/50
# 150/150 [==============================] - 9s 63ms/step - loss: 0.0332 - accuracy: 0.9953 - val_loss: 5.1676 - val_accuracy: 0.7100
# Epoch 50/50
# 150/150 [==============================] - 10s 63ms/step - loss: 0.0193 - accuracy: 0.9962 - val_loss: 4.8363 - val_accuracy: 0.7500
# 4/4 [==============================] - 0s 4ms/step - loss: 4.8363 - accuracy: 0.7500
# 정답률= 0.75 loss= 4.836276054382324

# %%
# 학습 상태를 그래프로 그리기 --- (*10)
# 정답률 추이를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# 손실 추이를 그래프로 그리기
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

model.save_weights('./image/photos-model.hdf5')
