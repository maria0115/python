# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름많음 더운날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름많음 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름많음 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름많음 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름많음 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름많음 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 518

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '뭉게구름',
#  '이',
#  '생기',
#  '면',
#  '날씨',
#  '가',
#  '맑다',
#  '?',
#  '2003.06',
#  '.',
#  '14',
#  '.',
#  '뭉게구름',
#  '이',
#  '생기',
#  '면',
#  '날씨',
#  '가',
#  '맑다는데요',
#  '.',
#  '.',
#  '.',
#  '왜',
#  '그런',
#  '겁',
#  '니까',
#  '?',
#  '알려주세요',
#  '⌒⌒',
#  '답변',
#  '여름',
#  '의',
#  '뜨거운',
#  '태양',
#  '볕',
#  '에',
#  '지면',
#  '의',
#  '온도',
#  '가',
#  '높아져',
#  '이',
#  '것',
#  '의',
#  '공기',
#  '가',
#  '상승',
#  '하여',
#  '큰',
#  '구름',
#  '을',
#  '...',
#  '이',
#  '것',
#  '을',
#  '산이',
#  '운다고',
#  '하는데',
#  ',',
#  '이',
#  '소리',
#  '가',
#  '날',
#  '정도',
#  '로',
#  '강한',
#  '바람',
#  '이면',
#  '산',
#  '을',
#  '넘으려고',
#  '산',
#  '을',
#  '...',
#  '질문',
#  '우리',
#  '나라',
#  '의',
#  '명절',
#  '과',
#  '음식',
#  '놀이',
#  '2005.01',
#  '.',
#  '05',
#  '.',
#  '안녕',
#  '하세요',
#  '저',
#  '는',
#  '예비',
#  '5',
#  '학년',
#  '인데요',
#  '이',
#  '것',
#  '을',
#  '꼭',
#  '알려',
#  '줬으면',
#  '해',
#  '요',
#  '이',
#  '것',
#  '이',
#  '머냐면',
#  '......',
#  '우리',
#  '나라',
#  '의',
#  '명절',
#  '과',
#  '음식',
#  '놀이',
#  '입니다',
#  '..',
#  '꼭',
#  '좀',
#  '부탁드립니다',
#  '..',
#  '답변',
#  '5',
#  '.',
#  '한식',
#  '동지',
#  '로부터',
#  '105일',
#  '째',
#  '되는',
#  '날로',
#  '음력',
#  '으로는',
#  '대개',
#  '...',
#  '비는',
#  '날',
#  '.',
#  '그리고',
#  '음식',
#  '은',
#  '이',
#  '사이트',
#  '에',
#  '^',
#  'ㅡ',
#  '^',
#  'ㅋ',
#  'http',
#  '://',
#  'www',
#  '....',
#  '이',
#  '것',
#  '을',
#  '마시면',
#  '더운',
#  '여름',
#  '내내',
#  '더위',
#  '를',
#  '먹지',
#  '않고',
#  '갈증',
#  '을',
#  '...',
#  '닉네임',
#  'rlas',
#  '****',
#  '질문',
#  '사자성어',
#  '좀',
#  '알려주세요',
#  'ㅠ',
#  '2020.05',
#  '.',
#  '11',
#  '.',
#  '사자성어',
#  '30',
#  '개',
#  '뜻',
#  '과',
#  '유래',
#  '좀',
#  '알려주세요',
#  'ㅜ',
#  '답변',
#  '雲',
#  '구름',
#  '운',
#  '之',
#  '갈',
#  '지',
#  '情',
#  '뜻',
#  '정',
#  '겉뜻',
#  ':',
#  '구름',
#  '을',
#  '바라보는',
#  '뜻',
#  '...',
#  '변화',
#  '가',
#  '많',
#  '음',
#  '을',
#  '이르는',
#  '말',
#  '계란',
#  '유골',
#  '/',
#  '鷄卵有骨',
#  '鷄',
#  '닭',
#  '계',
#  '...',
#  '사람',
#  '이',
#  '음식',
#  '만드는',
#  '일',
#  '을',
#  '하다는',
#  '뜻',
#  '속뜻',
#  ':',
#  '자신',
#  '의',
#  '...',
#  '닉네임',
#  '전',
#  '54',
#  '질문',
#  '일본',
#  '의',
#  '의식주',
#  '(',
#  '관광',
#  '홍보',
#  '발표',
#  ')',
#  '-',
#  '2018.10',
#  '.',
#  '31',
#  '.',
#  '일본',
#  '의',
#  '의식주',
#  '(',
#  '관광',
#  '홍보',
#  '발표',
#  ')',
#  '-',
#  '고',
#  '1',
#  '역사',
#  '나',
#  '그런',
#  '거',
#  '말고',
#  '관광',
#  '할',
#  '때',
#  '알려주는',
#  '기본',
#  '적',
#  '인',
#  '것',
#  '들',
#  '?',
#  '알려주세요',
#  '.',
#  '답변',
#  '그러나',
#  ',',
#  '이',
#  '들',
#  '음식',
#  '들',
#  '은',
#  '일본인',
#  '들',
#  '의',
#  '일상',
#  '적',
#  '인',
#  '식사',
#  '는',
#  '아니다',
#  '.',
#  '산이',
#  '많고',
#  '밭',
#  '이',
#  '많음',
#  '.',
#  '강우량',
#  '이',
#  '낮아',
#  '식물',
#  '풍부',
#  '...',
#  '흰자',
#  '는',
#  '구름',
#  '처럼',
#  '보',
#  '여서',
#  '쓰키미',
#  '라는',
#  '이름',
#  '이',
#  '붙었다',
#  '....',
#  '닉네임',
#  'ryul',
#  '****',
#  '질문',
#  '자연',
#  '개발',
#  '관련',
#  '한',
#  '속담',
#  '2017.06',
#  '.',
#  '26',
#  '.',
#  '제',
#  '가',
#  '지금',
#  '자연',
#  '개발',
#  '을',
#  '해야',
#  '한다를',
#  '주제',
#  '로',
#  '주장',
#  '하는',
#  '글',
#  '을',
#  '써야하는데',
#  '선생님',
#  '이',
#  '그',
#  '와',
#  '관련',
#  '된',
#  '속담',
#  '을',
#  '근거',
#  '로',
#  '넣으래요',
#  '.....',
#  '아무리',
#  '인터넷',
#  '을',
#  '뒤져',
#  '봐도',
#  '자연',
#  '개발',
#  '을',
#  '뒷받침',
#  '하는',
#  '...',
#  '답변',
#  '된것',
#  '더운',
#  '음식',
#  '을',
#  '잘',
#  '먹어야',
#  '처복',
#  '있다',
#  '.',
#  '더운',
#  '국',
#  '이나',
#  '...',
#  '용',
#  '가는데',
#  '구름',
#  '간다',
#  '.',
#  '언제나',
#  '같이',
#  '다니고',
#  '둘',
#  '이',
#  '서로',
#  '...',
#  '세월',
#  '의',
#  '흐름',
#  '이',
#  '덧',
#  '없고',
#  ',',
#  '세상',
#  '의',
#  '변화',
#  '가',
#  '많',
#  '음',
#  '을',
#  '나타낸',
#  '말',
#  '...',
#  '닉네임',
#  '독수리',
#  '강력한',
#  '힘',
#  '으로',
#  '질문',
#  '한문',
#  '수행평가',
#  '입니다만',
#  '..',
#  '2019.11',
#  '.',
#  '18',
#  '.',
#  '중',
#  '1',
#  '인데',
#  '이제',
#  '학교',
#  '에서',
#  '수행평가',
#  '를',
#  '하는데',
#  '한문',
#  '선생',
#  '이',
#  '사자성어',
#  '를',
#  '한자',
#  '와',
#  '뜻',
#  '과음',
#  ',',
#  '활용',
#  '의',
#  '예',
#  '까지',
#  '쓰는데',
#  '사자성어',
#  '50',
#  '개',
#  '를',
#  '이번',
#  '주',
#  '까지',
#  '하라',
#  '네',
#  '요',
#  '..(',
#  '오늘',
#  '나눠',
#  '줌',
#  '.....',
#  '답변',
#  '그런데',
#  '어느',
#  '날',
#  '양',
#  '을',
#  '잃어버리게',
#  '되었다',
#  '.',
#  '장',
#  '에서',
#  '어떤',
#  '일',
#  '을',
#  '하다가',
#  '양',
#  '을',
#  '돌보지',
#  '...',
#  '어느',
#  '날',
#  '초',
#  '(',
#  '楚',
#  ')',
#  '나라',
#  '의',
#  '침략',
#  '을',
#  '불시',
#  '에',
#  '받은',
#  '제나라',
#  '위',
#  '왕',
#  '(',
#  '威王',
#  ')',
#  '은',
#  '조',
#  '(',
#  '趙',
#  ')',
#  '나라',
#  '에게',
#  '구원',
#  '군',
#  '을',
#  '...',
#  '닉네임',
#  '감나무',
#  '질문',
#  '우리나라',
#  '&',
#  '일본',
#  '&',
#  '중국',
#  '의',
#  '의식주',
#  '2016.11',
#  '.',
#  '09',
#  '.',
#  '우리나라',
#  '와',
#  '일본',
#  ',',
#  '중국',
#  '의',
#  '의식주',
#  '를',
#  '알려주세요',
#  '.',
#  '오늘',
#  '까지',
#  '이니',
#  '최대한',
#  '빨리',
#  '알려주세요',
#  '.',
#  '답변',
#  '여름',
#  '에는',
#  '이열치열',
#  '이라',
#  '하여',
#  '더운',
#  '음식',
#  '을',
#  '먹고',
#  '땀',
#  '을',
#  '...',
#  '산이',
#  '많고',
#  '밭',
#  '이',
#  '많음',
#  '.',
#  '강우량',
#  '이',
#  '낮아',
#  '식물',
#  '풍부',
#  '화산',
#  '지형',
#  '...',
#  '흰자',
#  '는',
#  '구름',
#  '처럼',
#  '보',
#  '여서',
#  '쓰키미',
#  '라는',
#  '이름',
#  '이',
#  '붙었다',
#  '....',
#  '닉네임',
#  'ryul',
#  '****',
#  '질문',
#  '조상',
#  '들',
#  '이',
#  '즐겨',
#  '먹던',
#  '명절',
#  '음식',
#  '이',
#  '요',
#  '~~~',
#  '급해요',
#  '(',
#  '사진',
#  '도',
#  '부탁',
#  ',',
#  '4/6',
#  '...',
#  '2009.04',
#  '.',
#  '06',
#  '.',
#  '조상',
#  '들',
#  '이',
#  '즐겨',
#  '먹던',
#  '명절',
#  '음식',
#  '이',
#  '요',
#  '~~~(',
#  '사진',
#  '도',
#  '부탁',
#  ')',
#  '내공',
#  '냠냠',
#  '안',
#  '됌',
#  '!!',
#  '4/6',
#  ',',
#  '8시',
#  '50분',
#  '까지보너스내공',
#  '60',
#  '!!!',
#  '답변',
#  '중국',
#  '에서는',
#  '한식',
#  '을',
#  '냉절',
#  '(',
#  '冷絶',
#  ')',
#  '이라',
#  '하는데',
#  '그',
#  '유래',
#  '로',
#  '인하여',
#  '우리',
#  '도',
#  '이',
#  '날',
#  '은',
#  '미리',
#  '장만',
#  '해',
#  '놓은',
#  '찬',
#  '음식',
#  '을',
#  '먹고',
#  '...',
#  '이',
#  '것',
#  '을',
#  '마시면',
#  '더운',
#  '여름',
#  '내내',
#  '더위',
#  '를',
#  '먹지',
#  '않고',
#  '갈증',
#  '을',
#  '...',
#  '닉네임',
#  'dlrh',
#  '****',
#  '질문',
#  '일상생활',
#  '에',
#  '쓰이는',
#  '어려운',
#  '한자성어',
#  '알',
#  '2019.06',
#  '.',
#  '11',
#  '.',
#  '일상생활',
#  '에',
#  '쓰이는',
#  '어려운',
#  '한자성어',
#  '알려주세요',
#  'ㅠㅠ',
#  '그',
#  '한자성어',
#  '에',
#  '유래',
#  '와',
#  '의미',
#  '도',
#  '자세히',
#  '알려주시면',
#  '감사하겠습니다',
#  'ㅠ',
#  '답변',
#  '청운',
#  '지지',
#  '(',
#  '靑雲之志',
#  ')',
#  '<',
#  '靑',
#  '푸를',
#  '청',
#  ',',
#  '雲',
#  '구름',
#  '운',
#  ',',
#  '之',
#  '어조사',
#  '지',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹게',
#  '했다고',
#  '한다',
#  '.',
#  '바로',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '의',
#  '유래',
#  '다',
#  '....',
#  '수가',
#  '많음',
#  '’',
#  '을',
#  '나타내는',
#  '말',
#  '이다',
#  '.',
#  '전진',
#  '(',
#  '前秦',
#  ')',
#  '의',
#  '제',
#  '3',
#  '대',
#  '...',
#  '닉네임',
#  '감나무',
#  '질문',
#  '중국',
#  '대표',
#  '음식',
#  '조사',
#  '하는것',
#  '좀',
#  '도와주세요',
#  '!',
#  '내공',
#  '35',
#  '!!!!!!!!',
#  '2012.07',
#  '.',
#  '18',
#  '.',
#  '중국',
#  '의',
#  '대표',
#  '음식',
#  '조사',
#  '.',
#  '대표',
#  '음식',
#  '된',
#  '이유',
#  '.',
#  '사회',
#  '적',
#  '영향',
#  '.',
#  '특징',
#  '왜',
#  '유명해졌는지',
#  '사진',
#  '부탁드려요',
#  'ㅎㅎ',
#  '대학생',
#  '정도',
#  '의',
#  '글',
#  '솜씨',
#  '로',
#  '길게',
#  '써주시면',
#  '감사하겠습니다',
#  '!',
#  '내공',
#  '35',
#  '드려요',
#  '!',
#  '답변',
#  '음',
#  '식',
#  '중국',
#  '의',
#  '음식',
#  '은',
#  '그',
#  '가지',
#  '수도',
#  '많고',
#  '또',
#  '무척',
#  '기름',
#  '지다',
#  '....',
#  '오죽하면',
#  '한',
#  '식식',
#  '당',
#  '에서',
#  '고추장',
#  '으로',
#  '비빔밥',
#  '을',
#  '해',
#  '먹었을',
#  '...',
#  '현재',
#  '전국',
#  '많은',
#  '대도시',
#  '에서는',
#  '겨울',
#  '이나',
#  '무더운',
#  '...',
#  '닉네임',
#  'xude',
#  '****',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '중국',
#  '대표',
#  '음식',
#  '조사',
#  '하는것',
#  '좀',
#  '도와주세요',
#  '!',
#  '내공',
#  '35',
#  '!!!!!!!!',
#  '2012.07',
#  '.',
#  '18',
#  '.',
#  '중국',
#  '의',
#  '대표',
#  '음식',
#  '조사',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='구름많음 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='구름많음 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='구름많음 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='구름많음 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='구름많음 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='구름많음 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 74526
# 5545

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 1318),
#  ('...', 946),
#  (',', 762),
#  ('단어', 663),
#  ('이', 574),
#  ('의', 543),
#  ('을', 511),
#  ('가', 468),
#  ('검색', 402),
#  ('에', 391),
#  ('하는', 358),
#  ('를', 341),
#  ('답변', 339),
#  ('질문', 325),
#  ('입력', 300),
#  ('속담', 281),
#  ('닉네임', 264),
#  ('때', 256),
#  ('로', 243),
#  ('한', 242),
#  ('는', 224),
#  ('****', 215),
#  ('더운', 209),
#  ('포함', 204),
#  ('음식', 192),
#  ('개', 185),
#  ('구름', 175),
#  ('좀', 172),
#  ('과', 169),
#  ('된', 167),
#  ('날', 165),
#  ('은', 163),
#  ('영어', 148),
#  ('(', 144),
#  ('산', 131),
#  ('합니다', 125),
#  ('해서', 124),
#  (')', 123),
#  ('할', 119),
#  ('이상', 116),
#  ('것', 116),
#  ('내공', 114),
#  ('하나', 111),
#  ('사용', 110),
#  (':', 110),
#  ('여러', 109),
#  ('도', 108),
#  ('기본', 107),
#  ('1', 107),
#  ('알려주세요', 105),
#  ('/', 104),
#  ('문장', 104),
#  ('기', 104),
#  ('본', 104),
#  ('날씨', 102),
#  ('반드시', 101),
#  ('범위', 101),
#  ('구분', 101),
#  ('문서', 100),
#  ('상세', 100),
#  ('정확히', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('제외', 100),
#  ('(-)', 100),
#  ('결과', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('하세요', 100),
#  ('말', 96),
#  ('..', 96),
#  ('소리', 95),
#  ('에서', 94),
#  ('와', 92),
#  ('요', 92),
#  ('학년', 91),
#  ('뜻', 90),
#  ('많음', 89),
#  ('걱정', 88),
#  ('바람', 86),
#  ('으로', 82),
#  ('뜨거운', 81),
#  ('정도', 80),
#  ('들', 79),
#  ('해', 79),
#  ('음', 76),
#  ('사람', 76),
#  ('제', 75),
#  ('이다', 75),
#  ('98', 75),
#  ('관련', 71),
#  ('까지', 69),
#  ('아', 69),
#  ('빨리', 68),
#  ('....', 68),
#  ('저', 68),
#  ('hot', 67),
#  ('이면', 66),
#  ('많', 66),
#  ('5', 66),
#  ('강한', 63),
#  ('넘으려고', 63),
#  ('다수', 62),
#  ('다량', 62),
#  ('인데', 61),
#  ('숙제', 58),
#  ('까닭', 56),
#  ('~', 54),
#  ('많이', 54),
#  ('많은', 53),
#  ('밑', 53),
#  ('기운', 53),
#  ('아래', 53),
#  ('모이는', 53),
#  ('하는데', 52),
#  ('-', 52),
#  ('중', 52),
#  ('하다', 51),
#  ('가지', 51),
#  ('음식물', 51),
#  ('sunny', 51),
#  ('비치는', 51),
#  ('중국', 50),
#  ('알', 50),
#  ('100', 49),
#  ('한다', 49),
#  ('?', 48),
#  ('2', 48),
#  ('하여', 47),
#  ('만', 47),
#  ('식사', 47),
#  ('입니다', 47),
#  ('•', 45),
#  ('끼', 45),
#  ('산이', 44),
#  ('그', 44),
#  ('화창한', 44),
#  ('plenty', 44),
#  ('care', 44),
#  ('관', 43),
#  ('등', 43),
#  ('222', 43),
#  ('조심', 43),
#  ('223', 43),
#  ('meal', 43),
#  ('224', 43),
#  ('20', 42),
#  ('수', 42),
#  ('ㅠㅠ', 42),
#  ('3', 42),
#  ('운다고', 40),
#  ('30', 40),
#  (';', 40),
#  ('적', 39),
#  ('안', 39),
#  ('안녕하세요', 39),
#  ('제주도', 39),
#  ('이나', 37),
#  ('10', 36),
#  ('6', 35),
#  ('동남아', 34),
#  ('부탁', 34),
#  ('밥', 34),
#  ('water', 34),
#  ('잘', 33),
#  ('사회', 33),
#  ('여', 33),
#  ('물', 32),
#  ('영', 32),
#  ('ㅠ', 31),
#  ('고', 31),
#  ('저녁', 30),
#  ('전파', 30),
#  ('속도', 30),
#  ('게', 30),
#  ('못', 30),
#  ('!', 29),
#  ('하늘', 29),
#  ('절대온도', 28),
#  ('눈', 28),
#  ('주세요', 28),
#  ('서', 28),
#  ('거지', 27),
#  ('방학', 26),
#  ("'", 26),
#  ('면', 25),
#  ('하고', 25),
#  ('노을', 25),
#  ('서쪽', 25),
#  ('먼지', 25),
#  ('제발', 25),
#  ('경계', 25),
#  ('가마', 25),
#  ('솥', 25),
#  ('더러', 25),
#  ('검정', 25),
#  ('허겁지겁', 25),
#  ('먹어', 25),
#  ('치움을', 25),
#  ('대해', 25),
#  ('food', 25),
#  ('얻어먹는다', 25),
#  ('언제나', 24),
#  ('비', 24),
#  ('맑아서', 24),
#  ('19', 24),
#  ('있는', 24),
#  ('2008.03', 24),
#  ('생활', 24),
#  ('걸음', 24),
#  ('살려라', 24),
#  ('달아날', 24),
#  ('조급한', 24),
#  ('마음', 24),
#  ('감추듯', 24),
#  ('부지런해야', 24),
#  ('기초', 24),
#  ('공부', 24),
#  ('있고', 23),
#  ('때문', 23),
#  ('[', 23),
#  ('4', 23),
#  ('lot', 23),
#  ('친척', 23),
#  ('꼭', 22),
#  ('나', 22),
#  (']', 22),
#  ('가을', 22),
#  ('풀이', 22),
#  ('학교', 22),
#  ('50', 22),
#  ('중학교', 22),
#  ('대접', 22),
#  ('얼마나', 22),
#  ('비용', 22),
#  ('노력', 22),
#  ('인', 21),
#  ('해주세요', 21),
#  ('학기', 21),
#  ('2009.03', 21),
#  ('다', 21),
#  ('83', 21),
#  ('우리나라', 20),
#  ('오늘', 20),
#  ('예', 20),
#  ('정리', 20),
#  ('집', 20),
#  ('26', 19),
#  ('나라', 19),
#  ('책', 19),
#  ('조사', 19),
#  ('너무', 19),
#  ('12', 19),
#  ('일본', 18),
#  ('!!', 18),
#  ('k', 18),
#  ('선생님', 17),
#  ('31', 17),
#  ('내일', 17),
#  ('데', 17),
#  ('북한', 17),
#  ('과학', 17),
#  ('시간', 17),
#  ('994', 17),
#  ('이제', 17),
#  ('단원', 17),
#  ('0', 17),
#  ('끓는', 17),
#  ('요점', 17),
#  ('써주세요', 17),
#  ('식품', 17),
#  ('검은', 17),
#  ('기후', 16),
#  ('및', 16),
#  ('속', 16),
#  ('표현', 16),
#  ('부터', 16),
#  ('여러가지', 16),
#  ('차', 16),
#  ('초등학교', 16),
#  ('백로', 16),
#  ('날아간다', 16),
#  ('정처', 16),
#  ('없이', 16),
#  ('떠돌아다니는', 16),
#  ('여름', 15),
#  ('전', 15),
#  ('글', 15),
#  ('.....', 15),
#  ('^^', 15),
#  ('계절', 15),
#  ('거', 15),
#  ('학생', 15),
#  ('에게', 15),
#  ('양', 15),
#  ('22', 15),
#  (',,', 15),
#  ('곳', 15),
#  ('올려주세요', 15),
#  ('공기', 14),
#  ('상승', 14),
#  ('큰', 14),
#  ('운', 14),
#  ('저희', 14),
#  ('또', 14),
#  ('급해요', 14),
#  ('15', 14),
#  ('적어주세요', 14),
#  ('내용', 14),
#  ('04', 14),
#  ('고사성어', 14),
#  ('16', 14),
#  ('겁니다', 14),
#  ('fool', 14),
#  ('바보', 14),
#  ('에는', 13),
#  ('특징', 13),
#  ('무더운', 13),
#  ('문', 13),
#  ('17', 13),
#  ('☞', 13),
#  ('비유', 13),
#  ('부탁드립니다', 13),
#  ('그래서', 13),
#  (';;', 13),
#  ('조금', 13),
#  ('*', 13),
#  ('cloud', 13),
#  ('열대', 13),
#  ('일', 12),
#  ('이라', 12),
#  ('역사', 12),
#  ('식', 12),
#  ('모두', 12),
#  ('냠냠', 12),
#  ('드림', 12),
#  ('06', 12),
#  ('되', 12),
#  ('시험', 12),
#  ('유명한', 12),
#  ('28', 12),
#  ('2008.06', 12),
#  ('새털', 12),
#  ('내', 12),
#  ('2007.12', 12),
#  ('방콕', 12),
#  ('지면', 11),
#  ('온도', 11),
#  ('지', 11),
#  ('먹고', 11),
#  ('60', 11),
#  ('18', 11),
#  ('부탁드려요', 11),
#  ('감사하겠습니다', 11),
#  ('겨울', 11),
#  ('음식점', 11),
#  ('03', 11),
#  ('23', 11),
#  ('없는', 11),
#  ('국어', 11),
#  ('25', 11),
#  ('감사', 11),
#  ('우리', 11),
#  ('조', 11),
#  ('나무', 11),
#  ('13', 11),
#  ('몫', 11),
#  ('문화', 11),
#  ('몸', 11),
#  ('동', 11),
#  ('태양', 10),
#  ('볕', 10),
#  ('높아져', 10),
#  ('같이', 10),
#  ('베트남', 10),
#  ('_', 10),
#  ('많고', 10),
#  ('처럼', 10),
#  ('그리고', 10),
#  ('도와주세요', 10),
#  ('에서는', 10),
#  ('캐나다', 10),
#  ('오', 10),
#  ('위', 10),
#  ('어', 10),
#  (')...', 10),
#  ('개정', 10),
#  ('24', 10),
#  ('??', 10),
#  ('신고', 10),
#  ('필수', 10),
#  ('관용', 10),
#  ('2010.01', 10),
#  ('~~', 10),
#  ('27', 10),
#  ('개좀', 10),
#  ('해안', 10),
#  ('★', 10),
#  ('명', 10),
#  ('란', 10),
#  ('단', 10),
#  ('이번', 10),
#  ('그런데', 10),
#  ('hotel', 10),
#  ('2008.01', 10),
#  ('발음', 10),
#  ('모습', 10),
#  ('유래', 9),
#  ('간다', 9),
#  ('지식인', 9),
#  ('09', 9),
#  ('최대한', 9),
#  ('보', 9),
#  ('세계', 9),
#  ('현재', 9),
#  ('대만', 9),
#  ('지구', 9),
#  ('29', 9),
#  ('ㅜㅜ', 9),
#  ('가는', 9),
#  ('등등', 9),
#  ('맑은', 9),
#  ('어려운', 9),
#  ('초', 9),
#  ('2011.05', 9),
#  ('인데요', 9),
#  ('대륙', 9),
#  ('러시아', 9),
#  ('해양', 9),
#  ('담고', 9),
#  ('직하게', 9),
#  ('반죽', 9),
#  ('수저', 9),
#  ('한자', 9),
#  ('강', 9),
#  ('성', 9),
#  ('대한', 9),
#  ('대', 9),
#  ('밖에', 9),
#  ('달', 9),
#  ('오후', 9),
#  ('89', 9),
#  ('구', 9),
#  ('여자', 9),
#  ('"', 9),
#  ('진짜', 9),
#  ('club', 9),
#  ('클럽', 9),
#  ('호텔', 9),
#  ('세', 9),
#  ('박', 9),
#  ('지금', 8),
#  ('해야', 8),
#  ('이름', 8),
#  ('뭐', 8),
#  ('스시', 8),
#  ('사는', 8),
#  ('전국', 8),
#  ('대도시', 8),
#  ('각국', 8),
#  ('향항', 8),
#  ('해주시', 8),
#  ('낀', 8),
#  ('먹는다', 8),
#  ('2008.08', 8),
#  ('이렇게', 8),
#  ('),', 8),
#  ('관계', 8),
#  ('적어', 8),
#  ('저기압', 8),
#  ('가르쳐', 8),
#  ('!!!', 8),
#  ('알아야', 8),
#  ('해요', 8),
#  ('같은', 8),
#  ('방법', 8),
#  ('중국인', 8),
#  ('주', 8),
#  ('하', 8),
#  ('01', 8),
#  ('시작', 8),
#  ('지학사', 8),
#  ('afternoon', 8),
#  ('people', 8),
#  ('해산', 8),
#  ('산모', 8),
#  ('해주었던', 8),
#  ('보릿가루', 8),
#  ('염', 8),
#  ('이런', 8),
#  ('일이', 8),
#  ('class', 8),
#  ('형', 8),
#  ('분', 8),
#  ('□', 8),
#  ('hour', 8),
#  ('wjdd', 8),
#  ('14', 7),
#  ('왜', 7),
#  ('11', 7),
#  ('이르는', 7),
#  ('여행', 7),
#  ('+', 7),
#  ('식물', 7),
#  ('라는', 7),
#  ('ㅎㅎ', 7),
#  ('기름', 7),
#  ('열', 7),
#  ('적어서', 7),
#  ('대하', 7),
#  ('일기', 7),
#  ('해석', 7),
#  ('오기', 7),
#  ('알려주세여', 7),
#  ('정말', 7),
#  ('도움', 7),
#  ('예절', 7),
#  ('·', 7),
#  ('9', 7),
#  ('7', 7),
#  ('2008.04', 7),
#  ('먹는', 7),
#  ('조사해', 7),
#  ('~!', 7),
#  ('짧은', 7),
#  ('이건', 7),
#  ('있는데', 7),
#  ('비오는', 7),
#  ('하면', 7),
#  ('야할', 7),
#  ('02', 7),
#  ('듯', 7),
#  ('중학생', 7),
#  ('개월', 7),
#  ('국가', 7),
#  ('초등학생', 7),
#  ('coast', 7),
#  ('오면', 7),
#  ('dhle', 7),
#  ('김', 7),
#  ('명언', 7),
#  ('어떻게', 7),
#  ('8', 7),
#  ('점', 7),
#  ('번', 7),
#  ('이스라엘', 7),
#  ('가게', 7),
#  ('새', 7),
#  ('ㅜ', 6),
#  ('용', 6),
#  ('더', 6),
#  ('?...', 6),
#  ('분야', 6),
#  ('의식주', 6),
#  ('11월', 6),
#  ('아시아', 6),
#  ('이유', 6),
#  ('드려요', 6),
#  ('수도', 6),
#  ('바늘', 6),
#  ('실', 6),
#  ('가고', 6),
#  ('함께', 6),
#  ('님들', 6),
#  ('삼', 6),
#  ('여러분', 6),
#  ('안녕하세여', 6),
#  ('이랑', 6),
#  ('▷', 6),
#  ('시', 6),
#  ('사', 6),
#  ('ag', 6),
#  ('되요', 6),
#  ('어떤', 6),
#  ('주시', 6),
#  ('랑', 6),
#  ('문제', 6),
#  ('강수량', 6),
#  ('쪽', 6),
#  ('날시에', 6),
#  ('ethn', 6),
#  ('이라는', 6),
#  ('덩어리', 6),
#  ('내리는', 6),
#  ('부분', 6),
#  ('나오는', 6),
#  ('햄스터', 6),
#  ('......', 6),
#  ('ㅋ', 6),
#  ('거의', 6),
#  ('밤', 6),
#  ('되도록', 6),
#  ('저가', 6),
#  ('총', 6),
#  ('몇개', 6),
#  ('외워', 6),
#  ('자료', 6),
#  ('않고', 6),
#  ('중간고사', 6),
#  ('외워야', 6),
#  ('교과서', 6),
#  ('좋은', 6),
#  ('학원', 6),
#  ('우리말', 6),
#  ('알려', 6),
#  ('이에요', 6),
#  ('300', 6),
#  ('낱말', 6),
#  ('1000', 6),
#  ('따라', 6),
#  ('14일', 6),
#  ('격언', 6),
#  ('famous', 6),
#  ('수업', 6),
#  ('):', 6),
#  ('먹은', 6),
#  ('같지도', 6),
#  ('않다는', 6),
#  ('부지런하면', 6),
#  ('2008.02', 6),
#  ('90', 6),
#  ('last', 6),
#  ('month', 6),
#  ('학급', 6),
#  ('|', 6),
#  ('07', 6),
#  ('연안', 6),
#  ('팍팍', 6),
#  ('200', 6),
#  ('훌륭한', 6),
#  ('죽어', 6),
#  ('~!!!', 6),
#  ('ㅇ', 6),
#  ('처음', 6),
#  ('천자문', 6),
#  ('님', 6),
#  ('태국', 6),
#  ('주점', 6),
#  ('갖가지', 6),
#  ('기념품', 6),
#  ('덤핑', 6),
#  ('위만', 6),
#  ('멕', 6),
#  ('궁전', 6),
#  ('라마', 6),
#  ('펼쳐진', 6),
#  ('남아시아', 6),
#  ('최대', 6),
#  ('거리', 6),
#  ('혼잡하면서도', 6),
#  ('파타야', 6),
#  ('우선', 6),
#  ('순위', 6),
#  ('그런', 5),
#  ('변화', 5),
#  ('대부분', 5),
#  ('풍부', 5),
#  ('ryul', 5),
#  ('설', 5),
#  ('대표', 5),
#  ('2012.07', 5),
#  ('영향', 5),
#  ('추천', 5),
#  ('땅', 5),
#  ('가르쳐주세요', 5),
#  ('제목', 5),
#  ('=', 5),
#  ('08', 5),
#  ('유', 5),
#  ('전통', 5),
#  ('2005.06', 5),
#  ('씩', 5),
#  ('다음', 5),
#  ('하루', 5),
#  ('켜주세요', 5),
#  ('하는데요', 5),
#  ('좀더', 5),
#  ('걸', 5),
#  ('토박이', 5),
#  ('학교숙제', 5),
#  ('답', 5),
#  ('한글', 5),
#  ('되는데', 5),
#  ('급', 5),
#  ('한국', 5),
#  ('있으면', 5),
#  ('정보', 5),
#  ('싶습니다', 5),
#  ('초등', 5),
#  ('컬러', 5),
#  ('푸드', 5),
#  ('Color', 5),
#  ('Food', 5),
#  ('건강', 5),
#  ('효과', 5),
#  ('수분', 5),
#  ('저온', 5),
#  ('고온', 5),
#  ('반복', 5),
#  ('커져', 5),
#  ('말함', 5),
#  ('진눈깨비', 5),
#  ('차가운', 5),
#  ('종류', 5),
#  ('쓰이는', 5),
#  ('야', 5),
#  ('드립니다', 5),
#  ('찾아주세요', 5),
#  ('흑', 5),
#  ('2010.02', 5),
#  ('비구름', 5),
#  ('강수', 5),
#  ('순', 5),
#  ('2008.10', 5),
#  ('이라고', 5),
#  ('2013.06', 5),
#  ('21', 5),
#  ('식당', 5),
#  ('기름진', 5),
#  ('8월', 5),
#  ('2010.04', 5),
#  ('빨리요', 5),
#  ('모양', 5),
#  ('..-_-', 5),
#  ('수준', 5),
#  ('끝', 5),
#  ('급함', 5),
#  ('129', 5),
#  ('130', 5),
#  ('419', 5),
#  ('420', 5),
#  ('2007.03', 5),
#  ('죽고', 5),
#  ('줄거리', 5),
#  ('^', 5),
#  ('256', 5),
#  ('257', 5),
#  ('487', 5),
#  ('488', 5),
#  ('foolish', 5),
#  ('636', 5),
#  ('637', 5),
#  ('시각', 5),
#  ('아직', 5),
#  ('바', 5),
#  ('거든요', 5),
#  (".'", 5),
#  ('들면', 5),
#  ('한울', 5),
#  ('복', 5),
#  ('보기', 5),
#  ('추석', 5),
#  ('이란', 5),
#  ('pilh', 5),
#  ('일정', 5),
#  ('폼첩쿤', 5),
#  ('5일', 5),
#  ('2009.07', 5),
#  ('쉽게', 5),
#  ('외우는', 5),
#  (';;;', 5),
#  ('외우기', 5),
#  ('갈', 4),
#  ('아무리', 4),
#  ('없고', 4),
#  ('카드', 4),
#  ('특히', 4),
#  ('밭', 4),
#  ('강우량', 4),
#  ('낮아', 4),
#  ('지형', 4),
#  ('흰자', 4),
#  ('여서', 4),
#  ('쓰키미', 4),
#  ('붙었다', 4),
#  ('일본음식', 4),
#  ('전래', 4),
#  ('거슬러', 4),
#  ('올라가면', 4),
#  ('동남', 4),
#  ('산지', 4),
#  ('이기', 4),
#  ('우기', 4),
#  ('써주시면', 4),
#  ('무척', 4),
#  ('지다', 4),
#  ('관광', 4),
#  ('아니다', 4),
#  ('2014.01', 4),
#  ('요리', 4),
#  ('나서', 4),
#  ('찬', 4),
#  ('숙젠데', 4),
#  ('가장', 4),
#  ('하기', 4),
#  ('간단한', 4),
#  ('2008.05', 4),
#  ('봉동읍', 4),
#  ('ltah', 4),
#  ('그러는데', 4),
#  ('알수', 4),
#  ('있을까요', 4),
#  ('라서', 4),
#  ('나타나면', 4),
#  ('권적운', 4),
#  ('의미', 4),
#  ('하며', 4),
#  ('접근', 4),
#  ('따뜻한', 4),
#  ('사투리', 4),
#  ('혹시', 4),
#  ('뜻좀', 4),
#  ('생각', 4),
#  ('머리', 4),
#  ('께', 4),
#  ('알려주시면', 4),
#  ('살', 4),
#  ('다른', 4),
#  ('2007.10', 4),
#  ('대기오염', 4),
#  ('려', 4),
#  ('그럼', 4),
#  ('주민', 4),
#  ('별로', 4),
#  ('있는데요', 4),
#  ('한테', 4),
#  ('2010.08', 4),
#  ('올', 4),
#  ('니', 4),
#  ('변', 4),
#  ('.......', 4),
#  ('소금', 4),
#  ('간', 4),
#  ('사전', 4),
#  ('오래', 4),
#  ('하지', 4),
#  ('지리', 4),
#  ('추운', 4),
#  ('검', 4),
#  ('비단', 4),
#  ('에만', 4),
#  ('국한', 4),
#  ('되지', 4),
#  ('맛', 4),
#  ('따라서', 4),
#  ('보면', 4),
#  ('56%', 4),
#  ('28%', 4),
#  ('볼거리', 4),
#  ('할려고', 4),
#  ('2009.10', 4),
#  ('써', 4),
#  ('쓴다고', 4),
#  ('2008.07', 4),
#  ('들어', 4),
#  ('ㄳ', 4),
#  ('자전', 4),
#  ('특산', 4),
#  ('되어', 4),
#  ('13:10', 4),
#  ('l', 4),
#  ('박정연', 4),
#  ('planet', 4),
#  ('u', 4),
#  ('당국', 4),
#  ('해외', 4),
#  ('운영', 4),
#  ('스파이', 4),
#  ('통일', 4),
#  ('진정한', 4),
#  ('광복', 4),
#  ('평양', 4),
#  ('향', 4),
#  ('2013년', 4),
#  ('발', 4),
#  ('거구', 4),
#  ('월령', 4),
#  ('정확하게', 4),
#  ('44', 4),
#  ('108', 4),
#  ('있어요', 4),
#  ('돈', 4),
#  ('a', 4),
#  ('매운', 4),
#  ('흐린', 4),
#  ('볼', 4),
#  ('직접', 4),
#  ('짐승', 4),
#  ('고기', 4),
#  ('만든', 4),
#  ('맛있는', 4),
#  ('없', 4),
#  ('공', 4),
#  ('2011.01', 4),
#  ('동안', 4),
#  ('290', 4),
#  ('291', 4),
#  ('코', 4),
#  (',..', 4),
#  ('해주시길', 4),
#  ('이구', 4),
#  ('여름방학', 4),
#  ('ebs', 4),
#  ('백', 4),
#  ('채택', 4),
#  ('순서', 4),
#  ('읽는', 4),
#  ('갑니다', 4),
#  ('브라질', 4),
#  ('05', 4),
#  ('cloudy', 4),
#  ('여우', 4),
#  ('아주', 4),
#  ('2010.05', 4),
#  ('위인', 4),
#  ('남긴', 4),
#  ('없어요', 4),
#  ('농업', 4),
#  ('주셔도', 4),
#  ('되고', 4),
#  ('펌', 4),
#  ('짧게', 4),
#  ('②', 4),
#  ('식생', 4),
#  ('밀림', 4),
#  ('정글', 4),
#  ('사바나', 4),
#  ('입음', 4),
#  ('과일', 4),
#  ('향신료', 4),
#  ('개방', 4),
#  ('형성', 4),
#  ('④', 4),
#  ('초딩', 4),
#  ('원', 4),
#  ('없어서', 4),
#  ('상식', 4),
#  ('사고', 4),
#  ('자가', 4),
#  ('엄마', 4),
#  ('가르', 4),
#  ('4일', 4),
#  ('자유여행', 4),
#  ('요약', 4),
#  ('상의', 4),
#  ('자준', 4),
#  ('상대', 4),
#  ('숙어', 4),
#  ('심판', 4),
#  ('세계대전', 4),
#  ('지상천국', 4),
#  ('뿌리', 4),
#  ('뽑힌', 4),
#  ('열매', 4),
#  ('01:13', 4),
#  ('전북', 4),
#  ('e', 4),
#  ('스쿨', 4),
#  ('니까', 3),
#  ('雲', 3),
#  ('계', 3),
#  ('자연', 3),
#  ('개발', 3),
#  ('주제', 3),
#  ('있다', 3),
#  ('유럽', 3),
#  ('다니는', 3),
#  ('특성', 3),
#  ('&', 3),
#  ('2012.11', 3),
#  ('♥', 3),
#  ('!!!!!!!!', 3),
#  ('홍보', 3),
#  ('발표', 3),
#  ('2018.10', 3),
#  ('말고', 3),
#  ('그러나', 3),
#  ('일본인', 3),
#  ('일상', 3),
#  ('맞는', 3),
#  ('ㄱ', 3),
#  ('2006.03', 3),
#  ('높이', 3),
#  ('2009.04', 3),
#  ('특색', 3),
#  ('2009.08', 3),
#  ('악', 3),
#  ('불평', 3),
#  ('쉬운', 3),
#  ('무엇', 3),
#  ('많을수록', 3),
#  ('o', 3),
#  ('봄', 3),
#  ('이라도', 3),
#  ('되면', 3),
#  ('woni', 3),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='구름많음 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='구름많음 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='구름많음 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='구름많음 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='구름많음 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='구름많음 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [('검색', 402),
#  ('입력', 300),
#  ('속담', 281),
#  ('닉네임', 264),
#  ('****', 215),
#  ('더운', 209),
#  ('포함', 204),
#  ('음식', 192),
#  ('개', 185),
#  ('구름', 175),
#  ('된', 167),
#  ('날', 165),
#  ('영어', 148),
#  ('(', 144),
#  ('산', 131),
#  ('합니다', 125),
#  ('해서', 124),
#  (')', 123),
#  ('내공', 114),
#  ('사용', 110),
#  (':', 110),
#  ('여러', 109),
#  ('알려주세요', 105),
#  ('/', 104),
#  ('문장', 104),
#  ('기', 104),
#  ('본', 104),
#  ('날씨', 102),
#  ('반드시', 101),
#  ('범위', 101),
#  ('구분', 101),
#  ('문서', 100),
#  ('상세', 100),
#  ('정확히', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('제외', 100),
#  ('(-)', 100),
#  ('결과', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('하세요', 100),
#  ('말', 96),
#  ('소리', 95),
#  ('에서', 94),
#  ('와', 92),
#  ('학년', 91),
#  ('뜻', 90),
#  ('많음', 89),
#  ('걱정', 88),
#  ('바람', 86),
#  ('뜨거운', 81),
#  ('정도', 80),
#  ('해', 79),
#  ('음', 76),
#  ('사람', 76),
#  ('이다', 75),
#  ('98', 75),
#  ('관련', 71),
#  ('까지', 69),
#  ('아', 69),
#  ('빨리', 68),
#  ('저', 68),
#  ('hot', 67),
#  ('이면', 66),
#  ('많', 66),
#  ('5', 66),
#  ('강한', 63),
#  ('넘으려고', 63),
#  ('다수', 62),
#  ('다량', 62),
#  ('숙제', 58),
#  ('까닭', 56),
#  ('많이', 54),
#  ('많은', 53),
#  ('밑', 53),
#  ('기운', 53),
#  ('아래', 53),
#  ('모이는', 53),
#  ('하는데', 52),
#  ('-', 52),
#  ('하다', 51),
#  ('가지', 51),
#  ('음식물', 51),
#  ('sunny', 51),
#  ('비치는', 51),
#  ('중국', 50),
#  ('알', 50),
#  ('100', 49),
#  ('한다', 49),
#  ('하여', 47),
#  ('만', 47),
#  ('식사', 47),
#  ('입니다', 47),
#  ('•', 45),
#  ('끼', 45),
#  ('산이', 44),
#  ('그', 44),
#  ('화창한', 44),
#  ('plenty', 44),
#  ('care', 44),
#  ('관', 43),
#  ('등', 43),
#  ('222', 43),
#  ('조심', 43),
#  ('223', 43),
#  ('meal', 43),
#  ('224', 43),
#  ('ㅠㅠ', 42),
#  ('3', 42),
#  ('운다고', 40),
#  ('30', 40),
#  (';', 40),
#  ('적', 39),
#  ('안', 39),
#  ('안녕하세요', 39),
#  ('제주도', 39),
#  ('이나', 37),
#  ('동남아', 34),
#  ('부탁', 34),
#  ('밥', 34),
#  ('water', 34),
#  ('사회', 33),
#  ('여', 33),
#  ('물', 32),
#  ('영', 32),
#  ('ㅠ', 31),
#  ('저녁', 30),
#  ('전파', 30),
#  ('속도', 30),
#  ('!', 29),
#  ('하늘', 29),
#  ('절대온도', 28),
#  ('눈', 28),
#  ('주세요', 28),
#  ('서', 28),
#  ('거지', 27),
#  ('방학', 26),
#  ("'", 26),
#  ('면', 25),
#  ('하고', 25),
#  ('노을', 25),
#  ('서쪽', 25),
#  ('먼지', 25),
#  ('제발', 25),
#  ('경계', 25),
#  ('가마', 25),
#  ('솥', 25),
#  ('더러', 25),
#  ('검정', 25),
#  ('허겁지겁', 25),
#  ('먹어', 25),
#  ('치움을', 25),
#  ('대해', 25),
#  ('food', 25),
#  ('얻어먹는다', 25),
#  ('언제나', 24),
#  ('비', 24),
#  ('맑아서', 24),
#  ('19', 24),
#  ('2008.03', 24),
#  ('생활', 24),
#  ('걸음', 24),
#  ('살려라', 24),
#  ('달아날', 24),
#  ('조급한', 24),
#  ('마음', 24),
#  ('감추듯', 24),
#  ('부지런해야', 24),
#  ('기초', 24),
#  ('공부', 24),
#  ('있고', 23),
#  ('때문', 23),
#  ('[', 23),
#  ('4', 23),
#  ('lot', 23),
#  ('친척', 23),
#  ('꼭', 22),
#  ('나', 22),
#  (']', 22),
#  ('가을', 22),
#  ('풀이', 22),
#  ('학교', 22),
#  ('50', 22),
#  ('중학교', 22),
#  ('대접', 22),
#  ('얼마나', 22),
#  ('비용', 22),
#  ('노력', 22),
#  ('인', 21),
#  ('해주세요', 21),
#  ('학기', 21),
#  ('2009.03', 21),
#  ('83', 21),
#  ('우리나라', 20),
#  ('오늘', 20),
#  ('예', 20),
#  ('정리', 20),
#  ('집', 20),
#  ('26', 19),
#  ('나라', 19),
#  ('책', 19),
#  ('조사', 19),
#  ('너무', 19),
#  ('12', 19),
#  ('일본', 18),
#  ('k', 18),
#  ('선생님', 17),
#  ('31', 17),
#  ('내일', 17),
#  ('북한', 17),
#  ('과학', 17),
#  ('시간', 17),
#  ('994', 17),
#  ('이제', 17),
#  ('단원', 17),
#  ('0', 17),
#  ('끓는', 17),
#  ('요점', 17),
#  ('써주세요', 17),
#  ('식품', 17),
#  ('검은', 17),
#  ('기후', 16),
#  ('및', 16),
#  ('속', 16),
#  ('표현', 16),
#  ('부터', 16),
#  ('여러가지', 16),
#  ('차', 16),
#  ('초등학교', 16),
#  ('백로', 16),
#  ('날아간다', 16),
#  ('정처', 16),
#  ('없이', 16),
#  ('떠돌아다니는', 16),
#  ('여름', 15),
#  ('전', 15),
#  ('글', 15),
#  ('.....', 15),
#  ('^^', 15),
#  ('계절', 15),
#  ('학생', 15),
#  ('에게', 15),
#  ('양', 15),
#  ('22', 15),
#  (',,', 15),
#  ('곳', 15),
#  ('올려주세요', 15),
#  ('공기', 14),
#  ('상승', 14),
#  ('큰', 14),
#  ('운', 14),
#  ('저희', 14),
#  ('또', 14),
#  ('급해요', 14),
#  ('15', 14),
#  ('적어주세요', 14),
#  ('내용', 14),
#  ('04', 14),
#  ('고사성어', 14),
#  ('16', 14),
#  ('겁니다', 14),
#  ('fool', 14),
#  ('바보', 14),
#  ('에는', 13),
#  ('특징', 13),
#  ('무더운', 13),
#  ('문', 13),
#  ('17', 13),
#  ('☞', 13),
#  ('비유', 13),
#  ('부탁드립니다', 13),
#  ('그래서', 13),
#  (';;', 13),
#  ('조금', 13),
#  ('*', 13),
#  ('cloud', 13),
#  ('열대', 13),
#  ('이라', 12),
#  ('역사', 12),
#  ('식', 12),
#  ('모두', 12),
#  ('냠냠', 12),
#  ('드림', 12),
#  ('되', 12),
#  ('시험', 12),
#  ('유명한', 12),
#  ('28', 12),
#  ('2008.06', 12),
#  ('새털', 12),
#  ('내', 12),
#  ('2007.12', 12),
#  ('방콕', 12),
#  ('지면', 11),
#  ('온도', 11),
#  ('먹고', 11),
#  ('60', 11),
#  ('18', 11),
#  ('부탁드려요', 11),
#  ('감사하겠습니다', 11),
#  ('겨울', 11),
#  ('음식점', 11),
#  ('03', 11),
#  ('23', 11),
#  ('없는', 11),
#  ('국어', 11),
#  ('25', 11),
#  ('감사', 11),
#  ('우리', 11),
#  ('조', 11),
#  ('나무', 11),
#  ('13', 11),
#  ('몫', 11),
#  ('문화', 11),
#  ('몸', 11),
#  ('동', 11),
#  ('태양', 10),
#  ('볕', 10),
#  ('높아져', 10),
#  ('같이', 10),
#  ('베트남', 10),
#  ('_', 10),
#  ('많고', 10),
#  ('처럼', 10),
#  ('그리고', 10),
#  ('도와주세요', 10),
#  ('에서는', 10),
#  ('캐나다', 10),
#  ('오', 10),
#  ('위', 10),
#  ('어', 10),
#  (')...', 10),
#  ('개정', 10),
#  ('24', 10),
#  ('??', 10),
#  ('신고', 10),
#  ('필수', 10),
#  ('관용', 10),
#  ('2010.01', 10),
#  ('~~', 10),
#  ('27', 10),
#  ('개좀', 10),
#  ('해안', 10),
#  ('★', 10),
#  ('명', 10),
#  ('란', 10),
#  ('단', 10),
#  ('이번', 10),
#  ('그런데', 10),
#  ('hotel', 10),
#  ('2008.01', 10),
#  ('발음', 10),
#  ('모습', 10),
#  ('유래', 9),
#  ('간다', 9),
#  ('지식인', 9),
#  ('09', 9),
#  ('최대한', 9),
#  ('보', 9),
#  ('세계', 9),
#  ('현재', 9),
#  ('대만', 9),
#  ('지구', 9),
#  ('29', 9),
#  ('ㅜㅜ', 9),
#  ('가는', 9),
#  ('등등', 9),
#  ('맑은', 9),
#  ('어려운', 9),
#  ('초', 9),
#  ('2011.05', 9),
#  ('인데요', 9),
#  ('대륙', 9),
#  ('러시아', 9),
#  ('해양', 9),
#  ('담고', 9),
#  ('직하게', 9),
#  ('반죽', 9),
#  ('수저', 9),
#  ('한자', 9),
#  ('강', 9),
#  ('성', 9),
#  ('대한', 9),
#  ('밖에', 9),
#  ('달', 9),
#  ('오후', 9),
#  ('89', 9),
#  ('구', 9),
#  ('여자', 9),
#  ('"', 9),
#  ('진짜', 9),
#  ('club', 9),
#  ('클럽', 9),
#  ('호텔', 9),
#  ('세', 9),
#  ('박', 9),
#  ('지금', 8),
#  ('해야', 8),
#  ('이름', 8),
#  ('스시', 8),
#  ('사는', 8),
#  ('전국', 8),
#  ('대도시', 8),
#  ('각국', 8),
#  ('향항', 8),
#  ('해주시', 8),
#  ('낀', 8),
#  ('먹는다', 8),
#  ('2008.08', 8),
#  ('이렇게', 8),
#  ('),', 8),
#  ('관계', 8),
#  ('적어', 8),
#  ('저기압', 8),
#  ('가르쳐', 8),
#  ('!!!', 8),
#  ('알아야', 8),
#  ('해요', 8),
#  ('같은', 8),
#  ('방법', 8),
#  ('중국인', 8),
#  ('하', 8),
#  ('01', 8),
#  ('시작', 8),
#  ('지학사', 8),
#  ('afternoon', 8),
#  ('people', 8),
#  ('해산', 8),
#  ('산모', 8),
#  ('해주었던', 8),
#  ('보릿가루', 8),
#  ('염', 8),
#  ('이런', 8),
#  ('일이', 8),
#  ('class', 8),
#  ('형', 8),
#  ('분', 8),
#  ('□', 8),
#  ('hour', 8),
#  ('wjdd', 8),
#  ('14', 7),
#  ('왜', 7),
#  ('11', 7),
#  ('이르는', 7),
#  ('여행', 7),
#  ('+', 7),
#  ('식물', 7),
#  ('라는', 7),
#  ('기름', 7),
#  ('열', 7),
#  ('적어서', 7),
#  ('대하', 7),
#  ('일기', 7),
#  ('해석', 7),
#  ('오기', 7),
#  ('알려주세여', 7),
#  ('정말', 7),
#  ('도움', 7),
#  ('예절', 7),
#  ('·', 7),
#  ('9', 7),
#  ('7', 7),
#  ('2008.04', 7),
#  ('먹는', 7),
#  ('조사해', 7),
#  ('~!', 7),
#  ('짧은', 7),
#  ('이건', 7),
#  ('있는데', 7),
#  ('비오는', 7),
#  ('하면', 7),
#  ('야할', 7),
#  ('02', 7),
#  ('듯', 7),
#  ('중학생', 7),
#  ('개월', 7),
#  ('국가', 7),
#  ('초등학생', 7),
#  ('coast', 7),
#  ('오면', 7),
#  ('dhle', 7),
#  ('김', 7),
#  ('명언', 7),
#  ('어떻게', 7),
#  ('8', 7),
#  ('점', 7),
#  ('번', 7),
#  ('이스라엘', 7),
#  ('가게', 7),
#  ('새', 7),
#  ('ㅜ', 6),
#  ('용', 6),
#  ('더', 6),
#  ('?...', 6),
#  ('분야', 6),
#  ('의식주', 6),
#  ('11월', 6),
#  ('아시아', 6),
#  ('이유', 6),
#  ('드려요', 6),
#  ('수도', 6),
#  ('바늘', 6),
#  ('실', 6),
#  ('가고', 6),
#  ('함께', 6),
#  ('님들', 6),
#  ('삼', 6),
#  ('여러분', 6),
#  ('안녕하세여', 6),
#  ('이랑', 6),
#  ('▷', 6),
#  ('시', 6),
#  ('사', 6),
#  ('ag', 6),
#  ('되요', 6),
#  ('주시', 6),
#  ('랑', 6),
#  ('문제', 6),
#  ('강수량', 6),
#  ('쪽', 6),
#  ('날시에', 6),
#  ('ethn', 6),
#  ('이라는', 6),
#  ('덩어리', 6),
#  ('내리는', 6),
#  ('부분', 6),
#  ('나오는', 6),
#  ('햄스터', 6),
#  ('......', 6),
#  ('ㅋ', 6),
#  ('거의', 6),
#  ('밤', 6),
#  ('되도록', 6),
#  ('저가', 6),
#  ('총', 6),
#  ('몇개', 6),
#  ('외워', 6),
#  ('자료', 6),
#  ('않고', 6),
#  ('중간고사', 6),
#  ('외워야', 6),
#  ('교과서', 6),
#  ('좋은', 6),
#  ('학원', 6),
#  ('우리말', 6),
#  ('알려', 6),
#  ('이에요', 6),
#  ('300', 6),
#  ('낱말', 6),
#  ('1000', 6),
#  ('따라', 6),
#  ('14일', 6),
#  ('격언', 6),
#  ('famous', 6),
#  ('수업', 6),
#  ('):', 6),
#  ('먹은', 6),
#  ('같지도', 6),
#  ('않다는', 6),
#  ('부지런하면', 6),
#  ('2008.02', 6),
#  ('90', 6),
#  ('last', 6),
#  ('month', 6),
#  ('학급', 6),
#  ('|', 6),
#  ('07', 6),
#  ('연안', 6),
#  ('팍팍', 6),
#  ('200', 6),
#  ('훌륭한', 6),
#  ('죽어', 6),
#  ('~!!!', 6),
#  ('ㅇ', 6),
#  ('처음', 6),
#  ('천자문', 6),
#  ('님', 6),
#  ('태국', 6),
#  ('주점', 6),
#  ('갖가지', 6),
#  ('기념품', 6),
#  ('덤핑', 6),
#  ('위만', 6),
#  ('멕', 6),
#  ('궁전', 6),
#  ('라마', 6),
#  ('펼쳐진', 6),
#  ('남아시아', 6),
#  ('최대', 6),
#  ('거리', 6),
#  ('혼잡하면서도', 6),
#  ('파타야', 6),
#  ('우선', 6),
#  ('순위', 6),
#  ('그런', 5),
#  ('변화', 5),
#  ('대부분', 5),
#  ('풍부', 5),
#  ('ryul', 5),
#  ('설', 5),
#  ('대표', 5),
#  ('2012.07', 5),
#  ('영향', 5),
#  ('추천', 5),
#  ('땅', 5),
#  ('가르쳐주세요', 5),
#  ('제목', 5),
#  ('=', 5),
#  ('08', 5),
#  ('유', 5),
#  ('전통', 5),
#  ('2005.06', 5),
#  ('씩', 5),
#  ('다음', 5),
#  ('하루', 5),
#  ('켜주세요', 5),
#  ('하는데요', 5),
#  ('좀더', 5),
#  ('걸', 5),
#  ('토박이', 5),
#  ('학교숙제', 5),
#  ('답', 5),
#  ('한글', 5),
#  ('되는데', 5),
#  ('급', 5),
#  ('한국', 5),
#  ('있으면', 5),
#  ('정보', 5),
#  ('싶습니다', 5),
#  ('초등', 5),
#  ('컬러', 5),
#  ('푸드', 5),
#  ('Color', 5),
#  ('Food', 5),
#  ('건강', 5),
#  ('효과', 5),
#  ('수분', 5),
#  ('저온', 5),
#  ('고온', 5),
#  ('반복', 5),
#  ('커져', 5),
#  ('말함', 5),
#  ('진눈깨비', 5),
#  ('차가운', 5),
#  ('종류', 5),
#  ('쓰이는', 5),
#  ('야', 5),
#  ('드립니다', 5),
#  ('찾아주세요', 5),
#  ('흑', 5),
#  ('2010.02', 5),
#  ('비구름', 5),
#  ('강수', 5),
#  ('순', 5),
#  ('2008.10', 5),
#  ('이라고', 5),
#  ('2013.06', 5),
#  ('21', 5),
#  ('식당', 5),
#  ('기름진', 5),
#  ('8월', 5),
#  ('2010.04', 5),
#  ('빨리요', 5),
#  ('모양', 5),
#  ('..-_-', 5),
#  ('수준', 5),
#  ('끝', 5),
#  ('급함', 5),
#  ('129', 5),
#  ('130', 5),
#  ('419', 5),
#  ('420', 5),
#  ('2007.03', 5),
#  ('죽고', 5),
#  ('줄거리', 5),
#  ('^', 5),
#  ('256', 5),
#  ('257', 5),
#  ('487', 5),
#  ('488', 5),
#  ('foolish', 5),
#  ('636', 5),
#  ('637', 5),
#  ('시각', 5),
#  ('아직', 5),
#  ('바', 5),
#  ('거든요', 5),
#  (".'", 5),
#  ('들면', 5),
#  ('한울', 5),
#  ('복', 5),
#  ('보기', 5),
#  ('추석', 5),
#  ('이란', 5),
#  ('pilh', 5),
#  ('일정', 5),
#  ('폼첩쿤', 5),
#  ('5일', 5),
#  ('2009.07', 5),
#  ('쉽게', 5),
#  ('외우는', 5),
#  (';;;', 5),
#  ('외우기', 5),
#  ('갈', 4),
#  ('아무리', 4),
#  ('없고', 4),
#  ('카드', 4),
#  ('특히', 4),
#  ('밭', 4),
#  ('강우량', 4),
#  ('낮아', 4),
#  ('지형', 4),
#  ('흰자', 4),
#  ('여서', 4),
#  ('쓰키미', 4),
#  ('붙었다', 4),
#  ('일본음식', 4),
#  ('전래', 4),
#  ('거슬러', 4),
#  ('올라가면', 4),
#  ('동남', 4),
#  ('산지', 4),
#  ('이기', 4),
#  ('우기', 4),
#  ('써주시면', 4),
#  ('무척', 4),
#  ('지다', 4),
#  ('관광', 4),
#  ('아니다', 4),
#  ('2014.01', 4),
#  ('요리', 4),
#  ('나서', 4),
#  ('찬', 4),
#  ('숙젠데', 4),
#  ('가장', 4),
#  ('하기', 4),
#  ('간단한', 4),
#  ('2008.05', 4),
#  ('봉동읍', 4),
#  ('ltah', 4),
#  ('그러는데', 4),
#  ('알수', 4),
#  ('있을까요', 4),
#  ('라서', 4),
#  ('나타나면', 4),
#  ('권적운', 4),
#  ('의미', 4),
#  ('하며', 4),
#  ('접근', 4),
#  ('따뜻한', 4),
#  ('사투리', 4),
#  ('혹시', 4),
#  ('뜻좀', 4),
#  ('생각', 4),
#  ('머리', 4),
#  ('께', 4),
#  ('알려주시면', 4),
#  ('살', 4),
#  ('다른', 4),
#  ('2007.10', 4),
#  ('대기오염', 4),
#  ('려', 4),
#  ('그럼', 4),
#  ('주민', 4),
#  ('별로', 4),
#  ('있는데요', 4),
#  ('한테', 4),
#  ('2010.08', 4),
#  ('올', 4),
#  ('니', 4),
#  ('변', 4),
#  ('.......', 4),
#  ('소금', 4),
#  ('간', 4),
#  ('사전', 4),
#  ('오래', 4),
#  ('하지', 4),
#  ('지리', 4),
#  ('추운', 4),
#  ('검', 4),
#  ('비단', 4),
#  ('에만', 4),
#  ('국한', 4),
#  ('되지', 4),
#  ('맛', 4),
#  ('따라서', 4),
#  ('보면', 4),
#  ('56%', 4),
#  ('28%', 4),
#  ('볼거리', 4),
#  ('할려고', 4),
#  ('2009.10', 4),
#  ('써', 4),
#  ('쓴다고', 4),
#  ('2008.07', 4),
#  ('들어', 4),
#  ('ㄳ', 4),
#  ('자전', 4),
#  ('특산', 4),
#  ('되어', 4),
#  ('13:10', 4),
#  ('l', 4),
#  ('박정연', 4),
#  ('planet', 4),
#  ('u', 4),
#  ('당국', 4),
#  ('해외', 4),
#  ('운영', 4),
#  ('스파이', 4),
#  ('통일', 4),
#  ('진정한', 4),
#  ('광복', 4),
#  ('평양', 4),
#  ('향', 4),
#  ('2013년', 4),
#  ('발', 4),
#  ('거구', 4),
#  ('월령', 4),
#  ('정확하게', 4),
#  ('44', 4),
#  ('108', 4),
#  ('있어요', 4),
#  ('돈', 4),
#  ('a', 4),
#  ('매운', 4),
#  ('흐린', 4),
#  ('볼', 4),
#  ('직접', 4),
#  ('짐승', 4),
#  ('고기', 4),
#  ('만든', 4),
#  ('맛있는', 4),
#  ('없', 4),
#  ('공', 4),
#  ('2011.01', 4),
#  ('동안', 4),
#  ('290', 4),
#  ('291', 4),
#  ('코', 4),
#  (',..', 4),
#  ('해주시길', 4),
#  ('이구', 4),
#  ('여름방학', 4),
#  ('ebs', 4),
#  ('백', 4),
#  ('채택', 4),
#  ('순서', 4),
#  ('읽는', 4),
#  ('갑니다', 4),
#  ('브라질', 4),
#  ('05', 4),
#  ('cloudy', 4),
#  ('여우', 4),
#  ('아주', 4),
#  ('2010.05', 4),
#  ('위인', 4),
#  ('남긴', 4),
#  ('없어요', 4),
#  ('농업', 4),
#  ('주셔도', 4),
#  ('되고', 4),
#  ('펌', 4),
#  ('짧게', 4),
#  ('②', 4),
#  ('식생', 4),
#  ('밀림', 4),
#  ('정글', 4),
#  ('사바나', 4),
#  ('입음', 4),
#  ('과일', 4),
#  ('향신료', 4),
#  ('개방', 4),
#  ('형성', 4),
#  ('④', 4),
#  ('초딩', 4),
#  ('원', 4),
#  ('없어서', 4),
#  ('상식', 4),
#  ('사고', 4),
#  ('자가', 4),
#  ('엄마', 4),
#  ('가르', 4),
#  ('4일', 4),
#  ('자유여행', 4),
#  ('요약', 4),
#  ('상의', 4),
#  ('자준', 4),
#  ('상대', 4),
#  ('숙어', 4),
#  ('심판', 4),
#  ('세계대전', 4),
#  ('지상천국', 4),
#  ('뿌리', 4),
#  ('뽑힌', 4),
#  ('열매', 4),
#  ('01:13', 4),
#  ('전북', 4),
#  ('e', 4),
#  ('스쿨', 4),
#  ('니까', 3),
#  ('雲', 3),
#  ('계', 3),
#  ('자연', 3),
#  ('개발', 3),
#  ('주제', 3),
#  ('있다', 3),
#  ('유럽', 3),
#  ('다니는', 3),
#  ('특성', 3),
#  ('&', 3),
#  ('2012.11', 3),
#  ('♥', 3),
#  ('!!!!!!!!', 3),
#  ('홍보', 3),
#  ('발표', 3),
#  ('2018.10', 3),
#  ('말고', 3),
#  ('그러나', 3),
#  ('일본인', 3),
#  ('일상', 3),
#  ('맞는', 3),
#  ('ㄱ', 3),
#  ('2006.03', 3),
#  ('높이', 3),
#  ('2009.04', 3),
#  ('특색', 3),
#  ('2009.08', 3),
#  ('악', 3),
#  ('불평', 3),
#  ('쉬운', 3),
#  ('무엇', 3),
#  ('많을수록', 3),
#  ('o', 3),
#  ('봄', 3),
#  ('이라도', 3),
#  ('되면', 3),
#  ('woni', 3),
#  ('기상', 3),
#  ('요소', 3),
#  ('별', 3),
#  (',.', 3),
#  ('빼고', 3),
#  ('.....................', 3),
#  ('정어리', 3),
#  ('맑음', 3),
#  ('사하나', 3),
#  ('폭풍', 3),
#  ('징조', 3),
#  ('불', 3),
#  ('지역별', 3),
#  ('겨울방학', 3),
#  ('만들기', 3),
#  ('만들어야', 3),
#  ('2011.07', 3),
#  ('쯤', 3),
#  ('근데', 3),
#  ('될', 3),
#  ('모르겠네요', 3),
#  ('두', 3),
#  ('적어주시면', 3),
#  ('ㄷㄷ', 3),
#  (';[', 3),
#  ('할것', 3),
#  ('오지', 3),
#  ('않는', 3),
#  ('에선', 3),
#  ('수질오염', 3),
#  ('원인', 3),
#  ('성의', 3),
#  ('마시는', 3),
#  ('→', 3),
#  ('써오라고', 3),
#  ('추가', 3),
#  ('수행평가', 3),
#  ('기말고사', 3),
#  ('수학', 3),
#  ('따른', 3),
#  ('배우는', 3),
#  ('에요', 3),
#  ('글자', 3),
#  ('지역', 3),
#  ('EBS', 3),
#  ('부', 3),
#  ('히', 3),
#  ('십', 3),
#  ('빨', 3),
#  ('리좀', 3),
#  ('2015.07', 3),
#  ('두고', 3),
#  ('와서요', 3),
#  ('주인', 3),
#  ('계속', 3),
#  ('자꾸', 3),
#  ('급해서요', 3),
#  ('같아서요', 3),
#  ('인가요', 3),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9642 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9642 missing from current font.
#   font.load_char(ord(s), flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
