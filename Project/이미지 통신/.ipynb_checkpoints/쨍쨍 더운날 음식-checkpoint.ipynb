# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('쨍쨍 더운 날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('쨍쨍 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('쨍쨍 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('쨍쨍 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('쨍쨍 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('쨍쨍 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '뭉게구름',
#  '이',
#  '생기',
#  '면',
#  '날씨',
#  '가',
#  '맑다',
#  '?',
#  '2003.06',
#  '.',
#  '14',
#  '.',
#  '뭉게구름',
#  '이',
#  '생기',
#  '면',
#  '날씨',
#  '가',
#  '맑다는데요',
#  '.',
#  '.',
#  '.',
#  '왜',
#  '그런',
#  '겁',
#  '니까',
#  '?',
#  '알려주세요',
#  '⌒⌒',
#  '답변',
#  '여름',
#  '의',
#  '뜨거운',
#  '태양',
#  '볕',
#  '에',
#  '지면',
#  '의',
#  '온도',
#  '가',
#  '높아져',
#  '이',
#  '것',
#  '의',
#  '공기',
#  '가',
#  '상승',
#  '하여',
#  '큰',
#  '구름',
#  '을',
#  '...',
#  '이',
#  '것',
#  '을',
#  '산이',
#  '운다고',
#  '하는데',
#  ',',
#  '이',
#  '소리',
#  '가',
#  '날',
#  '정도',
#  '로',
#  '강한',
#  '바람',
#  '이면',
#  '산',
#  '을',
#  '넘으려고',
#  '산',
#  '을',
#  '...',
#  '질문',
#  '구름',
#  '이',
#  '날씨',
#  '에',
#  '미치는',
#  '영향',
#  '..[',
#  '내공',
#  '팍팍',
#  ']',
#  '2008.02',
#  '.',
#  '02',
#  '.',
#  '탐구',
#  '보고서',
#  '를',
#  '작성',
#  '하려고',
#  '하는데요',
#  '주제가',
#  '구름',
#  '이',
#  '날씨',
#  '에',
#  '끼치는',
#  '영향',
#  '이',
#  '거든요',
#  '근데',
#  '실험',
#  '과정',
#  '하고',
#  '결과',
#  '를',
#  '뭘',
#  '해야',
#  '될지',
#  '모르겠어요',
#  '아시',
#  '는',
#  '분',
#  '은',
#  '답변',
#  '좀',
#  '..',
#  '꼭',
#  '부탁',
#  '제발',
#  '답변',
#  '㉣',
#  '더운',
#  '날',
#  ':',
#  '얇은',
#  '옷',
#  '을',
#  '입고',
#  '차고',
#  '시원한',
#  '음식',
#  '을',
#  '찾게',
#  '되며',
#  '땀',
#  '이',
#  '많이',
#  '나',
#  '기',
#  '분',
#  '이',
#  '...',
#  '높았던',
#  '날',
#  ':',
#  '5월',
#  '21일',
#  '입니다',
#  '.',
#  '날씨',
#  ':',
#  '기온',
#  '은',
#  '25',
#  '도',
#  '이고',
#  '구름',
#  '한',
#  '점',
#  '없이',
#  '맑으며',
#  '남동풍',
#  '이',
#  '...',
#  '닉네임',
#  'proj',
#  '****',
#  '질문',
#  '7월',
#  '24일',
#  '날',
#  '싱가포르',
#  '에',
#  '큰아버지',
#  '직',
#  '2019.06',
#  '.',
#  '25',
#  '.',
#  '7월',
#  '24일',
#  '날',
#  '싱가포르',
#  '에',
#  '큰아버지',
#  '직장',
#  '이',
#  '있어',
#  '중',
#  '3',
#  '2',
#  '명',
#  '중',
#  '1',
#  '1',
#  '명',
#  '에서',
#  '놀러',
#  '갑니다',
#  '어른',
#  '동반',
#  '안',
#  '하고요',
#  '큰아버지',
#  '도',
#  '직장',
#  '이',
#  '있어',
#  '바쁘셔서',
#  '우리',
#  '에게',
#  '돌아다니라는데',
#  '...',
#  '답변',
#  '카페',
#  '들',
#  '이',
#  '많음',
#  ')',
#  '차이나타운',
#  'China',
#  'Town',
#  '(',
#  '싱가포르',
#  '에서',
#  '...',
#  '더운',
#  '날',
#  '에는',
#  '가시',
#  '지',
#  '않는',
#  '것',
#  '을',
#  '추천',
#  '드리며',
#  '유료',
#  '...',
#  '한국인',
#  '들',
#  '이',
#  '딱',
#  '좋아할',
#  '입맛',
#  '의',
#  '갈비탕',
#  '같은',
#  '음식',
#  '입니다',
#  '...',
#  '닉네임',
#  '다벡',
#  '질문',
#  '중국',
#  '의',
#  '음식',
#  '문화',
#  '에',
#  '대하',
#  '여',
#  '.',
#  '2016.10',
#  '.',
#  '19',
#  '.',
#  '제',
#  '가',
#  '학교',
#  '에서',
#  '프로젝트',
#  '로',
#  '중국',
#  '의',
#  '음식',
#  '문화',
#  '를',
#  '알아가야',
#  '합니다',
#  '!',
#  '중국',
#  '의',
#  '음식',
#  '문화',
#  '답변',
#  '부탁드립니다',
#  '~',
#  '채',
#  '택시',
#  '내공',
#  '70',
#  '드리겠습니다',
#  '~',
#  '(',
#  '주의',
#  ':',
#  '내공',
#  '을',
#  '노리는',
#  '허',
#  '접',
#  '한',
#  '답변',
#  '시',
#  '...',
#  '답변',
#  '凉菜',
#  ')',
#  '와',
#  '더운',
#  '음식',
#  '을',
#  '적절히',
#  '조정',
#  '하고',
#  '간단히',
#  '밥',
#  '이나',
#  '...',
#  '또한',
#  '지역',
#  '에',
#  '따라서',
#  '차이',
#  '가',
#  '많',
#  '음',
#  '을',
#  '알',
#  '수',
#  '있다',
#  '.',
#  '2',
#  ')...',
#  '그런데',
#  '어느',
#  '날',
#  '저',
#  '우',
#  '총리',
#  '가',
#  '그',
#  '를',
#  '초청',
#  '하여',
#  '만찬',
#  '을',
#  '베풀었고',
#  '...',
#  '닉네임',
#  '지구별',
#  '슈퍼맨',
#  '질문',
#  '중국',
#  '의',
#  '음식',
#  '2016.10',
#  '.',
#  '21',
#  '.',
#  '중국',
#  '의',
#  '음식',
#  '은',
#  '뭐',
#  '가',
#  '있나요',
#  '?(',
#  '사진',
#  '첨부',
#  ')',
#  '급해요',
#  '숙제',
#  '가',
#  '내일',
#  '까지',
#  '예요',
#  '.',
#  '답변',
#  '凉菜',
#  ')',
#  '와',
#  '더운',
#  '음식',
#  '을',
#  '적절히',
#  '조정',
#  '하고',
#  '간단히',
#  '밥',
#  '이나',
#  '...',
#  '또한',
#  '지역',
#  '에',
#  '따라서',
#  '차이',
#  '가',
#  '많',
#  '음',
#  '을',
#  '알',
#  '수',
#  '있다',
#  '.',
#  '2',
#  ')...',
#  '그런데',
#  '어느',
#  '날',
#  '저',
#  '우',
#  '총리',
#  '가',
#  '그',
#  '를',
#  '초청',
#  '하여',
#  '만찬',
#  '을',
#  '베풀었고',
#  '...',
#  '닉네임',
#  '지구별',
#  '슈퍼맨',
#  '질문',
#  '한국말',
#  '영어',
#  '로',
#  '번역',
#  '해주세요',
#  '내공',
#  '많음',
#  '2010.09',
#  '.',
#  '05',
#  '.',
#  '옛',
#  '부터',
#  '우리나라',
#  '사람',
#  '들',
#  '은',
#  '날씨',
#  '가',
#  '매우',
#  '더운',
#  '날',
#  '그',
#  '더위',
#  '를',
#  '물리',
#  '치기',
#  '위',
#  '하여',
#  '...',
#  '예',
#  '를',
#  '들어',
#  '그',
#  '들',
#  '은',
#  '햄버거',
#  ',',
#  '피자',
#  '와',
#  '같은',
#  '패스트푸드',
#  '음식',
#  '을',
#  '많이',
#  '먹는다',
#  '.',
#  '특히',
#  '...',
#  '답변',
#  '1',
#  ')',
#  'To',
#  'Korea',
#  'very',
#  'there',
#  'is',
#  'a',
#  'custom',
#  'which',
#  'is',
#  'special',
#  '.',
#  'It',
#  'rightly',
#  'the',
#  'dog',
#  'meat',
#  'the',
#  'ink',
#  'is',
#  'the',
#  'thing',
#  '.',
#  'From',
#  'the',
#  'old',
#  'our',
#  'country',
#  'people',
#  'ate',
#  'and',
#  'in',
#  'order',
#  'to',
#  '...',
#  '닉네임',
#  '유혹',
#  '질문',
#  '제주도',
#  '3',
#  '박',
#  '4일',
#  '여행',
#  '빠른',
#  '답변',
#  '부탁드립니다',
#  '.',
#  '(',
#  '내공',
#  '많음',
#  '100',
#  ')',
#  '2017.06',
#  '.',
#  '30',
#  '.',
#  '이',
#  '날',
#  '부터',
#  '숙소',
#  '를',
#  '성산',
#  '근처',
#  '로',
#  '2',
#  '박',
#  '잡아서',
#  '짐놓고',
#  '섭지코지',
#  '성산일출봉',
#  '둘러보는',
#  '...',
#  '먹고',
#  '오고',
#  '싶은',
#  '음식',
#  '은',
#  '우선',
#  '회',
#  '센터',
#  '같은',
#  '곳',
#  '에서',
#  '저렴하게',
#  '회랑',
#  '낙시',
#  '소라',
#  '전복',
#  '등',
#  '...',
#  '답변',
#  '먹고',
#  '오고',
#  '싶은',
#  '음식',
#  '은',
#  '우선',
#  '회',
#  '센터',
#  '같은',
#  '곳',
#  '에서',
#  '저렴하게',
#  '회랑',
#  '낙시',
#  '소라',
#  '전복',
#  '등',
#  '...',
#  '용두암',
#  '/',
#  '용',
#  '연',
#  '구름다리',
#  ',',
#  '신비의도로',
#  '관광지',
#  ':',
#  '러브랜드',
#  '(',
#  '야간',
#  '명소',
#  ')',
#  '맛집',
#  ':',
#  '은희',
#  '네',
#  '해장국',
#  '...',
#  '닉네임',
#  '플레이',
#  '케이팝',
#  '질문',
#  '독일',
#  '의',
#  '음식',
#  '에',
#  '대해',
#  '서',
#  '...',
#  '2010.01',
#  '.',
#  '13',
#  '.',
#  '독일',
#  '의',
#  '음식',
#  '에',
#  '대해',
#  '서',
#  '알려주세요',
#  '...',
#  '빨리요',
#  '...',
#  '답변',
#  '음식',
#  '보다는',
#  '더운',
#  '음식',
#  '을',
#  '즐기며',
#  '특히',
#  '점심시간',
#  '에',
#  '...',
#  '맥주',
#  '소',
#  '비량',
#  '이',
#  '많음',
#  '-',
#  '전세계',
#  '에서',
#  '맥주',
#  '소',
#  '비량',
#  '이',
#  '최고',
#  '인',
#  '...',
#  '맛일',
#  '날',
#  '때',
#  '까지',
#  '2-3일',
#  '간',
#  '발효',
#  '시킨',
#  '것',
#  '이다',
#  '.',
#  '이외',
#  '에도',
#  '붉은',
#  '...',
#  '닉네임',
#  'ocam',
#  '****',
#  '질문',
#  '안개',
#  '와',
#  '구름',
#  '의',
#  '특징',
#  '좀',
#  '...',
#  '2008.08',
#  '.',
#  '13',
#  '.',
#  '안개',
#  '와',
#  '구름',
#  '의',
#  '특징',
#  '들',
#  '좀',
#  '알려주세요',
#  '...',
#  '차이점',
#  '이나',
#  '공통점',
#  '은',
#  '필요',
#  '없는데',
#  '...',
#  '특징',
#  '들',
#  '만',
#  '해주시',
#  '고',
#  '그래서',
#  '결론',
#  '은',
#  '또',
#  '요약',
#  '도',
#  '해',
#  '주시',
#  '면',
#  '내공',
#  '팍팍',
#  '!!',
#  '답변',
#  '찬',
#  '공기',
#  '가',
#  '더운',
#  '공기',
#  '밑',
#  '을',
#  '파고',
#  '들면서',
#  '더운',
#  '공기',
#  '를',
#  '상승',
#  '시킬',
#  '경우',
#  '...',
#  '때',
#  '가',
#  '많음',
#  '.',
#  '종전',
#  '에는',
#  '하층',
#  '운',
#  '으로',
#  '취급',
#  '하던',
#  '어',
#  '두운',
#  '흑색',
#  '의',
#  '구름',
#  '으로서',
#  '비',
#  '오기',
#  '전',
#  '에',
#  '나타나서',
#  '형태',
#  '가',
#  '...',
#  '닉네임',
#  'rhtk',
#  '****',
#  '질문',
#  '구름',
#  '의',
#  '종류',
#  '(',
#  '사진',
#  '도',
#  '포함',
#  ')',
#  '2009.09',
#  '.',
#  '25',
#  '.',
#  '관찰',
#  '대상',
#  '은',
#  '구름',
#  '의',
#  '종류',
#  '이고',
#  ',',
#  '기간',
#  '은',
#  '9월',
#  '27일',
#  '까지입니다',
#  '.',
#  '부탁',
#  '입니다',
#  '.',
#  '사진',
#  '도',
#  '...',
#  '제',
#  '가',
#  "'",
#  '내공',
#  "'",
#  '이라는',
#  '뜻',
#  '을',
#  '몰르거든요',
#  '.',
#  '그럼',
#  '구름',
#  '의',
#  '종류',
#  '와',
#  '사진',
#  '도',
#  '포함',
#  '해서',
#  '답변',
#  '부탁',
#  '합니다',
#  '답변',
#  '구름',
#  '이',
#  '형성',
#  '된',
#  '것',
#  '으로',
#  '높은',
#  '하늘',
#  '을',
#  '비행기',
#  '가',
#  '날',
#  '경우',
#  '...',
#  '응결',
#  '되면서',
#  '구름',
#  '생',
#  '성',
#  ')',
#  '4',
#  '.',
#  '찬',
#  '공기',
#  '가',
#  '더운',
#  '공기',
#  '밑',
#  '을',
#  '...',
#  '때',
#  '가',
#  '많음',
#  '.',
#  '종전',
#  '에는',
#  '하층',
#  '운',
#  '으로',
#  '취급',
#  '하던',
#  '어',
#  '두운',
#  '흑색',
#  '의',
#  '...',
#  '닉네임',
#  'star',
#  '****',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '구름',
#  '종류',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='쨍쨍 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='쨍쨍 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='쨍쨍 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='쨍쨍 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='쨍쨍 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='쨍쨍 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 92272
# 9522

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 4018),
#  ('...', 3056),
#  ('이', 1900),
#  ('을', 1586),
#  (',', 1489),
#  ('에', 1345),
#  ('가', 1292),
#  ('답변', 1089),
#  ('의', 1055),
#  ('질문', 1055),
#  ('를', 979),
#  ('음식', 949),
#  ('닉네임', 931),
#  ('(', 828),
#  ('구름', 774),
#  ('더운', 771),
#  (')', 728),
#  (':', 718),
#  ('단어', 680),
#  ('은', 668),
#  ('****', 556),
#  ('것', 522),
#  ('는', 487),
#  ('날', 460),
#  ('좀', 448),
#  ('하는', 408),
#  ('검색', 404),
#  ('로', 388),
#  ('으로', 379),
#  ('도', 366),
#  ('한', 364),
#  ('속담', 350),
#  ('과', 338),
#  ('때', 334),
#  ('개', 315),
#  ('들', 308),
#  ('입력', 300),
#  ('..', 298),
#  ('요', 283),
#  ('비', 280),
#  ('많음', 272),
#  ('내공', 266),
#  ('알려주세요', 259),
#  ('말', 259),
#  ('12', 258),
#  ('에서', 254),
#  ('1', 230),
#  ('사람', 220),
#  ('제', 217),
#  ('날씨', 214),
#  ('뜻', 214),
#  ('하세요', 212),
#  ('등', 212),
#  ('된', 209),
#  ('와', 209),
#  ('포함', 208),
#  ('月', 208),
#  ('다', 207),
#  ('?', 198),
#  ('....', 198),
#  ('에는', 197),
#  ('기', 187),
#  ('운', 187),
#  ('합니다', 185),
#  ('안', 183),
#  ('나', 173),
#  ('~', 169),
#  ('-', 167),
#  ('많이', 164),
#  ('고', 164),
#  ('해서', 162),
#  ('할', 153),
#  ('영어', 153),
#  ('입니다', 152),
#  ('음', 151),
#  ('/', 150),
#  ('학년', 144),
#  ('중', 143),
#  ('2', 142),
#  ('이상', 140),
#  ('이나', 138),
#  ('음력', 136),
#  ('3', 135),
#  ('사주', 134),
#  ('숙제', 133),
#  ('하나', 129),
#  ('사용', 128),
#  ('여러', 127),
#  ('수', 127),
#  ('산', 125),
#  ('가고', 125),
#  ('게', 125),
#  ('차고', 124),
#  ('나라', 122),
#  ('많', 119),
#  ('까지', 118),
#  ('5', 118),
#  ('!', 117),
#  ('100', 117),
#  ('만', 116),
#  ('인데', 116),
#  ('바깥', 116),
#  ('☞', 115),
#  ('건강', 115),
#  ('반드시', 114),
#  ('그', 114),
#  ('가지', 114),
#  ('우리', 113),
#  ('저', 113),
#  ('햄스터', 111),
#  ('기본', 110),
#  ('우리말', 110),
#  ('[', 109),
#  ('20', 109),
#  ('여름', 108),
#  ('정도', 108),
#  ('방', 108),
#  ('본', 107),
#  ('결과', 107),
#  ('초목', 107),
#  ('범위', 106),
#  ('성공', 106),
#  ('내려', 106),
#  ('여기', 106),
#  ('문장', 105),
#  ('차례', 105),
#  ('구분', 104),
#  ('30', 104),
#  ('클릭', 104),
#  ('제외', 103),
#  ('있으니', 103),
#  ('필시', 103),
#  ('거두게', 103),
#  ('인한', 103),
#  ('질병', 103),
#  ('조심하는', 103),
#  ('정확히', 102),
#  (']', 102),
#  ('부탁드립니다', 102),
#  ('못', 102),
#  ('상세', 101),
#  ('바람', 101),
#  ('하고', 101),
#  ('속', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('알', 100),
#  ('몸', 99),
#  ('해', 97),
#  ('포장', 97),
#  ('10', 93),
#  ('관련', 93),
#  ('있는', 92),
#  ('안녕하세요', 92),
#  ('아', 92),
#  ('열', 90),
#  ('인', 89),
#  ('만든', 89),
#  ('밥', 88),
#  ('!!', 88),
#  ('빨리', 88),
#  ('나무', 87),
#  ('부탁', 86),
#  ('하늘', 86),
#  ('적', 86),
#  ('해주세요', 83),
#  ('6', 83),
#  ('먹는', 82),
#  ('주세요', 81),
#  ('밤', 81),
#  ('찬', 80),
#  ('잘', 78),
#  ('여자', 78),
#  ('질', 78),
#  ('돌', 78),
#  ('될', 77),
#  ('마소', 77),
#  ('비비는', 77),
#  ('방학', 77),
#  ('면', 76),
#  ('4', 76),
#  ('생활', 76),
#  ('풀이', 76),
#  ('물', 76),
#  ('짓', 75),
#  ('과학', 74),
#  ('순우리말', 73),
#  ('"', 73),
#  ('위', 72),
#  ('ㅠㅠ', 71),
#  ('하여', 70),
#  ('여', 70),
#  ('곳', 70),
#  ('쓰는', 70),
#  ('우리나라', 69),
#  ('●', 69),
#  ('아웃백', 69),
#  ('대해', 68),
#  ('사자성어', 68),
#  ('모두', 68),
#  ('예', 67),
#  ('서', 67),
#  ('그리고', 67),
#  ('소리', 66),
#  ('저녁', 66),
#  ("'", 65),
#  ('추천', 64),
#  ('전', 64),
#  ('좋은', 64),
#  ('뜨거운', 63),
#  ('하는데', 63),
#  ('이다', 63),
#  ('메뉴', 63),
#  ('분', 61),
#  ('일', 61),
#  ('너무', 61),
#  ('hot', 61),
#  ('피', 60),
#  ('순대', 60),
#  ('없이', 59),
#  ('간', 59),
#  ('고사성어', 59),
#  ('양력', 59),
#  ('돼지', 59),
#  ('8', 59),
#  ('공기', 58),
#  ('지', 58),
#  ('50', 58),
#  ('오늘', 58),
#  ('한다', 58),
#  ('섞어서', 58),
#  ('삶아', 58),
#  ('꼭', 57),
#  ('파골집', 57),
#  ('창자', 57),
#  ('하면', 57),
#  ('이면', 56),
#  ('거의', 56),
#  ('16', 56),
#  ('음식물', 56),
#  ('같은', 55),
#  ('학교', 55),
#  ('),', 55),
#  (';', 55),
#  ('눈', 54),
#  ('기운', 54),
#  ('걱정', 54),
#  ('맛', 53),
#  ('^^', 53),
#  ('따위', 53),
#  ('25', 52),
#  (')...', 52),
#  ('11', 52),
#  ('.....', 52),
#  ('양', 52),
#  ('사회', 52),
#  ('자', 52),
#  ('밑', 51),
#  ('17', 51),
#  ('ㅇ', 51),
#  ('많은', 50),
#  ('계속', 50),
#  ('랑', 49),
#  ('제발', 48),
#  ('13', 48),
#  ('부탁드려요', 48),
#  ('거', 48),
#  ('데', 48),
#  ('24', 47),
#  ('하', 47),
#  ('맑은', 47),
#  ('18', 47),
#  ('!!!', 47),
#  ('식사', 46),
#  ('다수', 46),
#  ('26', 46),
#  ('다른', 46),
#  ('15', 46),
#  ('시간', 46),
#  ('아래', 46),
#  ('먼지', 46),
#  ('야채', 46),
#  ('점', 45),
#  ('서쪽', 45),
#  ('겨울', 45),
#  ('19', 44),
#  ('이름', 44),
#  ('봐주세요', 44),
#  ('집', 44),
#  ('관', 44),
#  ('맑아서', 44),
#  ('정리', 44),
#  ('대부분', 44),
#  ('모르는', 44),
#  ('14', 43),
#  ('좋아', 43),
#  ('차', 43),
#  ('다량', 43),
#  ('여행', 42),
#  ('써주세요', 42),
#  ('선생님', 42),
#  ('어떤', 42),
#  ('조사', 42),
#  ('소금', 42),
#  ('빵', 42),
#  ('사이드', 42),
#  ('감자', 42),
#  ('모이는', 41),
#  ('까닭', 41),
#  ('으', 41),
#  ('가능', 41),
#  ('료', 41),
#  ('깬', 41),
#  ('강한', 40),
#  ('넘으려고', 40),
#  ('한자', 40),
#  ('지금', 40),
#  ('명절', 40),
#  ('더', 40),
#  ('있고', 40),
#  ('~~', 40),
#  ('남으면', 40),
#  ('은근', 40),
#  ('벗음', 40),
#  ('통감', 40),
#  ('감자칩', 40),
#  ('볶음밥', 40),
#  ('Jade', 40),
#  ('BWK', 40),
#  ('29', 39),
#  ('남자', 39),
#  ('맛있는', 39),
#  ('요점', 39),
#  ('식', 39),
#  ('ethn', 39),
#  ('98', 39),
#  ('내일', 38),
#  ('갈', 38),
#  ('끼', 38),
#  ('??', 38),
#  ('하다', 38),
#  ('2008.03', 38),
#  ('학기', 38),
#  ('한답니다', 38),
#  ('특징', 37),
#  ('경우', 37),
#  ('09', 37),
#  ('유래', 37),
#  ('처럼', 37),
#  ('순', 37),
#  ('아름다운', 37),
#  ('단원', 37),
#  ('사다리타기', 37),
#  ('간혹', 37),
#  ('묘기', 37),
#  ('부리곤', 37),
#  ('중국', 36),
#  ('그런데', 36),
#  ('걸', 36),
#  ('雲', 36),
#  ('조금', 36),
#  ('*', 36),
#  ('노을', 36),
#  ('구름다리', 35),
#  ('이랑', 35),
#  ('갑자기', 35),
#  ('있다', 34),
#  ('어느', 34),
#  ('그래서', 34),
#  ('해석', 34),
#  ('0', 34),
#  ('계절', 34),
#  ('오면', 34),
#  ('열대', 34),
#  ('영향', 33),
#  ('뭐', 33),
#  ('부터', 33),
#  ('제주도', 33),
#  ('박', 33),
#  ('종류', 33),
#  ('마음', 33),
#  ('겁니다', 33),
#  ('설사', 33),
#  ('사투리', 33),
#  ('•', 33),
#  ('기온', 32),
#  ('ㅠ', 32),
#  ('부지런해야', 32),
#  ('고유어', 32),
#  ('시험', 32),
#  ('^', 32),
#  ('주', 32),
#  ('방법', 32),
#  ('31', 32),
#  ('책', 32),
#  ('성', 31),
#  ('이렇게', 31),
#  ('없는', 31),
#  ('지식인', 31),
#  ('적어주세요', 31),
#  ('거지', 31),
#  ('되다가', 31),
#  ('추워지면', 31),
#  ('02', 30),
#  ('땀', 30),
#  ('05', 30),
#  ('최대한', 30),
#  ('글', 30),
#  ('28', 30),
#  ('때문', 30),
#  ('27', 30),
#  ('놀이', 30),
#  ('고기', 30),
#  ('농가월령가', 30),
#  ('대', 30),
#  ('얼음', 30),
#  ('근데', 29),
#  ('이고', 29),
#  ('명', 29),
#  ('입', 29),
#  ('간다', 29),
#  ('之', 29),
#  ('오후', 29),
#  ('03', 29),
#  ('이번', 29),
#  ('내', 29),
#  ('예쁜', 29),
#  ('않고', 29),
#  ('요리', 29),
#  ('기후', 29),
#  ('sunny', 29),
#  ('비치는', 29),
#  ('21', 28),
#  ('두', 28),
#  ('04', 28),
#  ('23', 28),
#  ('같이', 28),
#  ('가르쳐', 28),
#  ('검은', 28),
#  ('07', 28),
#  ('<', 28),
#  ('7', 28),
#  ('가을', 28),
#  (';;', 28),
#  ('냠냠', 28),
#  ('영', 28),
#  ('있음', 28),
#  ('산이', 27),
#  ('해야', 27),
#  ('에게', 27),
#  ('9월', 27),
#  ('라', 27),
#  ('분야', 27),
#  ('06', 27),
#  ('오전', 27),
#  ('학생', 27),
#  ('정말', 27),
#  ('구', 27),
#  ('가는', 27),
#  ('급해요', 26),
#  ('또', 26),
#  ('얻어먹는다', 26),
#  ('전통', 26),
#  ('다시', 26),
#  ('08', 26),
#  ('드립니다', 26),
#  ('채택', 26),
#  ('달', 26),
#  ('의미', 26),
#  ('아이', 26),
#  ('배', 26),
#  ('내용', 26),
#  ('위해', 26),
#  ('섭취', 26),
#  ('food', 26),
#  ('바로', 26),
#  ('천자문', 26),
#  ('미치는', 25),
#  ('옷', 25),
#  ('7월', 25),
#  ('감사하겠습니다', 25),
#  ('생각', 25),
#  ('22', 25),
#  ('문제', 25),
#  ('문', 25),
#  ('모양', 25),
#  ('한글', 25),
#  ('무엇', 25),
#  ('공부', 25),
#  ('물건', 25),
#  ('형식', 25),
#  ('조심', 25),
#  ('저희', 25),
#  ('씩', 25),
#  ('기행문', 25),
#  ('중학교', 25),
#  ('이런', 25),
#  ('plenty', 25),
#  ('care', 25),
#  ('문화', 24),
#  ('생', 24),
#  ('도와주세요', 24),
#  ('ㅜㅜ', 24),
#  ('낀', 24),
#  ('인지', 24),
#  ('떡', 24),
#  ('먹어', 24),
#  ('cloud', 24),
#  ('국어', 24),
#  ('새벽', 24),
#  ('표현', 24),
#  ('온난전선', 24),
#  ('②', 24),
#  ('화창한', 24),
#  ('222', 24),
#  ('223', 24),
#  ('meal', 24),
#  ('224', 24),
#  ('시원한', 23),
#  ('5월', 23),
#  ('지역', 23),
#  ('차이', 23),
#  ('특히', 23),
#  ('소', 23),
#  ('01', 23),
#  ('님', 23),
#  ('이제', 23),
#  ('일기', 23),
#  ('쪽', 23),
#  ('어떻게', 23),
#  ('대한', 23),
#  ('봄', 23),
#  ('초', 23),
#  ('2008.04', 23),
#  ('들면', 23),
#  ('가르쳐주세요', 23),
#  ('신고', 23),
#  ('이야기', 23),
#  ('초등학교', 23),
#  ('쯤되면', 23),
#  ('시', 22),
#  ('우', 22),
#  ('사진', 22),
#  ('9', 22),
#  ('그냥', 22),
#  ('11월', 22),
#  ('에요', 22),
#  ('이라', 22),
#  ('알려', 22),
#  ('웹툰', 22),
#  ('새끼', 22),
#  ('반', 22),
#  ('℃', 22),
#  ('있습니다', 22),
#  ('염', 22),
#  ('단순히', 22),
#  ('먹을', 22),
#  ('비유', 22),
#  ('관용', 22),
#  ('가마', 22),
#  ('살려라', 22),
#  ('치움을', 22),
#  ('즉', 22),
#  ('->', 22),
#  ('ㅎ', 22),
#  ('운다고', 21),
#  ('네', 21),
#  ('어', 21),
#  ('변화', 21),
#  ('세계', 21),
#  ('거리', 21),
#  ('머', 21),
#  ('따라', 21),
#  ('마시면', 21),
#  ('>', 21),
#  ('모', 21),
#  ('=', 21),
#  ('중간고사', 21),
#  ('함', 21),
#  ('전파', 21),
#  ('속도', 21),
#  ('원리', 21),
#  ('경계', 21),
#  ('솥', 21),
#  ('더러', 21),
#  ('검정', 21),
#  ('얼마나', 21),
#  ('진미', 21),
#  ('lot', 21),
#  ('하는데요', 20),
#  ('21일', 20),
#  ('4일', 20),
#  ('먹고', 20),
#  ('함께', 20),
#  ('에서는', 20),
#  ('없고', 20),
#  ('매', 20),
#  ('8월', 20),
#  ('아침', 20),
#  ('운동', 20),
#  ('운세', 20),
#  ('2020.04', 20),
#  ('ㅋ', 20),
#  ('먹지', 20),
#  ('하지만', 20),
#  ('흰', 20),
#  ('고기압', 20),
#  ('2011.07', 20),
#  ('가장', 20),
#  ('절대온도', 20),
#  ('몇', 20),
#  ('올려주세요', 20),
#  ('감추듯', 20),
#  ('허겁지겁', 20),
#  (',,', 20),
#  ('오는', 20),
#  ('훌륭한', 20),
#  ('있나요', 19),
#  ('에도', 19),
#  ('기초', 19),
#  ('ㅜ', 19),
#  ('라는', 19),
#  ('......', 19),
#  ('길게', 19),
#  ('요즘', 19),
#  ('정보', 19),
#  ('|', 19),
#  ('되도록', 19),
#  ('진짜', 19),
#  ('비용', 19),
#  ('오사카', 19),
#  ('아주', 19),
#  ('여러가지', 19),
#  ('되고', 19),
#  ('마을', 19),
#  ('밖에', 19),
#  ('가옥', 19),
#  ('걸음', 19),
#  ('달아날', 19),
#  ('조급한', 19),
#  ('2014.11', 19),
#  ('석빙고', 19),
#  ('왜', 18),
#  ('태양', 18),
#  ('얇은', 18),
#  ('더위', 18),
#  ('ocam', 18),
#  ('정', 18),
#  ('언제나', 18),
#  ('이르는', 18),
#  ('①', 18),
#  ('매지', 18),
#  ('금은', 18),
#  ('전체', 18),
#  ('있으면', 18),
#  ('김치', 18),
#  ('되는', 18),
#  ('일본', 18),
#  ('드림', 18),
#  ('등등', 18),
#  ('한국', 18),
#  ('자리', 18),
#  ('해요', 18),
#  ('코스', 18),
#  ('ㅋㅋ', 18),
#  ('실', 18),
#  ('세', 18),
#  ('봉동읍', 18),
#  ('ltah', 18),
#  ('권내', 18),
#  ('무더운', 18),
#  ('장', 18),
#  ('water', 18),
#  ('고유', 18),
#  ('할인', 18),
#  ('그런', 17),
#  ('상승', 17),
#  ('㉣', 17),
#  ('입고', 17),
#  ('찾게', 17),
#  ('되며', 17),
#  ('맑으며', 17),
#  ('남동풍', 17),
#  ('매우', 17),
#  ('먹는다', 17),
#  ('맛집', 17),
#  ('개도', 17),
#  ('단', 17),
#  ('이유', 17),
#  ('조각', 17),
#  ('맑음', 17),
#  ('보리', 17),
#  ('이구', 17),
#  ('꽃', 17),
#  ('인데요', 17),
#  ('쯤', 17),
#  ('한번', 17),
#  ('라고', 17),
#  ('친구', 17),
#  ('신', 17),
#  ('하기', 17),
#  ('여름철', 17),
#  ('끝', 17),
#  ('·', 17),
#  ('만큼', 17),
#  ('급한', 17),
#  ('나오는', 17),
#  ('친척', 17),
#  ('대접', 17),
#  ('노력', 17),
#  ('해달라고', 17),
#  ('고량', 17),
#  ('雨', 17),
#  ('높았던', 16),
#  ('2008.08', 16),
#  ('2020.06', 16),
#  ('속뜻', 16),
#  ('않은', 16),
#  ('궁합', 16),
#  ('ㅡ', 16),
#  ('내내', 16),
#  ('1일', 16),
#  ('은하', 16),
#  ('바', 16),
#  ('백', 16),
#  ('있을까요', 16),
#  ('식품', 16),
#  ('궁금합니다', 16),
#  ('후', 16),
#  ('~!', 16),
#  ('주문', 16),
#  ('북한', 16),
#  ('2019.09', 16),
#  ('답', 16),
#  ('조', 16),
#  ('떠', 16),
#  ('소화', 16),
#  ('삼', 16),
#  ('량', 16),
#  ('k', 16),
#  ('ag', 16),
#  ('바보', 16),
#  ('발', 16),
#  ('결', 16),
#  ('경상도', 16),
#  ('2008.01', 16),
#  ('망운', 16),
#  ('지정', 16),
#  ('정글', 16),
#  ('오를', 16),
#  ('이를', 16),
#  ('치', 16),
#  ('아니라도', 16),
#  ('큰', 15),
#  ('채', 15),
#  ('들어', 15),
#  ('용', 15),
#  ('연', 15),
#  ('빨리요', 15),
#  ('2010.04', 15),
#  ('말고', 15),
#  ('되지기', 15),
#  ('얹어', 15),
#  ('찌거나', 15),
#  ('자세하게', 15),
#  ('살', 15),
#  ('김', 15),
#  ('글자', 15),
#  ('감사', 15),
#  ('본문', 15),
#  ('먹거리', 15),
#  ('남북', 15),
#  ('30분', 15),
#  ('결혼', 15),
#  ('있는데', 15),
#  ('보다', 15),
#  ('니', 15),
#  ('일정', 15),
#  ('2009.08', 15),
#  ('모습', 15),
#  ('관계', 15),
#  ('인가요', 15),
#  ('저기압', 15),
#  ('~~~', 15),
#  ('2009.04', 15),
#  ('비오는', 15),
#  ('음식점', 15),
#  ('현대', 15),
#  ('처음', 15),
#  ('라서', 15),
#  ('적어', 15),
#  ('2012.04', 15),
#  ('기록', 15),
#  ('하루', 15),
#  ('자세히', 15),
#  ('coat', 15),
#  ('히', 15),
#  ('부분', 15),
#  ('2007.12', 15),
#  ('곡식', 15),
#  ('클럽', 15),
#  ('강수량', 15),
#  ('심어', 15),
#  ('騰', 15),
#  ('致', 15),
#  ('수증기', 15),
#  ('맞으면', 15),
#  ('채운다', 15),
#  ('飽', 15),
#  ('니까', 14),
#  ('발효', 14),
#  ('3일', 14),
#  ('일이', 14),
#  ('2월', 14),
#  ('많고', 14),
#  ('2020.03', 14),
#  ('라면', 14),
#  ('있어요', 14),
#  ('갈증', 14),
#  ('칼', 14),
#  ('40', 14),
#  ('곡', 14),
#  ('별로', 14),
#  ('할아버지', 14),
#  ('목연', 14),
#  ('에만', 14),
#  ('2006.01', 14),
#  ('시나', 14),
#  ('브로', 14),
#  ('보고', 14),
#  ('사', 14),
#  ('놈', 14),
#  ('온', 14),
#  ('새', 14),
#  ('베트남', 14),
#  ('조상', 14),
#  ('맑을', 14),
#  ('올려', 14),
#  ('어려운', 14),
#  ('그러므로', 14),
#  ('식당', 14),
#  ('994', 14),
#  ('알려주세여', 14),
#  ('fool', 14),
#  ('조사해', 14),
#  ('하지', 14),
#  ('얼마', 14),
#  ('갓', 14),
#  ('수학', 14),
#  ('있는데요', 14),
#  ('마리', 14),
#  ('능', 14),
#  ('싣고', 14),
#  ('지어', 14),
#  ('베어', 14),
#  ('갈이', 14),
#  ('밀', 14),
#  ('보세', 14),
#  ('끝끝', 14),
#  ('익어도', 14),
#  ('간단히', 13),
#  ('따라서', 13),
#  ('해주시', 13),
#  ('그럼', 13),
#  ('계', 13),
#  ('情', 13),
#  ('캐', 13),
#  ('께', 13),
#  ('1월', 13),
#  ('2일', 13),
#  ('&', 13),
#  ('3월', 13),
#  ('소녀', 13),
#  ('조부', 13),
#  ('준결승', 13),
#  ('보이는', 13),
#  ('유명한', 13),
#  ('했는데', 13),
#  ('아는', 13),
#  ('몇개', 13),
#  ('12월', 13),
#  ('법', 13),
#  ('직업', 13),
#  ('사이', 13),
#  ('발음', 13),
#  ('④', 13),
#  ('현재', 13),
#  ('시작', 13),
#  ('설명', 13),
#  ('군사', 13),
#  ('알리기', 13),
#  ('모아서', 13),
#  ('듯', 13),
#  ('대표', 13),
#  ('카드', 13),
#  ('번', 13),
#  ('없다', 13),
#  ('주변', 13),
#  ('자주', 13),
#  ('내부', 13),
#  ('빼내는', 13),
#  ('일종', 13),
#  ('아치로', 13),
#  ('보냈다는', 13),
#  ('용도', 13),
#  ('특색', 13),
#  ('가서', 13),
#  ('형', 13),
#  ('준다는', 13),
#  ('오', 13),
#  ('서울', 13),
#  ('좋아하는', 13),
#  ('바랄', 13),
#  ('논', 13),
#  ('지나가는', 13),
#  ('고립무원', 13),
#  ('膏梁珍味', 13),
#  ('뭉게뭉게', 13),
#  ('미쳐', 13),
#  ('뉘', 13),
#  ('하려니와', 13),
#  ('나네', 13),
#  ('방아', 13),
#  ('찧어', 13),
#  ('밥살', 13),
#  ('별명', 13),
#  ('탐구', 12),
#  ('거든요', 12),
#  ('아시', 12),
#  ('적절히', 12),
#  ('숙소', 12),
#  ('이라는', 12),
#  ('형성', 12),
#  ('신분', 12),
#  ('4월', 12),
#  ('좋습니다', 12),
#  ('만드는', 12),
#  ('노래', 12),
#  ('새참', 12),
#  ('핵심', 12),
#  ('태어난', 12),
#  ('엄마', 12),
#  ('없어서', 12),
#  ('먹기', 12),
#  ('싸움', 12),
#  ('싸', 12),
#  ('이라도', 12),
#  ('땅', 12),
#  ('검', 12),
#  ('인가', 12),
#  ('금', 12),
#  ('아직', 12),
#  (',.', 12),
#  ('10시', 12),
#  ('내리는', 12),
#  ('순서', 12),
#  ('부녀자', 12),
#  ('2019.10', 12),
#  ('되지', 12),
#  ('수행평가', 12),
#  ('놀은', 12),
#  ('한랭전선', 12),
#  ('샘', 12),
#  ('없음', 12),
#  ('맛있게', 12),
#  ('교', 12),
#  ('공', 12),
#  ('2007.07', 12),
#  ('필수', 12),
#  ('마당', 12),
#  ('2009.03', 12),
#  ('켜주세요', 12),
#  ('∼', 12),
#  ('지역별', 12),
#  ('거적', 12),
#  ('깔개', 12),
#  ('참나무', 12),
#  ('엷게', 12),
#  ('밀어서', 12),
#  ('지장', 12),
#  ('2010.08', 12),
#  ('수능', 12),
#  ('望', 12),
#  ('망', 12),
#  ('83', 12),
#  ('멍', 12),
#  ('대거', 12),
#  ('빼기', 12),
#  ('방축', 12),
#  ('꾼', 12),
#  ('비구름', 12),
#  ('강수', 12),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='쨍쨍 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='쨍쨍 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='쨍쨍 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='쨍쨍 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='쨍쨍 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='쨍쨍 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [('음식', 949),
#  ('닉네임', 931),
#  ('(', 828),
#  ('구름', 774),
#  ('더운', 771),
#  (')', 728),
#  (':', 718),
#  ('****', 556),
#  ('날', 460),
#  ('검색', 404),
#  ('속담', 350),
#  ('개', 315),
#  ('입력', 300),
#  ('비', 280),
#  ('많음', 272),
#  ('내공', 266),
#  ('알려주세요', 259),
#  ('말', 259),
#  ('12', 258),
#  ('에서', 254),
#  ('사람', 220),
#  ('날씨', 214),
#  ('뜻', 214),
#  ('하세요', 212),
#  ('등', 212),
#  ('된', 209),
#  ('와', 209),
#  ('포함', 208),
#  ('月', 208),
#  ('에는', 197),
#  ('기', 187),
#  ('운', 187),
#  ('합니다', 185),
#  ('안', 183),
#  ('나', 173),
#  ('-', 167),
#  ('많이', 164),
#  ('해서', 162),
#  ('영어', 153),
#  ('입니다', 152),
#  ('음', 151),
#  ('/', 150),
#  ('학년', 144),
#  ('이나', 138),
#  ('음력', 136),
#  ('3', 135),
#  ('사주', 134),
#  ('숙제', 133),
#  ('사용', 128),
#  ('여러', 127),
#  ('산', 125),
#  ('가고', 125),
#  ('차고', 124),
#  ('나라', 122),
#  ('많', 119),
#  ('까지', 118),
#  ('5', 118),
#  ('!', 117),
#  ('100', 117),
#  ('만', 116),
#  ('바깥', 116),
#  ('☞', 115),
#  ('건강', 115),
#  ('반드시', 114),
#  ('그', 114),
#  ('가지', 114),
#  ('우리', 113),
#  ('저', 113),
#  ('햄스터', 111),
#  ('우리말', 110),
#  ('[', 109),
#  ('여름', 108),
#  ('정도', 108),
#  ('방', 108),
#  ('본', 107),
#  ('결과', 107),
#  ('초목', 107),
#  ('범위', 106),
#  ('성공', 106),
#  ('내려', 106),
#  ('여기', 106),
#  ('문장', 105),
#  ('차례', 105),
#  ('구분', 104),
#  ('30', 104),
#  ('클릭', 104),
#  ('제외', 103),
#  ('있으니', 103),
#  ('필시', 103),
#  ('거두게', 103),
#  ('인한', 103),
#  ('질병', 103),
#  ('조심하는', 103),
#  ('정확히', 102),
#  (']', 102),
#  ('부탁드립니다', 102),
#  ('상세', 101),
#  ('바람', 101),
#  ('하고', 101),
#  ('속', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('알', 100),
#  ('몸', 99),
#  ('해', 97),
#  ('포장', 97),
#  ('관련', 93),
#  ('안녕하세요', 92),
#  ('아', 92),
#  ('열', 90),
#  ('인', 89),
#  ('만든', 89),
#  ('밥', 88),
#  ('빨리', 88),
#  ('나무', 87),
#  ('부탁', 86),
#  ('하늘', 86),
#  ('적', 86),
#  ('해주세요', 83),
#  ('먹는', 82),
#  ('주세요', 81),
#  ('밤', 81),
#  ('찬', 80),
#  ('여자', 78),
#  ('질', 78),
#  ('돌', 78),
#  ('될', 77),
#  ('마소', 77),
#  ('비비는', 77),
#  ('방학', 77),
#  ('면', 76),
#  ('4', 76),
#  ('생활', 76),
#  ('풀이', 76),
#  ('물', 76),
#  ('짓', 75),
#  ('과학', 74),
#  ('순우리말', 73),
#  ('"', 73),
#  ('위', 72),
#  ('ㅠㅠ', 71),
#  ('하여', 70),
#  ('여', 70),
#  ('곳', 70),
#  ('쓰는', 70),
#  ('우리나라', 69),
#  ('●', 69),
#  ('아웃백', 69),
#  ('대해', 68),
#  ('사자성어', 68),
#  ('모두', 68),
#  ('예', 67),
#  ('서', 67),
#  ('그리고', 67),
#  ('소리', 66),
#  ('저녁', 66),
#  ("'", 65),
#  ('추천', 64),
#  ('전', 64),
#  ('좋은', 64),
#  ('뜨거운', 63),
#  ('하는데', 63),
#  ('이다', 63),
#  ('메뉴', 63),
#  ('분', 61),
#  ('너무', 61),
#  ('hot', 61),
#  ('피', 60),
#  ('순대', 60),
#  ('없이', 59),
#  ('간', 59),
#  ('고사성어', 59),
#  ('양력', 59),
#  ('돼지', 59),
#  ('8', 59),
#  ('공기', 58),
#  ('50', 58),
#  ('오늘', 58),
#  ('한다', 58),
#  ('섞어서', 58),
#  ('삶아', 58),
#  ('꼭', 57),
#  ('파골집', 57),
#  ('창자', 57),
#  ('하면', 57),
#  ('이면', 56),
#  ('거의', 56),
#  ('16', 56),
#  ('음식물', 56),
#  ('같은', 55),
#  ('학교', 55),
#  ('),', 55),
#  (';', 55),
#  ('눈', 54),
#  ('기운', 54),
#  ('걱정', 54),
#  ('맛', 53),
#  ('^^', 53),
#  ('따위', 53),
#  ('25', 52),
#  (')...', 52),
#  ('11', 52),
#  ('.....', 52),
#  ('양', 52),
#  ('사회', 52),
#  ('자', 52),
#  ('밑', 51),
#  ('17', 51),
#  ('ㅇ', 51),
#  ('많은', 50),
#  ('계속', 50),
#  ('랑', 49),
#  ('제발', 48),
#  ('13', 48),
#  ('부탁드려요', 48),
#  ('24', 47),
#  ('하', 47),
#  ('맑은', 47),
#  ('18', 47),
#  ('!!!', 47),
#  ('식사', 46),
#  ('다수', 46),
#  ('26', 46),
#  ('다른', 46),
#  ('15', 46),
#  ('시간', 46),
#  ('아래', 46),
#  ('먼지', 46),
#  ('야채', 46),
#  ('점', 45),
#  ('서쪽', 45),
#  ('겨울', 45),
#  ('19', 44),
#  ('이름', 44),
#  ('봐주세요', 44),
#  ('집', 44),
#  ('관', 44),
#  ('맑아서', 44),
#  ('정리', 44),
#  ('대부분', 44),
#  ('모르는', 44),
#  ('14', 43),
#  ('좋아', 43),
#  ('차', 43),
#  ('다량', 43),
#  ('여행', 42),
#  ('써주세요', 42),
#  ('선생님', 42),
#  ('조사', 42),
#  ('소금', 42),
#  ('빵', 42),
#  ('사이드', 42),
#  ('감자', 42),
#  ('모이는', 41),
#  ('까닭', 41),
#  ('으', 41),
#  ('가능', 41),
#  ('료', 41),
#  ('깬', 41),
#  ('강한', 40),
#  ('넘으려고', 40),
#  ('한자', 40),
#  ('지금', 40),
#  ('명절', 40),
#  ('더', 40),
#  ('있고', 40),
#  ('~~', 40),
#  ('남으면', 40),
#  ('은근', 40),
#  ('벗음', 40),
#  ('통감', 40),
#  ('감자칩', 40),
#  ('볶음밥', 40),
#  ('Jade', 40),
#  ('BWK', 40),
#  ('29', 39),
#  ('남자', 39),
#  ('맛있는', 39),
#  ('요점', 39),
#  ('식', 39),
#  ('ethn', 39),
#  ('98', 39),
#  ('내일', 38),
#  ('갈', 38),
#  ('끼', 38),
#  ('??', 38),
#  ('하다', 38),
#  ('2008.03', 38),
#  ('학기', 38),
#  ('한답니다', 38),
#  ('특징', 37),
#  ('경우', 37),
#  ('09', 37),
#  ('유래', 37),
#  ('처럼', 37),
#  ('순', 37),
#  ('아름다운', 37),
#  ('단원', 37),
#  ('사다리타기', 37),
#  ('간혹', 37),
#  ('묘기', 37),
#  ('부리곤', 37),
#  ('중국', 36),
#  ('그런데', 36),
#  ('걸', 36),
#  ('雲', 36),
#  ('조금', 36),
#  ('*', 36),
#  ('노을', 36),
#  ('구름다리', 35),
#  ('이랑', 35),
#  ('갑자기', 35),
#  ('있다', 34),
#  ('어느', 34),
#  ('그래서', 34),
#  ('해석', 34),
#  ('0', 34),
#  ('계절', 34),
#  ('오면', 34),
#  ('열대', 34),
#  ('영향', 33),
#  ('부터', 33),
#  ('제주도', 33),
#  ('박', 33),
#  ('종류', 33),
#  ('마음', 33),
#  ('겁니다', 33),
#  ('설사', 33),
#  ('사투리', 33),
#  ('•', 33),
#  ('기온', 32),
#  ('ㅠ', 32),
#  ('부지런해야', 32),
#  ('고유어', 32),
#  ('시험', 32),
#  ('^', 32),
#  ('방법', 32),
#  ('31', 32),
#  ('책', 32),
#  ('성', 31),
#  ('이렇게', 31),
#  ('없는', 31),
#  ('지식인', 31),
#  ('적어주세요', 31),
#  ('거지', 31),
#  ('되다가', 31),
#  ('추워지면', 31),
#  ('02', 30),
#  ('땀', 30),
#  ('05', 30),
#  ('최대한', 30),
#  ('글', 30),
#  ('28', 30),
#  ('때문', 30),
#  ('27', 30),
#  ('놀이', 30),
#  ('고기', 30),
#  ('농가월령가', 30),
#  ('얼음', 30),
#  ('근데', 29),
#  ('이고', 29),
#  ('명', 29),
#  ('입', 29),
#  ('간다', 29),
#  ('之', 29),
#  ('오후', 29),
#  ('03', 29),
#  ('이번', 29),
#  ('내', 29),
#  ('예쁜', 29),
#  ('않고', 29),
#  ('요리', 29),
#  ('기후', 29),
#  ('sunny', 29),
#  ('비치는', 29),
#  ('21', 28),
#  ('두', 28),
#  ('04', 28),
#  ('23', 28),
#  ('같이', 28),
#  ('가르쳐', 28),
#  ('검은', 28),
#  ('07', 28),
#  ('<', 28),
#  ('7', 28),
#  ('가을', 28),
#  (';;', 28),
#  ('냠냠', 28),
#  ('영', 28),
#  ('있음', 28),
#  ('산이', 27),
#  ('해야', 27),
#  ('에게', 27),
#  ('9월', 27),
#  ('라', 27),
#  ('분야', 27),
#  ('오전', 27),
#  ('학생', 27),
#  ('정말', 27),
#  ('구', 27),
#  ('가는', 27),
#  ('급해요', 26),
#  ('또', 26),
#  ('얻어먹는다', 26),
#  ('전통', 26),
#  ('다시', 26),
#  ('08', 26),
#  ('드립니다', 26),
#  ('채택', 26),
#  ('달', 26),
#  ('의미', 26),
#  ('아이', 26),
#  ('배', 26),
#  ('내용', 26),
#  ('위해', 26),
#  ('섭취', 26),
#  ('food', 26),
#  ('바로', 26),
#  ('천자문', 26),
#  ('미치는', 25),
#  ('옷', 25),
#  ('7월', 25),
#  ('감사하겠습니다', 25),
#  ('생각', 25),
#  ('22', 25),
#  ('문제', 25),
#  ('문', 25),
#  ('모양', 25),
#  ('한글', 25),
#  ('무엇', 25),
#  ('공부', 25),
#  ('물건', 25),
#  ('형식', 25),
#  ('조심', 25),
#  ('저희', 25),
#  ('씩', 25),
#  ('기행문', 25),
#  ('중학교', 25),
#  ('이런', 25),
#  ('plenty', 25),
#  ('care', 25),
#  ('문화', 24),
#  ('생', 24),
#  ('도와주세요', 24),
#  ('ㅜㅜ', 24),
#  ('낀', 24),
#  ('인지', 24),
#  ('떡', 24),
#  ('먹어', 24),
#  ('cloud', 24),
#  ('국어', 24),
#  ('새벽', 24),
#  ('표현', 24),
#  ('온난전선', 24),
#  ('②', 24),
#  ('화창한', 24),
#  ('222', 24),
#  ('223', 24),
#  ('meal', 24),
#  ('224', 24),
#  ('시원한', 23),
#  ('5월', 23),
#  ('지역', 23),
#  ('차이', 23),
#  ('특히', 23),
#  ('소', 23),
#  ('01', 23),
#  ('님', 23),
#  ('이제', 23),
#  ('일기', 23),
#  ('쪽', 23),
#  ('어떻게', 23),
#  ('대한', 23),
#  ('봄', 23),
#  ('초', 23),
#  ('2008.04', 23),
#  ('들면', 23),
#  ('가르쳐주세요', 23),
#  ('신고', 23),
#  ('이야기', 23),
#  ('초등학교', 23),
#  ('쯤되면', 23),
#  ('시', 22),
#  ('우', 22),
#  ('사진', 22),
#  ('9', 22),
#  ('그냥', 22),
#  ('11월', 22),
#  ('에요', 22),
#  ('이라', 22),
#  ('알려', 22),
#  ('웹툰', 22),
#  ('새끼', 22),
#  ('반', 22),
#  ('℃', 22),
#  ('있습니다', 22),
#  ('염', 22),
#  ('단순히', 22),
#  ('먹을', 22),
#  ('비유', 22),
#  ('관용', 22),
#  ('가마', 22),
#  ('살려라', 22),
#  ('치움을', 22),
#  ('즉', 22),
#  ('->', 22),
#  ('ㅎ', 22),
#  ('운다고', 21),
#  ('어', 21),
#  ('변화', 21),
#  ('세계', 21),
#  ('거리', 21),
#  ('머', 21),
#  ('따라', 21),
#  ('마시면', 21),
#  ('>', 21),
#  ('모', 21),
#  ('=', 21),
#  ('중간고사', 21),
#  ('함', 21),
#  ('전파', 21),
#  ('속도', 21),
#  ('원리', 21),
#  ('경계', 21),
#  ('솥', 21),
#  ('더러', 21),
#  ('검정', 21),
#  ('얼마나', 21),
#  ('진미', 21),
#  ('lot', 21),
#  ('하는데요', 20),
#  ('21일', 20),
#  ('4일', 20),
#  ('먹고', 20),
#  ('함께', 20),
#  ('에서는', 20),
#  ('없고', 20),
#  ('매', 20),
#  ('8월', 20),
#  ('아침', 20),
#  ('운동', 20),
#  ('운세', 20),
#  ('2020.04', 20),
#  ('ㅋ', 20),
#  ('먹지', 20),
#  ('하지만', 20),
#  ('흰', 20),
#  ('고기압', 20),
#  ('2011.07', 20),
#  ('가장', 20),
#  ('절대온도', 20),
#  ('몇', 20),
#  ('올려주세요', 20),
#  ('감추듯', 20),
#  ('허겁지겁', 20),
#  (',,', 20),
#  ('오는', 20),
#  ('훌륭한', 20),
#  ('있나요', 19),
#  ('에도', 19),
#  ('기초', 19),
#  ('ㅜ', 19),
#  ('라는', 19),
#  ('......', 19),
#  ('길게', 19),
#  ('요즘', 19),
#  ('정보', 19),
#  ('|', 19),
#  ('되도록', 19),
#  ('진짜', 19),
#  ('비용', 19),
#  ('오사카', 19),
#  ('아주', 19),
#  ('여러가지', 19),
#  ('되고', 19),
#  ('마을', 19),
#  ('밖에', 19),
#  ('가옥', 19),
#  ('걸음', 19),
#  ('달아날', 19),
#  ('조급한', 19),
#  ('2014.11', 19),
#  ('석빙고', 19),
#  ('왜', 18),
#  ('태양', 18),
#  ('얇은', 18),
#  ('더위', 18),
#  ('ocam', 18),
#  ('정', 18),
#  ('언제나', 18),
#  ('이르는', 18),
#  ('①', 18),
#  ('매지', 18),
#  ('금은', 18),
#  ('전체', 18),
#  ('있으면', 18),
#  ('김치', 18),
#  ('되는', 18),
#  ('일본', 18),
#  ('드림', 18),
#  ('등등', 18),
#  ('한국', 18),
#  ('자리', 18),
#  ('해요', 18),
#  ('코스', 18),
#  ('ㅋㅋ', 18),
#  ('실', 18),
#  ('세', 18),
#  ('봉동읍', 18),
#  ('ltah', 18),
#  ('권내', 18),
#  ('무더운', 18),
#  ('장', 18),
#  ('water', 18),
#  ('고유', 18),
#  ('할인', 18),
#  ('그런', 17),
#  ('상승', 17),
#  ('㉣', 17),
#  ('입고', 17),
#  ('찾게', 17),
#  ('되며', 17),
#  ('맑으며', 17),
#  ('남동풍', 17),
#  ('매우', 17),
#  ('먹는다', 17),
#  ('맛집', 17),
#  ('개도', 17),
#  ('단', 17),
#  ('이유', 17),
#  ('조각', 17),
#  ('맑음', 17),
#  ('보리', 17),
#  ('이구', 17),
#  ('꽃', 17),
#  ('인데요', 17),
#  ('쯤', 17),
#  ('한번', 17),
#  ('친구', 17),
#  ('신', 17),
#  ('하기', 17),
#  ('여름철', 17),
#  ('끝', 17),
#  ('·', 17),
#  ('만큼', 17),
#  ('급한', 17),
#  ('나오는', 17),
#  ('친척', 17),
#  ('대접', 17),
#  ('노력', 17),
#  ('해달라고', 17),
#  ('고량', 17),
#  ('雨', 17),
#  ('높았던', 16),
#  ('2008.08', 16),
#  ('2020.06', 16),
#  ('속뜻', 16),
#  ('않은', 16),
#  ('궁합', 16),
#  ('ㅡ', 16),
#  ('내내', 16),
#  ('1일', 16),
#  ('은하', 16),
#  ('바', 16),
#  ('백', 16),
#  ('있을까요', 16),
#  ('식품', 16),
#  ('궁금합니다', 16),
#  ('~!', 16),
#  ('주문', 16),
#  ('북한', 16),
#  ('2019.09', 16),
#  ('답', 16),
#  ('조', 16),
#  ('떠', 16),
#  ('소화', 16),
#  ('삼', 16),
#  ('량', 16),
#  ('k', 16),
#  ('ag', 16),
#  ('바보', 16),
#  ('발', 16),
#  ('결', 16),
#  ('경상도', 16),
#  ('2008.01', 16),
#  ('망운', 16),
#  ('지정', 16),
#  ('정글', 16),
#  ('오를', 16),
#  ('이를', 16),
#  ('치', 16),
#  ('아니라도', 16),
#  ('큰', 15),
#  ('채', 15),
#  ('들어', 15),
#  ('용', 15),
#  ('연', 15),
#  ('빨리요', 15),
#  ('2010.04', 15),
#  ('말고', 15),
#  ('되지기', 15),
#  ('얹어', 15),
#  ('찌거나', 15),
#  ('자세하게', 15),
#  ('살', 15),
#  ('김', 15),
#  ('글자', 15),
#  ('감사', 15),
#  ('본문', 15),
#  ('먹거리', 15),
#  ('남북', 15),
#  ('30분', 15),
#  ('결혼', 15),
#  ('있는데', 15),
#  ('보다', 15),
#  ('니', 15),
#  ('일정', 15),
#  ('2009.08', 15),
#  ('모습', 15),
#  ('관계', 15),
#  ('인가요', 15),
#  ('저기압', 15),
#  ('~~~', 15),
#  ('2009.04', 15),
#  ('비오는', 15),
#  ('음식점', 15),
#  ('현대', 15),
#  ('처음', 15),
#  ('라서', 15),
#  ('적어', 15),
#  ('2012.04', 15),
#  ('기록', 15),
#  ('하루', 15),
#  ('자세히', 15),
#  ('coat', 15),
#  ('히', 15),
#  ('부분', 15),
#  ('2007.12', 15),
#  ('곡식', 15),
#  ('클럽', 15),
#  ('강수량', 15),
#  ('심어', 15),
#  ('騰', 15),
#  ('致', 15),
#  ('수증기', 15),
#  ('맞으면', 15),
#  ('채운다', 15),
#  ('飽', 15),
#  ('니까', 14),
#  ('발효', 14),
#  ('3일', 14),
#  ('일이', 14),
#  ('2월', 14),
#  ('많고', 14),
#  ('2020.03', 14),
#  ('라면', 14),
#  ('있어요', 14),
#  ('갈증', 14),
#  ('칼', 14),
#  ('40', 14),
#  ('곡', 14),
#  ('별로', 14),
#  ('할아버지', 14),
#  ('목연', 14),
#  ('에만', 14),
#  ('2006.01', 14),
#  ('시나', 14),
#  ('브로', 14),
#  ('보고', 14),
#  ('사', 14),
#  ('놈', 14),
#  ('온', 14),
#  ('새', 14),
#  ('베트남', 14),
#  ('조상', 14),
#  ('맑을', 14),
#  ('올려', 14),
#  ('어려운', 14),
#  ('그러므로', 14),
#  ('식당', 14),
#  ('994', 14),
#  ('알려주세여', 14),
#  ('fool', 14),
#  ('조사해', 14),
#  ('하지', 14),
#  ('얼마', 14),
#  ('갓', 14),
#  ('수학', 14),
#  ('있는데요', 14),
#  ('마리', 14),
#  ('능', 14),
#  ('싣고', 14),
#  ('지어', 14),
#  ('베어', 14),
#  ('갈이', 14),
#  ('밀', 14),
#  ('보세', 14),
#  ('끝끝', 14),
#  ('익어도', 14),
#  ('간단히', 13),
#  ('따라서', 13),
#  ('해주시', 13),
#  ('그럼', 13),
#  ('계', 13),
#  ('情', 13),
#  ('캐', 13),
#  ('께', 13),
#  ('1월', 13),
#  ('2일', 13),
#  ('&', 13),
#  ('3월', 13),
#  ('소녀', 13),
#  ('조부', 13),
#  ('준결승', 13),
#  ('보이는', 13),
#  ('유명한', 13),
#  ('했는데', 13),
#  ('아는', 13),
#  ('몇개', 13),
#  ('12월', 13),
#  ('법', 13),
#  ('직업', 13),
#  ('사이', 13),
#  ('발음', 13),
#  ('④', 13),
#  ('현재', 13),
#  ('시작', 13),
#  ('설명', 13),
#  ('군사', 13),
#  ('알리기', 13),
#  ('모아서', 13),
#  ('듯', 13),
#  ('대표', 13),
#  ('카드', 13),
#  ('번', 13),
#  ('없다', 13),
#  ('주변', 13),
#  ('자주', 13),
#  ('내부', 13),
#  ('빼내는', 13),
#  ('일종', 13),
#  ('아치로', 13),
#  ('보냈다는', 13),
#  ('용도', 13),
#  ('특색', 13),
#  ('가서', 13),
#  ('형', 13),
#  ('준다는', 13),
#  ('오', 13),
#  ('서울', 13),
#  ('좋아하는', 13),
#  ('바랄', 13),
#  ('논', 13),
#  ('지나가는', 13),
#  ('고립무원', 13),
#  ('膏梁珍味', 13),
#  ('뭉게뭉게', 13),
#  ('미쳐', 13),
#  ('뉘', 13),
#  ('하려니와', 13),
#  ('나네', 13),
#  ('방아', 13),
#  ('찧어', 13),
#  ('밥살', 13),
#  ('별명', 13),
#  ('탐구', 12),
#  ('거든요', 12),
#  ('아시', 12),
#  ('적절히', 12),
#  ('숙소', 12),
#  ('이라는', 12),
#  ('형성', 12),
#  ('신분', 12),
#  ('4월', 12),
#  ('좋습니다', 12),
#  ('만드는', 12),
#  ('노래', 12),
#  ('새참', 12),
#  ('핵심', 12),
#  ('태어난', 12),
#  ('엄마', 12),
#  ('없어서', 12),
#  ('먹기', 12),
#  ('싸움', 12),
#  ('싸', 12),
#  ('이라도', 12),
#  ('땅', 12),
#  ('검', 12),
#  ('인가', 12),
#  ('금', 12),
#  ('아직', 12),
#  (',.', 12),
#  ('10시', 12),
#  ('내리는', 12),
#  ('순서', 12),
#  ('부녀자', 12),
#  ('2019.10', 12),
#  ('되지', 12),
#  ('수행평가', 12),
#  ('놀은', 12),
#  ('한랭전선', 12),
#  ('샘', 12),
#  ('없음', 12),
#  ('맛있게', 12),
#  ('교', 12),
#  ('공', 12),
#  ('2007.07', 12),
#  ('필수', 12),
#  ('마당', 12),
#  ('2009.03', 12),
#  ('켜주세요', 12),
#  ('∼', 12),
#  ('지역별', 12),
#  ('거적', 12),
#  ('깔개', 12),
#  ('참나무', 12),
#  ('엷게', 12),
#  ('밀어서', 12),
#  ('지장', 12),
#  ('2010.08', 12),
#  ('수능', 12),
#  ('望', 12),
#  ('망', 12),
#  ('83', 12),
#  ('멍', 12),
#  ('대거', 12),
#  ('빼기', 12),
#  ('방축', 12),
#  ('꾼', 12),
#  ('비구름', 12),
#  ('강수', 12),
#  ('스키', 12),
#  ('미소', 12),
#  ('순수한', 12),
#  ('가격', 12),
#  ('밀림', 12),
#  ('nhha', 12),
#  ('2014.12', 12),
#  ('백로', 12),
#  ('날아간다', 12),
#  ('정처', 12),
#  ('떠돌아다니는', 12),
#  ('거재두량', 12),
#  ('車載斗量', 12),
#  ('인재', 12),
#  ('썩', 12),
#  ('건곤', 12),
#  ('일색', 12),
#  ('살찐', 12),
#  ('팍팍', 11),
#  ('凉菜', 11),
#  ('조정', 11),
#  ('예요', 11),
#  ('a', 11),
#  ('the', 11),
#  ('2010.01', 11),
#  ('알려주시면', 11),
#  ('심장', 11),
#  ('제목', 11),
#  ('각', 11),
#  ('고갱', 11),
#  ('사물', 11),
#  ('타고', 11),
#  ('2008.07', 11),
#  ('과일', 11),
#  ('5일', 11),
#  ('성의', 11),
#  ('가족', 11),
#  ('그림', 11),
#  ('재', 11),
#  ('했다', 11),
#  ('2020.02', 11),
#  ('주위', 11),
#  ('어디', 11),
#  ('만약', 11),
#  ('남아', 11),
#  ('올해', 11),
#  ('있어서', 11),
#  ('해안', 11),
#  ('천', 11),
#  ('이며', 11),
#  ('이라고', 11),
#  ('주어', 11),
#  ('드려요', 11),
#  ('비단', 11),
#  ('국한', 11),
#  ('56%', 11),
#  ('28%', 11),
#  ('향기', 11),
#  ('2005.06', 11),
#  ('2019.08', 11),
#  ('불', 11),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65039 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32461 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33410 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20010 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27185 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9786 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27671 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 34810 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9673 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27809 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 30338 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33527 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26497 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20135 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23545 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32416 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28165 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9729 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 65039 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32461 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33410 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20010 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27185 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9786 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27671 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 34810 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 29612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9673 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27809 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32553 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 30338 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33527 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26497 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21442 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20135 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23545 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32416 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28165 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
""" 이미지로 마스킹하여 워드 크라우드 그리기 """

from wordcloud import ImageColorGenerator

mask = np.array(Image.open('./img/heart_image.jpg'))
image_colors=ImageColorGenerator(mask)
data = ko.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2,mask=mask, background_color ='white').generate_from_frequencies(dict(data))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud.recolor(color_func=image_colors))
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-283331afb443> in <module>
#       3 from wordcloud import ImageColorGenerator
#       4
# ----> 5 mask = np.array(Image.open('./img/heart_image.jpg'))
#       6 image_colors=ImageColorGenerator(mask)
#       7 data = ko.vocab().most_common(100)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: './img/heart_image.jpg'
