# %% [markdown]
# ## 네이버 지식IN 을 통한 검색을 워드클라우드
#
# - 물론 네이버 개발자 API를 이용하면 훨씬 빠르게 데이타를 가져올 수 있다
#
# - 간단하게 주소창의 주소로 크롤링한다.
#
# - 크롬 개발자모드에서 검색부분을 가져온다 ( 각 dl 태그 )

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %matplotlib inline

# 간단한 한글 폰드 등록
from matplotlib import rc
plt.rcParams['axes.unicode_minus']=False
rc('font', family='Malgun Gothic')

# %%
#1000 만개 정도의 검색 결과를 읽어온다.
# 첫번째 페이지 start=1, 두번째 페이지인 경우 start=11인거 확인한다.
# 웹 페이지 직접 접근 할 땐느 간단이 time.sleep()으로 요청을 간격적으로 한다.
# 시간이 10분 정도 소요되기에 상태바를 보여준다. ( tqdm.tqdm_notebook 이용)

from urllib.request import urlopen
from tqdm import tqdm_notebook

present_candi_text = []
present_candi_text1 = []
present_candi_text2 = []
present_candi_text3 = []
present_candi_text4 = []
present_candi_text5 = []

tmp1 = 'https://search.naver.com/search.naver?where=kin'
html = tmp1 + '&sm=tab_jum&ie=utf8&query={key_word}&kin_start={num}'


for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름 더운날 음식 한식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름 더운 날 음식 중식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text1.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름 더운 날 음식 일식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text2.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름 더운 날 음식 양식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text3.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름 더운 날 음식 분식')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text4.append(line.text)
    time.sleep(5)
for n in tqdm_notebook(range(1,1000,10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('구름 더운 날 음식 동남아')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        present_candi_text5.append(line.text)
    time.sleep(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:55: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
len(present_candi_text)
len(present_candi_text1)
len(present_candi_text2)
len(present_candi_text3)
len(present_candi_text4)
len(present_candi_text5)
# Out:
# 1200

# %%
#만개의 글을 하나의 변수에 저장

import nltk
from konlpy.tag import Okt

okt= Okt()

present_text =''
present_text1 =''
present_text2 =''
present_text3 =''
present_text4 =''
present_text5 =''

for each_line in present_candi_text[:10000]:
    present_text = present_text + each_line + '\n'
for each_line in present_candi_text1[:10000]:
    present_text1 = present_text1 + each_line + '\n'
for each_line in present_candi_text2[:10000]:
    present_text2 = present_text2 + each_line + '\n'
for each_line in present_candi_text3[:10000]:
    present_text3 = present_text3 + each_line + '\n'
for each_line in present_candi_text4[:10000]:
    present_text4 = present_text4 + each_line + '\n'
for each_line in present_candi_text5[:10000]:
    present_text5 = present_text5 + each_line + '\n'

# %%
# 형태소 분석
tokens_ko = okt.morphs(present_text)
tokens_ko1 = okt.morphs(present_text1)
tokens_ko2 = okt.morphs(present_text2)
tokens_ko3 = okt.morphs(present_text3)
tokens_ko4 = okt.morphs(present_text4)
tokens_ko5 = okt.morphs(present_text5)
tokens_ko
# Out:
# ['기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '2013.02',
#  '.',
#  '15',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '와',
#  '먹는',
#  '음식',
#  '좀',
#  '알려주세요',
#  '제발',
#  '부탁드림니다',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  '정답',
#  '질문',
#  '전통',
#  '한식',
#  '상차림',
#  '2019.09',
#  '.',
#  '16',
#  '.',
#  '1',
#  '.',
#  '전통',
#  '한식',
#  '의',
#  '첩',
#  '반상',
#  '(',
#  '3',
#  ',',
#  '5',
#  ',',
#  '7',
#  ',',
#  '9',
#  ',',
#  '12',
#  ')',
#  '과',
#  '반찬',
#  '2',
#  '.',
#  '전통',
#  '밥상',
#  '차림',
#  '어떤',
#  '배열',
#  '을',
#  '하는가',
#  '3',
#  '.',
#  '전통',
#  '상',
#  '에',
#  '죽',
#  '상',
#  ',',
#  '장국상',
#  '주안상',
#  '교자상',
#  '다과상',
#  '등',
#  '이',
#  '것',
#  '들',
#  '좀',
#  '알려주세요',
#  '답변',
#  '숟가락',
#  '은',
#  '뜨거운',
#  '국물',
#  '음식',
#  '이',
#  '발달',
#  '한',
#  '한식',
#  '의',
#  '특성',
#  '에',
#  '잘',
#  '맞는',
#  '도구',
#  '이다',
#  '.',
#  '젓가락',
#  '은',
#  '...',
#  '오른쪽',
#  '에는',
#  '더운',
#  '반찬',
#  '을',
#  '놓아',
#  '오른손',
#  '으로',
#  '집어',
#  '먹기',
#  '편하게',
#  '배려',
#  '한',
#  '것',
#  '이',
#  '재미있다',
#  '....',
#  '닉네임',
#  '골드',
#  '질문',
#  '2013년',
#  '한식',
#  '날',
#  '2013.01',
#  '.',
#  '02',
#  '.',
#  '저기',
#  '한식',
#  '날',
#  '날짜',
#  '가',
#  '어떻게',
#  '되나요',
#  '??',
#  '인터넷',
#  '찾아봐도',
#  '없어서요',
#  '.......',
#  '자세하게',
#  '답좀',
#  '해주세요',
#  '답변',
#  '한식',
#  '은',
#  '글자',
#  '자의',
#  '대로',
#  '더운',
#  '음식',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '음식',
#  '을',
#  '먹어야',
#  '한다는',
#  '속',
#  '신',
#  '(',
#  '俗信',
#  ')...',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제',
#  '사',
#  '음식',
#  '을',
#  '마련',
#  '하여',
#  '제사',
#  '를',
#  '지내는데',
#  ',',
#  '이를',
#  '절사',
#  '(',
#  '節祀',
#  ')...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는',
#  '음식',
#  '추천',
#  '!!(',
#  '한식',
#  ')',
#  '2007.08',
#  '.',
#  '04',
#  '.',
#  '질리',
#  '고',
#  '뭔가',
#  '색다른',
#  '것',
#  '먹고싶은데',
#  '뭐',
#  '가',
#  '있을까요',
#  '??',
#  '맛있는',
#  '메뉴',
#  '좀',
#  '추천',
#  '해주세요',
#  '.',
#  '깔끔하게',
#  '먹을',
#  '수',
#  '있는것',
#  '뜨거운거',
#  '매운건',
#  '싫어요',
#  '~~',
#  '한식',
#  '으로',
#  '추천',
#  '부탁드립니다',
#  '.^^',
#  '답변',
#  '한식',
#  '은',
#  '아니지만',
#  '씨',
#  '푸드',
#  '뷔페',
#  '레스토랑',
#  '어때요',
#  '?',
#  '^',
#  'ㅡ',
#  '^',
#  '해산물',
#  '중',
#  '에서',
#  '장어',
#  ',',
#  '병어',
#  ',',
#  '농어',
#  '...',
#  '▦',
#  '찬',
#  '음식',
#  '에서',
#  '더운',
#  '음식',
#  '으로',
#  '=',
#  '뷔페',
#  '도',
#  '일종',
#  '의',
#  '코스',
#  '요리',
#  '로',
#  '생각',
#  '하고',
#  '음식',
#  '을',
#  '선택',
#  '해야',
#  '...',
#  '질문',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '2005.04',
#  '.',
#  '05',
#  '.',
#  '한식',
#  '날',
#  '의',
#  '유래',
#  '와',
#  '하는',
#  '일이',
#  '무엇',
#  '인가요',
#  '?',
#  '작은',
#  '사진',
#  '을',
#  '올려주셔도',
#  '괜찮습니다',
#  '.',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '한식',
#  '조사',
#  '여',
#  '.....',
#  '2016.06',
#  '.',
#  '01',
#  '.',
#  '뭐',
#  '가',
#  '우리나라',
#  '음식',
#  '인지',
#  '모르겠어서요',
#  '일단',
#  '1',
#  '.',
#  '한식',
#  '종류',
#  '!',
#  '를',
#  '알려주세요',
#  '2',
#  '.',
#  '그',
#  '음식',
#  '들',
#  '을',
#  '만드는',
#  '방법',
#  '도',
#  '알려주세요',
#  '오늘',
#  '안',
#  '에',
#  '알려주세요',
#  '.....',
#  '지금',
#  '엄청',
#  '급해서요',
#  '.....',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '질문',
#  '한식',
#  '에',
#  '관',
#  '한',
#  '여러가지',
#  '알려주세요',
#  '2005.04',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '이란',
#  '?',
#  '시기',
#  '유래',
#  '풍습',
#  '속담',
#  '한식',
#  '날',
#  '먹는',
#  '음식',
#  '이',
#  '것좀',
#  '간단하게',
#  '알려주세요',
#  '할것이',
#  '너무',
#  '많아서',
#  '여기저기',
#  '찾아볼',
#  '시간',
#  '이',
#  '없네요',
#  'ㅋ',
#  '꼭좀',
#  '알려주세요',
#  'ㅋ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '밥',
#  '...',
#  '찬',
#  '음식',
#  '을',
#  '먹는',
#  '풍습',
#  '이',
#  '있다',
#  '.',
#  '농가',
#  '에서는',
#  '이',
#  '날',
#  '농작물',
#  '의',
#  '씨',
#  '를',
#  '뿌린다',
#  '.',
#  '속담',
#  ':',
#  '한식',
#  '에',
#  '죽으나',
#  '청명',
#  '(',
#  '淸明',
#  ')',
#  '에',
#  '죽으나',
#  '...',
#  '닉네임',
#  'moon',
#  '****',
#  '질문',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '이',
#  '뭐',
#  '에요',
#  '?',
#  '2011.08',
#  '.',
#  '26',
#  '.',
#  '그',
#  '..',
#  '우리나라',
#  '음식',
#  '한식',
#  '말구요',
#  '..;;',
#  '차가울',
#  '한',
#  '?',
#  '그거',
#  '쓴',
#  '...',
#  '한',
#  '문',
#  '숙제',
#  '가',
#  '한식',
#  '(',
#  '寒食',
#  ')',
#  '에',
#  '대해',
#  '서',
#  '조사',
#  '해오는건데',
#  '....',
#  '조사',
#  '를',
#  '해서',
#  '어떻게',
#  '해야',
#  '될지도',
#  '모르겠고',
#  '..',
#  '사전',
#  '같은',
#  '덴',
#  '너무',
#  '...',
#  '답변',
#  '더운',
#  '밥',
#  '을',
#  '피하',
#  '고',
#  '찬',
#  '밥',
#  '을',
#  '먹는다고는',
#  '하나',
#  '잘',
#  '지켜지지',
#  '않았다',
#  '.',
#  '한식',
#  '은',
#  '조선시대',
#  '에',
#  '설날',
#  '·',
#  '단오',
#  '·',
#  '추석',
#  '과',
#  '함께',
#  '사대',
#  '명절',
#  '(',
#  '四大名節',
#  ')',
#  '에',
#  '속',
#  '했다',
#  '.',
#  '이',
#  '날',
#  '각',
#  '가정',
#  '에서는',
#  '제사',
#  '음식',
#  '...',
#  '닉네임',
#  '늘',
#  '해랑',
#  '질문',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대하',
#  '여',
#  '2007.04',
#  '.',
#  '05',
#  '.',
#  '학교숙제',
#  '인대',
#  '요',
#  '식목일',
#  ',',
#  '청명',
#  ',',
#  '한식',
#  '에',
#  '대한',
#  '조사',
#  '를',
#  '해',
#  '라',
#  '해서',
#  '하게',
#  '된것인데',
#  '제',
#  '말',
#  '도와주세요',
#  'ㅠㅠ',
#  '답변',
#  '그',
#  '뒤',
#  '그',
#  '를',
#  '애도',
#  '하는',
#  '뜻',
#  '에서',
#  ',',
#  '또',
#  '타',
#  '죽',
#  '은',
#  '사람',
#  '에게',
#  '더운',
#  '...',
#  '이',
#  '날',
#  '성묘',
#  '하는',
#  '습관',
#  '은',
#  '당나라',
#  '때',
#  '중국',
#  '에서',
#  '시작',
#  '하여',
#  '...',
#  '한식',
#  '날',
#  '음식',
#  '한식',
#  '을',
#  '청명절',
#  '이라',
#  '하고',
#  '동지',
#  '부터',
#  '105일',
#  '째',
#  '...',
#  '닉네임',
#  'han',
#  '0',
#  '****',
#  '질문',
#  '한식',
#  '의',
#  '종류',
#  '가르쳐주세요',
#  '2017.10',
#  '.',
#  '28',
#  '.',
#  '한식',
#  '의',
#  '종류',
#  '와',
#  '특징',
#  '을',
#  '가르쳐주세요',
#  '답변',
#  '한식',
#  '에',
#  '대한',
#  '모든',
#  '것',
#  ',',
#  '한식',
#  '의',
#  '종류',
#  ',',
#  '한식',
#  '의',
#  '특징',
#  '...',
#  '것',
#  '이다',
#  '.',
#  '더운',
#  '음식',
#  '을',
#  '식힐',
#  '때',
#  '는',
#  '입김',
#  '이',
#  '상대방',
#  '의',
#  '얼굴',
#  '...',
#  '굴',
#  '이나',
#  '조갯살',
#  '로',
#  '국물',
#  '을',
#  '내어',
#  '날',
#  '떡국',
#  '이나',
#  '칼국수',
#  '를',
#  '끓이며',
#  '...',
#  '음식점',
#  ',',
#  '맛집',
#  '분야',
#  '지식인',
#  '답변',
#  '닉네임',
#  '왕초',
#  '기본',
#  '검색',
#  '입력',
#  '한',
#  '단어',
#  '가',
#  '하나',
#  '이상',
#  '포함',
#  '된',
#  '문서',
#  '검색',
#  '상세',
#  '검색',
#  '정확히',
#  '일치',
#  '하는',
#  '단어',
#  '/',
#  '문장',
#  '("',
#  '")',
#  '반드시',
#  '포함',
#  '하는',
#  '단어',
#  '(+)',
#  '제외',
#  '하는',
#  '단어',
#  '(-)',
#  '기',
#  '본',
#  '검색',
#  '의',
#  '결과',
#  '범위',
#  '를',
#  '줄이고자',
#  '할',
#  '때',
#  '사용',
#  '합니다',
#  '.',
#  '여러',
#  '개',
#  '의',
#  '단어',
#  '를',
#  '입력',
#  '하실',
#  '때',
#  '는',
#  '쉼표',
#  '(,)',
#  '로',
#  '구분',
#  '해서',
#  '입력',
#  '하세요',
#  '.',
#  '질문',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '(',
#  '월욜',
#  '까지',
#  ')',
#  '2007.02',
#  '.',
#  '03',
#  '.',
#  '한식',
#  '에',
#  '하는',
#  '놀이',
#  '좀',
#  '부탁',
#  '해요',
#  '!!!!',
#  '답변',
#  '바랍니다',
#  '한식',
#  '(',
#  '寒食',
#  ':',
#  '동지',
#  '후',
#  '105일',
#  '째',
#  '되는',
#  '날',
#  ')',
#  '한식',
#  '의',
#  '어원',
#  '에',
#  ...]

# %%
ko = nltk.Text(tokens_ko,name='구름 더운 날 음식 한식')
ko1 = nltk.Text(tokens_ko1,name='구름 더운 날 음식 중식')
ko2 = nltk.Text(tokens_ko2,name='구름 더운 날 음식 일식')
ko3 = nltk.Text(tokens_ko3,name='구름 더운 날 음식 양식')
ko4 = nltk.Text(tokens_ko4,name='구름 더운 날 음식 분식')
ko5 = nltk.Text(tokens_ko5,name='구름 더운 날 음식 동남아')
print(len(ko.tokens))
print(len(set(ko.tokens))) #중복제거
# Out:
# 91815
# 7862

# %%
ko.vocab().most_common()
ko1.vocab().most_common()
ko2.vocab().most_common()
ko3.vocab().most_common()
ko4.vocab().most_common()
ko5.vocab().most_common()
# Out:
# [('.', 4033),
#  ('...', 2983),
#  ('이', 1948),
#  ('을', 1647),
#  ('에', 1392),
#  ('의', 1341),
#  (',', 1328),
#  ('를', 1186),
#  ('가', 1126),
#  ('답변', 1100),
#  ('질문', 1049),
#  ('음식', 1046),
#  ('닉네임', 935),
#  ('더운', 848),
#  ('구름', 784),
#  ('은', 709),
#  (':', 704),
#  ('(', 690),
#  ('****', 634),
#  ('단어', 604),
#  (')', 575),
#  ('하는', 523),
#  ('는', 516),
#  ('것', 515),
#  ('날', 513),
#  ('때', 455),
#  ('좀', 450),
#  ('로', 443),
#  ('검색', 403),
#  ('으로', 396),
#  ('과', 394),
#  ('들', 376),
#  ('도', 363),
#  ('비', 326),
#  ('나라', 322),
#  ('..', 320),
#  ('한', 309),
#  ('에는', 306),
#  ('요', 303),
#  ('입력', 300),
#  ('말', 270),
#  ('등', 266),
#  ('나', 265),
#  ('알려주세요', 264),
#  ('12', 253),
#  ('여러', 251),
#  ('속담', 241),
#  ('다', 236),
#  ('개', 234),
#  ('내공', 230),
#  ('?', 223),
#  ('사람', 220),
#  ('에서', 217),
#  ('안', 208),
#  ('月', 208),
#  ('포함', 207),
#  ('하세요', 206),
#  ('고', 199),
#  ('된', 197),
#  ('제', 195),
#  ('날씨', 194),
#  ('만든', 193),
#  ('합니다', 189),
#  ('동남아', 188),
#  ('할', 183),
#  ('기', 176),
#  ('다른', 173),
#  ('운', 171),
#  ('명절', 171),
#  ('게', 171),
#  ('많이', 168),
#  ('숙제', 166),
#  ('1', 159),
#  ('이다', 154),
#  ('바깥', 154),
#  ('우리말', 151),
#  ('-', 149),
#  ('세계', 147),
#  ('해서', 146),
#  ('뜻', 142),
#  ('저', 141),
#  ('입니다', 141),
#  ('....', 140),
#  ('와', 139),
#  ('놀이', 139),
#  ('3', 137),
#  ('이상', 136),
#  ('사주', 136),
#  ('가고', 136),
#  ('이나', 135),
#  ('음력', 135),
#  ('●', 134),
#  ('하나', 132),
#  ('/', 132),
#  ('20', 132),
#  ('방', 132),
#  ('시간', 131),
#  ('학년', 129),
#  ('계절', 127),
#  ('"', 126),
#  ('차고', 123),
#  ('정도', 122),
#  ('열', 121),
#  ('전통', 121),
#  ('시원한', 120),
#  ('까지', 120),
#  ('속', 120),
#  ('사용', 119),
#  ('곳', 118),
#  ('그', 118),
#  ('또', 116),
#  ('만', 115),
#  ('몸', 115),
#  (')...', 115),
#  ('반드시', 113),
#  ('중', 112),
#  ('☞', 112),
#  ('건강', 112),
#  ('~', 111),
#  ('기념일', 111),
#  ('햄스터', 111),
#  ('본', 110),
#  ('못', 110),
#  ('산', 110),
#  ('인데', 109),
#  ('5', 108),
#  ('여름철', 108),
#  ('대해', 107),
#  ('나무', 107),
#  ('여기', 106),
#  ('질', 106),
#  ('문장', 105),
#  ('!', 105),
#  ('차례', 105),
#  ('내려', 105),
#  ('하며', 105),
#  ('기본', 104),
#  ('결과', 104),
#  ('있으니', 104),
#  ('클릭', 104),
#  ('구분', 103),
#  ('필시', 103),
#  ('성공', 103),
#  ('거두게', 103),
#  ('인한', 103),
#  ('질병', 103),
#  ('조심하는', 103),
#  ('초목', 103),
#  ('상세', 102),
#  ('제외', 102),
#  ('여름', 102),
#  ('빨리', 102),
#  ('정확히', 101),
#  ('해', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('위', 100),
#  ('부탁', 100),
#  ('돌', 99),
#  ('마소', 98),
#  ('비비는', 98),
#  ('인', 97),
#  ('적', 97),
#  ('우리', 97),
#  ('성인', 97),
#  ('부탁드립니다', 96),
#  ('순우리말', 96),
#  ('2010.12', 96),
#  ('짓', 96),
#  ('설날', 95),
#  ('연날리기', 95),
#  ('즐거운', 95),
#  ('보낸다', 95),
#  ('成人の日', 95),
#  ('밥', 94),
#  ('지나가고', 94),
#  ('일', 93),
#  ('하고', 93),
#  ('도래', 93),
#  ('2', 93),
#  ('밤', 91),
#  ('먹는', 90),
#  ('서', 89),
#  ('4', 88),
#  ('찬', 88),
#  ('10', 87),
#  ('꼭', 86),
#  ('30', 86),
#  ('생활', 86),
#  ('있는', 86),
#  ('안녕하세요', 85),
#  ('주세요', 85),
#  ('오늘', 84),
#  ('쓰는', 84),
#  (']', 82),
#  ('분', 81),
#  ('!!', 81),
#  ('피', 81),
#  ('여행', 80),
#  ('수', 79),
#  ('순대', 79),
#  ('돼지', 78),
#  ('[', 78),
#  ('잘', 77),
#  ('하여', 76),
#  ('이름', 76),
#  ('파골집', 76),
#  ('창자', 76),
#  ('섞어서', 76),
#  ('삶아', 76),
#  ('그리고', 75),
#  ('필리핀', 74),
#  ('물', 74),
#  ('면', 73),
#  ('가지', 73),
#  ('여자', 72),
#  ('관련', 72),
#  ('바람', 70),
#  ("'", 70),
#  ('100', 70),
#  ('전', 69),
#  ('예', 69),
#  ('ㅠㅠ', 68),
#  ('소리', 68),
#  ('될', 68),
#  ('ag', 68),
#  ('모두', 68),
#  ('너무', 67),
#  ('영어', 67),
#  ('맛', 67),
#  ('간', 66),
#  ('하는데', 66),
#  ('우리나라', 66),
#  ('여', 66),
#  ('^^', 64),
#  ('해주세요', 63),
#  ('15', 63),
#  ('??', 62),
#  ('중국', 61),
#  ('아', 61),
#  ('13', 60),
#  ('방학', 60),
#  ('6', 59),
#  ('양력', 59),
#  ('조사', 59),
#  ('어떤', 58),
#  ('16', 58),
#  ('간혹', 57),
#  ('일본', 57),
#  ('눈', 56),
#  ('풀이', 56),
#  ('하', 56),
#  ('한국', 55),
#  ('14', 55),
#  ('제발', 54),
#  ('계속', 54),
#  ('정말', 53),
#  ('과학', 53),
#  ('거의', 52),
#  ('.....', 52),
#  ('오면', 52),
#  ('남자', 51),
#  ('이면', 51),
#  ('데', 51),
#  ('18', 50),
#  ('천자문', 50),
#  ('11', 49),
#  ('17', 49),
#  ('사회', 49),
#  ('25', 48),
#  ('24', 48),
#  ('처럼', 48),
#  ('학교', 48),
#  ('좋은', 48),
#  ('같은', 48),
#  ('알', 48),
#  ('아름다운', 48),
#  ('관', 47),
#  ('하면', 46),
#  ('대부분', 46),
#  ('겨울', 46),
#  ('선생님', 46),
#  ('추천', 45),
#  ('타고', 45),
#  ('하늘', 45),
#  ('예수님', 45),
#  ('기록', 44),
#  ('지금', 44),
#  ('거', 44),
#  ('!!!', 44),
#  ('농가월령가', 44),
#  ('소금', 44),
#  ('점', 43),
#  ('봐주세요', 43),
#  ('제주도', 43),
#  ('mhos', 43),
#  ('좋아', 42),
#  ('달', 42),
#  ('대', 42),
#  ('무엇', 42),
#  ('ethn', 42),
#  ('지역', 41),
#  ('없고', 41),
#  ('한다', 41),
#  ('ocam', 41),
#  ('순', 41),
#  ('하지만', 40),
#  ('부탁드려요', 40),
#  ('없이', 40),
#  ('먹고', 40),
#  ('특징', 40),
#  ('다시', 40),
#  ('핵심', 40),
#  ('땅', 40),
#  ('03', 40),
#  ('음식물', 40),
#  ('살', 39),
#  ('간다', 39),
#  ('쪽', 38),
#  ('지', 38),
#  ('재림', 38),
#  ('내일', 38),
#  ('갑자기', 38),
#  ('사다리타기', 38),
#  ('묘기', 38),
#  ('부리곤', 38),
#  ('한답니다', 38),
#  ('이르는', 38),
#  ('26', 37),
#  ('09', 37),
#  ('거리', 37),
#  ('머', 37),
#  ('21', 36),
#  ('태국', 36),
#  ('밑', 36),
#  ('북한', 36),
#  ('바다', 35),
#  ('강한', 35),
#  ('넘으려고', 35),
#  ('고유어', 35),
#  ('부터', 35),
#  ('검은', 35),
#  ('매', 35),
#  ('낀', 35),
#  ('내', 35),
#  ('19', 35),
#  ('29', 34),
#  ('조금', 34),
#  ('금은', 34),
#  ('지식인', 34),
#  ('예쁜', 34),
#  ('기운', 34),
#  ('적어주세요', 34),
#  ('더', 33),
#  ('ㅠ', 33),
#  ('입', 33),
#  ('매지', 33),
#  ('전혀', 33),
#  ('의미', 33),
#  ('아이', 33),
#  ('하루', 33),
#  ('04', 33),
#  ('따라', 33),
#  ('함', 33),
#  ('07', 32),
#  ('때문', 32),
#  ('랑', 32),
#  ('①', 32),
#  ('분야', 32),
#  ('*', 32),
#  ('있나요', 32),
#  ('알려', 32),
#  ('감사', 32),
#  ('되다가', 32),
#  ('추워지면', 32),
#  ('설사', 32),
#  ('섭취', 31),
#  ('뜨거운', 31),
#  ('조각', 31),
#  ('오후', 31),
#  ('양', 31),
#  ('아래', 31),
#  ('이고', 30),
#  ('그래서', 30),
#  ('해야', 30),
#  ('옷', 30),
#  ('되지기', 30),
#  ('얹어', 30),
#  ('찌거나', 30),
#  ('태어난', 30),
#  ('베트남', 30),
#  ('같이', 30),
#  ('떡', 30),
#  ('오는', 30),
#  ('세', 30),
#  ('내용', 30),
#  ('얼음', 30),
#  ('까닭', 30),
#  ('•', 30),
#  ('박', 29),
#  ('걸', 29),
#  (',,', 29),
#  ('뭐', 29),
#  ('부지런해야', 29),
#  ('23', 29),
#  ('50', 29),
#  ('생각', 29),
#  ('아메리카', 29),
#  ('모른다', 29),
#  ('마음', 29),
#  ('28', 29),
#  ('두', 29),
#  ('2016.11', 29),
#  ('들면', 29),
#  ('단순히', 29),
#  ('배', 29),
#  ('써주세요', 29),
#  ('가르쳐', 29),
#  ('사투리', 29),
#  ('히', 29),
#  ('83', 29),
#  ('호텔', 28),
#  ('2008.03', 28),
#  ('캐', 28),
#  ('책', 28),
#  ('겁니다', 28),
#  ('미국', 28),
#  ('신고', 28),
#  ('갈', 27),
#  ('저희', 27),
#  ('이런', 27),
#  ('공기', 27),
#  ('있다', 27),
#  ('한자', 27),
#  ('도와주세요', 27),
#  ('새참', 27),
#  ('되고', 27),
#  ('한글', 27),
#  ('雲', 27),
#  ('집', 27),
#  ('<', 27),
#  ('모이는', 27),
#  ('전파', 27),
#  ('속도', 27),
#  ('방법', 27),
#  ('모습', 27),
#  ('보리', 27),
#  ('치', 27),
#  ('설명', 26),
#  ('식', 26),
#  ('기온', 26),
#  ('가장', 26),
#  ('개도', 26),
#  ('고갱', 26),
#  ('사물', 26),
#  ('......', 26),
#  ('세째', 26),
#  ('식물', 26),
#  ('주', 26),
#  ('오를', 26),
#  ('절대온도', 26),
#  ('초등학교', 26),
#  ('즉', 26),
#  ('이를', 26),
#  ('우', 26),
#  ('아니라도', 26),
#  ('~~', 25),
#  ('최대한', 25),
#  ('22', 25),
#  ('특히', 25),
#  ('이번', 25),
#  ('맑은', 25),
#  ('어느', 25),
#  ('함께', 25),
#  ('대한', 25),
#  ('hot', 25),
#  ('구름다리', 25),
#  ('네', 25),
#  ('^', 25),
#  ('심어', 25),
#  ('騰', 25),
#  ('致', 25),
#  ('雨', 25),
#  ('수증기', 25),
#  ('훌륭한', 25),
#  ('맞으면', 25),
#  ('채운다', 25),
#  ('飽', 25),
#  ('해외', 24),
#  ('06', 24),
#  ('05', 24),
#  ('맛있게', 24),
#  ('감사하겠습니다', 24),
#  ('글', 24),
#  ('1월', 24),
#  ('7월', 24),
#  ('에도', 24),
#  ('구', 24),
#  ('성경', 24),
#  ('많은', 24),
#  ('이유', 24),
#  ('7', 24),
#  ('밀', 24),
#  ('보세', 24),
#  ('있으며', 23),
#  ('영향', 23),
#  ('5월', 23),
#  ('오', 23),
#  ('이랑', 23),
#  ('차', 23),
#  ('별', 23),
#  ('인지', 23),
#  ('급해요', 23),
#  ('봉동읍', 23),
#  ('ltah', 23),
#  ('2011.07', 23),
#  ('끝', 23),
#  ('냠냠', 23),
#  ('끼', 23),
#  ('능', 23),
#  ('지어', 23),
#  ('급한', 23),
#  ('현지', 22),
#  ('근데', 22),
#  ('에요', 22),
#  ('02', 22),
#  ('왜', 22),
#  ('27', 22),
#  ('이야기', 22),
#  ('food', 22),
#  ('조사해', 22),
#  ('뭉게뭉게', 22),
#  ('미쳐', 22),
#  ('뉘', 22),
#  ('베어', 22),
#  ('갈이', 22),
#  ('끝끝', 22),
#  ('익어도', 22),
#  ('하려니와', 22),
#  ('나네', 22),
#  ('방아', 22),
#  ('찧어', 22),
#  ('밥살', 22),
#  ('103', 22),
#  ('자매', 22),
#  ('결연', 22),
#  ('인가요', 21),
#  ('2008.04', 21),
#  ('땀', 21),
#  ('전체', 21),
#  ('대표', 21),
#  ('오전', 21),
#  ('8월', 21),
#  ('만들고', 21),
#  ('비유', 21),
#  ('종류', 21),
#  ('모양', 21),
#  ('요리', 21),
#  ('드립니다', 21),
#  ('어떻게', 21),
#  ('소', 21),
#  ('먹어', 21),
#  ('모', 21),
#  ('고유', 21),
#  ('뉴욕', 20),
#  ('오른', 20),
#  ('드시는', 20),
#  ('비경', 20),
#  ('보통', 20),
#  ('이라', 20),
#  ('등등', 20),
#  ('산이', 20),
#  ('있을까요', 20),
#  ('유래', 20),
#  ('문화', 20),
#  ('생', 20),
#  ('않고', 20),
#  ('흰', 20),
#  ('길게', 20),
#  ('경우', 20),
#  ('명', 20),
#  ('라는', 20),
#  ('문', 20),
#  ('없다', 20),
#  ('이렇게', 20),
#  ('가르쳐주세요', 20),
#  ('바로', 20),
#  ('바보', 20),
#  ('프랑스', 20),
#  ('인도', 20),
#  ('볼', 20),
#  ('11월', 19),
#  ('타임스', 19),
#  ('선정', 19),
#  ('죽기전에', 19),
#  ('가봐야', 19),
#  ('맛있기는', 19),
#  ('계시는데', 19),
#  ('문제', 19),
#  ('08', 19),
#  ('그냥', 19),
#  ('-->', 19),
#  ('미치는', 19),
#  ('ㅜ', 19),
#  ('큰', 19),
#  ('운다고', 19),
#  ('얻어먹는다', 19),
#  ('정', 19),
#  ('에서는', 19),
#  ('단', 19),
#  ('천지창조', 19),
#  ('기후', 19),
#  ('2월', 19),
#  ('01', 19),
#  ('결혼', 19),
#  ('용', 19),
#  ('사', 19),
#  ('음', 19),
#  ('라고', 19),
#  ('초', 19),
#  ('드려요', 19),
#  ('가는', 19),
#  ('자세히', 19),
#  ('고기', 19),
#  ('fool', 19),
#  ('발', 19),
#  ('소화', 19),
#  ('생명', 19),
#  ('감추듯', 19),
#  ('허겁지겁', 19),
#  ('치움을', 19),
#  ('멸망', 19),
#  ('구원', 19),
#  ('12월', 18),
#  ('성', 18),
#  ('라서', 18),
#  ('1일', 18),
#  ('네째', 18),
#  ('되는', 18),
#  ('운세', 18),
#  ('남북', 18),
#  ('올려주세요', 18),
#  ('별로', 18),
#  ('정보', 18),
#  ('처음', 18),
#  ('있습니다', 18),
#  ('친구', 18),
#  ('사진', 18),
#  ('무더운', 18),
#  ('님', 18),
#  ('차이', 18),
#  ('몇', 18),
#  ('해석', 18),
#  ('준다는', 18),
#  ('최고', 18),
#  ('인데요', 18),
#  ('걸음', 18),
#  ('살려라', 18),
#  ('달아날', 18),
#  ('조급한', 18),
#  ('발걸음', 18),
#  ('재촉', 18),
#  ('게도', 18),
#  ('세상', 18),
#  ('남미', 18),
#  ('여행지', 17),
#  ('2019.10', 17),
#  ('쯤', 17),
#  ('아시', 17),
#  ('요즘', 17),
#  ('???', 17),
#  ('시', 17),
#  ('그런데', 17),
#  ('2019.09', 17),
#  ('있어요', 17),
#  ('알려주세여', 17),
#  ('되도록', 17),
#  ('40', 17),
#  ('드림', 17),
#  ('원리', 17),
#  ('②', 17),
#  ('냉각', 17),
#  ('지장', 17),
#  ('8', 17),
#  ('정리', 17),
#  ('위해', 17),
#  ('ㅡ', 17),
#  ('있는데요', 17),
#  ('순수한', 17),
#  ('2016.10', 17),
#  ('강', 17),
#  ('개념', 17),
#  ('의상', 17),
#  ('맺은', 17),
#  ('됩니다', 16),
#  ('얼마', 16),
#  (';;', 16),
#  ('21일', 16),
#  ('없는', 16),
#  ('그런', 16),
#  ('하지', 16),
#  ('2020.06', 16),
#  ('각', 16),
#  ('지방', 16),
#  ('자세하게', 16),
#  ('해외여행', 16),
#  ('은하', 16),
#  ('운동', 16),
#  ('식품', 16),
#  ('~!', 16),
#  ('빨리요', 16),
#  ('국어', 16),
#  ('공부', 16),
#  ('=', 16),
#  ('에게', 16),
#  ('따라서', 16),
#  ('시기', 16),
#  ('켜주세요', 16),
#  ('러시아', 16),
#  ('올라갈', 16),
#  ('결정', 16),
#  ('타', 16),
#  ('접대', 16),
#  ('받는다', 16),
#  ('신도', 16),
#  ('고추', 16),
#  ('cloudy', 16),
#  ('얇은', 15),
#  ('입고', 15),
#  ('알려주시면', 15),
#  ('아침', 15),
#  ('맑음', 15),
#  ('이구', 15),
#  ('궁금합니다', 15),
#  ('31', 15),
#  ('_', 15),
#  ('학생', 15),
#  ('2020.03', 15),
#  ('글자', 15),
#  ('진짜', 15),
#  ('자리', 15),
#  ('먹거리', 15),
#  ('해주시', 15),
#  ('있는데', 15),
#  ('새', 15),
#  ('~~~', 15),
#  ('온', 15),
#  ('가을', 15),
#  ('각국', 15),
#  ('후', 15),
#  ('번', 15),
#  ('영', 15),
#  ('염', 15),
#  ('채', 15),
#  ('불', 15),
#  ('삼', 15),
#  ('씩', 15),
#  (';', 15),
#  ('0', 15),
#  ('대전', 15),
#  ('상층', 15),
#  ('권층운', 15),
#  ('엷은', 15),
#  ('께서', 15),
#  ('라', 15),
#  ('아무', 15),
#  ('경상도', 15),
#  ('하게', 15),
#  ('9', 15),
#  ('이라는', 15),
#  ('마리', 15),
#  ('k', 15),
#  ('천', 15),
#  ('보다', 14),
#  ('하는데요', 14),
#  ('㉣', 14),
#  ('찾게', 14),
#  ('되며', 14),
#  ('맑으며', 14),
#  ('남동풍', 14),
#  ('약간', 14),
#  ('빠른', 14),
#  ('상', 14),
#  ('궁합', 14),
#  ('전통의상', 14),
#  ('조부', 14),
#  ('할아버지', 14),
#  ('준결승', 14),
#  ('보이는', 14),
#  ('시나', 14),
#  ('브로', 14),
#  ('6월', 14),
#  ('신', 14),
#  ('지만', 14),
#  ('비오는', 14),
#  ('대하', 14),
#  ('>', 14),
#  ('이제', 14),
#  ('먹어서', 14),
#  ('먹는다', 14),
#  ('밖에', 14),
#  ('구체', 14),
#  ('2010.01', 14),
#  ('듯', 14),
#  ('형식', 14),
#  ('단원', 14),
#  ('본문', 14),
#  ('떠', 14),
#  ('지역별', 14),
#  ('마차', 14),
#  ('으로는', 14),
#  ('지나가는', 14),
#  ('거지', 14),
#  ('께', 14),
#  ('지식', 14),
#  ('2010.06', 14),
#  ('학기', 14),
#  ('부정', 14),
#  ('부분', 14),
#  ('무늬', 14),
#  ('반', 13),
#  ('보고', 13),
#  ('높았던', 13),
#  ('니까', 13),
#  ('연', 13),
#  ('똥', 13),
#  ('ㅜㅜ', 13),
#  ('2007.08', 13),
#  ('사실', 13),
#  ('엔', 13),
#  ('한번', 13),
#  ('음식점', 13),
#  ('현재', 13),
#  ('어', 13),
#  ('캄보디아', 13),
#  ('보면', 13),
#  ('사이', 13),
#  ('2019.08', 13),
#  ('자', 13),
#  ('되지', 13),
#  ('울', 13),
#  ('여러가지', 13),
#  ('2012.04', 13),
#  ('답', 13),
#  ('관계', 13),
#  ('2009.08', 13),
#  ('ㅇ', 13),
#  ('손', 13),
#  ('들어', 13),
#  ('요약', 13),
#  ('2008.08', 13),
#  ('논', 13),
#  ('꾼', 13),
#  ('ㅎ', 13),
#  ('키우는', 13),
#  ('놈', 13),
#  ('994', 13),
#  ('산책', 13),
#  ('여름방학', 13),
#  ('내리는', 13),
#  ('A', 13),
#  ('흐린', 13),
#  ('특이', 13),
#  ('까다롭게', 13),
#  ('민소매', 13),
#  ('이외', 13),
#  ('폭포', 13),
#  ('쓰인다', 13),
#  ('춥고', 13),
#  ('환경', 12),
#  ('혼자', 12),
#  ('코스', 12),
#  ('지면', 12),
#  ('좋습니다', 12),
#  ('제목', 12),
#  ('4월', 12),
#  ('올라간', 12),
#  ('표현', 12),
#  ('역사', 12),
#  ('채택', 12),
#  ('같아요', 12),
#  ('학교숙제', 12),
#  ('이란', 12),
#  ('일기', 12),
#  ('술', 12),
#  ('새벽', 12),
#  ('했는데', 12),
#  ('올해', 12),
#  ('어디', 12),
#  ('이라고', 12),
#  ('&', 12),
#  ('의식주', 12),
#  ('남아', 12),
#  ('한편', 12),
#  ('에만', 12),
#  ('3일', 12),
#  (',,,', 12),
#  ('예요', 12),
#  ('예절', 12),
#  ('님들', 12),
#  ('대륙', 12),
#  ('방언', 12),
#  ('2008.10', 12),
#  ('결', 12),
#  ('차지', 12),
#  ('않는다는', 12),
#  ('중학교', 12),
#  ('갓', 12),
#  ('2008.01', 12),
#  ('멍', 12),
#  ('대거', 12),
#  ('빼기', 12),
#  ('방축', 12),
#  ('2007.12', 12),
#  ('낱말', 12),
#  ('2009.03', 12),
#  ('nhha', 12),
#  ('200', 12),
#  ('하나님', 12),
#  ('요점', 12),
#  ('찾기', 12),
#  ('98', 12),
#  ('말함', 12),
#  ('농가', 12),
#  ('이황', 12),
#  ('5일', 11),
#  ('발생', 11),
#  ('래', 11),
#  ('2008.02', 11),
#  ('거든요', 11),
#  ('겨울방학', 11),
#  ('이에요', 11),
#  ('아니면', 11),
#  ('및', 11),
#  ('아니라', 11),
#  ('않은', 11),
#  ('맛있는', 11),
#  ('?...', 11),
#  ('2일', 11),
#  ('2020.04', 11),
#  ('3월', 11),
#  ('2020.02', 11),
#  ('목연', 11),
#  ('30분', 11),
#  ('가서', 11),
#  ('직업', 11),
#  ('국', 11),
#  ('물건', 11),
#  ('급함', 11),
#  ('300', 11),
#  ('있어서', 11),
#  ('사이트', 11),
#  ('아직', 11),
#  ('9월', 11),
#  ('엄마', 11),
#  ('하기', 11),
#  ('저녁', 11),
#  ('확률', 11),
#  ('역시', 11),
#  ('cloud', 11),
#  ('식당', 11),
#  ('육', 11),
#  ('나면', 11),
#  ('내부', 11),
#  ('빼내는', 11),
#  ('일종', 11),
#  ('그러므로', 11),
#  ('아치로', 11),
#  ('보냈다는', 11),
#  ('용도', 11),
#  ('푸드', 11),
#  ('날짜', 11),
#  ('2009.09', 11),
#  ('거적', 11),
#  ('깔개', 11),
#  ('참나무', 11),
#  ('엷게', 11),
#  ('밀어서', 11),
#  ('역', 11),
#  ('신세', 11),
#  ('마는', 11),
#  ('보기', 11),
#  ('상식', 11),
#  ('있으면', 11),
#  ('동물', 11),
#  ('외래어', 11),
#  ('▶', 11),
#  ('따위', 11),
#  ('주면', 11),
#  ('봄', 11),
#  ('이요', 11),
#  ...]

# %%
# 의미없는 단어들을 수동으로 제거해준다.
stop_words = ['.','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','선물해','라고','중요한','합','가요','....','보이','네','무지']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]
tokens_ko1 = [each_word for each_word in tokens_ko1 
                          if each_word not in stop_words]
tokens_ko2 = [each_word for each_word in tokens_ko2 
                          if each_word not in stop_words]
tokens_ko3 = [each_word for each_word in tokens_ko3 
                          if each_word not in stop_words]
tokens_ko4 = [each_word for each_word in tokens_ko4 
                          if each_word not in stop_words]
tokens_ko5 = [each_word for each_word in tokens_ko5 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko,name='구름 더운 날 음식 한식')
ko.vocab().most_common()

ko1 = nltk.Text(tokens_ko1,name='구름 더운 날 음식 중식')
ko1.vocab().most_common()

ko2 = nltk.Text(tokens_ko2,name='구름 더운 날 음식 일식')
ko2.vocab().most_common()

ko3 = nltk.Text(tokens_ko3,name='구름 더운 날 음식 양식')
ko3.vocab().most_common()

ko4 = nltk.Text(tokens_ko4,name='구름 더운 날 음식 분식')
ko4.vocab().most_common()

ko5 = nltk.Text(tokens_ko5,name='구름 더운 날 음식 동남아')
ko5.vocab().most_common()
# Out:
# [('음식', 1046),
#  ('닉네임', 935),
#  ('더운', 848),
#  ('구름', 784),
#  (':', 704),
#  ('(', 690),
#  ('****', 634),
#  (')', 575),
#  ('날', 513),
#  ('검색', 403),
#  ('비', 326),
#  ('나라', 322),
#  ('에는', 306),
#  ('입력', 300),
#  ('말', 270),
#  ('등', 266),
#  ('나', 265),
#  ('알려주세요', 264),
#  ('12', 253),
#  ('여러', 251),
#  ('속담', 241),
#  ('개', 234),
#  ('내공', 230),
#  ('사람', 220),
#  ('에서', 217),
#  ('안', 208),
#  ('月', 208),
#  ('포함', 207),
#  ('하세요', 206),
#  ('된', 197),
#  ('날씨', 194),
#  ('만든', 193),
#  ('합니다', 189),
#  ('동남아', 188),
#  ('기', 176),
#  ('다른', 173),
#  ('운', 171),
#  ('명절', 171),
#  ('많이', 168),
#  ('숙제', 166),
#  ('이다', 154),
#  ('바깥', 154),
#  ('우리말', 151),
#  ('-', 149),
#  ('세계', 147),
#  ('해서', 146),
#  ('뜻', 142),
#  ('저', 141),
#  ('입니다', 141),
#  ('와', 139),
#  ('놀이', 139),
#  ('3', 137),
#  ('사주', 136),
#  ('가고', 136),
#  ('이나', 135),
#  ('음력', 135),
#  ('●', 134),
#  ('/', 132),
#  ('방', 132),
#  ('시간', 131),
#  ('학년', 129),
#  ('계절', 127),
#  ('"', 126),
#  ('차고', 123),
#  ('정도', 122),
#  ('열', 121),
#  ('전통', 121),
#  ('시원한', 120),
#  ('까지', 120),
#  ('속', 120),
#  ('사용', 119),
#  ('곳', 118),
#  ('그', 118),
#  ('또', 116),
#  ('만', 115),
#  ('몸', 115),
#  (')...', 115),
#  ('반드시', 113),
#  ('☞', 112),
#  ('건강', 112),
#  ('기념일', 111),
#  ('햄스터', 111),
#  ('본', 110),
#  ('산', 110),
#  ('5', 108),
#  ('여름철', 108),
#  ('대해', 107),
#  ('나무', 107),
#  ('여기', 106),
#  ('질', 106),
#  ('문장', 105),
#  ('!', 105),
#  ('차례', 105),
#  ('내려', 105),
#  ('하며', 105),
#  ('결과', 104),
#  ('있으니', 104),
#  ('클릭', 104),
#  ('구분', 103),
#  ('필시', 103),
#  ('성공', 103),
#  ('거두게', 103),
#  ('인한', 103),
#  ('질병', 103),
#  ('조심하는', 103),
#  ('초목', 103),
#  ('상세', 102),
#  ('제외', 102),
#  ('여름', 102),
#  ('빨리', 102),
#  ('정확히', 101),
#  ('해', 101),
#  ('문서', 100),
#  ('일치', 100),
#  ('("', 100),
#  ('")', 100),
#  ('(+)', 100),
#  ('(-)', 100),
#  ('범위', 100),
#  ('줄이고자', 100),
#  ('하실', 100),
#  ('쉼표', 100),
#  ('(,)', 100),
#  ('위', 100),
#  ('부탁', 100),
#  ('돌', 99),
#  ('마소', 98),
#  ('비비는', 98),
#  ('인', 97),
#  ('적', 97),
#  ('우리', 97),
#  ('성인', 97),
#  ('부탁드립니다', 96),
#  ('순우리말', 96),
#  ('2010.12', 96),
#  ('짓', 96),
#  ('설날', 95),
#  ('연날리기', 95),
#  ('즐거운', 95),
#  ('보낸다', 95),
#  ('成人の日', 95),
#  ('밥', 94),
#  ('지나가고', 94),
#  ('하고', 93),
#  ('도래', 93),
#  ('밤', 91),
#  ('먹는', 90),
#  ('서', 89),
#  ('4', 88),
#  ('찬', 88),
#  ('꼭', 86),
#  ('30', 86),
#  ('생활', 86),
#  ('안녕하세요', 85),
#  ('주세요', 85),
#  ('오늘', 84),
#  ('쓰는', 84),
#  (']', 82),
#  ('분', 81),
#  ('피', 81),
#  ('여행', 80),
#  ('순대', 79),
#  ('돼지', 78),
#  ('[', 78),
#  ('하여', 76),
#  ('이름', 76),
#  ('파골집', 76),
#  ('창자', 76),
#  ('섞어서', 76),
#  ('삶아', 76),
#  ('그리고', 75),
#  ('필리핀', 74),
#  ('물', 74),
#  ('면', 73),
#  ('가지', 73),
#  ('여자', 72),
#  ('관련', 72),
#  ('바람', 70),
#  ("'", 70),
#  ('100', 70),
#  ('전', 69),
#  ('예', 69),
#  ('ㅠㅠ', 68),
#  ('소리', 68),
#  ('될', 68),
#  ('ag', 68),
#  ('모두', 68),
#  ('너무', 67),
#  ('영어', 67),
#  ('맛', 67),
#  ('간', 66),
#  ('하는데', 66),
#  ('우리나라', 66),
#  ('여', 66),
#  ('^^', 64),
#  ('해주세요', 63),
#  ('15', 63),
#  ('??', 62),
#  ('중국', 61),
#  ('아', 61),
#  ('13', 60),
#  ('방학', 60),
#  ('양력', 59),
#  ('조사', 59),
#  ('16', 58),
#  ('간혹', 57),
#  ('일본', 57),
#  ('눈', 56),
#  ('풀이', 56),
#  ('하', 56),
#  ('한국', 55),
#  ('14', 55),
#  ('제발', 54),
#  ('계속', 54),
#  ('정말', 53),
#  ('과학', 53),
#  ('거의', 52),
#  ('.....', 52),
#  ('오면', 52),
#  ('남자', 51),
#  ('이면', 51),
#  ('18', 50),
#  ('천자문', 50),
#  ('11', 49),
#  ('17', 49),
#  ('사회', 49),
#  ('25', 48),
#  ('24', 48),
#  ('처럼', 48),
#  ('학교', 48),
#  ('좋은', 48),
#  ('같은', 48),
#  ('알', 48),
#  ('아름다운', 48),
#  ('관', 47),
#  ('하면', 46),
#  ('대부분', 46),
#  ('겨울', 46),
#  ('선생님', 46),
#  ('추천', 45),
#  ('타고', 45),
#  ('하늘', 45),
#  ('예수님', 45),
#  ('기록', 44),
#  ('지금', 44),
#  ('!!!', 44),
#  ('농가월령가', 44),
#  ('소금', 44),
#  ('점', 43),
#  ('봐주세요', 43),
#  ('제주도', 43),
#  ('mhos', 43),
#  ('좋아', 42),
#  ('달', 42),
#  ('무엇', 42),
#  ('ethn', 42),
#  ('지역', 41),
#  ('없고', 41),
#  ('한다', 41),
#  ('ocam', 41),
#  ('순', 41),
#  ('하지만', 40),
#  ('부탁드려요', 40),
#  ('없이', 40),
#  ('먹고', 40),
#  ('특징', 40),
#  ('다시', 40),
#  ('핵심', 40),
#  ('땅', 40),
#  ('03', 40),
#  ('음식물', 40),
#  ('살', 39),
#  ('간다', 39),
#  ('쪽', 38),
#  ('재림', 38),
#  ('내일', 38),
#  ('갑자기', 38),
#  ('사다리타기', 38),
#  ('묘기', 38),
#  ('부리곤', 38),
#  ('한답니다', 38),
#  ('이르는', 38),
#  ('26', 37),
#  ('09', 37),
#  ('거리', 37),
#  ('머', 37),
#  ('21', 36),
#  ('태국', 36),
#  ('밑', 36),
#  ('북한', 36),
#  ('바다', 35),
#  ('강한', 35),
#  ('넘으려고', 35),
#  ('고유어', 35),
#  ('부터', 35),
#  ('검은', 35),
#  ('매', 35),
#  ('낀', 35),
#  ('내', 35),
#  ('19', 35),
#  ('29', 34),
#  ('조금', 34),
#  ('금은', 34),
#  ('지식인', 34),
#  ('예쁜', 34),
#  ('기운', 34),
#  ('적어주세요', 34),
#  ('더', 33),
#  ('ㅠ', 33),
#  ('입', 33),
#  ('매지', 33),
#  ('전혀', 33),
#  ('의미', 33),
#  ('아이', 33),
#  ('하루', 33),
#  ('04', 33),
#  ('따라', 33),
#  ('함', 33),
#  ('07', 32),
#  ('때문', 32),
#  ('랑', 32),
#  ('①', 32),
#  ('분야', 32),
#  ('*', 32),
#  ('있나요', 32),
#  ('알려', 32),
#  ('감사', 32),
#  ('되다가', 32),
#  ('추워지면', 32),
#  ('설사', 32),
#  ('섭취', 31),
#  ('뜨거운', 31),
#  ('조각', 31),
#  ('오후', 31),
#  ('양', 31),
#  ('아래', 31),
#  ('이고', 30),
#  ('그래서', 30),
#  ('해야', 30),
#  ('옷', 30),
#  ('되지기', 30),
#  ('얹어', 30),
#  ('찌거나', 30),
#  ('태어난', 30),
#  ('베트남', 30),
#  ('같이', 30),
#  ('떡', 30),
#  ('오는', 30),
#  ('세', 30),
#  ('내용', 30),
#  ('얼음', 30),
#  ('까닭', 30),
#  ('•', 30),
#  ('박', 29),
#  ('걸', 29),
#  (',,', 29),
#  ('부지런해야', 29),
#  ('23', 29),
#  ('50', 29),
#  ('생각', 29),
#  ('아메리카', 29),
#  ('모른다', 29),
#  ('마음', 29),
#  ('28', 29),
#  ('두', 29),
#  ('2016.11', 29),
#  ('들면', 29),
#  ('단순히', 29),
#  ('배', 29),
#  ('써주세요', 29),
#  ('가르쳐', 29),
#  ('사투리', 29),
#  ('히', 29),
#  ('83', 29),
#  ('호텔', 28),
#  ('2008.03', 28),
#  ('캐', 28),
#  ('책', 28),
#  ('겁니다', 28),
#  ('미국', 28),
#  ('신고', 28),
#  ('갈', 27),
#  ('저희', 27),
#  ('이런', 27),
#  ('공기', 27),
#  ('있다', 27),
#  ('한자', 27),
#  ('도와주세요', 27),
#  ('새참', 27),
#  ('되고', 27),
#  ('한글', 27),
#  ('雲', 27),
#  ('집', 27),
#  ('<', 27),
#  ('모이는', 27),
#  ('전파', 27),
#  ('속도', 27),
#  ('방법', 27),
#  ('모습', 27),
#  ('보리', 27),
#  ('치', 27),
#  ('설명', 26),
#  ('식', 26),
#  ('기온', 26),
#  ('가장', 26),
#  ('개도', 26),
#  ('고갱', 26),
#  ('사물', 26),
#  ('......', 26),
#  ('세째', 26),
#  ('식물', 26),
#  ('오를', 26),
#  ('절대온도', 26),
#  ('초등학교', 26),
#  ('즉', 26),
#  ('이를', 26),
#  ('우', 26),
#  ('아니라도', 26),
#  ('~~', 25),
#  ('최대한', 25),
#  ('22', 25),
#  ('특히', 25),
#  ('이번', 25),
#  ('맑은', 25),
#  ('어느', 25),
#  ('함께', 25),
#  ('대한', 25),
#  ('hot', 25),
#  ('구름다리', 25),
#  ('^', 25),
#  ('심어', 25),
#  ('騰', 25),
#  ('致', 25),
#  ('雨', 25),
#  ('수증기', 25),
#  ('훌륭한', 25),
#  ('맞으면', 25),
#  ('채운다', 25),
#  ('飽', 25),
#  ('해외', 24),
#  ('05', 24),
#  ('맛있게', 24),
#  ('감사하겠습니다', 24),
#  ('글', 24),
#  ('1월', 24),
#  ('7월', 24),
#  ('에도', 24),
#  ('구', 24),
#  ('성경', 24),
#  ('많은', 24),
#  ('이유', 24),
#  ('7', 24),
#  ('밀', 24),
#  ('보세', 24),
#  ('있으며', 23),
#  ('영향', 23),
#  ('5월', 23),
#  ('오', 23),
#  ('이랑', 23),
#  ('차', 23),
#  ('별', 23),
#  ('인지', 23),
#  ('급해요', 23),
#  ('봉동읍', 23),
#  ('ltah', 23),
#  ('2011.07', 23),
#  ('끝', 23),
#  ('냠냠', 23),
#  ('끼', 23),
#  ('능', 23),
#  ('지어', 23),
#  ('급한', 23),
#  ('현지', 22),
#  ('근데', 22),
#  ('에요', 22),
#  ('02', 22),
#  ('왜', 22),
#  ('27', 22),
#  ('이야기', 22),
#  ('food', 22),
#  ('조사해', 22),
#  ('뭉게뭉게', 22),
#  ('미쳐', 22),
#  ('뉘', 22),
#  ('베어', 22),
#  ('갈이', 22),
#  ('끝끝', 22),
#  ('익어도', 22),
#  ('하려니와', 22),
#  ('나네', 22),
#  ('방아', 22),
#  ('찧어', 22),
#  ('밥살', 22),
#  ('103', 22),
#  ('자매', 22),
#  ('결연', 22),
#  ('인가요', 21),
#  ('2008.04', 21),
#  ('땀', 21),
#  ('전체', 21),
#  ('대표', 21),
#  ('오전', 21),
#  ('8월', 21),
#  ('만들고', 21),
#  ('비유', 21),
#  ('종류', 21),
#  ('모양', 21),
#  ('요리', 21),
#  ('드립니다', 21),
#  ('어떻게', 21),
#  ('소', 21),
#  ('먹어', 21),
#  ('모', 21),
#  ('고유', 21),
#  ('뉴욕', 20),
#  ('오른', 20),
#  ('드시는', 20),
#  ('비경', 20),
#  ('보통', 20),
#  ('이라', 20),
#  ('등등', 20),
#  ('산이', 20),
#  ('있을까요', 20),
#  ('유래', 20),
#  ('문화', 20),
#  ('생', 20),
#  ('않고', 20),
#  ('흰', 20),
#  ('길게', 20),
#  ('경우', 20),
#  ('명', 20),
#  ('라는', 20),
#  ('문', 20),
#  ('없다', 20),
#  ('이렇게', 20),
#  ('가르쳐주세요', 20),
#  ('바로', 20),
#  ('바보', 20),
#  ('프랑스', 20),
#  ('인도', 20),
#  ('볼', 20),
#  ('11월', 19),
#  ('타임스', 19),
#  ('선정', 19),
#  ('죽기전에', 19),
#  ('가봐야', 19),
#  ('맛있기는', 19),
#  ('계시는데', 19),
#  ('문제', 19),
#  ('08', 19),
#  ('그냥', 19),
#  ('-->', 19),
#  ('미치는', 19),
#  ('ㅜ', 19),
#  ('큰', 19),
#  ('운다고', 19),
#  ('얻어먹는다', 19),
#  ('정', 19),
#  ('에서는', 19),
#  ('단', 19),
#  ('천지창조', 19),
#  ('기후', 19),
#  ('2월', 19),
#  ('01', 19),
#  ('결혼', 19),
#  ('용', 19),
#  ('사', 19),
#  ('음', 19),
#  ('초', 19),
#  ('드려요', 19),
#  ('가는', 19),
#  ('자세히', 19),
#  ('고기', 19),
#  ('fool', 19),
#  ('발', 19),
#  ('소화', 19),
#  ('생명', 19),
#  ('감추듯', 19),
#  ('허겁지겁', 19),
#  ('치움을', 19),
#  ('멸망', 19),
#  ('구원', 19),
#  ('12월', 18),
#  ('성', 18),
#  ('라서', 18),
#  ('1일', 18),
#  ('네째', 18),
#  ('되는', 18),
#  ('운세', 18),
#  ('남북', 18),
#  ('올려주세요', 18),
#  ('별로', 18),
#  ('정보', 18),
#  ('처음', 18),
#  ('있습니다', 18),
#  ('친구', 18),
#  ('사진', 18),
#  ('무더운', 18),
#  ('님', 18),
#  ('차이', 18),
#  ('몇', 18),
#  ('해석', 18),
#  ('준다는', 18),
#  ('최고', 18),
#  ('인데요', 18),
#  ('걸음', 18),
#  ('살려라', 18),
#  ('달아날', 18),
#  ('조급한', 18),
#  ('발걸음', 18),
#  ('재촉', 18),
#  ('게도', 18),
#  ('세상', 18),
#  ('남미', 18),
#  ('여행지', 17),
#  ('2019.10', 17),
#  ('쯤', 17),
#  ('아시', 17),
#  ('요즘', 17),
#  ('???', 17),
#  ('시', 17),
#  ('그런데', 17),
#  ('2019.09', 17),
#  ('있어요', 17),
#  ('알려주세여', 17),
#  ('되도록', 17),
#  ('40', 17),
#  ('드림', 17),
#  ('원리', 17),
#  ('②', 17),
#  ('냉각', 17),
#  ('지장', 17),
#  ('8', 17),
#  ('정리', 17),
#  ('위해', 17),
#  ('ㅡ', 17),
#  ('있는데요', 17),
#  ('순수한', 17),
#  ('2016.10', 17),
#  ('강', 17),
#  ('개념', 17),
#  ('의상', 17),
#  ('맺은', 17),
#  ('됩니다', 16),
#  ('얼마', 16),
#  (';;', 16),
#  ('21일', 16),
#  ('없는', 16),
#  ('그런', 16),
#  ('하지', 16),
#  ('2020.06', 16),
#  ('각', 16),
#  ('지방', 16),
#  ('자세하게', 16),
#  ('해외여행', 16),
#  ('은하', 16),
#  ('운동', 16),
#  ('식품', 16),
#  ('~!', 16),
#  ('빨리요', 16),
#  ('국어', 16),
#  ('공부', 16),
#  ('=', 16),
#  ('에게', 16),
#  ('따라서', 16),
#  ('시기', 16),
#  ('켜주세요', 16),
#  ('러시아', 16),
#  ('올라갈', 16),
#  ('결정', 16),
#  ('타', 16),
#  ('접대', 16),
#  ('받는다', 16),
#  ('신도', 16),
#  ('고추', 16),
#  ('cloudy', 16),
#  ('얇은', 15),
#  ('입고', 15),
#  ('알려주시면', 15),
#  ('아침', 15),
#  ('맑음', 15),
#  ('이구', 15),
#  ('궁금합니다', 15),
#  ('31', 15),
#  ('_', 15),
#  ('학생', 15),
#  ('2020.03', 15),
#  ('글자', 15),
#  ('진짜', 15),
#  ('자리', 15),
#  ('먹거리', 15),
#  ('해주시', 15),
#  ('있는데', 15),
#  ('새', 15),
#  ('~~~', 15),
#  ('온', 15),
#  ('가을', 15),
#  ('각국', 15),
#  ('번', 15),
#  ('영', 15),
#  ('염', 15),
#  ('채', 15),
#  ('불', 15),
#  ('삼', 15),
#  ('씩', 15),
#  (';', 15),
#  ('0', 15),
#  ('대전', 15),
#  ('상층', 15),
#  ('권층운', 15),
#  ('엷은', 15),
#  ('께서', 15),
#  ('라', 15),
#  ('아무', 15),
#  ('경상도', 15),
#  ('하게', 15),
#  ('9', 15),
#  ('이라는', 15),
#  ('마리', 15),
#  ('k', 15),
#  ('천', 15),
#  ('보다', 14),
#  ('하는데요', 14),
#  ('㉣', 14),
#  ('찾게', 14),
#  ('되며', 14),
#  ('맑으며', 14),
#  ('남동풍', 14),
#  ('약간', 14),
#  ('빠른', 14),
#  ('상', 14),
#  ('궁합', 14),
#  ('전통의상', 14),
#  ('조부', 14),
#  ('할아버지', 14),
#  ('준결승', 14),
#  ('보이는', 14),
#  ('시나', 14),
#  ('브로', 14),
#  ('6월', 14),
#  ('신', 14),
#  ('지만', 14),
#  ('비오는', 14),
#  ('대하', 14),
#  ('>', 14),
#  ('이제', 14),
#  ('먹어서', 14),
#  ('먹는다', 14),
#  ('밖에', 14),
#  ('구체', 14),
#  ('2010.01', 14),
#  ('듯', 14),
#  ('형식', 14),
#  ('단원', 14),
#  ('본문', 14),
#  ('떠', 14),
#  ('지역별', 14),
#  ('마차', 14),
#  ('으로는', 14),
#  ('지나가는', 14),
#  ('거지', 14),
#  ('께', 14),
#  ('지식', 14),
#  ('2010.06', 14),
#  ('학기', 14),
#  ('부정', 14),
#  ('부분', 14),
#  ('무늬', 14),
#  ('반', 13),
#  ('보고', 13),
#  ('높았던', 13),
#  ('니까', 13),
#  ('연', 13),
#  ('똥', 13),
#  ('ㅜㅜ', 13),
#  ('2007.08', 13),
#  ('사실', 13),
#  ('엔', 13),
#  ('한번', 13),
#  ('음식점', 13),
#  ('현재', 13),
#  ('어', 13),
#  ('캄보디아', 13),
#  ('보면', 13),
#  ('사이', 13),
#  ('2019.08', 13),
#  ('자', 13),
#  ('되지', 13),
#  ('울', 13),
#  ('여러가지', 13),
#  ('2012.04', 13),
#  ('답', 13),
#  ('관계', 13),
#  ('2009.08', 13),
#  ('ㅇ', 13),
#  ('손', 13),
#  ('들어', 13),
#  ('요약', 13),
#  ('2008.08', 13),
#  ('논', 13),
#  ('꾼', 13),
#  ('ㅎ', 13),
#  ('키우는', 13),
#  ('놈', 13),
#  ('994', 13),
#  ('산책', 13),
#  ('여름방학', 13),
#  ('내리는', 13),
#  ('A', 13),
#  ('흐린', 13),
#  ('특이', 13),
#  ('까다롭게', 13),
#  ('민소매', 13),
#  ('이외', 13),
#  ('폭포', 13),
#  ('쓰인다', 13),
#  ('춥고', 13),
#  ('환경', 12),
#  ('혼자', 12),
#  ('코스', 12),
#  ('지면', 12),
#  ('좋습니다', 12),
#  ('제목', 12),
#  ('4월', 12),
#  ('올라간', 12),
#  ('표현', 12),
#  ('역사', 12),
#  ('채택', 12),
#  ('같아요', 12),
#  ('학교숙제', 12),
#  ('이란', 12),
#  ('일기', 12),
#  ('술', 12),
#  ('새벽', 12),
#  ('했는데', 12),
#  ('올해', 12),
#  ('어디', 12),
#  ('이라고', 12),
#  ('&', 12),
#  ('의식주', 12),
#  ('남아', 12),
#  ('한편', 12),
#  ('에만', 12),
#  ('3일', 12),
#  (',,,', 12),
#  ('예요', 12),
#  ('예절', 12),
#  ('님들', 12),
#  ('대륙', 12),
#  ('방언', 12),
#  ('2008.10', 12),
#  ('결', 12),
#  ('차지', 12),
#  ('않는다는', 12),
#  ('중학교', 12),
#  ('갓', 12),
#  ('2008.01', 12),
#  ('멍', 12),
#  ('대거', 12),
#  ('빼기', 12),
#  ('방축', 12),
#  ('2007.12', 12),
#  ('낱말', 12),
#  ('2009.03', 12),
#  ('nhha', 12),
#  ('200', 12),
#  ('하나님', 12),
#  ('요점', 12),
#  ('찾기', 12),
#  ('98', 12),
#  ('말함', 12),
#  ('농가', 12),
#  ('이황', 12),
#  ('5일', 11),
#  ('발생', 11),
#  ('래', 11),
#  ('2008.02', 11),
#  ('거든요', 11),
#  ('겨울방학', 11),
#  ('이에요', 11),
#  ('아니면', 11),
#  ('및', 11),
#  ('아니라', 11),
#  ('않은', 11),
#  ('맛있는', 11),
#  ('?...', 11),
#  ('2일', 11),
#  ('2020.04', 11),
#  ('3월', 11),
#  ('2020.02', 11),
#  ('목연', 11),
#  ('30분', 11),
#  ('가서', 11),
#  ('직업', 11),
#  ('국', 11),
#  ('물건', 11),
#  ('급함', 11),
#  ('300', 11),
#  ('있어서', 11),
#  ('사이트', 11),
#  ('아직', 11),
#  ('9월', 11),
#  ('엄마', 11),
#  ('하기', 11),
#  ('저녁', 11),
#  ('확률', 11),
#  ('역시', 11),
#  ('cloud', 11),
#  ('식당', 11),
#  ('육', 11),
#  ('나면', 11),
#  ('내부', 11),
#  ('빼내는', 11),
#  ('일종', 11),
#  ('그러므로', 11),
#  ('아치로', 11),
#  ('보냈다는', 11),
#  ('용도', 11),
#  ('푸드', 11),
#  ('날짜', 11),
#  ('2009.09', 11),
#  ('거적', 11),
#  ('깔개', 11),
#  ('참나무', 11),
#  ('엷게', 11),
#  ('밀어서', 11),
#  ('역', 11),
#  ('신세', 11),
#  ('마는', 11),
#  ('보기', 11),
#  ('상식', 11),
#  ('있으면', 11),
#  ('동물', 11),
#  ('외래어', 11),
#  ('▶', 11),
#  ('따위', 11),
#  ('주면', 11),
#  ('봄', 11),
#  ('이요', 11),
#  ('곡', 11),
#  ('적어', 11),
#  ('알아야', 11),
#  ('해요', 11),
#  ('교회', 11),
#  ('길마', 11),
#  ('석빙고', 11),
#  ('EBS', 11),
#  ('과일', 11),
#  ('검', 11),
#  ('afternoon', 11),
#  ('sunny', 11),
#  ('비치는', 11),
#  ('surprise', 11),
#  ('퇴계', 11),
#  ('일정', 10),
#  ('2019.11', 10),
#  ('4일', 10),
#  ('해도', 10),
#  ('+', 10),
#  ('선택', 10),
#  ('준비', 10),
#  ('되어', 10),
#  ('주문', 10),
#  ('팍팍', 10),
#  ('혹시', 10),
#  ('추가', 10),
#  ('a', 10),
#  ('ryul', 10),
#  ('무슨', 10),
#  ('일이', 10),
#  ('인터넷', 10),
#  ('몇개', 10),
#  ('돈', 10),
#  ('써', 10),
#  ('김', 10),
#  ('정확하게', 10),
#  ('가는데', 10),
#  ('알려주', 10),
#  ('2006.08', 10),
#  ('ㅋㅋ', 10),
#  ('국수', 10),
#  ('먹을', 10),
#  ('동남아시아', 10),
#  ('감사합니다', 10),
#  ('2007.05', 10),
#  ('비단', 10),
#  ('국한', 10),
#  ('56%', 10),
#  ('28%', 10),
#  ('로서', 10),
#  ('가시', 10),
#  ('먼저', 10),
#  ('전부', 10),
#  ('가옥', 10),
#  ('℃', 10),
#  ('장', 10),
#  ('행사', 10),
#  ('편', 10),
#  ('형', 10),
#  ('유명한', 10),
#  ...]

# %%
plt.figure(figsize=(15,6))
ko.plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9642 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32461 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 33410 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20010 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27185 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9786 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 9642 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32461 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 38889 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 33410 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20010 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 28385 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27185 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9786 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#!pip install wordcloud

# %%
""" 워드 크라우드 그리기 """

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(100)
data1 = ko1.vocab().most_common(100)
data2 = ko2.vocab().most_common(100)
data3 = ko3.vocab().most_common(100)
data4 = ko4.vocab().most_common(100)
data5 = ko5.vocab().most_common(100)

wordcloud = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data))
wordcloud1 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data1))
wordcloud2 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data2))
wordcloud3 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data3))
wordcloud4 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data4))
wordcloud5 = WordCloud(font_path = 'c:Windows/Fonts/malgun.ttf',relative_scaling=0.2, background_color ='white').generate_from_frequencies(dict(data5))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')

plt.figure(figsize=(16,8))
plt.imshow(wordcloud1)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud2)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud3)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud4)
plt.axis('off')
plt.figure(figsize=(16,8))
plt.imshow(wordcloud5)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
