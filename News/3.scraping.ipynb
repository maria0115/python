# %%
import re
import json
import math
import requests
import urllib.request
import urllib.error
import urllib.parse
from bs4 import BeautifulSoup
import pandas as pd

# %%
# 전처리 과정 'Form Data' 복사해서 사전타입으로 정리
lines = '''pageInfo:bksMain
login_chk:null
LOGIN_SN:null
LOGIN_NAME:null
indexName:news
keyword:주식
byLine:
searchScope:1
searchFtr:1
startDate:2020-01-01
endDate:2021-03-29
sortMethod:date
contentLength:100
providerCode:
categoryCode:
incidentCode:
dateCode:
highlighting:true
sessionUSID:
sessionUUID:test
listMode:
categoryTab:
newsId:
filterProviderCode:
filterCategoryCode:
filterIncidentCode:
filterDateCode:
filterAnalysisCode:
startNo:1
resultNumber:10
topmenuoff:
resultState:
keywordJson:
keywordFilterJson:
realKeyword:
totalCount:
interval:
quotationKeyword1:
quotationKeyword2:
quotationKeyword3:
searchFromUseYN:N
mainTodayPersonYn:
period:3month'''.splitlines()

data = {}
for line in lines:
    key, value = line.split(':', 1)
    if value == 'null':
        value = None
    data[key] = value

import requests
from bs4 import BeautifulSoup

result_url = "https://www.bigkinds.or.kr/news/newsResult.do"
response = requests.post(result_url, data=data)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

for tag in soup.select('.resultList li h3'):
    doc_id = tag['id'].replace('news_', '')
    doc_url = 'https://www.bigkinds.or.kr/news/detailView.do?docId={}&returnCnt=1'.format(doc_id)
    print(tag.text.strip(), doc_url)
# Out:
# 김남희, ‘필살기 고수외전’서 맹활약 예고…주식+투자 꿀팁 대방출 https://www.bigkinds.or.kr/news/detailView.do?docId=02100101.20210329122345002&returnCnt=1
# 벼락거지 벗어나려 주식·코인하는 젊은이 https://www.bigkinds.or.kr/news/detailView.do?docId=02100101.20210329122345001&returnCnt=1
# 한국인 돈은 열심히 모으는데... ‘계획’이 없네 https://www.bigkinds.or.kr/news/detailView.do?docId=01100801.20210329121516001&returnCnt=1
# '자산어보' 이준익 “과도한 세금, 백성 착취하던 시대 돌아본 건…” https://www.bigkinds.or.kr/news/detailView.do?docId=01100901.20210329120356001&returnCnt=1
# 똑똑해진 동학개미…한국인 금융이해력, OECD 평균 웃돈다 https://www.bigkinds.or.kr/news/detailView.do?docId=02100601.20210329120348001&returnCnt=1
# 장학재단 생활비 대출까지 받아 주식 투자 ‘올인’하는 대학생들 https://www.bigkinds.or.kr/news/detailView.do?docId=01100701.20210329120304001&returnCnt=1
# 경제 모르면 뒤처질까 열공…성인 금융이해력 상승 https://www.bigkinds.or.kr/news/detailView.do?docId=02100311.20210329120039001&returnCnt=1
# ...

# %%
lines = '''byLine: ""
categoryCodes: []
dateCodes: []
editorialIs: false
endDate: "2021-03-29"
incidentCodes: []
indexName: "news"
isNotTmUsable: false
isTmUsable: false
mainTodayPersonYn: ""
networkNodeType: ""
newsIds: []
providerCodes: []
resultNumber: 10
searchFilterType: "1"
searchKey: "배터리"
searchKeys: [{}]
searchScopeType: "1"
searchSortType: "date"
sortMethod: "date"
startDate: "2020-12-29"
startNo: 1
topicOrigin: ""'''.splitlines()

data = {}
for line in lines:
    key, value = line.split(':', 1)
    if value == 'null':
        value = None
    data[key] = value

import requests
from bs4 import BeautifulSoup

result_url = "https://www.bigkinds.or.kr/v2/news/index.do"
response = requests.post(result_url, data=data)
print(response,"response")
html = response.text
soup = BeautifulSoup(html, 'html.parser')

print(soup)
# Out:
# <Response [405]> response
#
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <!-- timestamp 변수  -->
# <!-- timestamp 없앨 시 해당 부분 참고하세요-->
# <head>
# <meta charset="utf-8"/>
# <link href="https://www.bigkinds.or.kr" rel="canonical"/>
# <link href="/images/favicon/apple-icon-57x57.png;Bigkinds=7CBF4C148EED822C0B63721387B4EFD0" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/images/favicon/apple-icon-60x60.png;Bigkinds=7CBF4C148EED822C0B63721387B4EFD0" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/images/favicon/apple-icon-72x72.png;Bigkinds=7CBF4C148EED822C0B63721387B4EFD0" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/images/favicon/apple-icon-76x76.png;Bigkinds=7CBF4C148EED822C0B63721387B4EFD0" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/images/favicon/apple-icon-114x114.png;Bigkinds=7CBF4C148EED822C0B63721387B4EFD0" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
import re
def get_filename_from_cd(cd):
    """
    Get filename from content-disposition
    """
    if not cd:
        return None
    fname = re.findall('filename=(.+)', cd)
    if len(fname) == 0:
        return None
    return fname[0]

# %%
data = {"indexName":"news","searchKey":"주식","searchKeys":[{}],"byLine":"","searchFilterType":"1","searchScopeType":"1","searchSortType":"date","sortMethod":"date","mainTodayPersonYn":"","startDate":"2020-12-29","endDate":"2021-03-29","newsIds":[],"categoryCodes":[],"providerCodes":[],"incidentCodes":[],"networkNodeType":"","topicOrigin":"","dateCodes":[],"editorialIs":False,"startNo":1,"resultNumber":10,"isTmUsable":False,"isNotTmUsable":False,"sectionDiv":"1000","realURI":"/api/news/previewData.do"}


result_url = "https://www.bigkinds.or.kr/api/news/download.do"
response = requests.post(result_url, data=data,allow_redirects=True)
print(response.content)
filename = get_filename_from_cd(response.headers.get('content-disposition'))
open("news.xlsx", 'wb').write(response.content)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 20491857

# %%
import pandas

data = pandas.read_excel("./news.xlsx")
data
# Out:
#              일자    언론사                             기고자  \
# 0      20210330   경기일보                          이정민 기자
# 1      20210330   경기일보                          김두현 기자
# 2      20210330   경기일보                          구재원 기자
# 3      20210330   경기일보                          박석원 기자
# 4      20210330   경기일보                          정자연 기자
# ...         ...    ...                             ...
# 19995  20210326    KBS                             강푸른
# 19996  20210326   중앙일보  이태윤(lee.taeyun@joongang.co.kr)
# 19997  20210326  아시아경제                      호남취재본부 정승현
# 19998  20210326   세계일보                             서필웅
# 19999  20210326  헤럴드경제                          손미정 기자
#
#                                             제목     통합 분류1      통합 분류2  \
# 0                성남 하이테크밸리 업종 변경 통해 경쟁력 확보 나선다      지역>경기       지역>충남
# 1        국립수목원, 울릉도 자생 '두메부추' 새 특산종으로 국제학술지 발표      사회>환경         NaN
# 2           안산시 일본식 지명 '풍도', 옛 한자 이름 되찾아 豊島→楓島      지역>강원       문화>출판
# ...

# %%
len(data['본문'])
bon = data['본문'][:200]
strr =''
for d in range(len(bon)):
    strr = strr + bon[d] + ' '

# %%
data['본문'][:20]
# Out:
# 0     성남시가 노후화된 성남일반산업단지(성남하이테크밸리) 체질개선에 나선다. \n\n직주...
# 1     국립수목원은 울릉도에서만 자생하는 ‘두메부추’를 새로운 특산종으로 확인, 국제 학술...
# 2     안산시 단원구 풍도의 지명이 일본식 표기였던 ‘풍도(豊島)에서 옛 이름 ’풍도(楓島...
# 3     안성경찰서는 29일 술을 마시고 운전하다 승용차와 충돌한 혐의(도로교통법 위반 등)...
# 4     김성환 가톨릭대학교 성빈센트병원 방사선종양학과 교수가 최근 열린 제15차 대한방사선...
# 5     의왕지역 공공 어린이놀이터를 관리할 ‘놀이터프렌즈’가 출범했다. \n\n의왕시는 지...
# 6     가평군이 내년 예산에 반영키 위해 오는 6월까지 주민참여예산제를 운영한다. \n\n...
# 7     파주시는 조리읍 캠프 하우즈 공여구역 내 존치 건물 6개동에 대한 건축설계 제안을 ...
# 8     홍재연씨 별세, 이화순(경기도사회서비스원장)씨 모친상=29일, 용인 평온의숲장례식장...
# 9     ‘골프 여제’ 박인비(33ㆍKB금융그룹)가 첫 출전 대회인 미국여자프로골프(LPGA...
# 10    부동산 투기 의혹을 수사 중인 경찰이 3기 신도시 안산 장상지구 땅 투기 의혹을 받...
# 11    여자 프로배구 수원 현대건설이 강성형 여자대표팀 수석코치(50)를 신임 감독으로 선...
# 12    여자 프로배구 ‘우승후보 0순위’였던 인천 흥국생명이 챔피언결정전 무득세트 준우승 ...
# 13    “기량면에서 이미 검증이 된 타자라 걱정하지 않았는데 역시나 믿고 지켜볼 만 합니다...
# 14    수도권 사업장 중 미세먼지 저감을 위해 자발적으로 협약에 참여한 사업장들의 대기오염...
# 15    포천시는 최근 사흘 동안 6명이 추가로 코로나19에 확진됐다고 29일 밝혔다. \n...
# 16    연천군은 최근 사흘 동안 전곡읍 무도학원 관련 8명이 코로나19에 확진됐다고 29일...
# ...

# %%
strr
# Out:
# '성남시가 노후화된 성남일반산업단지(성남하이테크밸리) 체질개선에 나선다. \n\n직주 근접 주택을 조성, 젊은 인력을 공급해 오는 2023년까지 제조업 중심의 산단을 신산업 융합단지로 탈바꿈하게 한다는 계획이다. \n\n시는 준공된 지 45년 된 성남하이테크밸리(151만㎡) 재생사업지구의 경쟁력을 강화하고자 제조혁신 워라밸 스마트 등 3개 분야, 34개 세부방안.. 국립수목원은 울릉도에서만 자생하는 ‘두메부추’를 새로운 특산종으로 확인, 국제 학술지에 발표했다고 29일 밝혔다. \n\n두메부추는 러시아, 몽골, 중국 등지에 분포하는 ‘알리움 세네스켄스’(Allium senescens)‘와 같은 종으로 분류됐으나 분류학적 연구를 통해 연분홍색의 비교적 큰 꽃과 늦은 개화기 등 독특한 형질을 갖는 새로운 종으로 확인했다... 안산시 단원구 풍도의 지명이 일본식 표기였던 ‘풍도(豊島)에서 옛 이름 ’풍도(楓島)‘로 변경됐다. \n\n시는 29일 “국가지명위원회가 풍도 지명을 풍성할 ‘풍(豊)‘자가 아닌 단풍나무 ‘풍(楓)‘자를 쓰는 ’풍도(楓島)로 최종 변경 결정했다”고 밝혔다. \n\n풍도는 고려시대부터 조선시대 말까지 단풍나무가 많아 풍(楓)자를 사용해 표기해 왔으나 일본이 청일.. 안성경찰서는 29일 술을 마시고 운전하다 승용차와 충돌한 혐의(도로교통법 위반 등)로 30대 A씨를 입건, 조사 중이라고 밝혔다. \n\nA씨는 이날 오전 8시30분께 안성시 가사동의 한 도로에서 모닝승용차를 타고 가던 중 죄회전, 맞은편에서 오던 다마스 승합차와 부딪친 혐의를 받고 있다. \n\n이 사고로 다마스 승합차 운전자 60대 B씨가 중상을 입어 병원.. 김성환 가톨릭대학교 성빈센트병원 방사선종양학과 교수가 최근 열린 제15차 대한방사선수술학회 정기학술대회 및 정기총회에서 대한방사선수술학회장에 취임했다. \n\n임기는 1년으로, 김 교수는 오는 2022년 3월까지 대한방사선수술학회를 이끌게 된다. \n\n김 교수는 대한방사선종양학회장, 성빈센트암병원장을 맡고 있으며, 대
# ...

# %%
import nltk
from konlpy.tag import Okt

okt = Okt()

tokens_ko = okt.morphs(strr)
tokens_ko

ko = nltk.Text(tokens_ko, name='주식')

# %%
ko.vocab().most_common(100)
# Out:
# [('.', 415),
#  ('을', 357),
#  ('이', 279),
#  ('를', 268),
#  ('의', 222),
#  ('에', 212),
#  (',', 202),
#  ('..', 174),
#  ('은', 169),
#  ('는', 165),
#  ('(', 158),
#  ('한', 153),
#  (')', 152),
#  ('29일', 126),
#  ('으로', 125),
#  ('에서', 123),
#  ('가', 120),
#  ("'", 106),
#  ('했다', 102),
#  ('과', 90),
#  ('로', 89),
#  ('‘', 83),
#  ('와', 72),
#  ('들', 68),
#  ('’', 67),
#  ('등', 64),
#  ('기자', 62),
#  ('[', 61),
#  ('밝혔다', 60),
#  (']', 60),
#  ('하고', 57),
#  ('해', 55),
#  ('적', 54),
#  ('대통령', 52),
#  ('"', 47),
#  ('부동산', 46),
#  ('\n', 45),
#  ('고', 44),
#  ('사업', 42),
#  ('하는', 42),
#  ('부패', 42),
#  ('인', 41),
#  ('“', 40),
#  ('전', 40),
#  ('제', 38),
#  ('된', 36),
#  ('날', 36),
#  ('지난', 36),
#  ('문', 36),
#  ('\n\n ', 36),
#  ('명', 35),
#  ('정책', 35),
#  ('3', 34),
#  ('있다', 34),
#  ('및', 34),
#  ('위', 34),
#  ('위해', 34),
#  ('까지', 33),
#  ('부터', 33),
#  ('대', 33),
#  ('것', 33),
#  ('했다고', 30),
#  ('\n\n', 30),
#  ('회', 29),
#  ('수', 29),
#  ('다', 29),
#  ('경제', 29),
# ...

# %%
stop_words = ['을', '한', '중', '일부', '는', '이제',  '을', '팔', '수', '있다', '은', '지난','-',',','.',
 '..',
 '(',
 ')',
 "'", 
 '‘',
 '\n\n',
 '[',
 ']',
'시간', '부터','일부',  '의',  '이', '충족','됐다고','밝혔다', '후','6', '번째','"',
 '일', '만에', '을', '팔', '수','있게', '된', '것', '이다', '이번', '에', '을', '팔', '수', '있는', '건',
 '이나',  '전',  '가', '아닌','이다',  '는', '기존',  '에게',  '돼야', '하는',
  '적', '인',  '동안', '의', '을',  '로',  '했다며', '은', '이번','개','보기',
  '이', '아니다라고', '했다','직후', '엔','때문', '에','은','제공','자요','다양한','보는','기','뒤','박','데','있습니다','다음',
'을',  '할', '수', '없다', '는', '나', '등', '내','가', '통해', '게','모습','단',
 '후',  '을', '팔', '수', '없게', '한', '것', '이다', '및', '관련','씨',
 '간', '에',  '된', '에', '따르면', '“', '”','이어', '따른','기자',
 '기준', '으로',  '에',  '하던', '중',  '에', '중인',  '이',  '까지', '고',
 '하고', '있던','은',  '이',  '되고', '도', '할', '수', '있다', '한편',
 '시간', '는',  '약', '에',  '했다', '전날', '보다', '오른', '수치', '다',
 '는',  '이후', '줄곧', '떨어졌다',  '첫', '날','가',  '의', '두', '배', '인', '까지', '오르', '기도', '했으나',
 '이후', '가', '계속', '떨어져', '17일', '엔',  '로',  '했다', '인',  '의',
 '는', '약',  '이','됐다',  '은',  '를', '갖고', '있다',
 '가치', '로만', '보면',  '에', '이', '은', '2',  '다', '은', '인',
 '대비',  '을', '가진',  '을', '하고', '있다', '해당', '가치', '는', '의',
 '약', '10', '다', '◎', '공감', '언론', '뉴시스', 'jb', '\n', '그러나', '이', '것', '만으로는', '부족하다고', '느낀',
 '들', '이', '있었으니', '바로', '을', '노리는', '이', '들', '이다',
 '이란', '말', '그대로', '이나', '에', '되지', '않은', '으로',  '’', '이라고도',
 '한다', '가', '운영', '하는', '’', '를', '비롯', '해', '너무', '요','한다고',
 '’',  '’',  '’', '등', '에서','코리아','아니라','했던','특히','에서도','으로는','또한',
 '된다', '은',  '처럼',  '에', '을','이고','다시','했다고','3',
 '올려', '사고팔', '수', '있다', '장이', '나', '은',  '된','를',
 '통한',  '’', '를', '내세워',  '를', '해준다', '일러스트', '이', '철원', '요즘', '은',
 '’', '’', '를', '꿈꾸는', '이', '들', '로', '붐빈다', '지난해', '부터', '이어진',
 '로', '’', '이','되는',  '의',  '을',  '에', '미리',  '하기',
 '위함', '이다', '이런', '와', '함께',  '·',  '·', '닷컴','하겠다고','이하','돼','없이',
 '비롯', '한','·', '과', '같은',  '·','다른','라고','에도','보이는',
 '의',  '이',  '되면서', '더욱',  '하고', '있다', '이', '중',   '의',
 '은', '이다', '다만',  '만', '사면','만사', '오케이', '’', '라는',
 '태도', '는', '지', '양해', '야', '한다',  '의',  '이', '100',  '이후', '주가', '로', '이어지는',
 '것', '은', '아니기', '때문', '이다',  '마지막', '는', '직전', '까지',  '30만원', '대에','됐지만',
'이후',  '대에', '머물고', '있다', '한','는', '은',  '보다',  '의',  '과','기사','아래','사진','합니다','하며','경제','예정',
'에서',  '에게', '불리할', '수', '밖에', '없다고', '말', '했다', '현재', '나','><','>','<','1','며','ⓒ','_',
  '은','중', '가', '높은',  '를', '위','안','보인다','에는','때','곳','속','명','하면','조선',
 '하고', '있다', '그러나', '애초', '에',  '은', '이', '아닐', '뿐더러', '에',
 '된',  '있는', '도', '적기', '때문', '에',  '’', '가', '될', '가능성', '이', '높다', '당연히',
'이나',  '를', '정확히', '파악', '하기도', '어렵다', '몇', '가', '의',
 '를', '발간', '하고', '있지만', '이', '마저도', '소수', '에', '그', '치고', '있다', '또', '에',  '되는',  '자체', '가', '적기',
 '때문', '에',  '가',  '보다', '이뤄지기', '어려울', '수', '있다', '이', '관계자', '는',  '이', '없어서','내내', '못', '사고',
 '못', '파는', '경우', '도', '허다하다고', '말', '했다', '각',  '들', '이', '를', '내세우는', '이유', '도', '이', '때문',
 '이다',  '에서는', '지금',  '에', '여력', '이', '남아돌아','까지', '떠오르고', '있다고', '보고', '있다', '즉', '에', '자금', '이',
 '줄어들면',  '에', '되는', '이용자', '와', '자금', '도', '줄어들어', '유동성', '이', '더', '적어질', '수', '있다는', '얘기', '다',
  '에서', '바보', '가', '되지', '않으려면', '내', '을', '꼭', '따져', '봐야', '한다',
 '을', '사려', '면',  '에', '된','과',  '을','하', '라는', '것', '이다', '들', '사이',
 '에서는', '에서',  '이', '이미', '들', '의','을', '뛰어넘어','많이','이상','대해','있도록','오는','대한',
 '에', '이른다는',  '이', '나오고', '있다', '아울러',  '는',  '있는',  '의', '를','입니다','했습니다',
 '확인','하고', '를', '100', '믿기', '보다는',  '에게', '확인', '해야', '한다고도', '조언', '했다', '무엇', '보다', '모든',
  '이', '나중', '에', '효자', '’', '가', '될', '것', '이라는', '맹목', '적', '인', '믿음', '은',
 '금물', '이다', '생소한', '은', '사기', '의', '온', '상일', '수도', '있다', '한',  '는','김민정','따라','바로가기','위해','이라고','뉴스']

tokens_ko = [each_word for each_word in tokens_ko 
                          if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='주식')
ko.vocab().most_common(20)
# Out:
# [('26일', 4579),
#  ('코로나', 3896),
#  ('28일', 3818),
#  ('19', 3735),
#  ('29일', 3543),
#  ('사업', 3079),
#  ('대', 3040),
#  ('서울', 2696),
#  ('지역', 2690),
#  ('후보', 2674),
#  ('제', 2668),
#  ('한국', 2562),
#  ('장', 2544),
#  ('원', 2249),
#  ('국민', 2081),
#  ('27일', 2041),
#  ('4', 1959),
#  ('지원', 1916),
#  ('자', 1845),
#  ('\n\n ', 1844)]

# %%
data = {"indexName":"news","searchKey":"배터리","searchKeys":[{}],"byLine":"","searchFilterType":"1","searchScopeType":"1","searchSortType":"date","sortMethod":"date","mainTodayPersonYn":"","startDate":"2020-12-29","endDate":"2021-03-29","newsIds":[],"categoryCodes":[],"providerCodes":[],"incidentCodes":[],"networkNodeType":"","topicOrigin":"","dateCodes":[],"editorialIs":false,"startNo":1,"resultNumber":800,"isTmUsable":true,"isNotTmUsable":false,"sectionDiv":"1000","realURI":"/api/news/previewData.do","maxNewsCount":800,"analysisType":"relational_word"}

header = {"Content-Type": "application/json;charset=UTF-8","User-Agent": "Mozilla/5.0",
         "Cookie": "_ga=GA1.3.1789623978.1616662621; _gid=GA1.3.740530372.1616976425; Bigkinds=6468F136C88EBDEBD6D53BB10C3810F7; qna_759=qna_759; qna_719=qna_719; qna_692=qna_692; _gat=1",
         "Referer": "https://www.bigkinds.or.kr/v2/news/index.do"}

result_url = "https://www.bigkinds.or.kr/api/analysis/relationalWords.do"

responses = requests.post(result_url, data=data,allow_redirects=True)
response.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-41c6a82777c7> in <module>
# ----> 1 data = {"indexName":"news","searchKey":"배터리","searchKeys":[{}],"byLine":"","searchFilterType":"1","searchScopeType":"1","searchSortType":"date","sortMethod":"date","mainTodayPersonYn":"","startDate":"2020-12-29","endDate":"2021-03-29","newsIds":[],"categoryCodes":[],"providerCodes":[],"incidentCodes":[],"networkNodeType":"","topicOrigin":"","dateCodes":[],"editorialIs":false,"startNo":1,"resultNumber":800,"isTmUsable":true,"isNotTmUsable":false,"sectionDiv":"1000","realURI":"/api/news/previewData.do","maxNewsCount":800,"analysisType":"relational_word"}
#       2
#       3 header = {"Content-Type": "application/json;charset=UTF-8","User-Agent": "Mozilla/5.0",
# ...
