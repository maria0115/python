# %% [markdown]
# ## 파이썬 엑셀 라이브러리
#
# + openpyx
# + pyexcel
# + xlsxwriter
# + xlrd
# + xlwt
# + xlwings : 엑셀 프로그램에 대한 자동화 라이브러리
#             다른 라이브러리들은 엑셀 프로그램과 연동되는 것이 아니라 엑셀 파일 포맷을 지원하는 형태인데 반해,
#             엑셀을 띄워 놓고 파이썬을 통한 값 가져오기 변경등이 지원
#             윈도우/맥 지원
#
#             설치> pip install xlwings / conda install xlwings
#             Anaconda Python에는 포함되어 있음

# %%
# !pip install xlwings
# 여기선 걸리는 부분이 있어서 [Anaconda Prompt]를 관리자 권한으로 실행하여 명령어 실행해야 한다

# %%
import xlwings as xw

xw.__version__
# Out:
# '0.19.5'

# %%
# 데이타를 바로 엑셀로 보내기
data = [
    ['apple','pear','mango'],
    [100,150, 200],
    [120, 160, 170]
]

# %%
xw.view(data)

# %% [markdown]
# ### 인터넷 상의 데이타를 엑셀로 보내기
#
# + 네이버 환율정보 : https://finance.naver.com/marketindex/exchangeList.nhn
#
#
# 1. 데이타를 데이타프레임으로 로딩하기
#
# 2. 데이타셋 정보 확인하기
#
# 3. 엑셀로 데이타셋 보내기
#
# 4. 엑셀에서 데이타 가져오기

# %%
# (1) 데이타를 데이타프레임으로 로딩하기

import pandas as pd

url = 'https://finance.naver.com/marketindex/exchangeList.nhn'

df_list = pd.read_html(url)
df_list

df = df_list[0]
df
# Out:
#               통화명    매매기준율       현찰                송금           미화환산율
#               통화명    매매기준율     사실 때     파실 때    보내실 때    받으실 때  미화환산율
# 0          미국 USD  1197.10  1218.04  1176.16  1208.80  1185.40  1.000
# 1        유럽연합 EUR  1348.29  1375.12  1321.46  1361.77  1334.81  1.126
# 2   일본 JPY (100엔)  1111.87  1131.32  1092.42  1122.76  1100.98  0.929
# 3          중국 CNY   169.45   177.92   160.98   171.14   167.76  0.142
# 4          홍콩 HKD   154.46   157.50   151.42   156.00   152.92  0.129
# 5          대만 TWD    40.61    45.92    37.77     0.00     0.00  0.034
# 6          영국 GBP  1493.80  1523.22  1464.38  1508.73  1478.87  1.248
# 7          오만 OMR  3109.51  3386.25  2922.94     0.00     0.00  2.598
# 8         캐나다 CAD   883.66   901.06   866.26   892.49   874.83  0.738
# 9         스위스 CHF  1267.85  1292.82  1242.88  1280.52  1255.18  1.059
# 10        스웨덴 SEK   128.74   131.89   125.59   130.02   127.46  0.108
# 11         호주 AUD   832.16   848.55   815.77   840.48   823.84  0.695
# 12       뉴질랜드 NZD   783.62   799.05   768.19   791.45   775.79  0.655
# 13         체코 CZK    50.55    54.84    46.01    51.10    50.00  0.042
# 14         칠레 CLP     1.49     1.60     1.38     0.00     0.00  0.001
# 15         터키 TRY   174.44     0.00     0.00   176.35   172.53  0.146
# 16         몽골 MNT     0.42     0.00     0.00     0.00     0.00  0.000
# 17       이스라엘 ILS   348.40   383.24   320.53     0.00     0.00  0.291
# 18        덴마크 DKK   180.99   185.42   176.56   182.79   179.19  0.151
# 19       노르웨이 NOK   126.56   129.66   123.46   127.82   125.30  0.106
# 20    사우디아라비아 SAR   319.14   339.24   297.12   322.33   315.95  0.267
# 21       쿠웨이트 KWD  3889.21  4142.00  3578.08  3928.10  3850.32  3.249
# 22        바레인 BHD  3170.29  3373.18  2916.67  3201.99  3138.59  2.648
# 23     아랍에미리트 AED   325.91   343.83   303.43   329.16   322.66  0.272
# 24        요르단 JOD  1688.43  1838.70  1553.36     0.00     0.00  1.410
# 25        이집트 EGP    74.35     0.00     0.00     0.00     0.00  0.062
# 26         태국 THB    38.45    40.37    36.15    38.83    38.07  0.032
# 27       싱가포르 SGD   859.24   876.33   842.15   867.83   850.65  0.718
# 28      말레이시아 MYR   279.53   297.14   258.85     0.00   276.74  0.234
# 29  인도네시아 IDR 100     8.30     8.88     7.47     8.38     8.22  0.007
# 30        카타르 QAR   328.78     0.00     0.00     0.00     0.00  0.275
# 31      카자흐스탄 KZT     2.94     0.00     0.00     0.00     0.00  0.003
# 32       브루나이 BND   858.14   892.46   806.66     0.00     0.00  0.717
# 33         인도 INR    16.04     0.00     0.00     0.00     0.00  0.013
# 34       파키스탄 PKR     7.16     0.00     0.00     0.00     0.00  0.006
# 35      방글라데시 BDT    14.11     0.00     0.00     0.00     0.00  0.012
# 36        필리핀 PHP    24.19    26.60    22.21    24.43    23.95  0.020
# 37        멕시코 MXN    53.53    58.88    49.04    54.06    53.00  0.045
# 38        브라질 BRL   225.25   248.22   207.23     0.00   222.55  0.188
# 39    베트남 VND 100     5.16     5.76     4.56     5.21     5.11  0.004
# 40  남아프리카 공화국 ZAR    70.29    74.50    64.67    71.13    69.45  0.059
# 41        러시아 RUB    16.77    17.94    14.93    16.93    16.61  0.014
# 42        헝가리 HUF     3.81     4.16     3.51     3.85     3.77  0.003
# 43        폴란드 PLN   302.18   326.35   278.01   305.50   298.86  0.252

# %%
# (2) 데이타셋 정보 확인하기
# 컬럼명 지정
df.columns=['통화명', '매매기준율','현찰-사실때','현찰-파실때','송금-보낼때','송금-받을때','미화환산율']

# %%
# 인덱스 지정

df = df.set_index('통화명')
#df.set_index('통화명',inplace=True)
df
# Out:
#                  매매기준율   현찰-사실때   현찰-파실때   송금-보낼때   송금-받을때  미화환산율
# 통화명
# 미국 USD         1197.10  1218.04  1176.16  1208.80  1185.40  1.000
# 유럽연합 EUR       1348.29  1375.12  1321.46  1361.77  1334.81  1.126
# 일본 JPY (100엔)  1111.87  1131.32  1092.42  1122.76  1100.98  0.929
# 중국 CNY          169.45   177.92   160.98   171.14   167.76  0.142
# 홍콩 HKD          154.46   157.50   151.42   156.00   152.92  0.129
# 대만 TWD           40.61    45.92    37.77     0.00     0.00  0.034
# 영국 GBP         1493.80  1523.22  1464.38  1508.73  1478.87  1.248
# 오만 OMR         3109.51  3386.25  2922.94     0.00     0.00  2.598
# 캐나다 CAD         883.66   901.06   866.26   892.49   874.83  0.738
# 스위스 CHF        1267.85  1292.82  1242.88  1280.52  1255.18  1.059
# 스웨덴 SEK         128.74   131.89   125.59   130.02   127.46  0.108
# 호주 AUD          832.16   848.55   815.77   840.48   823.84  0.695
# 뉴질랜드 NZD        783.62   799.05   768.19   791.45   775.79  0.655
# 체코 CZK           50.55    54.84    46.01    51.10    50.00  0.042
# 칠레 CLP            1.49     1.60     1.38     0.00     0.00  0.001
# 터키 TRY          174.44     0.00     0.00   176.35   172.53  0.146
# 몽골 MNT            0.42     0.00     0.00     0.00     0.00  0.000
# 이스라엘 ILS        348.40   383.24   320.53     0.00     0.00  0.291
# 덴마크 DKK         180.99   185.42   176.56   182.79   179.19  0.151
# 노르웨이 NOK        126.56   129.66   123.46   127.82   125.30  0.106
# 사우디아라비아 SAR     319.14   339.24   297.12   322.33   315.95  0.267
# 쿠웨이트 KWD       3889.21  4142.00  3578.08  3928.10  3850.32  3.249
# 바레인 BHD        3170.29  3373.18  2916.67  3201.99  3138.59  2.648
# 아랍에미리트 AED      325.91   343.83   303.43   329.16   322.66  0.272
# 요르단 JOD        1688.43  1838.70  1553.36     0.00     0.00  1.410
# 이집트 EGP          74.35     0.00     0.00     0.00     0.00  0.062
# 태국 THB           38.45    40.37    36.15    38.83    38.07  0.032
# 싱가포르 SGD        859.24   876.33   842.15   867.83   850.65  0.718
# 말레이시아 MYR       279.53   297.14   258.85     0.00   276.74  0.234
# 인도네시아 IDR 100     8.30     8.88     7.47     8.38     8.22  0.007
# 카타르 QAR         328.78     0.00     0.00     0.00     0.00  0.275
# 카자흐스탄 KZT         2.94     0.00     0.00     0.00     0.00  0.003
# 브루나이 BND        858.14   892.46   806.66     0.00     0.00  0.717
# 인도 INR           16.04     0.00     0.00     0.00     0.00  0.013
# 파키스탄 PKR          7.16     0.00     0.00     0.00     0.00  0.006
# 방글라데시 BDT        14.11     0.00     0.00     0.00     0.00  0.012
# 필리핀 PHP          24.19    26.60    22.21    24.43    23.95  0.020
# 멕시코 MXN          53.53    58.88    49.04    54.06    53.00  0.045
# 브라질 BRL         225.25   248.22   207.23     0.00   222.55  0.188
# 베트남 VND 100       5.16     5.76     4.56     5.21     5.11  0.004
# 남아프리카 공화국 ZAR    70.29    74.50    64.67    71.13    69.45  0.059
# 러시아 RUB          16.77    17.94    14.93    16.93    16.61  0.014
# 헝가리 HUF           3.81     4.16     3.51     3.85     3.77  0.003
# 폴란드 PLN         302.18   326.35   278.01   305.50   298.86  0.252

# %%
# (3) 엑셀로 데이타셋 보내기 
#   - 엑셀에서 활성화된(선택된) 시트로 보내짐
xw.view(df, xw.sheets.active)

# %%
# (4) 엑셀에서 가져오기
xw.Range('a1:e7').value
# Out:
# [['통화명', '매매기준율', '현찰-사실때', '현찰-파실때', '송금-보낼때'],
#  ['미국 USD', 1197.1, 1218.04, 1176.16, 1208.8],
#  ['유럽연합 EUR', 1348.29, 1375.12, 1321.46, 1361.77],
#  ['일본 JPY (100엔)', 1111.87, 1131.32, 1092.42, 1122.76],
#  ['중국 CNY', 169.45, 177.92, 160.98, 171.14],
#  ['홍콩 HKD', 154.46, 157.5, 151.42, 156.0],
#  ['대만 TWD', 40.61, 45.92, 37.77, 0.0]]
