# %% [markdown]
# # 일변량질적자료
#
# > 1. 일변량 - 변수 하나
#
# > 2. 질적자료 - 명목형(카테고리) / 이산형
#         (ex. 남자/여자, 고급/중급/초급 )
#
#
#     * 질적자료 = 명목형 = 이산형
#     * 양적자료 = 수치형 = 연속형
#
# ### 빈도와 그래프
#
# - 빈도 : 자료가 가지는 각각의 값이 몇 개 있는지를 구한 수치
#
# - 백분율 : 자료가 가지는 각각의 값이 전체를 100으로 보았을 때의 차지하고 얼마나 차지하고 있는지를 알려주는 수치
#
# ### 질적자료 시각화
#
# 1.
#
# 2.

# %%
# 데이타 읽어오기

import pandas as pd

diamonds = pd.read_csv('data/diamonds.csv',index_col = 'Unnamed: 0')
diamonds.head()

dairy = pd.read_csv('data/dairy.csv')
data = dairy[dairy['year']>=2000]
data[data['dairy']=='치즈']
# Out:
#      year dairy  production  consumption
# 1    2017    치즈       23779       117829
# 9    2016    치즈      596998       589968
# 18   2015    치즈       23188       103899
# 28   2014    치즈       23779       117829
# 36   2013    치즈       22389       107558
# 52   2012    치즈       22522        99243
# 60   2011    치즈       24708        99520
# 71   2010    치즈       27404        88608
# 79   2009    치즈       23199        71444
# 82   2008    치즈       25016        71951
# 90   2007    치즈       24366        74384
# 106  2006    치즈       27929        72153
# 115  2005    치즈       23724        68290
# 124  2004    치즈       24296        63595
# 133  2003    치즈       22637        57934
# 140  2002    치즈       20706        52356
# 145  2001    치즈       20060        53089
# 160  2000    치즈       14980        44189

# %%
# 데이타프레임 구조 살피기
# [*] 질적자료와 양적자료 확인 
diamonds.shape
diamonds.info()
diamonds.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
""" 1. 빈도구하기 : value_counts() """

diamonds['cut'].value_counts()
diamonds['price'].value_counts() # 빈도 구하기 적합하지 않음
diamonds['color'].value_counts()
# price를 빈도 구하려면 명목형으로 변환 (1000미만)
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
""" 2. 백분율  = 빈도수/전체수 * 100 """
diamonds['color'].value_counts()/len(diamonds['color']) *100
# Out:
# G    20.934372
# E    18.162773
# F    17.690026
# H    15.394883
# D    12.560252
# I    10.051910
# J     5.205784
# Name: color, dtype: float64

# %%
""" 3. 시각화 """

diamonds['color'].value_counts().plot(kind='bar')
